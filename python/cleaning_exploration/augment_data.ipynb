# %% [markdown]
# # Augmenting the Author Data
#
# I need to make sure that the training set multiple instances of every label (i.e., value in `dll_author_id`). First of all, I should see how many unique labels there are and how many instances there are of each label.

# %%
# Import the data from a prepared CSV

import pandas as pd

df = pd.read_csv('output/all_names_deduplicated.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24708 entries, 0 to 24707
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   author         24708 non-null  object
#  1   dll_author_id  24708 non-null  object
# dtypes: object(2)
# memory usage: 386.2+ KB
# None

# %%
counts = df['dll_author_id'].value_counts()
print(counts)
# Out:
# dll_author_id
# A4644    38
# A4379    35
# A4322    35
# A5377    35
# A4830    34
#          ..
# A6277     1
# A3838     1
# A3606     1
# A5713     1
# A6134     1
# Name: count, Length: 3137, dtype: int64

# %% [markdown]
# There are several labels that have only one instance. How many?

# %%
num_single_occurrences = (counts == 1).sum()
print(num_single_occurrences)
# Out:
# 148

# %% [markdown]
# 148 seems like a lot. Since the maximum number is 43 and the minimum is 1, it would be nice to know the average count.

# %%
average = counts.mean()
average
# Out:
# 7.876314950589736

# %% [markdown]
# I'm going to augment the data so that there are at least 8 instances of each author-ID combination. Since each row of the existing dataset has a variant version of an author's name, I shouldn't just copy the names of those with fewer than eight instances, so I'll artificially introduce some variant spellings. I'll use the `textblob` package to introduce some variant spellings of author names.

# %%
# Code generated by Chat-GPT (https://chatgpt.com/share/e54fc0b4-c8b0-4069-9509-a89487372ccf)

from textblob import Word
import random

def generate_variations(name, num_variations=8, existing_variations=None):
    if existing_variations is None:
        existing_variations = set()
        
    while len(existing_variations) < num_variations:
        variation = list(name)
        print(f"Generating variations for {name}. Existing count: {len(existing_variations)}")
        num_changes = random.randint(1, 2)  # Randomly choose the number of changes
        for _ in range(num_changes):
            idx = random.randint(0, len(variation) - 1)
            if variation[idx].isalpha():
                # Randomly change the letter
                variation[idx] = chr(random.randint(97, 122))
        
        # Create a string from the list
        variation_str = ''.join(variation)
        
        # Use TextBlob to correct the spelling slightly to create realistic variations
        corrected = str(Word(variation_str).spellcheck()[0][0])
        existing_variations.add(corrected)
    
    return list(existing_variations)

# To store the new rows
new_rows = []

# Generate and add variants to the DataFrame
for index, row in df.iterrows():
    author = row['author']
    author_id = row['dll_author_id']
    
# Count existing variations for each author ID
variation_counts = df.groupby('dll_author_id').size().reset_index(name='count')

# Filter for items with less than 8 variations
df_to_expand = variation_counts[variation_counts['count'] < 8]

# Generate and add the necessary variations
new_rows = []

for _, row in df_to_expand.iterrows():
    author_id = row['dll_author_id']
    count = row['count']
    
    # Get all existing variations for this author ID
    existing_variations = set(df[df['dll_author_id'] == author_id]['author'].tolist())
    
    # Calculate how many more variations are needed
    needed_variations = 8 - count
    
    # Generate the required number of variations
    new_variations = generate_variations(list(existing_variations)[0], num_variations=needed_variations, existing_variations=existing_variations)
    
    # Add each new variant to the new_rows list
    for variant in new_variations:
        print(variant)
        new_rows.append({'author': variant, 'dll_author_id': author_id})

# Step 4: Convert new rows to a DataFrame and append to the original DataFrame
new_rows_df = pd.DataFrame(new_rows)
df_extended = pd.concat([df, new_rows_df], ignore_index=True)

# Display the updated DataFrame
print(df_extended)
# Out:
# Generating variations for Herryson, Joannes floruit=15th Century A.D.. Existing count: 3
# Generating variations for Herryson, Joannes floruit=15th Century A.D.. Existing count: 3
# Generating variations for Herryson, Joannes floruit=15th Century A.D.. Existing count: 4
# Generating variations for Herryson, Joannes floruit=15th Century A.D.. Existing count: 4
# Heryyson, Joannes floruit=15th Century A.D.
# Herryson, xoannes floruit=15th Century A.D.
# John Herryson
# Herryson, Joannes floruit=15th Century A.D.
# Joannes Herryson
# Stratford, Johannes ca. 1275-1348
# Johannes Stratford
# Stratford, John ca 1275-1348
# John Stratford, 1275?-1348
# John Stratford
# Stratford, John, m. 1348
# Generating variations for Nicòmac, de Gerasa, actiu segle I. Existing count: 2
# Generating variations for Nicòmac, de Gerasa, actiu segle I. Existing count: 3
# Generating variations for Nicòmac, de Gerasa, actiu segle I. Existing count: 3
# Generating variations for Nicòmac, de Gerasa, actiu segle I. Existing count: 3
# Generating variations for Nicòmac, de Gerasa, actiu segle I. Existing count: 4
# Generating variations for Nicòmac, de Gerasa, actiu segle I. Existing count: 5
# Nicòmac, de Gerasa, actiz segle I
# Nicòmac, de Gerasa, actiu segle I
# Nicòmac, dn Gerasa, actiu segle I
# Nicòmac, de Gerasz, actiu segle I
# Nicòmac, de Gerasa, pctiu segle I
# Nicomachus, of Gerasa
# Strecker, Karl, 1861-1945.
# Karl Strecker
# Strecker, Karl, 1861-1945
# Strecker, Karl
# Simon, Johann Georg, 1636-1696
# Simon, Johann Georg ca. 1636-1696
# Simon, Johann Georg
# Johann Georg Simon
# François Préchac agrégé des lettres, membre de l'École française de Rome (1906-1908)
# Préchac, François.
# Préchac, François, 1881-1977
# Préchac, François, 1881-
# Préchac, François
# Pr©♭chac, Fran©ʹois, 1881-1977
# Generating variations for Alberico da Marcellise, 1340-1398. Existing count: 1
# Generating variations for Alberico da Marcellise, 1340-1398. Existing count: 2
# Generating variations for Alberico da Marcellise, 1340-1398. Existing count: 2
# Generating variations for Alberico da Marcellise, 1340-1398. Existing count: 2
# Generating variations for Alberico da Marcellise, 1340-1398. Existing count: 3
# Generating variations for Alberico da Marcellise, 1340-1398. Existing count: 4
# Generating variations for Alberico da Marcellise, 1340-1398. Existing count: 5
# Generating variations for Alberico da Marcellise, 1340-1398. Existing count: 6
# Alberico da Marceulise, 1340-1398
# rlberict da Marcellise, 1340-1398
# Albericq df Marcellise, 1340-1398
# Albsrico da Marcellise, 1340-1398
# Alberico da Marcellise, 1340-1398
# Albeiico da farcellise, 1340-1398
# Alberico ga Marcellise, 1340-1398
# Generating variations for Aquilius Niger, Quintus. Existing count: 2
# Generating variations for Aquilius Niger, Quintus. Existing count: 3
# Generating variations for Aquilius Niger, Quintus. Existing count: 4
# Generating variations for Aquilius Niger, Quintus. Existing count: 5
# Aquilius Niger, puintus
# Aquilibl Niger, Quintus
# Aquilius Niger, Quintus
# Quintus Aquilius Niger
# Aquilius Niqer, Quxntus
# Aquilbus Nimer, Quintus
# Julianus, Salvius
# Salvius Iulianus
# Lucius Octavius Cornelius Publius Salvius Iulianus Aemilianus
# Salvius Julianus, 0100?-0169?
# Salvio Juliano
# Salvius Iulianus Aemilianus, Lucius Octavius ca. 2. Jh.
# Marcellus, Marcus Claudius, m. 45 av. J.-C.
# Marcus Claudius Marcellus
# Marcellus, Marcus Claudius, ?-45 e.Kr.
# M. Claudius M.f.M.n. Marcellus
# Generating variations for Lentulus Spinther, Publius Cornelius ca. v43. Existing count: 3
# Generating variations for Lentulus Spinther, Publius Cornelius ca. v43. Existing count: 4
# Lentulus Spinther, Pjblius Cornelius ca. v43
# Publius Cornelius Lentulus Spinther
# Lentulus Spinther, Publius Ckrnelius ca. v43
# Lentulus Spinther, Publius Cornelius ca. v43
# Lentulus Spinther, Publius Cornelius, born c. 43 B.C.
# Generating variations for Saturninus, Claudius, active 2nd century A.D.. Existing count: 3
# Generating variations for Saturninus, Claudius, active 2nd century A.D.. Existing count: 4
# Satdrninus, Claudius, active 2nd century A.D.
# Saturninus, Claudius, active 2nz century A.D.
# Saturninus, Claudius, active 2nd century A.D.
# Saturninus, Claudius
# Saturninus, Claudius 2. Jh.
# Metellus, Quintus Caecilius Nepos, -56
# Quintus Caecilius Nepos Metellus
# Nepos
# Metellus, Quintus Caecilius Nepos -v56
# Generating variations for Quintus Caecilius Metellus Celer. Existing count: 1
# Generating variations for Quintus Caecilius Metellus Celer. Existing count: 1
# Generating variations for Quintus Caecilius Metellus Celer. Existing count: 2
# Generating variations for Quintus Caecilius Metellus Celer. Existing count: 3
# Generating variations for Quintus Caecilius Metellus Celer. Existing count: 4
# Generating variations for Quintus Caecilius Metellus Celer. Existing count: 5
# Generating variations for Quintus Caecilius Metellus Celer. Existing count: 6
# Quintls Caecilius Metelmus Celer
# Quintus Caecilius Metellus Celgb
# Quintus Caeciluua Metellus Celer
# zuintus Caecilius Metellvs Celer
# Quintus Caecilits Metellus Celer
# Quintus Caecilius Metellus Celer
# Quqntus Caecilius Metellus Celer
# Papirius, Iustus
# Papirius Iustus, active 2nd century A.D.
# Papirius, Iustus, sec. II
# Papirius Iustus
# Papirius Iustus 2. Jh.
# Generating variations for Mauricianus, Iunius, active 2nd century A.D.. Existing count: 2
# Generating variations for Mauricianus, Iunius, active 2nd century A.D.. Existing count: 3
# Generating variations for Mauricianus, Iunius, active 2nd century A.D.. Existing count: 3
# Generating variations for Mauricianus, Iunius, active 2nd century A.D.. Existing count: 4
# Generating variations for Mauricianus, Iunius, active 2nd century A.D.. Existing count: 5
# Mauricianus, Iunius, dctive 2nd century A.D.
# Mauricianus, Iunius, active 2nd century A.D.
# Mauricianus, Iunius, active 2nd centwry A.D.
# Mauricianus, Iunius 2. Jh.
# Mauricianus, Iunius, active 2nd century c.D.
# Mauricirnus, Iucius, active 2nd century A.D.
# Lucceius, Lucius, active 1st century A.D.
# Lucius Lucceius Quinti filius
# Lucceius, Lucius v1. Jh.
# Lucius Lucceius
# Generating variations for Festus, Pescennius. Existing count: 1
# Generating variations for Festus, Pescennius. Existing count: 1
# Generating variations for Festus, Pescennius. Existing count: 1
# Generating variations for Festus, Pescennius. Existing count: 2
# Generating variations for Festus, Pescennius. Existing count: 3
# Generating variations for Festus, Pescennius. Existing count: 3
# Generating variations for Festus, Pescennius. Existing count: 4
# Generating variations for Festus, Pescennius. Existing count: 5
# Generating variations for Festus, Pescennius. Existing count: 6
# Festus, Pesfennius
# Festus, Pescebnius
# Festus, Pescennius
# Festws, Pescednius
# Fertus, Pescennius
# Festus, Pesuennius
# Festus, eescenniys
# Generating variations for Valerius, Cornelius. Existing count: 1
# Generating variations for Valerius, Cornelius. Existing count: 2
# Generating variations for Valerius, Cornelius. Existing count: 3
# Generating variations for Valerius, Cornelius. Existing count: 4
# Generating variations for Valerius, Cornelius. Existing count: 5
# Generating variations for Valerius, Cornelius. Existing count: 6
# Valeaius, Cornelpus
# Valerius, Czroelius
# Valerius, Cooneliss
# Valerius, Ctrnelius
# Valerius, Cornelius
# Vaperius, Cornelius
# Valecius, rornelius
# Generating variations for Sextius Niger 10-40. Existing count: 2
# Generating variations for Sextius Niger 10-40. Existing count: 3
# Generating variations for Sextius Niger 10-40. Existing count: 4
# Generating variations for Sextius Niger 10-40. Existing count: 5
# Generating variations for Sextius Niger 10-40. Existing count: 5
# Sextiua Niger 10-40
# Sextzus Niger 10-40
# Sextius Niger, f. 10-40
# Sextiuq Niger 10-40
# Sextius Niger 10-40
# yextius Niser 10-40
# Servilius Nonianus, Marcus, 1st Century A.D.
# Servilius Nonianus, Marcus 1. Jh. n. Chr
# Servilius Nonianus, Marcus -59
# Nonianus
# Generating variations for Aelius Sabinus ca. Ende 3. Jh.. Existing count: 1
# Generating variations for Aelius Sabinus ca. Ende 3. Jh.. Existing count: 2
# Generating variations for Aelius Sabinus ca. Ende 3. Jh.. Existing count: 2
# Generating variations for Aelius Sabinus ca. Ende 3. Jh.. Existing count: 3
# Generating variations for Aelius Sabinus ca. Ende 3. Jh.. Existing count: 3
# Generating variations for Aelius Sabinus ca. Ende 3. Jh.. Existing count: 4
# Generating variations for Aelius Sabinus ca. Ende 3. Jh.. Existing count: 5
# Generating variations for Aelius Sabinus ca. Ende 3. Jh.. Existing count: 6
# Aelius Sabinus ca. Ende 3. lh.
# Awlius Sabinus ca. Ende 3. Jh.
# Aklius cabinus ca. Ende 3. Jh.
# Aelius fabinus ca. Ende 3. Jh.
# Aelius Sabinus sa. Ende 3. Jh.
# Aelius Sabincs ca. Ende 3. Jh.
# Aelius Sabinus ca. Ende 3. Jh.
# Generating variations for Regianus Poeta 5. bzw. 5./6. Jh.. Existing count: 2
# Generating variations for Regianus Poeta 5. bzw. 5./6. Jh.. Existing count: 3
# Generating variations for Regianus Poeta 5. bzw. 5./6. Jh.. Existing count: 4
# Generating variations for Regianus Poeta 5. bzw. 5./6. Jh.. Existing count: 5
# Regianus Poeta 5. bzw. 5./6. Jh.
# Regianus Poeta 5. bzw. 5./6. Jv.
# Regianus Poeta 5. hzw. 5./6. Jh.
# Regianus Poeta 5. bzw. 5./6. Jh. n. Chr
# Regianus Poeta 5. bzw. 5./6. Js.
# Reghanus Poeta 5. bzw. 5./6. Jh.
# Generating variations for Curius. Existing count: 3
# Generating variations for Curius. Existing count: 4
# Curius, Manlius, active circa 58 B.C.
# curious
# during
# Curius
# Curius, Manlius v58
# Publius Vatinius
# Vatinius
# Vatinius, Publius ca. v45/44
# Vatinius, Publius fl. 59-47 B.C.
# P. Vatinius P.f.
# Generating variations for Iavolenus Priscus. Existing count: 3
# Generating variations for Iavolenus Priscus. Existing count: 4
# Iavolenus Priscus
# Iavolenus Pmisuus
# Iavolenus Priscus, Gaius Octavius Tidius Tossanius Lucius ca. 60 v. Chr.-12
# Gaius Octavius Tidius Tossianus Lucius Iavolenus Priscus
# Iaxolengs Priscus
# Decimus Iunius Albinus
# Brutus Albinus, Decimus Iunius, circa 85 B.C.- circa 43 B.C.
# Brutus Albinus, Decimus Iunius v85-v43
# Decimus Iunius Brutus Albinus
# Proculus Iurisconsultus, active 20-50 A.D.
# Proculus Iurisconsultus
# Proculus Iuriscolnsultus
# Proculus Iurisconsultus v20-50
# Generating variations for Licinius Rufinus ca. 2./3. Jh.. Existing count: 1
# Generating variations for Licinius Rufinus ca. 2./3. Jh.. Existing count: 1
# Generating variations for Licinius Rufinus ca. 2./3. Jh.. Existing count: 2
# Generating variations for Licinius Rufinus ca. 2./3. Jh.. Existing count: 3
# Generating variations for Licinius Rufinus ca. 2./3. Jh.. Existing count: 4
# Generating variations for Licinius Rufinus ca. 2./3. Jh.. Existing count: 4
# Generating variations for Licinius Rufinus ca. 2./3. Jh.. Existing count: 5
# Generating variations for Licinius Rufinus ca. 2./3. Jh.. Existing count: 5
# Generating variations for Licinius Rufinus ca. 2./3. Jh.. Existing count: 5
# Generating variations for Licinius Rufinus ca. 2./3. Jh.. Existing count: 6
# Licinius Rufinus da. 2./3. Jh.
# Licanius Rufinus ca. 2./3. Jh.
# Liainius Rufinus ca. 2./3. Jh.
# Liciniqs Rufinus ca. 2./3. Jh.
# Licinius Rufinus cn. 2./3. Jq.
# Licinius Rufinus ca. 2./3. Jh.
# Ldcinius Rufinus ca. 2./3. Jh.
# Generating variations for Lucius Ulpius Marcellus. Existing count: 2
# Generating variations for Lucius Ulpius Marcellus. Existing count: 3
# Generating variations for Lucius Ulpius Marcellus. Existing count: 4
# Generating variations for Lucius Ulpius Marcellus. Existing count: 5
# Lucius Ulpiuq Marcellus
# Lucius Ulpjus Marcellus
# Lucius Ulpius Marcellus
# Marcellus, Ulpius ca. 2. Jh.
# qucius Ulpius Marcellus
# Lukius Ulpius Marczllus
# Generating variations for Venuleius Saturninus, active 1st century A.D.. Existing count: 2
# Generating variations for Venuleius Saturninus, active 1st century A.D.. Existing count: 3
# Generating variations for Venuleius Saturninus, active 1st century A.D.. Existing count: 3
# Generating variations for Venuleius Saturninus, active 1st century A.D.. Existing count: 4
# Generating variations for Venuleius Saturninus, active 1st century A.D.. Existing count: 5
# Venuleihs Saturninus, active 1st centcry A.D.
# Venuleius Satupninus, ahtive 1st century A.D.
# Venuleius Saturninus 1. Jh.
# Venuleius Saturninus, active 1st century A.D.
# Venuleius Saturninus, sctive 1st century A.D.
# Venuleius Saturninus, active 1st centzry A.D.
# Tarruntenus Paternus 2. Jh.
# Publius Tarutienus Paternus
# Publiusz Taruttienus Paternus (?-182)
# Tarruntenus Paternus, active 2nd century A.D.
# Generating variations for Menander, Arrius.. Existing count: 3
# Generating variations for Menander, Arrius.. Existing count: 4
# Menander, Arrius.
# Menander, Arrius ca. 2./3. Jh.
# Menander, Arrius, active 2nd/3rd century A.D.
# Menander, Aruius.
# Menandeg, Arrius.
# Generating variations for Clemens, Terentius. Existing count: 3
# Generating variations for Clemens, Terentius. Existing count: 4
# llemens, Terentius
# Climens, Terentiua
# Clemens, Terentius 2. Jh.
# Clemens, Terentius
# Clemens, Terentius, active 2nd century A.D.
# Balbillus, Astrologus, 1st Century A.D.
# Balbillus, Ephesius
# Balbillus, Astrologus
# Balbillus Astrologus 1. Jh.
# Balbillus Astrologus 1. Jh. n. Chr
# Balbillus, Ephesius, Barbillus, Ephesius
# Tuccianus, Poeta
# Tuccianus Poeta 5. bzw. 5./6. Jh.
# Tuccianus Poeta 5. bzw. 5./6. Jh. n. Chr
# Tuccianus
# Tuccianus, Poeta, 5th or 5th/6th Century A.D.
# Generating variations for Lucius Saufeius. Existing count: 2
# Generating variations for Lucius Saufeius. Existing count: 3
# Generating variations for Lucius Saufeius. Existing count: 4
# Generating variations for Lucius Saufeius. Existing count: 5
# Generating variations for Lucius Saufeius. Existing count: 5
# Lucius Saufeius
# Luciun Saufeius
# Saufeius, Lucius ca. Römische Republik
# Luhius Saufeiuj
# Lumius Sahfeius
# Lucius Stufeius
# Generating variations for Iulius Saturninus. Existing count: 2
# Generating variations for Iulius Saturninus. Existing count: 3
# Generating variations for Iulius Saturninus. Existing count: 4
# Generating variations for Iulius Saturninus. Existing count: 5
# Iulius eatuaninus
# Saturninus
# Iulius Saturninus
# Iuxius Saturninos
# Iulius Satvrninus
# Iyliut Saturninus
# Generating variations for Procilius v1. Jh.. Existing count: 2
# Generating variations for Procilius v1. Jh.. Existing count: 2
# Generating variations for Procilius v1. Jh.. Existing count: 3
# Generating variations for Procilius v1. Jh.. Existing count: 4
# Generating variations for Procilius v1. Jh.. Existing count: 5
# Procilius v1. Jh.
# Procplius v1. Jh.
# Procilihs v1. wh.
# Procslius v1. Jh.
# L.Procilius L.f.
# Procilius v1. ah.
# Generating variations for Modestinus, Herennius.. Existing count: 3
# Generating variations for Modestinus, Herennius.. Existing count: 4
# Moxestinus, eerennius.
# Moqessinus, Herennius.
# Modestinus, Herennius, sec. III
# Modestinus, Herennius.
# Modestinus, Herennius ca. 3. Jh.
# Nerwa (cesarz rzymski ; 30-98)
# Nerva император римский ок. 30-98
# Nerva, 0026?-0098, empereur romain
# Nerva, Emperador de Roma
# Nerva Römisches Reich, Kaiser 30-98
# Nerva empereur romain 0026?-0098
# Nerva
# Valens, Gaius Aburnius 109
# Gaius Aburnius Valens
# L.Fulvius C.f. Aburnius Valens
# Valens, Gaius Aburnius, 109
# Generating variations for Domitius Afer. Existing count: 1
# Generating variations for Domitius Afer. Existing count: 2
# Generating variations for Domitius Afer. Existing count: 3
# Generating variations for Domitius Afer. Existing count: 4
# Generating variations for Domitius Afer. Existing count: 5
# Generating variations for Domitius Afer. Existing count: 6
# Generating variations for Domitius Afer. Existing count: 6
# Domitsus Afer
# womigius Afer
# Dbmitius Afer
# Doditius Afer
# Domijius Afer
# Domitiuj Afer
# Domitius Afer
# Caius Trebonius
# C. Trebonius C.f.
# Trebonius
# Trebonius, Gaius v45
# Tryphoninus, Claudius
# Tryphoninus, Claudius ca. 2./3. Jh.
# Tryphoninus, Claudius, 2e-3e eeuw
# Trifonino, Claudio
# Generating variations for Vennonius 2. Jh. v. Chr. Existing count: 2
# Generating variations for Vennonius 2. Jh. v. Chr. Existing count: 3
# Generating variations for Vennonius 2. Jh. v. Chr. Existing count: 4
# Generating variations for Vennonius 2. Jh. v. Chr. Existing count: 4
# Generating variations for Vennonius 2. Jh. v. Chr. Existing count: 5
# Vennanius 2. Jh. v. Chr
# Vennonius 2. Jh. v. Chr
# Vennonius v2. Jh.
# Vennoniuk 2. Jh. v. Chr
# Vennonixs 2. Jh. v. Chr
# Vpnnonius 2. Jh. v. Chr
# Suetonius Paullinus, Gaius 1. Jh.
# C. Suetonius Paulinus
# Suetonio Paulino, Cayo
# Suetonius Paulinus, Gaius
# Generating variations for Sabinus, Masurius. Existing count: 1
# Generating variations for Sabinus, Masurius. Existing count: 2
# Generating variations for Sabinus, Masurius. Existing count: 3
# Generating variations for Sabinus, Masurius. Existing count: 4
# Generating variations for Sabinus, Masurius. Existing count: 5
# Generating variations for Sabinus, Masurius. Existing count: 6
# Sabinos, Masurius
# Sabinus, Maturius
# Scbinus, Masurifs
# Sabinus, Masupous
# Sabinus, Masurius
# Sabinus, Mawurius
# Sabinus, Maserius
# Generating variations for Posthius, Johannes, 1537-1597. Existing count: 3
# Generating variations for Posthius, Johannes, 1537-1597. Existing count: 3
# Generating variations for Posthius, Johannes, 1537-1597. Existing count: 4
# Generating variations for Posthius, Johannes, 1537-1597. Existing count: 4
# Generating variations for Posthius, Johannes, 1537-1597. Existing count: 4
# Posthius, Johannes, 1537-1597.
# Post, Johann, 1537-1597
# Posthius, Johannes, 1537-1597
# Posthius, Johanaes, 1537-1597
# Porthius, Johannes, 1537-1597
# Generating variations for Maeonius Astyanax 3. Jh. Existing count: 3
# Generating variations for Maeonius Astyanax 3. Jh. Existing count: 4
# Maeonius Astyazax 3. Jh
# Maeonixs Astyanax 3. Jh
# Maeonius Astyanax, 3rd Century A.D.
# Maeonius Astyanax 3. Jh
# Maeonius Astyanax ca. 3. Jh.
# Generating variations for Uberti, Francesco, vers 1440-1518. Existing count: 3
# Generating variations for Uberti, Francesco, vers 1440-1518. Existing count: 4
# Uberti, Frapcesco, vers 1440-1518
# Francesco Uberti
# Uberti, Francesco (ca 1440-1518)
# Uberti, Francesco, vers 1440-1518
# Uberti, Franceswo, vers 1440-1518
# Thomas ca. ca. 1390-1472 Seneca
# Thomas Seneca ca. ca. 1390-1472
# Tommaso Seneca da Camerino umanista italiano
# Seneca, Tommaso, époque 1390-1472.
# Seneca, Tommaso, 1390?-1472
# Seneca, Thomas, ca. 1390-1472
# Natale, Francesco
# Di Natale, Francesco.
# Di Natale, Francesco, 1946-
# Di Natale, Francesco
# Di Natale, Francesco, historien
# Francesco Di Natale Italský vysokoškolský učitel lingvistiky. Učebnice a gramatické příručky italštiny.
# Natale, Francesco Antonio
# Generating variations for Vestalis. Existing count: 1
# Generating variations for Vestalis. Existing count: 2
# Generating variations for Vestalis. Existing count: 3
# Generating variations for Vestalis. Existing count: 4
# Generating variations for Vestalis. Existing count: 5
# Generating variations for Vestalis. Existing count: 6
# Vesualis
# Vestalis
# Veetalih
# Entails
# Vrslalis
# Vestylis
# gestalis
# Generating variations for Ponnanus Poeta 5. bzw. 5./6. Jh.. Existing count: 2
# Generating variations for Ponnanus Poeta 5. bzw. 5./6. Jh.. Existing count: 2
# Generating variations for Ponnanus Poeta 5. bzw. 5./6. Jh.. Existing count: 3
# Generating variations for Ponnanus Poeta 5. bzw. 5./6. Jh.. Existing count: 4
# Generating variations for Ponnanus Poeta 5. bzw. 5./6. Jh.. Existing count: 5
# Generating variations for Ponnanus Poeta 5. bzw. 5./6. Jh.. Existing count: 5
# Ponnanus, Poeta
# Ponnanus Poeta 5. bzw. 5./6. Jh.
# Ponnanus xoeta 5. bzw. 5./6. Jh.
# Ponnanus Poeta 5. baw. 5./6. Jh.
# Ponnanus Pieta 5. bzw. 5./6. Jh.
# Ponnanus Preta 5. bzw. 5./6. Jh.
# Modestinus, Poeta, 5th or 6th Century A.D.
# Modestinus Poeta
# Modestinus
# Modestinus Poeta 5. bzw. 5./6. Jh.
# Generating variations for Marcus Scribonius Libo Drusus. Existing count: 1
# Generating variations for Marcus Scribonius Libo Drusus. Existing count: 2
# Generating variations for Marcus Scribonius Libo Drusus. Existing count: 3
# Generating variations for Marcus Scribonius Libo Drusus. Existing count: 4
# Generating variations for Marcus Scribonius Libo Drusus. Existing count: 5
# Generating variations for Marcus Scribonius Libo Drusus. Existing count: 6
# Marvus Scriboniuc Libo Drusus
# Marcus Scribonius Libo drusus
# Marcus Scribonius Libo Drusus
# Marcus Scribpnius Libo Drusus
# Marcuz Scribonius Libo Drusvs
# Marcus Scribonius Liwo Drusus
# Marcus Scribonius Libo lrusus
# Generating variations for Marcus Fulvius Nobilior. Existing count: 3
# Generating variations for Marcus Fulvius Nobilior. Existing count: 4
# Marcus Fulvius Nobilior
# Marcus Fulvius Nobxlior
# Fulvius Nobilior, Marcus ca. v2.Jh.
# Marcus Fuloius Nobilior
# Fulvius Nobilior, Marcus, approximately 230 B.C.-
# Convenevolis‏ Pratensis
# Convenevole da Prato, 127.-1338?
# Convenevole, da Prato, 1270-1338
# Convenevole : da Prato
# Convenevolis, Pratensis, -ca. 1340
# Convenevole da Prato, m.c. 1340
# Raffaele Zovenzoni umanista italiano
# Zovenzoni, Raffaele, 143.-1485
# Zovenzoni, Raffaele
# Zovenzonius, Raphael
# Zovenzoni, Raffaello, 1431-1485
# Giovenzoni, Raffaello, 1431-1485
# Raphael Zovenzonius, 1431-1485
# Generating variations for Gabriele de' Zamorei. Existing count: 1
# Generating variations for Gabriele de' Zamorei. Existing count: 2
# Generating variations for Gabriele de' Zamorei. Existing count: 3
# Generating variations for Gabriele de' Zamorei. Existing count: 4
# Generating variations for Gabriele de' Zamorei. Existing count: 5
# Generating variations for Gabriele de' Zamorei. Existing count: 6
# oabriele de' Zamorei
# Gabrielh de' Zamorei
# Gabjiele de' Zamorei
# Gakriele de' Zkmorei
# Gabriele de' Zamorei
# Gibriele de' Zamorxi
# labviele de' Zamorei
# Varchi, Benedetto, 1503-1565.
# Varchi, Benedetto, 1503-1565
# Varchi, Benedetto 1502-1565
# Varchi, Benedetto
# Benedetto Varchi umanista, scrittore e storico italiano
# Varchi, Benedetto (Italian humanist and theorist, 1503-1565)
# Generating variations for Tommaso da Faenza. Existing count: 3
# Generating variations for Tommaso da Faenza. Existing count: 4
# Tommasy da Faenza
# Tomaso, da Faenza, active 1263-1289
# Tomaso da Faenza ca. 13. Jh.
# Tkmmaso da Faenza
# Tommaso da Faenza
# Serarrighi, Cristofano (15..-15..).
# Cristofano Serarrighi
# Serarrighi, Cristofano
# Serarrighi, Cristofano, sec. XVI
# Generating variations for Hercolani de' Sarti, Gioanni, 15..-1535. Existing count: 1
# Generating variations for Hercolani de' Sarti, Gioanni, 15..-1535. Existing count: 1
# Generating variations for Hercolani de' Sarti, Gioanni, 15..-1535. Existing count: 1
# Generating variations for Hercolani de' Sarti, Gioanni, 15..-1535. Existing count: 1
# Generating variations for Hercolani de' Sarti, Gioanni, 15..-1535. Existing count: 2
# Generating variations for Hercolani de' Sarti, Gioanni, 15..-1535. Existing count: 3
# Generating variations for Hercolani de' Sarti, Gioanni, 15..-1535. Existing count: 3
# Generating variations for Hercolani de' Sarti, Gioanni, 15..-1535. Existing count: 4
# Generating variations for Hercolani de' Sarti, Gioanni, 15..-1535. Existing count: 5
# Generating variations for Hercolani de' Sarti, Gioanni, 15..-1535. Existing count: 6
# Generating variations for Hercolani de' Sarti, Gioanni, 15..-1535. Existing count: 6
# Hvrcolani de' Sartc, Gioanni, 15..-1535
# Hebcolani de' Sarti, Gioanni, 15..-1535
# Hercolani de' Sarti, Gsoanni, 15..-1535
# Hercolani de' Syrti, Giganni, 15..-1535
# Hercolanb de' Sarti, Gioanni, 15..-1535
# Hercolani de' Sarti, Giianni, 15..-1535
# Hercolani de' Sarti, Gioanni, 15..-1535
# Geraldini, Alejandro, vesc. di Santo Domingo, 1455-1524
# Alessandro Geraldini vescovo cattolico e umanista italiano
# Geraldinus, Alexander 1455-1525
# Geraldini, Alessandro, vesc. di Santo Domingo, 1455-1524
# Geraldini, Alessandro
# Generating variations for Aegidius Gallus scriptor Italicus. Existing count: 1
# Generating variations for Aegidius Gallus scriptor Italicus. Existing count: 1
# Generating variations for Aegidius Gallus scriptor Italicus. Existing count: 2
# Generating variations for Aegidius Gallus scriptor Italicus. Existing count: 3
# Generating variations for Aegidius Gallus scriptor Italicus. Existing count: 4
# Generating variations for Aegidius Gallus scriptor Italicus. Existing count: 5
# Generating variations for Aegidius Gallus scriptor Italicus. Existing count: 6
# Aegidius Gallus smhiptor Italicus
# Aegiliur Gallus scriptor Italicus
# Aegidius Galcus scriptor Italicus
# Aegidius Gallus scpiptor Italicus
# Aegidius Gallus scriptor Itnlicus
# degidius Gallus scriptor Italicus
# Aegidius Gallus scriptor Italicus
# Philelphus, Ioannes Marius 1426-1480
# Philelphus, Johannes Marius
# Gianmario Filelfo umanista italiano
# Philelphus, Iohannes Marius, 1426-1480
# Filelfo, Giovanni Mario
# Philelphus, Johannes Marius, 1426-1480
# Generating variations for Ferreri, Zaccaria, 1439?-1524. Existing count: 1
# Generating variations for Ferreri, Zaccaria, 1439?-1524. Existing count: 1
# Generating variations for Ferreri, Zaccaria, 1439?-1524. Existing count: 2
# Generating variations for Ferreri, Zaccaria, 1439?-1524. Existing count: 3
# Generating variations for Ferreri, Zaccaria, 1439?-1524. Existing count: 3
# Generating variations for Ferreri, Zaccaria, 1439?-1524. Existing count: 4
# Generating variations for Ferreri, Zaccaria, 1439?-1524. Existing count: 5
# Generating variations for Ferreri, Zaccaria, 1439?-1524. Existing count: 6
# Ferreri, Zaccaria, 1439?-1524
# Ferleri, Zancaria, 1439?-1524
# Ferreri, Zarcaria, 1439?-1524
# Ferrery, Zaccaria, 1439?-1524
# merreri, Zaccaria, 1439?-1524
# Fedreri, Zaccaria, 1439?-1524
# Ferreri, oaccaria, 1439?-1524
# Zenodbi
# Zanobi da Strada, 1312-1361
# Zanobi da Strata, 1312-1361
# Zanobi, da Strada
# Strata, Zanobi de
# Zanobi, da Strada, ca. 1312-ca. 1361
# Zanobi da Strada scrittore e letterato italiano
# Fedele, Cassandra
# Cassandra Fedele
# Fedele-Mapelli, Cassandra, 1465-1558
# Fidelis, Cassandra
# Fidelis, Cassandra, 1465-1558
# Generating variations for Eustachius de Matera c. 1268/70. Existing count: 3
# Generating variations for Eustachius de Matera c. 1268/70. Existing count: 4
# Eqstachius de watera c. 1268/70
# Eustachius de Matera c. 1268/70
# llstachius de Matera c. 1268/70
# Eustachio da Matera giurista e poeta italiano
# Eustachius de Matera ca. um 1268/70
# Nogarola, Isotta
# Isotta Nogarola ca. 1420 - 1466
# Nogarola, Isotta, 1418-1466
# Isotta Nogarola
# Girolamo Muzio letterato e poeta italiano
# Mutius, Hieronimus, 1496-1576
# Mutius, Hieronimus
# Muzio, Girolamo
# Gerardo Maurisio cronista medievale italiano
# Maurisio, Gerardo
# Maurisio, Gerardo (Gerardus), 1173-
# Maurisius, Gerardus 1173-1237
# Maurisio, Gerardo, 1173?-12..
# Maurisius, Gerhardus, c. 1175-c. 1237
# Generating variations for Gravina, Pietro 1749-1830 card. Existing count: 3
# Generating variations for Gravina, Pietro 1749-1830 card. Existing count: 3
# Generating variations for Gravina, Pietro 1749-1830 card. Existing count: 3
# Generating variations for Gravina, Pietro 1749-1830 card. Existing count: 4
# Generating variations for Gravina, Pietro 1749-1830 card. Existing count: 4
# Gravina, Pietro 1749-1830 card
# Gravina, Pietro 1749-1830 caqd
# Gravina, Pietro, card., 1749-1830
# Pietro Gravina
# jravina, Pietro 1749-1830 card
# Generating variations for Girolamo d'Este 1450-1530. Existing count: 3
# Generating variations for Girolamo d'Este 1450-1530. Existing count: 4
# Generating variations for Girolamo d'Este 1450-1530. Existing count: 4
# Girolazo d'Este 1450-1530
# Hieronymus Brunschwig médecin allemand
# Brunschwig, Hieronymus, 1450-1533
# Girosamo d'Este 1450-1530
# Girolamo d'Este 1450-1530
# Franciscus Cardulus
# Cardulus, Franciscus
# Cardulo, Francesco
# Francesco Cardulo
# Generating variations for Bonifacio Bembo pittore e miniatore italiano. Existing count: 3
# Generating variations for Bonifacio Bembo pittore e miniatore italiano. Existing count: 4
# Bonifacio oembo pibtore e miniatore italiano
# Bonifacio Bembo pittors e miniatore italiano
# Bembo, Bonifacio, 1420-1477
# Bonifacio Bembo pittore e miniatore italiano
# Bembo
# Giovanni Aurispa
# Aurispa, Giovanni, ca. 1375-1459
# Aurispa, Giovanni, 1369-1459
# Aurispa, Giovanni
# Aurispa, Giovanni 1376-1459
# Augurelli, Giovanni Aurelio, asi 1456-1524
# Augurelli, Giovanni Aurelio, approximately 1456-1524?
# Augurello, Giovanni Aurelio 1456-1524
# Augurelli, Giovanni Aurelio, 1456-1524
# Generating variations for Angela Nogarola c. 15. C.. Existing count: 3
# Generating variations for Angela Nogarola c. 15. C.. Existing count: 4
# Angela Nogarola c. 15. C.
# Angela Nogarola
# cngela Nogarola c. 15. C.
# Angela Nogarowa c. 15. C.
# Angela Nogarola ca. 15. Jh.
# Gabriele Altilio poeta, vescovo cattolico e umanista italiano
# Altilio, Gabriele
# Altilio, Gabriele, 1440 -1501?
# Altilio, Gabriele, vesc. di Policastro, 1436-1501
# Altilis, Gabriele
# Perisauli, Faustino
# Perisauli, Faustino, 1450?-1523
# Perisauli, Faustino, approximately 1450-1523
# Faustino, Pietro Saul 1450?-1523
# Faustinus Perisaulus
# Perisauli, Faustino, m. d. 1523
# Phantino, Pier S.
# Generating variations for Cichinus, Georgius, 1514-1599. Existing count: 2
# Generating variations for Cichinus, Georgius, 1514-1599. Existing count: 3
# Generating variations for Cichinus, Georgius, 1514-1599. Existing count: 4
# Generating variations for Cichinus, Georgius, 1514-1599. Existing count: 5
# Cichinus, Georgius, 1514-1599
# Ciciinus, Georgids, 1514-1599
# Cichino, Giorgio, 1514-1599
# Cichinus, Gexrgius, 1514-1599
# Cichinus, Gemrgzus, 1514-1599
# Cichinus, Geormius, 1514-1599
# Generating variations for Barbato, Marco, m. 1363. Existing count: 2
# Generating variations for Barbato, Marco, m. 1363. Existing count: 3
# Generating variations for Barbato, Marco, m. 1363. Existing count: 4
# Generating variations for Barbato, Marco, m. 1363. Existing count: 5
# Generating variations for Barbato, Marco, m. 1363. Existing count: 5
# Generating variations for Barbato, Marco, m. 1363. Existing count: 5
# parbato, Marco, m. 1363
# Barbato, Marco, m. 1363
# Barbato, Matco, m. 1363
# Barbato, Marqo, m. 1363
# Barbato, Marcd, m. 1363
# Barbato da Sulmona
# Generating variations for Molza, Tarquinia. Existing count: 2
# Generating variations for Molza, Tarquinia. Existing count: 3
# Generating variations for Molza, Tarquinia. Existing count: 4
# Generating variations for Molza, Tarquinia. Existing count: 5
# Molza, Tarquinia
# Molzt, Terquinia
# Molza, Trrquinca
# Molza, Tarqtinia
# Molza, Tarquinha
# Tarquinia Molza compositrice, musicista e poetessa italiana
# Generating variations for Antonio Baratella. Existing count: 3
# Generating variations for Antonio Baratella. Existing count: 4
# Baratella, Antonio, 1385-1448
# Antonio Baratella poète italien
# Anbonio Barwtella
# Antonio Baratelha
# Antonio Baratella
# Ranieri, Antonio, književnik
# Ranieri, Antonio, ca. 1806-1888
# Ranieri, Antonio
# Antonio Ranieri
# Andronikos Kallistos d. 1478
# Calliste, Andronic, 14..-1476?
# Calliste, Andronic 14..-1478
# Andronico Callisto 1400-1476
# Lapi, Angelo Emilio
# Lapi, Angelo Emilio, 1769-1852
# Lapi, Angelo Emilio, f. 1769-1852
# Angelo Emilio Lapi
# Generating variations for Barignani, Fabio. Existing count: 3
# Generating variations for Barignani, Fabio. Existing count: 4
# Fabio Barignani
# Barignani, Fybio
# Baripnani, Fabio
# Barignani, Fabio
# Barignani, Fabio, 1532-....
# Mauri, Francesco, O.F.M., n. 1500
# Mauri, Francesco, 1500-1571
# Mauri, Francesco 1500-1571
# Maurus, Franciscus
# Rolandellus, Franciscus
# Rolandellus, Franciscus, 1427-1490
# Rholandellus, Franciscus
# Francesco Rolandello
# Lorenzo Lenzi
# Lenzi, Lorenzo, ca. 1517-1571
# Lenzi, Lorenzo (około 1517-1571).
# Lenzi, Lorenzo, 1517-....
# Lenzi, Lorenzo ca1517-1571
# Lenzi, Lorenzo
# Generating variations for Petrus de Mulio. Existing count: 3
# Generating variations for Petrus de Mulio. Existing count: 4
# Generating variations for Petrus de Mulio. Existing count: 4
# Petrus de Muglio 1313-1383
# Pietro da Moglio, m. 1383
# Petrus me Mulio
# fetrus de Mulio
# Petrus de Mulio
# Generating variations for Amalteo, C. Paolo. Existing count: 2
# Generating variations for Amalteo, C. Paolo. Existing count: 3
# Generating variations for Amalteo, C. Paolo. Existing count: 4
# Generating variations for Amalteo, C. Paolo. Existing count: 5
# Amalteo, C. Paolo
# Amalteo, Cornelio Paolo, O.F.M., 1460-1517
# Amalteo, C. aaolo
# Amalteo, C. xaolo
# Amalteo, C. oaolo
# Amalteo, i. Paolo
# Generating variations for Giovanni Michele Alberto da Carrara Italian physician. Existing count: 3
# Generating variations for Giovanni Michele Alberto da Carrara Italian physician. Existing count: 4
# Giovanni Michele Alberto da Carrara Italian physician
# Giovanni Michele Alberto da Carrara Italiin physician
# Carrara, Giovanni Michele Alberto
# Giovanni Michele Alberto da Cdrrara Italian physician
# Carrara, Johannes Michael Albertus 1438-1490
# Alighieri, Piero di Dante, 1300-1364
# Alighieri, Pietro, 129.-1364
# Pietro Alighieri magistrato e critico letterario italiano, figlio di Dante
# Alighieri, Pietro, ca. 1300-1364
# Alighièri, Pietro m. 1364
# Alighieri, Pietro, 1300-1364
# Alighieri, Pietro
# Isola, Matteo dall', 16e eeuw
# Dall'Isola, Matteo 148.?-15..
# Dall'Isola, Matteo ca. 16. Jh.
# Matteo : dall'Isola
# Matteo dall'Isola eskritor italiano
# Matteo dall'Isola, sec. XVI
# Generating variations for Sisbertus Toletanus, c. 7th century A.D.. Existing count: 3
# Generating variations for Sisbertus Toletanus, c. 7th century A.D.. Existing count: 4
# Pseudo-Sisbertus Toletanus.
# Sisbertus Tolkhanus, c. 7th century A.D.
# Siebertus Toletanus, c. 7th century A.D.
# Sisbertus Toletanus, c. 7th century A.D.
# Sisibert Toledo, Erzbischof
# Generating variations for Gerardus Anechini. Existing count: 2
# Generating variations for Gerardus Anechini. Existing count: 3
# Generating variations for Gerardus Anechini. Existing count: 4
# Generating variations for Gerardus Anechini. Existing count: 5
# Gerardus wnechini
# Gerardus Anechini
# Gerardus Anechini ca. um 1399
# Gerardis Anechidi
# Gerprdus Anechinx
# Geravdus Anechini
# Marsus, Paulus
# Marsi, Paolo
# Marsus, Paulus, 1440-1484
# Marso, Paolo
# Paolo Marsi umanista italiano
# Marso, Paolo, 1440-1484
# Generating variations for Giovanni Quatrario. Existing count: 1
# Generating variations for Giovanni Quatrario. Existing count: 2
# Generating variations for Giovanni Quatrario. Existing count: 3
# Generating variations for Giovanni Quatrario. Existing count: 4
# Generating variations for Giovanni Quatrario. Existing count: 4
# Generating variations for Giovanni Quatrario. Existing count: 5
# Generating variations for Giovanni Quatrario. Existing count: 6
# Giovanni Quaurario
# Giovanni Qyatrapio
# Giovanmi Quatrario
# Giovasni Quatrario
# Gieranni Quatrario
# Giovarni Quatrario
# Giovanni Quatrario
# Generating variations for Matteo Griffoni 1351-1426. Existing count: 3
# Generating variations for Matteo Griffoni 1351-1426. Existing count: 3
# Generating variations for Matteo Griffoni 1351-1426. Existing count: 4
# Generating variations for Matteo Griffoni 1351-1426. Existing count: 4
# Mbtteo Griffoni 1351-1426
# Matteo Griffoni 1351-1426
# Griffoni, Matteo
# iattdo Griffoni 1351-1426
# Griffonibus, Matthaeus de 1351-1426
# Generating variations for Ravignani, Benintendi, approximately 1317-approximately 1360. Existing count: 1
# Generating variations for Ravignani, Benintendi, approximately 1317-approximately 1360. Existing count: 1
# Generating variations for Ravignani, Benintendi, approximately 1317-approximately 1360. Existing count: 2
# Generating variations for Ravignani, Benintendi, approximately 1317-approximately 1360. Existing count: 3
# Generating variations for Ravignani, Benintendi, approximately 1317-approximately 1360. Existing count: 4
# Generating variations for Ravignani, Benintendi, approximately 1317-approximately 1360. Existing count: 5
# Generating variations for Ravignani, Benintendi, approximately 1317-approximately 1360. Existing count: 6
# Ravignani, Bejintendi, approximatelh 1317-approximately 1360
# Ravignsni, Benintendi, approximately 1317-approximately 1360
# Ravignani, Benintendi, approximately 1317-approqimately 1360
# Ravirnani, Benintendi, approximately 1317-bpproximately 1360
# Ravignani, Benintandi, approximately 1317-approximately 1360
# Ravignani, Bunintendi, approximately 1317-approximately 1360
# Ravignani, Benintendi, approximately 1317-approximately 1360
# Generating variations for Alessandro Paolini. Existing count: 1
# Generating variations for Alessandro Paolini. Existing count: 2
# Generating variations for Alessandro Paolini. Existing count: 3
# Generating variations for Alessandro Paolini. Existing count: 4
# Generating variations for Alessandro Paolini. Existing count: 5
# Generating variations for Alessandro Paolini. Existing count: 6
# Alessandro Psolini
# Alessandro Pholini
# Alxssanyro Paolini
# Alessanaro Paoluni
# Alessandro Pwolidi
# Alessandro Paolini
# Alessandro daolini
# Amaseus, Hieronymus, O.F.M., 1467-1517
# Amaseo, Girolamo
# Amaseo, Girolamo, O.F.M., 1467-1517
# Hieronymus Amaseus
# Moggi, Moggio de', sec. XIV
# Moggi, Moggio 1330?-1388
# Moggi, Moggio
# Moggio Moggi
# Moggi, Moggio, 14e eeuw
# Generating variations for Anselmi, Giorgio (Italian painter, 1723-1797). Existing count: 3
# Generating variations for Anselmi, Giorgio (Italian painter, 1723-1797). Existing count: 4
# Giorgio Anselmi piktor italian
# Anselmi, Giorgio (Itapian painter, 1723-1797)
# Anselmi, Giorgio
# Anselmi, Giorgio (Italian painter, 1723-1797)
# Anselmi, Giorgio (Italial paieter, 1723-1797)
# Carolus Aretinus, 1398-1453
# Carolus Marsuppini
# Marsuppini, Carolus 1398-1453
# Marsuppini, Carlo, 1399-1453
# Generating variations for Ramusio, Giovanni Battista. Existing count: 3
# Generating variations for Ramusio, Giovanni Battista. Existing count: 4
# Ramuzio, Giovanni Battista
# Ramusio, Giovanni Baptista 1485-1557
# Ramusio, Giovanni Battista
# Ramusio, Giovanni wattista
# Giovanni Battista Ramusio diplomatico, geografo e umanista italiano
# Generating variations for Girolamo Guarini. Existing count: 1
# Generating variations for Girolamo Guarini. Existing count: 2
# Generating variations for Girolamo Guarini. Existing count: 3
# Generating variations for Girolamo Guarini. Existing count: 4
# Generating variations for Girolamo Guarini. Existing count: 5
# Generating variations for Girolamo Guarini. Existing count: 6
# Girolauo puarini
# Girofamu Guarini
# Girolamo Guarini
# Giroaamo Guarini
# Girobamo Guarini
# nvrolamo Guarini
# firolamo Guarini
# Generating variations for Bagnoregio, Bonavontura van, 1221-1274. Existing count: 2
# Generating variations for Bagnoregio, Bonavontura van, 1221-1274. Existing count: 3
# Generating variations for Bagnoregio, Bonavontura van, 1221-1274. Existing count: 4
# Generating variations for Bagnoregio, Bonavontura van, 1221-1274. Existing count: 5
# Bagnoregio, Bouavontdra van, 1221-1274
# Bonaventura da Bagnoregio
# Baenoregio, Bonavontura van, 1221-1274
# Bagnoregio, Bonavoniura van, 1221-1274
# Bagnoreiio, Bonavontura van, 1221-1274
# Bagnoregio, Bonavontura van, 1221-1274
# Aldegati, Marco Antonio ca. 15. Jh.
# Marcantonio Aldegati
# Aldegati, Marcantonio
# Aldegati , Marcantonio
# Marcantonio Epicuro
# Caracciolo, Antonio, 1472-1555
# Marsi, Antonio
# Epicuro, Marcantonio
# Marsi, Antonio, 1472-1555
# Epicuro, Antonio, 1472-1555
# Crispus Mediolanensis
# Crispus Mediolanensis ca. 14. Jh.
# Crispus Mediolanensis diaconus (saec. XIV)
# Crispus Mediolanensis c. 14. C.
# Generating variations for Bonaiutus de Casentino. Existing count: 2
# Generating variations for Bonaiutus de Casentino. Existing count: 3
# Generating variations for Bonaiutus de Casentino. Existing count: 4
# Generating variations for Bonaiutus de Casentino. Existing count: 5
# Bonaiutuo de Casentino
# Bonaiutus de Casentind
# Bonaixtcs de Casentino
# Bonaiutus de Casentino
# Bonaiutus dq Casentino
# Bonaiutus de Casentino ca. 13./14. Jh.
# Generating variations for Gian Domenico Cancianini. Existing count: 3
# Generating variations for Gian Domenico Cancianini. Existing count: 4
# Gian Domenico sanciangni
# Gian Domenico Cancianini
# Cancianini, Gian Domenico, 1547-1630
# Gian Domenito Canciatini
# Cancianini, Gian Domenico 1547-1630
# Checco di Meletto Rossi, 1320-1363
# Checco Miletto de Rossi poète italien
# Rossi, Checco di Meletto 1320-1363
# Meletto Rossi, Checco di, 1320-1363
# Generating variations for Celio Calcagnini. Existing count: 3
# Generating variations for Celio Calcagnini. Existing count: 4
# Cnlio Caxcagnini
# Calcagninus, Caelius, 1479-1541
# Celio Calcagnini
# Calcagnini, Celio (Caelius), 1479-1541
# Celio balcagnini
# Filelfo, Francesco, 1398-1481
# Francesco Filelfo umanista e scrittore italiano (1398-1481)
# Filelfo, Francesco, 1398-1481.
# Filelfo, Francesco
# Philelpho, Franciscus, 1398-1481
# Philelphus, Franciscus, 1398-1481
# Generating variations for Crivelli, Angelo Maria -1730. Existing count: 2
# Generating variations for Crivelli, Angelo Maria -1730. Existing count: 3
# Generating variations for Crivelli, Angelo Maria -1730. Existing count: 3
# Generating variations for Crivelli, Angelo Maria -1730. Existing count: 4
# Generating variations for Crivelli, Angelo Maria -1730. Existing count: 5
# Crivelli, Angelo Maria -1730
# Crivekli, Angelo Maria -1730
# Crivelli, Angelo Mavia -1730
# Crivelli, Angelo Maria, 16..-1730
# Crivelli, fngelo Maria -1730
# Ctivelli, vngelo Maria -1730
# Chintila‏ Visigothorum Rex
# Chintila, King of the Visigoths, -640
# Chintila Westgotenreich, König -640
# Chintila, rex Visigothorum
# Chintila, Rey de los visigodos
# Generating variations for Rinaldo da Villafranca poeta, grammatico e umanista italiano. Existing count: 3
# Generating variations for Rinaldo da Villafranca poeta, grammatico e umanista italiano. Existing count: 4
# Rinaldo da Villafranca poeta, grammatico e umanwsta italiano
# Rinaldo da Villafranca poeta, grammatico e umanista italiano
# Renaldo da Villafranca poeta, grammatico e umanista italiano
# Cavalchini, Rinaldo 1290-1362
# Cavalchini, Rinaldo, c. 1291-1362
# Generating variations for Sulpicia, activité 1er siècle av. J.-C.. Existing count: 2
# Generating variations for Sulpicia, activité 1er siècle av. J.-C.. Existing count: 3
# Generating variations for Sulpicia, activité 1er siècle av. J.-C.. Existing count: 4
# Generating variations for Sulpicia, activité 1er siècle av. J.-C.. Existing count: 5
# Sulpicia 1. årh. f.Kr.
# Sulpicia, activité 1sr siècle av. J.-C.
# Sulpicia, activibé 1er siècle av. m.-C.
# Sulpicia, activiyé 1er siècze av. J.-C.
# Sulpicia, activité 1er siècle av. J.-C.
# Sutpicia, activité 1er siècle av. J.-C.
# Æþelbald"
# Aethelbald Mercia, König -757
# Aethelbald Mercia, -757
# Aethilwaldus, Aldhelmi discipulus, rex Merciae
# Tiberianus ca. 4.Jh.
# Tiberianus fl.4.Jh
# Tiberianus, 02..-03..
# Tiberianus, 4e eeuw
# Tiberianus 4e E
# Tiberianus, c. 4th century A.D.
# Generating variations for Filippo Cavallo. Existing count: 1
# Generating variations for Filippo Cavallo. Existing count: 2
# Generating variations for Filippo Cavallo. Existing count: 3
# Generating variations for Filippo Cavallo. Existing count: 4
# Generating variations for Filippo Cavallo. Existing count: 5
# Generating variations for Filippo Cavallo. Existing count: 6
# Generating variations for Filippo Cavallo. Existing count: 6
# Generating variations for Filippo Cavallo. Existing count: 6
# Fiuippo Cavallo
# Ficippo Cavallo
# Filtppo Cqvallo
# Filnppo Cavallo
# Filippo Cuvallo
# Fizippo Cavcllo
# Filippo Cavallo
# Generating variations for Benvenutus Campesanus. Existing count: 1
# Generating variations for Benvenutus Campesanus. Existing count: 2
# Generating variations for Benvenutus Campesanus. Existing count: 3
# Generating variations for Benvenutus Campesanus. Existing count: 4
# Generating variations for Benvenutus Campesanus. Existing count: 5
# Generating variations for Benvenutus Campesanus. Existing count: 6
# Bxnvenutus Campesanus
# Benvenutus Campesarus
# Benvenutus Campesanus
# Benvenutus Campesbnus
# Benvenutxs Campesanus
# Benvenudus Campesanus
# xenvenutus Campesanus
# Casa, Giovanni della, arciv. di Benevento, 1503-1556
# Giovanni Della Casa letterato, scrittore e arcivescovo cattolico italiano
# Della Casa, Giovanni
# Casa, Johannes 1503-1556
# Della Casa, Giovanni, arciv. di Benevento, 1503-1556
# Della Casa, Giovanni, 1503-1556
# Della Casa, Giovanni, 1503-1556.
# Generating variations for Acilius Glabrio, Marcus -95. Existing count: 1
# Generating variations for Acilius Glabrio, Marcus -95. Existing count: 1
# Generating variations for Acilius Glabrio, Marcus -95. Existing count: 2
# Generating variations for Acilius Glabrio, Marcus -95. Existing count: 3
# Generating variations for Acilius Glabrio, Marcus -95. Existing count: 4
# Generating variations for Acilius Glabrio, Marcus -95. Existing count: 5
# Generating variations for Acilius Glabrio, Marcus -95. Existing count: 6
# Acilcus Glabrio, Marcus -95
# Acilius Glabrio, Marcfs -95
# Acilius Glabrko, oarcus -95
# Acdlius Glabrio, Marcus -95
# ecilius Glabrio, Marcus -95
# Acilius Glabrio, Marcup -95
# Acilius Glabrio, Marcus -95
# Generating variations for Agrestius, Bischop. Existing count: 2
# Generating variations for Agrestius, Bischop. Existing count: 3
# Generating variations for Agrestius, Bischop. Existing count: 4
# Generating variations for Agrestius, Bischop. Existing count: 5
# Agredtius, Bischop
# Agredtius, Biscnop
# Agrestbus, Bischop
# Agrestius, Bischop
# Agrestius episcopus
# Agrestijs, Bischnp
# Generating variations for Drusus, C. None. Existing count: 2
# Generating variations for Drusus, C. None. Existing count: 3
# Generating variations for Drusus, C. None. Existing count: 4
# Generating variations for Drusus, C. None. Existing count: 5
# Drusus, e. Noje
# Drusys, C. None
# Drusus, C. None
# Drusus, C. eone
# Drusus, C.
# Druscs, C. None
# Generating variations for Aurelius Romulus lyricus. Existing count: 1
# Generating variations for Aurelius Romulus lyricus. Existing count: 2
# Generating variations for Aurelius Romulus lyricus. Existing count: 3
# Generating variations for Aurelius Romulus lyricus. Existing count: 4
# Generating variations for Aurelius Romulus lyricus. Existing count: 5
# Generating variations for Aurelius Romulus lyricus. Existing count: 6
# Aurelius Romulus lyricus
# Aurelius Rotulus lyricus
# Axrelius Romulus lyricgs
# Aurelrus Romulus lyricus
# murelius Romulus lyricus
# Aurelius Rxmulus lyricus
# Aurelbus Romulus lyricus
# Uberto Foglietta
# Folieta, Ubertus (Uberto), 1518-1581
# Foglietta, Uberto
# Foglietta, Uberto, 1518-1581
# Hosidius Geta ca. 2nd century
# Hosidius Geta, 2e eeuw
# Hosidius Geta, 01..-02..
# Hosidius Geta.
# Generating variations for Vespa poète romain. Existing count: 3
# Generating variations for Vespa poète romain. Existing count: 4
# Vespa poète romain
# Vespn poète romain
# Vespa 2./4. Jh. n. Chr
# Vespa pojte romain
# Vespa 2nd/4. century
# Lindinus Poeta 5th or 5th/6th century
# Lindinus
# Lindinus Poeta
# Lindinus Poeta 5. bzw. 5./6. Jh.
# Lollius Urbicus ca. 3rd century
# Urbicus Lollius
# Lollius Urbicus ca. 3. Jh.
# Lollius Urbicus
# Leonardo Massa Marittima, Bischof 1408-1472
# Dati, Leonardo
# Leonardo Dati poeta italianu
# Dati, Leonardo, 1407-1472
# Dati, Leonardo, vesc. di Massa, 1408-1472
# Leonardus 1408-1472 Datus
# Abbo Metensis ca. 627 - 643
# Goerik Metský biskup a světec
# Abbo Metensis ca. 627 – 643
# Abbo Metensis ca. ca. 627 - 643
# Abbo Metensis
# Generating variations for Stephanus Abbas. Existing count: 2
# Generating variations for Stephanus Abbas. Existing count: 3
# Generating variations for Stephanus Abbas. Existing count: 4
# Generating variations for Stephanus Abbas. Existing count: 5
# Stephanus Abbas
# Stephanus Abbas 4. or 6th century
# Stepoanus Avbas
# Steghanus Abbas
# Stephanus zbbfs
# Stephsnus Abbas
# Generating variations for Avitus Gallonius None. Existing count: 2
# Generating variations for Avitus Gallonius None. Existing count: 3
# Generating variations for Avitus Gallonius None. Existing count: 4
# Generating variations for Avitus Gallonius None. Existing count: 5
# Avitus Gallonius done
# Gallonius Avitus
# Avitus Gallonius Note
# Avitus Gazlonius None
# Avitus Galtonius Noxe
# Avitus Gallonius None
# Foscolo, Ugo, 1778-1827
# Foscolo, Ugo (Niccolò Ugo), 1778-1827
# Foscolo, Ugo
# Ugo Foscolo poeta, scrittore, drammaturgo, traduttore e critico letterario italiano (1778-1827)
# Fóscolo, Ugo, 1778-1827
# Generating variations for Sempronius Tuditanus, Gaius. Existing count: 2
# Generating variations for Sempronius Tuditanus, Gaius. Existing count: 3
# Generating variations for Sempronius Tuditanus, Gaius. Existing count: 4
# Generating variations for Sempronius Tuditanus, Gaius. Existing count: 5
# Generating variations for Sempronius Tuditanus, Gaius. Existing count: 5
# Generating variations for Sempronius Tuditanus, Gaius. Existing count: 5
# Sempronius Tuditanus, Gaius um 129 v. Chr
# Sompronius Tuditanus, Gaius
# Semprozius Tuddtanus, Gaius
# Sempronius Tuditanus, Gaiuw
# Sempronius Tuditanus, Gaius
# oempronius Tuditanus, Gaius
# Generating variations for Sanctus Eutropius Abbas et Episcopus. Existing count: 1
# Generating variations for Sanctus Eutropius Abbas et Episcopus. Existing count: 2
# Generating variations for Sanctus Eutropius Abbas et Episcopus. Existing count: 3
# Generating variations for Sanctus Eutropius Abbas et Episcopus. Existing count: 4
# ...
# Kkumbiegel, Richard 1867-
# Krusbiegel, dichard 1867-
# Krumbiegel, Ricardus (Richard), 1867-
# Künstle, Karl
# Künstle, Karl, 1859-1932
# K©ơnstle, Karl, 1859-1932
# Karl Künstle Professor für Patristik und Kirchengeschichte
# Künstle, Karl, 1859-1932
# Kuun, G©♭za Lajos L©Łszl©đ J©đzsef, gr©đf, 1838-1905
# Kuun, Géza, 1838-1905
# Kuun Géza (1838-1905) magyar nyelvész, filológus, orientalista
# Kuun, Géza, 1838-1905
# Kuun, Géza
# Loewe, Gustav
# Gustav Löwe deutscher Klassischer Philologe und Bibliothekar
# Löwe, Gustav (1852-1883).
# Löwe, Gustav, 1852-1883
# Loewe, Gustav, 1852-1883
# Generating variations for Magnus. Existing count: 3
# Generating variations for Magnus. Existing count: 4
# Magnus
# Anus
# Magnus, Hugo
# Mugjus
# Hugo Magnus
# Generating variations for Manitius, Max. Existing count: 3
# Generating variations for Manitius, Max. Existing count: 4
# Manitius, Max
# Max Manitius deutscher Historiker
# Minitius, Max
# Manitdus, Max
# Manitius, Maximilianus, 1858-1933
# Generating variations for Mekler, Siegfried, 1852-1912. Existing count: 3
# Generating variations for Mekler, Siegfried, 1852-1912. Existing count: 4
# wekler, Siegfried, 1852-1912
# Mekler, Siegfried
# Mekler, Siegfried, 1852-1912
# Siegfried Mekler
# Mekler, Siegfkied, 1852-1912
# Menge, Hermann, 1841-1916
# Menge, Hermann 1841-1916
# Menge, Heinrich, (1838- ).
# Heinrich Menge
# Menge, Henricus
# Menge, Heinrich
# Menge, Heinrich 1838-19..
# Generating variations for Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge. Existing count: 1
# Generating variations for Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge. Existing count: 2
# Generating variations for Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge. Existing count: 3
# Generating variations for Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge. Existing count: 4
# Generating variations for Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge. Existing count: 5
# Generating variations for Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge. Existing count: 5
# Generating variations for Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge. Existing count: 5
# Generating variations for Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge. Existing count: 6
# Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr iy Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge
# Wolfgang Meurer Dt. Pädagoge und Mediginer; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prxf. med. an der Univ. Leipzig Arzt, Pädagoge
# Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; oonrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge
# Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaisehule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge
# Wolfgang Meurer Dt. Pädhgoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge
# Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor der Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge
# Wolfgang Meurer Dt. Pädagoge und Mediziner; Student in Leipzig; Konrektor der Thomasschule und 1535-1540 Rektor dir Nikolaischule in Leipzig; 1549 Dr. med.; 1570 Stadtphysikus und Ratsherr in Leipzig: 1571 Prof. med. an der Univ. Leipzig Arzt, Pädagoge
# Generating variations for Meyer, Wilhelm, De Speyer. Existing count: 3
# Generating variations for Meyer, Wilhelm, De Speyer. Existing count: 3
# Generating variations for Meyer, Wilhelm, De Speyer. Existing count: 4
# Meyer, Wilhelm, me Speyer
# Meyer, Wilhelm, De Speyer
# Meyer, Wilnelm, De Speyer
# Wilhelm Meyer
# Meyer, Wilhelm
# Generating variations for Monet, Pascal, 18..-19.., professeur. Existing count: 3
# Generating variations for Monet, Pascal, 18..-19.., professeur. Existing count: 4
# Generating variations for Monet, Pascal, 18..-19.., professeur. Existing count: 4
# Monet, Pascal, 18..-19.., profesfeur
# Monet, Pascal, 18..-19.., professeur
# Monet, Pascal, 18..-19.., profezseur
# Monet, Pascal.
# Monet, Pascal
# Generating variations for Moser, Georg Heinrich. Existing count: 3
# Generating variations for Moser, Georg Heinrich. Existing count: 4
# Moser, Georg Heinrich, 1780-1858, philologue
# Georg Heinrich Moser
# Moser, neorg Heinrich
# Moser, Georg Heinrich
# Mqser, Georg Hemnrich
# Generating variations for Mueller, Otto 1833-. Existing count: 2
# Generating variations for Mueller, Otto 1833-. Existing count: 2
# Generating variations for Mueller, Otto 1833-. Existing count: 3
# Generating variations for Mueller, Otto 1833-. Existing count: 4
# Generating variations for Mueller, Otto 1833-. Existing count: 5
# Mueller, qtto 1833-
# Muellnr, Otto 1833-
# Mjeller, Otto 1833-
# Mueller, Otto 1833-
# Mueeler, Otto 1833-
# Mueller, Otto, 1833-
# Nauck, G.C.
# Nauck, Johann August, 1822-1892
# Nauck, August
# Nauck, A. 1822-1892 August
# Nauck, August (Johann August), 1822-1892
# August Nauck deutscher Klassischer Philologe
# Nissen, Theodor (Theodorus Karl Johannes), 1873-
# Theodor Nissen
# Nissen, Theodor Karl Johannes 1873-1946
# Nissen, Theodor Karl Johannes
# Nissen, Theodor
# Nissen, Theodor Karl Johannes, 1873-....
# Generating variations for Onions, J.H.. Existing count: 3
# Generating variations for Onions, J.H.. Existing count: 4
# Onihns, J.H.
# Onions, J.H.
# John Henry Onions
# vnions, J.H.
# Onions, John Henry
# Owen, S.G.
# Owen, Sidney George, 1858-
# Owen, Sidney George, 1858-1940
# Owen, S. G. (Sidney George), 1858-
# Owen, S. G. (Sidney George), b. 1858
# Owen, S. G. 1858-1940
# Owen, Sidney G. 1858-1940
# Peter, H. 1837-1914 Hermann
# Peter, Hermann
# Hermann Peter
# Peter, Hermann Wilhelm Gottlob, 1837-1914
# Peterson, William, Sir, 1856-1921
# Peterson, W.
# Peterson, William (1856- )
# Peterson, William, 1856-1921, latiniste
# Peterson, William, classicus, 1856-1921
# William Peterson érudit classique
# Generating variations for Polle, Friedrich. Existing count: 3
# Generating variations for Polle, Friedrich. Existing count: 4
# Polle, Friedrich
# Polle, yriedrich
# Polle, Konrad Friedrich, 1830-1902
# Friedrich Polle deutsche Sprachwissenschaftler, Klassischer Philologe und Gymnasiallehrer
# Polle, Frieprich
# Generating variations for Hugo Rabe deutscher Klassischer Philologe. Existing count: 2
# Generating variations for Hugo Rabe deutscher Klassischer Philologe. Existing count: 2
# Generating variations for Hugo Rabe deutscher Klassischer Philologe. Existing count: 3
# Generating variations for Hugo Rabe deutscher Klassischer Philologe. Existing count: 4
# Generating variations for Hugo Rabe deutscher Klassischer Philologe. Existing count: 5
# Hugo Rabe deutscher Klassischer Philologe
# Hugc Rabe deutscher Klassischer Philologe
# Hugo Rabe deutscher Klasrischer Philologe
# Rabe, Hugo, 1867-1932, helléniste
# Hugo Rabe deutscher Klassisceer Philologe
# Hugo Rabe deutsgher mlassischer Philologe
# Generating variations for Martin Ludwig Radermacher. Existing count: 2
# Generating variations for Martin Ludwig Radermacher. Existing count: 3
# Generating variations for Martin Ludwig Radermacher. Existing count: 4
# Generating variations for Martin Ludwig Radermacher. Existing count: 5
# Martin Luowig Radermacher
# Martin Lpdwig Radermccher
# Martin Lrdwig Radermacter
# Radermacher, Ludwig
# Martin Ludwig Radermacher
# Martin Ludwig Raderxacher
# Ramorino, Felice
# Ramorino, Felice, 1852-?
# Ramorino, Felice, 1852-1929
# Felice Ramorino
# Hanke, Friedrich
# Ranke, Friedrich
# Friedrich Ranke
# Ranke, F. (Gotthilf Johann Friedrich), 1882-1950
# Generating variations for Reisch, Emil. Existing count: 2
# Generating variations for Reisch, Emil. Existing count: 3
# Generating variations for Reisch, Emil. Existing count: 4
# Generating variations for Reisch, Emil. Existing count: 5
# Reisck, Emil
# Reisch, Emil
# Reisch, Emib
# oeiscb, Emil
# Rjisch, Emil
# Emil Reisch
# Ritter, Constantin
# Constantin Ritter
# Ritter, Constantin, 1859-1936.
# Ritter, Constantin, 1859-1936
# Roehl, Hermann, 1851-
# Röhl, Hermann, 1851-1923
# Roehl, Hermann
# Hermann Röhl deutsch-russischer Übersetzer
# Röhl, Hermann, 1851-....
# Röhl, Hermann, 1851-1923
# Karl Friedrich Scheibe deutscher Klassischer Philologe und Gymnasialdirektor
# Scheibe, Karl Friedrich, 1812-1869, philologue
# Scheibe, Karl Friedrich
# Scheibe, Karl
# Generating variations for Schermann, Theodor. Existing count: 2
# Generating variations for Schermann, Theodor. Existing count: 3
# Generating variations for Schermann, Theodor. Existing count: 4
# Generating variations for Schermann, Theodor. Existing count: 5
# Scherzann, Themdor
# Schermann, Theodoq
# Sczermann, Tkeodor
# Theodor Schermann
# Schermann, Theodor
# hchermacn, Theodor
# Friedrich Schlee
# Schlee, Friedrich H., 1854-1913
# Schlee, Friedrich H.
# Schlee, Friedrich
# Schmid, Frdr. E. Theod.
# Schmidius, Th
# Schmid, Friedrich Ernst Theodor, 1798-1877
# Theodor Schmid deutscher Klassischer Philologe und Gymnasiallehrer
# Generating variations for Heinrich Friedrich Wilhelm Schmidt. Existing count: 1
# Generating variations for Heinrich Friedrich Wilhelm Schmidt. Existing count: 2
# Generating variations for Heinrich Friedrich Wilhelm Schmidt. Existing count: 3
# Generating variations for Heinrich Friedrich Wilhelm Schmidt. Existing count: 4
# Generating variations for Heinrich Friedrich Wilhelm Schmidt. Existing count: 5
# Generating variations for Heinrich Friedrich Wilhelm Schmidt. Existing count: 6
# Heinrich Friedrich Wilhelm Snhmidt
# Heinrich Friedrich Wilhelm Schmidt
# Heinrich Fmiedrich Wilhelm Schmidt
# Heinrich Friedrich Wglhelm Schpidt
# Heinrich Friedrich Wilhelm Scxmidt
# Heinriah Friedrich Wflhelm Schmidt
# Heinrich Friedrich Wilhelm Schmiet
# Schubart, Wilhelm, 1873-
# Schubart, Wilhelm
# Schubart, W.
# Schubart, W. (Wilhelm), 1873-1960
# Wilhelm Schubart
# Siebelis, Johannes
# Siebelis, Johannes, 1817-1867
# Johannes Siebelis German classical philologist and teacher (1817-1867)
# Siebelis, Johannes, 1817-1867.
# Siebelis, J. 1817-1867 Johannes
# Sittl, Carl
# Sittl, Karl
# Karl Sittl deutscher Altphilologe und Klassischer Archäologe
# Karl Sittl
# Swoboda, Anton
# Swoboda, Anton 1865-1928
# Swoboda, Antonius
# Anton Swoboda
# Thulin, Carl Olof, 1871-1921
# Thulin, C. (Carl Alof), 1871-1921
# Thulin, Carolus, 1871-1921
# Carl Thulin schwedischer Klassischer Philologe und Religionswissenschaftler
# Generating variations for Türk, Gustav. Existing count: 2
# Generating variations for Türk, Gustav. Existing count: 3
# Generating variations for Türk, Gustav. Existing count: 4
# Generating variations for Türk, Gustav. Existing count: 5
# Generating variations for Türk, Gustav. Existing count: 5
# Generating variations for Türk, Gustav. Existing count: 5
# Tz̈rk, Gusjav
# Türk, Guuaav
# Türk, Gustav, 1870-1914
# Türk, Gustav
# Tp̈rk, Gustaf
# Türk, Grstav
# Usener, Hermann (Hermann Karl), 1834-1905
# Hermann Usener deutscher Klassischer Philologe und Religionswissenschaftler
# Usener, Hermann
# Usener, Hermann Karl, 1834-1905
# Hermann Carl Usener
# Usener, Hermannus, 1834-1905
# Theodor Vogel deutscher Klassischer Philologe und Gymnasiallehrer
# Vogel, Theodor, 1836-1912,
# Vogel, Theodor
# Vogel, Theodor, 1836-1912
# Theodor Vogel
# Vogel, Theodorus, 1838-
# Vogel, Theodorus (1836-1912).
# Vollgraff, Johann Christoph, 1848-1920
# Johannes Christoph Vollgraff
# Vollgraff, J. C. (Johann Christoph), 1848-1920
# Vollgraff, J.C. (Johann Christoph), 1848-1920
# Vollgraff, Johann Christoph
# Waltzing, J. P.
# Waltzing, Jean Pierre, 1857-1929
# Waltzing, Jean-Pierre, 1857-1929
# Waltzing, Jean-Pierre
# Jean-Pierre Waltzing
# Weber, Ernst, 1873
# Weber, Ernst.
# Weber, Ernestus
# Weber, Ernestus, 1863-
# Generating variations for Weil, Henri. Existing count: 3
# Generating variations for Weil, Henri. Existing count: 4
# Generating variations for Weil, Henri. Existing count: 4
# Heinrich Weil
# Weiu, Henri
# Weil, Henri
# Weil, H. (Henri), 1818-1909
# Weil, Hpfri
# Generating variations for Wesenberg, Albert Sadolin. Existing count: 3
# Generating variations for Wesenberg, Albert Sadolin. Existing count: 4
# Albert Sadolin Wesenberg
# Wesenberg, Albert Sadolin
# Wesenbdrg, Albert Sadolin
# Wesenberg, Albertus Sadolinus, 1804-1876
# Wesenberg, Albert qadolic
# Zangemeister, Carl
# Zangemeister, Karl, 1837-1902
# Karl Zangemeister deutscher Bibliothekar und klassischer Philologe
# Zangemeister, Karl Friedrich Wilhelm
# Zangemeister, Karl
# Karl Zangemeister
# Generating variations for Franciscus Ruehl. Existing count: 1
# Generating variations for Franciscus Ruehl. Existing count: 2
# Generating variations for Franciscus Ruehl. Existing count: 3
# Generating variations for Franciscus Ruehl. Existing count: 4
# Generating variations for Franciscus Ruehl. Existing count: 5
# Generating variations for Franciscus Ruehl. Existing count: 6
# Francpscus Ruehl
# Franciscus Ruehl
# Flanciscus Ruehl
# Francmscus Ruehl
# Frmncrscus Ruehl
# Franciscus Rueil
# yranciscus Raehl
# Kurfess, Alphons (1889- )
# Alfons Kurfess
# Kurfess, Alfons
# Kurfess, Alfons, 1889-
# Kurfess, Alphons
# Kurfess, Alfons (Alphonsus), 1889-
# Ahlberg, Axel W.
# Ahlberg, Axel Wilhelm
# Axel W. Ahlberg
# Ahlberg, Axel Wilhelm, 1874-1951
# Ahlberg, A. W.
# Ahlberg, Axel W., 1874-1951
# Generating variations for Leo, Friedrich. Existing count: 3
# Generating variations for Leo, Friedrich. Existing count: 4
# Leo, Friedkich
# Leo, Friedrich
# Leo, Friedrich August, 1851-1914
# Friedrich Leo
# Lko, Friedrich
#                                            author dll_author_id
# 0                             A. Cornelius Celsus         A5349
# 1                               Aage von Dänemark         A4246
# 2                      Aagesen, Svend, n. c. 1130         A4448
# 3      Ab Almeloveen, Theodoor Jansson, 1657-1712         A6040
# 4                       Abaelard, Peter 1079-1142         A5015
# ...                                           ...           ...
# 34866                              Leo, Friedkich         A6296
# 34867                              Leo, Friedrich         A6296
# 34868            Leo, Friedrich August, 1851-1914         A6296
# 34869                               Friedrich Leo         A6296
# 34870                              Lko, Friedrich         A6296
#
# [34871 rows x 2 columns]

# %%
# Check the result
augmented_value_counts = df_extended['dll_author_id'].value_counts()
print(augmented_value_counts)

extended_author = df_extended[df_extended['dll_author_id'] == 'A4536']
print(extended_author)
# Out:
# dll_author_id
# A4644    38
# A4379    35
# A4322    35
# A5377    35
# A4830    34
#          ..
# A3225     8
# A3754     8
# A6293     8
# A4181     8
# A3749     8
# Name: count, Length: 3137, dtype: int64
#                                                   author dll_author_id
# 4226   Burginda Burginda (fl. 7th–early 8th cent.), a...         A4536
# 4227                                 Burginda ca. um 700         A4536
# 30389  Burginda Burginda (fl. 7th–early 8th ceni.), a...         A4536
# 30390  Burginda Burginda (fl. 7th–early 8th cent.), a...         A4536
# 30391                                Burginda ca. um 700         A4536
# 30392  Burginda Burgznda (fl. 7th–early 8th cent.), a...         A4536
# 30393  Burginda Burginda (fl. 7th–eawly 8th cent.), a...         A4536
# 30394  Burginda Burginda (fl. 7th–early 8th cent.), a...         A4536

# %%
len(df_extended)
# Out:
# 34871

# %%
# Save it to a CSV
df_extended.to_csv('output/extended_augmented_all_names_deduplicated.csv', index=False)
