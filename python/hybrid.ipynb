# %% [markdown]
# # Hybrid Matching

# %% [markdown]
# ## Step 1: Prepare the Data
#
# The data has already been preprocessed in the `data-preparation.ipynb` notebook. Now it needs to be loaded here and converted into the lookup dictionaries that will be used for the deterministic matching routine.

# %%
# Import the Pandas library for working with CSV data
import pandas as pd

# Read in the authors data
authors = pd.read_csv('../data/authors_db.csv',encoding='utf-8',quotechar='"')
# Read in the works data
works = pd.read_csv('../data/works_db.csv',encoding='utf-8',quotechar='"')

# Get basic information about the dataframes
authors.info()
works.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27290 entries, 0 to 27289
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Variant                  27290 non-null  object
#  1   Authorized Name          27290 non-null  object
#  2   DLL Identifier (Author)  27290 non-null  object
# dtypes: object(3)
# memory usage: 639.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5315 entries, 0 to 5314
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Title                    5315 non-null   object
#  1   DLL Identifier (Work)    5315 non-null   object
#  2   DLL Identifier (Author)  5315 non-null   object
# dtypes: object(3)
# memory usage: 124.7+ KB

# %%
# Change the names of the columns to be lower case without spaces or punctuation
authors = authors.rename(columns={'Variant':'variant_name','Authorized Name':'authorized_name','DLL Identifier (Author)':'dll_id_author'})
works = works.rename(columns={'Title':'title','DLL Identifier (Work)':'dll_id_work','DLL Identifier (Author)': 'dll_id_author'})

# %%
import re

def normalize_author_name(name):
    """Normalize author names for consistent matching."""
    # Convert to lowercase, strip whitespace, and remove non-alphanumeric characters (except spaces)
    normalized_name = re.sub(r"[^\w\s]", "", name.lower().strip())
    return re.sub(r"\s+", " ", normalized_name)  # Normalize multiple spaces

# %%
# Prepare the lookup dictionary of variant author names
variant_to_authorized = {
    normalize_author_name(row["variant_name"]): {
        "authorized_name": row["authorized_name"], 
        "author_id": row["dll_id_author"]
    }
    for _, row in authors.iterrows()
}

variant_to_authorized
# Out:
# {'herryson joannes floruit15th century ad': {'authorized_name': 'herryson, joannes',
#   'author_id': 'A1868'},
#  'joannes herryson': {'authorized_name': 'herryson, joannes',
#   'author_id': 'A1868'},
#  'john herryson': {'authorized_name': 'herryson, joannes',
#   'author_id': 'A1868'},
#  'heryyson joannes floruit15th century ad': {'authorized_name': 'herryson, joannes',
#   'author_id': 'A1868'},
#  'herryson xoannes floruit15th century ad': {'authorized_name': 'herryson, joannes',
#   'author_id': 'A1868'},
#  'johannes stratford': {'authorized_name': 'stratford, john, -1348',
#   'author_id': 'A1870'},
#  'john stratford': {'authorized_name': 'stratford, john, -1348',
#   'author_id': 'A1870'},
#  'john stratford 12751348': {'authorized_name': 'stratford, john, -1348',
#   'author_id': 'A1870'},
#  'stratford johannes ca 12751348': {'authorized_name': 'stratford, john, -1348',
#   'author_id': 'A1870'},
#  'stratford john ca 12751348': {'authorized_name': 'stratford, john, -1348',
#   'author_id': 'A1870'},
#  'stratford john m 1348': {'authorized_name': 'stratford, john, -1348',
#   'author_id': 'A1870'},
#  'nicomac de gerasa actiu segle i': {'authorized_name': 'nicomachus, of gerasa',
#   'author_id': 'A2181'},
#  'nicomachus of gerasa': {'authorized_name': 'nicomachus, of gerasa',
#   'author_id': 'A2181'},
#  'nicomac de gerasa actiz segle i': {'authorized_name': 'nicomachus, of gerasa',
#   'author_id': 'A2181'},
#  'nicomac dn gerasa actiu segle i': {'authorized_name': 'nicomachus, of gerasa',
#   'author_id': 'A2181'},
#  'nicomac de gerasz actiu segle i': {'authorized_name': 'nicomachus, of gerasa',
#   'author_id': 'A2181'},
#  'nicomac de gerasa pctiu segle i': {'authorized_name': 'nicomachus, of gerasa',
#   'author_id': 'A2181'},
#  'abu alʿabbas alfadl ibn hatim nayrizi': {'authorized_name': 'anaritius, -approximately 922',
#   'author_id': 'A2491'},
#  'abulabbas al fadl ibn hatim alnayrizi 865około 922': {'authorized_name': 'anaritius, -approximately 922',
#   'author_id': 'A2491'},
#  'alnayrizi alfadl b hatim': {'authorized_name': 'anaritius, -approximately 922',
#   'author_id': 'A2491'},
#  'anaritius': {'authorized_name': 'anaritius, -approximately 922',
#   'author_id': 'A2491'},
#  'anaritius d ca 922': {'authorized_name': 'anaritius, -approximately 922',
#   'author_id': 'A2491'},
#  'anaritius m c 922': {'authorized_name': 'anaritius, -approximately 922',
#   'author_id': 'A2491'},
#  'nairizi alfadl ibnhatim an 922': {'authorized_name': 'anaritius, -approximately 922',
#   'author_id': 'A2491'},
#  'nayrizi abuʾl ʾabbas alfadl ibn hatim 865922': {'authorized_name': 'anaritius, -approximately 922',
#   'author_id': 'A2491'},
#  'nayrizi alfadl b hatim al abu alʿabbas alfadl b hatim ca 897922': {'authorized_name': 'anaritius, -approximately 922',
#   'author_id': 'A2491'},
#  'nayrizi alfadl ibn hatim abu alʿabbas al 08970922': {'authorized_name': 'anaritius, -approximately 922',
#   'author_id': 'A2491'},
#  'nayrizi alfadl ibnhatim an abu alabbas al ca 897ca 922': {'authorized_name': 'anaritius, -approximately 922',
#   'author_id': 'A2491'},
#  'karl strecker': {'authorized_name': 'strecker, karl, 1861-1945',
#   'author_id': 'A2492'},
#  'strecker karl': {'authorized_name': 'strecker, karl, 1861-1945',
#   'author_id': 'A2492'},
#  'strecker karl 18611945': {'authorized_name': 'strecker, karl, 1861-1945',
#   'author_id': 'A2492'},
#  'johann georg simon': {'authorized_name': 'simon, johann georg, approximately 1636-1696',
#   'author_id': 'A2493'},
#  'simon johann georg': {'authorized_name': 'simon, johann georg, approximately 1636-1696',
#   'author_id': 'A2493'},
#  'simon johann georg ca 16361696': {'authorized_name': 'simon, johann georg, approximately 1636-1696',
#   'author_id': 'A2493'},
#  'simon johann georg 16361696': {'authorized_name': 'simon, johann georg, approximately 1636-1696',
#   'author_id': 'A2493'},
#  'giovanni giacomo komarek': {'authorized_name': 'komarek, giovanni giacomo, 1648-1706',
#   'author_id': 'A2494'},
#  'komarek giovanni giacomo': {'authorized_name': 'komarek, giovanni giacomo, 1648-1706',
#   'author_id': 'A2494'},
#  'komarek giovanni giacomo 16501705': {'authorized_name': 'komarek, giovanni giacomo, 1648-1706',
#   'author_id': 'A2494'},
#  'komarek giovanni giacomo 1617 libraire': {'authorized_name': 'komarek, giovanni giacomo, 1648-1706',
#   'author_id': 'A2494'},
#  'komarek giovanni giacomo fl 16881712': {'authorized_name': 'komarek, giovanni giacomo, 1648-1706',
#   'author_id': 'A2494'},
#  'komarek jan jakub asi 16501706': {'authorized_name': 'komarek, giovanni giacomo, 1648-1706',
#   'author_id': 'A2494'},
#  'komarek johann jacob 1650c1706': {'authorized_name': 'komarek, giovanni giacomo, 1648-1706',
#   'author_id': 'A2494'},
#  'komarek johann jacob': {'authorized_name': 'komarek, giovanni giacomo, 1648-1706',
#   'author_id': 'A2494'},
#  'francois prechac agrege des lettres membre de lecole francaise de rome 19061908': {'authorized_name': 'préchac, françois',
#   'author_id': 'A2495'},
#  'prchac franʹois 18811977': {'authorized_name': 'préchac, françois',
#   'author_id': 'A2495'},
#  'prechac francois': {'authorized_name': 'préchac, françois',
#   'author_id': 'A2495'},
#  'prechac francois 1881': {'authorized_name': 'préchac, françois',
#   'author_id': 'A2495'},
#  'prechac francois 18811977': {'authorized_name': 'préchac, françois',
#   'author_id': 'A2495'},
#  'ignace 077508 metropolite de nicee': {'authorized_name': 'ignatios, the deacon, approximately 775-approximately 848',
#   'author_id': 'A2508'},
#  'ignatios ca 775ca 848 the deacon': {'authorized_name': 'ignatios, the deacon, approximately 775-approximately 848',
#   'author_id': 'A2508'},
#  'ignatios diakonos asi 775asi 848': {'authorized_name': 'ignatios, the deacon, approximately 775-approximately 848',
#   'author_id': 'A2508'},
#  'ignatios diakon ca 775ca 848': {'authorized_name': 'ignatios, the deacon, approximately 775-approximately 848',
#   'author_id': 'A2508'},
#  'ignatios the deacon ca 775ca 848': {'authorized_name': 'ignatios, the deacon, approximately 775-approximately 848',
#   'author_id': 'A2508'},
#  'ignatius diaconus biskop av nicaea': {'authorized_name': 'ignatios, the deacon, approximately 775-approximately 848',
#   'author_id': 'A2508'},
#  'ignatius diaconus': {'authorized_name': 'ignatios, the deacon, approximately 775-approximately 848',
#   'author_id': 'A2508'},
#  'ignatius diaconus constantinopolitanus': {'authorized_name': 'ignatios, the deacon, approximately 775-approximately 848',
#   'author_id': 'A2508'},
#  'ignatius diaconus archbishop of nicaea 9th century': {'authorized_name': 'ignatios, the deacon, approximately 775-approximately 848',
#   'author_id': 'A2508'},
#  'alberico da marcellise 13401398': {'authorized_name': 'alberico da marcellise',
#   'author_id': 'A2755'},
#  'alberico da marceulise 13401398': {'authorized_name': 'alberico da marcellise',
#   'author_id': 'A2755'},
#  'rlberict da marcellise 13401398': {'authorized_name': 'alberico da marcellise',
#   'author_id': 'A2755'},
#  'albericq df marcellise 13401398': {'authorized_name': 'alberico da marcellise',
#   'author_id': 'A2755'},
#  'albsrico da marcellise 13401398': {'authorized_name': 'alberico da marcellise',
#   'author_id': 'A2755'},
#  'albeiico da farcellise 13401398': {'authorized_name': 'alberico da marcellise',
#   'author_id': 'A2755'},
#  'alberico ga marcellise 13401398': {'authorized_name': 'alberico da marcellise',
#   'author_id': 'A2755'},
#  'aquilius niger quintus': {'authorized_name': 'aquilius niger, quintus',
#   'author_id': 'A2868'},
#  'quintus aquilius niger': {'authorized_name': 'aquilius niger, quintus',
#   'author_id': 'A2868'},
#  'aquilius niger puintus': {'authorized_name': 'aquilius niger, quintus',
#   'author_id': 'A2868'},
#  'aquilibl niger quintus': {'authorized_name': 'aquilius niger, quintus',
#   'author_id': 'A2868'},
#  'aquilius niqer quxntus': {'authorized_name': 'aquilius niger, quintus',
#   'author_id': 'A2868'},
#  'aquilbus nimer quintus': {'authorized_name': 'aquilius niger, quintus',
#   'author_id': 'A2868'},
#  'julianus salvius': {'authorized_name': 'salvius julianus',
#   'author_id': 'A2870'},
#  'lucius octavius cornelius publius salvius iulianus aemilianus': {'authorized_name': 'salvius julianus',
#   'author_id': 'A2870'},
#  'salvio juliano': {'authorized_name': 'salvius julianus',
#   'author_id': 'A2870'},
#  'salvius iulianus': {'authorized_name': 'salvius julianus',
#   'author_id': 'A2870'},
#  'salvius iulianus aemilianus lucius octavius ca 2 jh': {'authorized_name': 'salvius julianus',
#   'author_id': 'A2870'},
#  'salvius julianus 01000169': {'authorized_name': 'salvius julianus',
#   'author_id': 'A2870'},
#  'm claudius mfmn marcellus': {'authorized_name': 'marcellus, marcus claudius, -45 b.c.',
#   'author_id': 'A2871'},
#  'marcellus marcus claudius 45 ekr': {'authorized_name': 'marcellus, marcus claudius, -45 b.c.',
#   'author_id': 'A2871'},
#  'marcellus marcus claudius m 45 av jc': {'authorized_name': 'marcellus, marcus claudius, -45 b.c.',
#   'author_id': 'A2871'},
#  'marcus claudius marcellus': {'authorized_name': 'marcellus, marcus claudius, -45 b.c.',
#   'author_id': 'A2871'},
#  'lentulus spinther publius cornelius ca v43': {'authorized_name': 'lentulus spinther, publius cornelius, born c. 43 b.c.',
#   'author_id': 'A2872'},
#  'lentulus spinther publius cornelius born c 43 bc': {'authorized_name': 'lentulus spinther, publius cornelius, born c. 43 b.c.',
#   'author_id': 'A2872'},
#  'publius cornelius lentulus spinther': {'authorized_name': 'lentulus spinther, publius cornelius, born c. 43 b.c.',
#   'author_id': 'A2872'},
#  'lentulus spinther pjblius cornelius ca v43': {'authorized_name': 'lentulus spinther, publius cornelius, born c. 43 b.c.',
#   'author_id': 'A2872'},
#  'lentulus spinther publius ckrnelius ca v43': {'authorized_name': 'lentulus spinther, publius cornelius, born c. 43 b.c.',
#   'author_id': 'A2872'},
#  'saturninus claudius': {'authorized_name': 'saturninus, claudius, active 2nd century a.d.',
#   'author_id': 'A2873'},
#  'saturninus claudius 2 jh': {'authorized_name': 'saturninus, claudius, active 2nd century a.d.',
#   'author_id': 'A2873'},
#  'saturninus claudius active 2nd century ad': {'authorized_name': 'saturninus, claudius, active 2nd century a.d.',
#   'author_id': 'A2873'},
#  'satdrninus claudius active 2nd century ad': {'authorized_name': 'saturninus, claudius, active 2nd century a.d.',
#   'author_id': 'A2873'},
#  'saturninus claudius active 2nz century ad': {'authorized_name': 'saturninus, claudius, active 2nd century a.d.',
#   'author_id': 'A2873'},
#  'metellus quintus caecilius nepos v56': {'authorized_name': 'metellus, quintus caecilius nepos, -56',
#   'author_id': 'A2874'},
#  'metellus quintus caecilius nepos 56': {'authorized_name': 'metellus, quintus caecilius nepos, -56',
#   'author_id': 'A2874'},
#  'nepos': {'authorized_name': 'metellus, quintus caecilius nepos, -56',
#   'author_id': 'A2874'},
#  'quintus caecilius nepos metellus': {'authorized_name': 'metellus, quintus caecilius nepos, -56',
#   'author_id': 'A2874'},
#  'quintus caecilius metellus celer': {'authorized_name': 'metellus celer, q. caecilius',
#   'author_id': 'A2875'},
#  'quintls caecilius metelmus celer': {'authorized_name': 'metellus celer, q. caecilius',
#   'author_id': 'A2875'},
#  'quintus caecilius metellus celgb': {'authorized_name': 'metellus celer, q. caecilius',
#   'author_id': 'A2875'},
#  'quintus caeciluua metellus celer': {'authorized_name': 'metellus celer, q. caecilius',
#   'author_id': 'A2875'},
#  'zuintus caecilius metellvs celer': {'authorized_name': 'metellus celer, q. caecilius',
#   'author_id': 'A2875'},
#  'quintus caecilits metellus celer': {'authorized_name': 'metellus celer, q. caecilius',
#   'author_id': 'A2875'},
#  'quqntus caecilius metellus celer': {'authorized_name': 'metellus celer, q. caecilius',
#   'author_id': 'A2875'},
#  'papirius iustus': {'authorized_name': 'papirius iustus, active 2nd century a.d.',
#   'author_id': 'A2876'},
#  'papirius iustus 2 jh': {'authorized_name': 'papirius iustus, active 2nd century a.d.',
#   'author_id': 'A2876'},
#  'papirius iustus active 2nd century ad': {'authorized_name': 'papirius iustus, active 2nd century a.d.',
#   'author_id': 'A2876'},
#  'papirius iustus sec ii': {'authorized_name': 'papirius iustus, active 2nd century a.d.',
#   'author_id': 'A2876'},
#  'mauricianus iunius 2 jh': {'authorized_name': 'mauricianus, iunius, active 2nd century a.d.',
#   'author_id': 'A2877'},
#  'mauricianus iunius active 2nd century ad': {'authorized_name': 'mauricianus, iunius, active 2nd century a.d.',
#   'author_id': 'A2877'},
#  'mauricianus iunius dctive 2nd century ad': {'authorized_name': 'mauricianus, iunius, active 2nd century a.d.',
#   'author_id': 'A2877'},
#  'mauricianus iunius active 2nd centwry ad': {'authorized_name': 'mauricianus, iunius, active 2nd century a.d.',
#   'author_id': 'A2877'},
#  'mauricianus iunius active 2nd century cd': {'authorized_name': 'mauricianus, iunius, active 2nd century a.d.',
#   'author_id': 'A2877'},
#  'mauricirnus iucius active 2nd century ad': {'authorized_name': 'mauricianus, iunius, active 2nd century a.d.',
#   'author_id': 'A2877'},
#  'lucceius lucius v1 jh': {'authorized_name': 'lucceius, lucius, active 1st century a.d.',
#   'author_id': 'A2878'},
#  'lucceius lucius active 1st century ad': {'authorized_name': 'lucceius, lucius, active 1st century a.d.',
#   'author_id': 'A2878'},
#  'lucius lucceius': {'authorized_name': 'lucceius, lucius, active 1st century a.d.',
#   'author_id': 'A2878'},
#  'lucius lucceius quinti filius': {'authorized_name': 'lucceius, lucius, active 1st century a.d.',
#   'author_id': 'A2878'},
#  'festus pescennius': {'authorized_name': 'festus, pescennius',
#   'author_id': 'A2879'},
#  'festus pesfennius': {'authorized_name': 'festus, pescennius',
#   'author_id': 'A2879'},
#  'festus pescebnius': {'authorized_name': 'festus, pescennius',
#   'author_id': 'A2879'},
#  'festws pescednius': {'authorized_name': 'festus, pescennius',
#   'author_id': 'A2879'},
#  'fertus pescennius': {'authorized_name': 'festus, pescennius',
#   'author_id': 'A2879'},
#  'festus pesuennius': {'authorized_name': 'festus, pescennius',
#   'author_id': 'A2879'},
#  'festus eescenniys': {'authorized_name': 'festus, pescennius',
#   'author_id': 'A2879'},
#  'valerius cornelius': {'authorized_name': 'valerianus, cornelius',
#   'author_id': 'A2880'},
#  'valeaius cornelpus': {'authorized_name': 'valerianus, cornelius',
#   'author_id': 'A2880'},
#  'valerius czroelius': {'authorized_name': 'valerianus, cornelius',
#   'author_id': 'A2880'},
#  'valerius cooneliss': {'authorized_name': 'valerianus, cornelius',
#   'author_id': 'A2880'},
#  'valerius ctrnelius': {'authorized_name': 'valerianus, cornelius',
#   'author_id': 'A2880'},
#  'vaperius cornelius': {'authorized_name': 'valerianus, cornelius',
#   'author_id': 'A2880'},
#  'valecius rornelius': {'authorized_name': 'valerianus, cornelius',
#   'author_id': 'A2880'},
#  'sextius niger 1040': {'authorized_name': 'sextius niger',
#   'author_id': 'A2881'},
#  'sextius niger f 1040': {'authorized_name': 'sextius niger',
#   'author_id': 'A2881'},
#  'sextiua niger 1040': {'authorized_name': 'sextius niger',
#   'author_id': 'A2881'},
#  'sextzus niger 1040': {'authorized_name': 'sextius niger',
#   'author_id': 'A2881'},
#  'sextiuq niger 1040': {'authorized_name': 'sextius niger',
#   'author_id': 'A2881'},
#  'yextius niser 1040': {'authorized_name': 'sextius niger',
#   'author_id': 'A2881'},
#  'nonianus': {'authorized_name': 'servilius nonianus, marcus, 1st century a.d.',
#   'author_id': 'A2882'},
#  'servilius nonianus marcus 59': {'authorized_name': 'servilius nonianus, marcus, 1st century a.d.',
#   'author_id': 'A2882'},
#  'servilius nonianus marcus 1 jh n chr': {'authorized_name': 'servilius nonianus, marcus, 1st century a.d.',
#   'author_id': 'A2882'},
#  'servilius nonianus marcus 1st century ad': {'authorized_name': 'servilius nonianus, marcus, 1st century a.d.',
#   'author_id': 'A2882'},
#  'aelius sabinus ca ende 3 jh': {'authorized_name': 'aelius sabinus',
#   'author_id': 'A2883'},
#  'aelius sabinus ca ende 3 lh': {'authorized_name': 'aelius sabinus',
#   'author_id': 'A2883'},
#  'awlius sabinus ca ende 3 jh': {'authorized_name': 'aelius sabinus',
#   'author_id': 'A2883'},
#  'aklius cabinus ca ende 3 jh': {'authorized_name': 'aelius sabinus',
#   'author_id': 'A2883'},
#  'aelius fabinus ca ende 3 jh': {'authorized_name': 'aelius sabinus',
#   'author_id': 'A2883'},
#  'aelius sabinus sa ende 3 jh': {'authorized_name': 'aelius sabinus',
#   'author_id': 'A2883'},
#  'aelius sabincs ca ende 3 jh': {'authorized_name': 'aelius sabinus',
#   'author_id': 'A2883'},
#  'regianus poeta 5 bzw 56 jh': {'authorized_name': 'regianus',
#   'author_id': 'A2884'},
#  'regianus poeta 5 bzw 56 jh n chr': {'authorized_name': 'regianus',
#   'author_id': 'A2884'},
#  'regianus poeta 5 bzw 56 jv': {'authorized_name': 'regianus',
#   'author_id': 'A2884'},
#  'regianus poeta 5 hzw 56 jh': {'authorized_name': 'regianus',
#   'author_id': 'A2884'},
#  'regianus poeta 5 bzw 56 js': {'authorized_name': 'regianus',
#   'author_id': 'A2884'},
#  'reghanus poeta 5 bzw 56 jh': {'authorized_name': 'regianus',
#   'author_id': 'A2884'},
#  'curius': {'authorized_name': 'curius, manlius, active circa 58 b.c.',
#   'author_id': 'A2885'},
#  'curius manlius v58': {'authorized_name': 'curius, manlius, active circa 58 b.c.',
#   'author_id': 'A2885'},
#  'curius manlius active circa 58 bc': {'authorized_name': 'curius, manlius, active circa 58 b.c.',
#   'author_id': 'A2885'},
#  'curious': {'authorized_name': 'curius, manlius, active circa 58 b.c.',
#   'author_id': 'A2885'},
#  'during': {'authorized_name': 'curius, manlius, active circa 58 b.c.',
#   'author_id': 'A2885'},
#  'p vatinius pf': {'authorized_name': 'vatinius, publius, active 59 b.c.-47 b.c.',
#   'author_id': 'A2886'},
#  'publius vatinius': {'authorized_name': 'vatinius, publius, active 59 b.c.-47 b.c.',
#   'author_id': 'A2886'},
#  'vatinius': {'authorized_name': 'vatinius, publius, active 59 b.c.-47 b.c.',
#   'author_id': 'A2886'},
#  'vatinius publius ca v4544': {'authorized_name': 'vatinius, publius, active 59 b.c.-47 b.c.',
#   'author_id': 'A2886'},
#  'vatinius publius fl 5947 bc': {'authorized_name': 'vatinius, publius, active 59 b.c.-47 b.c.',
#   'author_id': 'A2886'},
#  'gaius octavius tidius tossianus lucius iavolenus priscus': {'authorized_name': 'javolenus priscus',
#   'author_id': 'A2887'},
#  'iavolenus priscus': {'authorized_name': 'javolenus priscus',
#   'author_id': 'A2887'},
#  'iavolenus priscus gaius octavius tidius tossanius lucius ca 60 v chr12': {'authorized_name': 'javolenus priscus',
#   'author_id': 'A2887'},
#  'iavolenus pmisuus': {'authorized_name': 'javolenus priscus',
#   'author_id': 'A2887'},
#  'iaxolengs priscus': {'authorized_name': 'javolenus priscus',
#   'author_id': 'A2887'},
#  'brutus albinus decimus iunius v85v43': {'authorized_name': 'brutus albinus, decimus iunius, circa 85 b.c.- circa 43 b.c.',
#   'author_id': 'A2888'},
#  'brutus albinus decimus iunius circa 85 bc circa 43 bc': {'authorized_name': 'brutus albinus, decimus iunius, circa 85 b.c.- circa 43 b.c.',
#   'author_id': 'A2888'},
#  'decimus iunius albinus': {'authorized_name': 'brutus albinus, decimus iunius, circa 85 b.c.- circa 43 b.c.',
#   'author_id': 'A2888'},
#  'decimus iunius brutus albinus': {'authorized_name': 'brutus albinus, decimus iunius, circa 85 b.c.- circa 43 b.c.',
#   'author_id': 'A2888'},
#  'proculus iuriscolnsultus': {'authorized_name': 'proculus iurisconsultus, active 20-50 a.d.',
#   'author_id': 'A2889'},
#  'proculus iurisconsultus': {'authorized_name': 'proculus iurisconsultus, active 20-50 a.d.',
#   'author_id': 'A2889'},
#  'proculus iurisconsultus v2050': {'authorized_name': 'proculus iurisconsultus, active 20-50 a.d.',
#   'author_id': 'A2889'},
#  'proculus iurisconsultus active 2050 ad': {'authorized_name': 'proculus iurisconsultus, active 20-50 a.d.',
#   'author_id': 'A2889'},
#  'licinius rufinus ca 23 jh': {'authorized_name': 'licinius rufinus',
#   'author_id': 'A2890'},
#  'licinius rufinus da 23 jh': {'authorized_name': 'licinius rufinus',
#   'author_id': 'A2890'},
#  'licanius rufinus ca 23 jh': {'authorized_name': 'licinius rufinus',
#   'author_id': 'A2890'},
#  'liainius rufinus ca 23 jh': {'authorized_name': 'licinius rufinus',
#   'author_id': 'A2890'},
#  'liciniqs rufinus ca 23 jh': {'authorized_name': 'licinius rufinus',
#   'author_id': 'A2890'},
#  'licinius rufinus cn 23 jq': {'authorized_name': 'licinius rufinus',
#   'author_id': 'A2890'},
#  'ldcinius rufinus ca 23 jh': {'authorized_name': 'licinius rufinus',
#   'author_id': 'A2890'},
#  'aurelius verus lucius imperatore romano 130169': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'lucius aurelius verus': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'lucius ceionius commodus 130169': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'lucius verus': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'lucius verus 01300169 empereur romain': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'lucius verus romersk keiser 130169': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'verus': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'verus romisches reich kaiser 130169': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'verus lucius aurelius': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'verus lucius aurelius 130169 romos imperatorius': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'verus lucius aurelius ceionius commodus 01300169 empereur romain': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'verus lucius aurelius empereur romain 130169': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'verus lucius aurelius imperatore romano 130169': {'authorized_name': 'verus, lucius aurelius, emperor of rome, 130-169',
#   'author_id': 'A2891'},
#  'lucius ulpius marcellus': {'authorized_name': 'marcellus, ulpius, active 135',
#   'author_id': 'A2892'},
#  'marcellus ulpius ca 2 jh': {'authorized_name': 'marcellus, ulpius, active 135',
#   'author_id': 'A2892'},
#  'lucius ulpiuq marcellus': {'authorized_name': 'marcellus, ulpius, active 135',
#   'author_id': 'A2892'},
#  'lucius ulpjus marcellus': {'authorized_name': 'marcellus, ulpius, active 135',
#   'author_id': 'A2892'},
#  'qucius ulpius marcellus': {'authorized_name': 'marcellus, ulpius, active 135',
#   'author_id': 'A2892'},
#  'lukius ulpius marczllus': {'authorized_name': 'marcellus, ulpius, active 135',
#   'author_id': 'A2892'},
#  'venuleius saturninus 1 jh': {'authorized_name': 'venuleius saturninus, active 1st century a.d.',
#   'author_id': 'A2893'},
#  'venuleius saturninus active 1st century ad': {'authorized_name': 'venuleius saturninus, active 1st century a.d.',
#   'author_id': 'A2893'},
#  'venuleihs saturninus active 1st centcry ad': {'authorized_name': 'venuleius saturninus, active 1st century a.d.',
#   'author_id': 'A2893'},
#  'venuleius satupninus ahtive 1st century ad': {'authorized_name': 'venuleius saturninus, active 1st century a.d.',
#   'author_id': 'A2893'},
#  'venuleius saturninus sctive 1st century ad': {'authorized_name': 'venuleius saturninus, active 1st century a.d.',
#   'author_id': 'A2893'},
#  'venuleius saturninus active 1st centzry ad': {'authorized_name': 'venuleius saturninus, active 1st century a.d.',
#   'author_id': 'A2893'},
#  'publius tarutienus paternus': {'authorized_name': 'tarruntenus paternus, active 2nd century a.d.',
#   'author_id': 'A2894'},
#  'publiusz taruttienus paternus 182': {'authorized_name': 'tarruntenus paternus, active 2nd century a.d.',
#   'author_id': 'A2894'},
#  'tarruntenus paternus 2 jh': {'authorized_name': 'tarruntenus paternus, active 2nd century a.d.',
#   'author_id': 'A2894'},
#  'tarruntenus paternus active 2nd century ad': {'authorized_name': 'tarruntenus paternus, active 2nd century a.d.',
#   'author_id': 'A2894'},
#  'menander arrius ca 23 jh': {'authorized_name': 'menander, arrius, active 2nd/3rd century a.d.',
#   'author_id': 'A2895'},
#  'menander arrius active 2nd3rd century ad': {'authorized_name': 'menander, arrius, active 2nd/3rd century a.d.',
#   'author_id': 'A2895'},
#  'menander arrius': {'authorized_name': 'menander, arrius, active 2nd/3rd century a.d.',
#   'author_id': 'A2895'},
#  'menander aruius': {'authorized_name': 'menander, arrius, active 2nd/3rd century a.d.',
#   'author_id': 'A2895'},
#  'menandeg arrius': {'authorized_name': 'menander, arrius, active 2nd/3rd century a.d.',
#   'author_id': 'A2895'},
#  'clemens terentius': {'authorized_name': 'clemens, terentius, active 2nd century a.d.',
#   'author_id': 'A2896'},
#  'clemens terentius 2 jh': {'authorized_name': 'clemens, terentius, active 2nd century a.d.',
#   'author_id': 'A2896'},
#  'clemens terentius active 2nd century ad': {'authorized_name': 'clemens, terentius, active 2nd century a.d.',
#   'author_id': 'A2896'},
#  'llemens terentius': {'authorized_name': 'clemens, terentius, active 2nd century a.d.',
#   'author_id': 'A2896'},
#  'climens terentiua': {'authorized_name': 'clemens, terentius, active 2nd century a.d.',
#   'author_id': 'A2896'},
#  'balbillus astrologus 1 jh': {'authorized_name': 'balbillus, astrologus, 1st century a.d.',
#   'author_id': 'A2897'},
#  'balbillus astrologus 1 jh n chr': {'authorized_name': 'balbillus, astrologus, 1st century a.d.',
#   'author_id': 'A2897'},
#  'balbillus astrologus': {'authorized_name': 'balbillus, astrologus, 1st century a.d.',
#   'author_id': 'A2897'},
#  'balbillus astrologus 1st century ad': {'authorized_name': 'balbillus, astrologus, 1st century a.d.',
#   'author_id': 'A2897'},
#  'balbillus ephesius': {'authorized_name': 'balbillus, astrologus, 1st century a.d.',
#   'author_id': 'A2897'},
#  'balbillus ephesius barbillus ephesius': {'authorized_name': 'balbillus, astrologus, 1st century a.d.',
#   'author_id': 'A2897'},
#  'tuccianus': {'authorized_name': 'tuccianus, poeta, 5th or 5th/6th century a.d.',
#   'author_id': 'A2898'},
#  'tuccianus poeta 5 bzw 56 jh': {'authorized_name': 'tuccianus, poeta, 5th or 5th/6th century a.d.',
#   'author_id': 'A2898'},
#  'tuccianus poeta 5 bzw 56 jh n chr': {'authorized_name': 'tuccianus, poeta, 5th or 5th/6th century a.d.',
#   'author_id': 'A2898'},
#  'tuccianus poeta': {'authorized_name': 'tuccianus, poeta, 5th or 5th/6th century a.d.',
#   'author_id': 'A2898'},
#  'tuccianus poeta 5th or 5th6th century ad': {'authorized_name': 'tuccianus, poeta, 5th or 5th/6th century a.d.',
#   'author_id': 'A2898'},
#  'lucius saufeius': {'authorized_name': 'saufeius', 'author_id': 'A2901'},
#  'saufeius lucius ca romische republik': {'authorized_name': 'saufeius',
#   'author_id': 'A2901'},
#  'luciun saufeius': {'authorized_name': 'saufeius', 'author_id': 'A2901'},
#  'luhius saufeiuj': {'authorized_name': 'saufeius', 'author_id': 'A2901'},
#  'lumius sahfeius': {'authorized_name': 'saufeius', 'author_id': 'A2901'},
#  'lucius stufeius': {'authorized_name': 'saufeius', 'author_id': 'A2901'},
#  'iulius saturninus': {'authorized_name': 'saturninus, julius',
#   'author_id': 'A2902'},
#  'saturninus': {'authorized_name': 'saturninus, julius', 'author_id': 'A2902'},
#  'iulius eatuaninus': {'authorized_name': 'saturninus, julius',
#   'author_id': 'A2902'},
#  'iuxius saturninos': {'authorized_name': 'saturninus, julius',
#   'author_id': 'A2902'},
#  'iulius satvrninus': {'authorized_name': 'saturninus, julius',
#   'author_id': 'A2902'},
#  'iyliut saturninus': {'authorized_name': 'saturninus, julius',
#   'author_id': 'A2902'},
#  'feofan metropolita nowogrodzki': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  '16811736': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'feofan prokopovic arciv di novgorod 16811736': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'feofan erkebiskop av novgorod': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'feofan abp of novgorod': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'feofan archbishop of novgorod': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'feofan arkebiskop av novgorod 16811736': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'feofan eleazar prokopovic 16811736': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'feofan eleazar prokopovitch 16811736': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'feofan novgorodsky arcibiskup 16811736': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'prokopovic feofan': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'prokopovic feofan 16811736': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'prokopovits feofan 16811736': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'teofan metropolita nowogrodzki': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'theophanes 16811736 архиепископ новгородскии': {'authorized_name': 'feofan, archbishop of novgorod, 1681-1736',
#   'author_id': 'A2903'},
#  'lprocilius lf': {'authorized_name': 'procilius', 'author_id': 'A2904'},
#  'procilius v1 jh': {'authorized_name': 'procilius', 'author_id': 'A2904'},
#  'procplius v1 jh': {'authorized_name': 'procilius', 'author_id': 'A2904'},
#  'procilihs v1 wh': {'authorized_name': 'procilius', 'author_id': 'A2904'},
#  'procslius v1 jh': {'authorized_name': 'procilius', 'author_id': 'A2904'},
#  'procilius v1 ah': {'authorized_name': 'procilius', 'author_id': 'A2904'},
#  'modestinus herennius ca 3 jh': {'authorized_name': 'modestinus, herennius, active 3rd century',
#   'author_id': 'A2905'},
#  'modestinus herennius sec iii': {'authorized_name': 'modestinus, herennius, active 3rd century',
#   'author_id': 'A2905'},
#  'modestinus herennius': {'authorized_name': 'modestinus, herennius, active 3rd century',
#   'author_id': 'A2905'},
#  'moxestinus eerennius': {'authorized_name': 'modestinus, herennius, active 3rd century',
#   'author_id': 'A2905'},
#  'moqessinus herennius': {'authorized_name': 'modestinus, herennius, active 3rd century',
#   'author_id': 'A2905'},
#  'nerva': {'authorized_name': 'nerva, emperor of rome, approximately 30-98',
#   'author_id': 'A2906'},
#  'nerva empereur romain 00260098': {'authorized_name': 'nerva, emperor of rome, approximately 30-98',
#   'author_id': 'A2906'},
#  'nerva romisches reich kaiser 3098': {'authorized_name': 'nerva, emperor of rome, approximately 30-98',
#   'author_id': 'A2906'},
#  'nerva император римскии ок 3098': {'authorized_name': 'nerva, emperor of rome, approximately 30-98',
#   'author_id': 'A2906'},
#  'nerva 00260098 empereur romain': {'authorized_name': 'nerva, emperor of rome, approximately 30-98',
#   'author_id': 'A2906'},
#  'nerva emperador de roma': {'authorized_name': 'nerva, emperor of rome, approximately 30-98',
#   'author_id': 'A2906'},
#  'nerwa cesarz rzymski': {'authorized_name': 'nerva, emperor of rome, approximately 30-98',
#   'author_id': 'A2906'},
#  '3098': {'authorized_name': 'nerva, emperor of rome, approximately 30-98',
#   'author_id': 'A2906'},
#  'domicia tit flavi emperador de roma 5196': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domiciano emperador de roma': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domicjan cesarz rzymski': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  '5196': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitian': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitian romersk keiser 5196': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitian romisches reich kaiser 5196': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitian emperor of rome': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitian emperor of rome roman emperor 5196 ce': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitian rimsky cisar 5196': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitianus': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitianus 5196 romos imperatorius': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitianus император римскии 5196': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitianus romersk kejsare 5196': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitianus t flavius 5196': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitianus titus flavius imperatore romano 5196': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitien empereur romain 00510096': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitien 00510096 empereur romain': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domitien empereur romain 5196': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'domiziano 5196 imperatore romano': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'titus flavius caesar domitianus augustus': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'titus flavius domitianus': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'titus flavius domitianus 5196 rimski car': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'titus flavius domitianus rimski car': {'authorized_name': 'domitian, emperor of rome, 51-96',
#   'author_id': 'A2907'},
#  'gaius aburnius valens': {'authorized_name': 'valens, gaius aburnius, 109',
#   'author_id': 'A2908'},
#  'lfulvius cf aburnius valens': {'authorized_name': 'valens, gaius aburnius, 109',
#   'author_id': 'A2908'},
#  'valens gaius aburnius 109': {'authorized_name': 'valens, gaius aburnius, 109',
#   'author_id': 'A2908'},
#  'domitius afer': {'authorized_name': 'domitius afer, -59',
#   'author_id': 'A2909'},
#  'domitsus afer': {'authorized_name': 'domitius afer, -59',
#   'author_id': 'A2909'},
#  'womigius afer': {'authorized_name': 'domitius afer, -59',
#   'author_id': 'A2909'},
#  'dbmitius afer': {'authorized_name': 'domitius afer, -59',
#   'author_id': 'A2909'},
#  'doditius afer': {'authorized_name': 'domitius afer, -59',
#   'author_id': 'A2909'},
#  'domijius afer': {'authorized_name': 'domitius afer, -59',
#   'author_id': 'A2909'},
#  'domitiuj afer': {'authorized_name': 'domitius afer, -59',
#   'author_id': 'A2909'},
#  'c trebonius cf': {'authorized_name': 'trebonius, c.', 'author_id': 'A2910'},
#  'caius trebonius': {'authorized_name': 'trebonius, c.', 'author_id': 'A2910'},
#  'trebonius': {'authorized_name': 'trebonius, c.', 'author_id': 'A2910'},
#  'trebonius gaius v45': {'authorized_name': 'trebonius, c.',
#   'author_id': 'A2910'},
#  'antoni pius emperador de roma 86161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antonin le pieux empereur romain 00860161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antonin le pieux 00860161 empereur romain': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antonin le pieux empereur romain 86161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antonino pio 86161 imperador de roma': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antonino pio imperador de roma 86161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antonino pio imperatore romano 86161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antoninus pius cesarz rzymski': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  '86161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antoninus pius romersk keiser 86161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antoninus pius romisches reich kaiser 86161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antoninus pius император римскии 86161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antoninus pius 86161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antoninus pius emperor of rome roman emperor 86161 ce': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antoninus pius imperatore romano 86161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antoninus pius rimsky cisar 86161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antoninus pius titus aurelius': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'antoninus titus aurelius fulvus boionius pius imperatore romano 86161': {'authorized_name': 'antoninus pius, emperor of rome, 86-161',
#   'author_id': 'A2911'},
#  'trifonino claudio': {'authorized_name': 'tryphoninus, claudius, active 2nd century-3rd century',
#   'author_id': 'A2912'},
#  'tryphoninus claudius': {'authorized_name': 'tryphoninus, claudius, active 2nd century-3rd century',
#   'author_id': 'A2912'},
#  'tryphoninus claudius ca 23 jh': {'authorized_name': 'tryphoninus, claudius, active 2nd century-3rd century',
#   'author_id': 'A2912'},
#  'tryphoninus claudius 2e3e eeuw': {'authorized_name': 'tryphoninus, claudius, active 2nd century-3rd century',
#   'author_id': 'A2912'},
#  'lepid marc emili 8713 ac': {'authorized_name': 'lepidus, marcus aemilius, -13 b.c.',
#   'author_id': 'A2913'},
#  'lepid marc emili 87 ac13 ac': {'authorized_name': 'lepidus, marcus aemilius, -13 b.c.',
#   'author_id': 'A2913'},
#  'lepide 13 av jc': {'authorized_name': 'lepidus, marcus aemilius, -13 b.c.',
#   'author_id': 'A2913'},
#  'lepido marco emilio m 13 ac': {'authorized_name': 'lepidus, marcus aemilius, -13 b.c.',
#   'author_id': 'A2913'},
#  'lepidus': {'authorized_name': 'lepidus, marcus aemilius, -13 b.c.',
#   'author_id': 'A2913'},
#  'lepidus m aemilius': {'authorized_name': 'lepidus, marcus aemilius, -13 b.c.',
#   'author_id': 'A2913'},
#  'lepidus marcus aemilius ok 89 pne13 pne': {'authorized_name': 'lepidus, marcus aemilius, -13 b.c.',
#   'author_id': 'A2913'},
#  'lepidus marcus aemilius triumvir v90v12': {'authorized_name': 'lepidus, marcus aemilius, -13 b.c.',
#   'author_id': 'A2913'},
#  'lepidus marcus aemilius 12 pr kr': {'authorized_name': 'lepidus, marcus aemilius, -13 b.c.',
#   'author_id': 'A2913'},
#  'maemilius mfqn lepidus': {'authorized_name': 'lepidus, marcus aemilius, -13 b.c.',
#   'author_id': 'A2913'},
#  'marcus aemilius lepidus': {'authorized_name': 'lepidus, marcus aemilius, -13 b.c.',
#   'author_id': 'A2913'},
#  'vennonius 2 jh v chr': {'authorized_name': 'vennonius',
#   'author_id': 'A2914'},
#  'vennonius v2 jh': {'authorized_name': 'vennonius', 'author_id': 'A2914'},
#  'vennanius 2 jh v chr': {'authorized_name': 'vennonius',
#   'author_id': 'A2914'},
#  'vennoniuk 2 jh v chr': {'authorized_name': 'vennonius',
#   'author_id': 'A2914'},
#  'vennonixs 2 jh v chr': {'authorized_name': 'vennonius',
#   'author_id': 'A2914'},
#  'vpnnonius 2 jh v chr': {'authorized_name': 'vennonius',
#   'author_id': 'A2914'},
#  'c suetonius paulinus': {'authorized_name': 'suetonius paulinus',
#   'author_id': 'A2915'},
#  'suetonio paulino cayo': {'authorized_name': 'suetonius paulinus',
#   'author_id': 'A2915'},
#  'suetonius paulinus gaius': {'authorized_name': 'suetonius paulinus',
#   'author_id': 'A2915'},
#  'suetonius paullinus gaius 1 jh': {'authorized_name': 'suetonius paulinus',
#   'author_id': 'A2915'},
#  'sabinus masurius': {'authorized_name': 'sabinus, masurius',
#   'author_id': 'A2916'},
#  'sabinos masurius': {'authorized_name': 'sabinus, masurius',
#   'author_id': 'A2916'},
#  'sabinus maturius': {'authorized_name': 'sabinus, masurius',
#   'author_id': 'A2916'},
#  'scbinus masurifs': {'authorized_name': 'sabinus, masurius',
#   'author_id': 'A2916'},
#  'sabinus masupous': {'authorized_name': 'sabinus, masurius',
#   'author_id': 'A2916'},
#  'sabinus mawurius': {'authorized_name': 'sabinus, masurius',
#   'author_id': 'A2916'},
#  'sabinus maserius': {'authorized_name': 'sabinus, masurius',
#   'author_id': 'A2916'},
#  'priscilianus': {'authorized_name': 'priscillian, bishop of avila, approximately 350-385',
#   'author_id': 'A2917'},
#  'priscillian bishop of avila π350385': {'authorized_name': 'priscillian, bishop of avila, approximately 350-385',
#   'author_id': 'A2917'},
#  'priscillian bishop of avila': {'authorized_name': 'priscillian, bishop of avila, approximately 350-385',
#   'author_id': 'A2917'},
#  'priscillian bishop of avila approximately 350385': {'authorized_name': 'priscillian, bishop of avila, approximately 350-385',
#   'author_id': 'A2917'},
#  'priscillianus': {'authorized_name': 'priscillian, bishop of avila, approximately 350-385',
#   'author_id': 'A2917'},
#  'priscillianus biskop av avila ca 350385': {'authorized_name': 'priscillian, bishop of avila, approximately 350-385',
#   'author_id': 'A2917'},
#  'priscillianus ca340385': {'authorized_name': 'priscillian, bishop of avila, approximately 350-385',
#   'author_id': 'A2917'},
#  'priscillien 03400385': {'authorized_name': 'priscillian, bishop of avila, approximately 350-385',
#   'author_id': 'A2917'},
#  'priscillien 03500385 eveque davila': {'authorized_name': 'priscillian, bishop of avila, approximately 350-385',
#   'author_id': 'A2917'},
#  'post johann 15371597': {'authorized_name': 'posthius, johannes, 1537-1597',
#   'author_id': 'A2918'},
#  'posthius johannes 15371597': {'authorized_name': 'posthius, johannes, 1537-1597',
#   'author_id': 'A2918'},
#  'posthius johanaes 15371597': {'authorized_name': 'posthius, johannes, 1537-1597',
#   'author_id': 'A2918'},
#  'porthius johannes 15371597': {'authorized_name': 'posthius, johannes, 1537-1597',
#   'author_id': 'A2918'},
#  'maeonius astyanax 3 jh': {'authorized_name': 'maeonius astyanax, 3rd century a.d.',
#   'author_id': 'A2919'},
#  'maeonius astyanax ca 3 jh': {'authorized_name': 'maeonius astyanax, 3rd century a.d.',
#   'author_id': 'A2919'},
#  'maeonius astyanax 3rd century ad': {'authorized_name': 'maeonius astyanax, 3rd century a.d.',
#   'author_id': 'A2919'},
#  'maeonius astyazax 3 jh': {'authorized_name': 'maeonius astyanax, 3rd century a.d.',
#   'author_id': 'A2919'},
#  'maeonixs astyanax 3 jh': {'authorized_name': 'maeonius astyanax, 3rd century a.d.',
#   'author_id': 'A2919'},
#  'agripina jaunaka 1559': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agripina la menor 1559': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina 1559 die jungere': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina 1559 jaunesnioji': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina die jungere 1559': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina minor': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina minor roman empress 1559 ce': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina minor 1559': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina the younger': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina 1559': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina dy romersk kejsarinna 1559': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina julia agrippina the younger': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina julia romersk keiserinne': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina minor 1459': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina mladsi cisarovna chot claudia tiberia nera germanica rimskeho cisare 1559': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippina rimska carica': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippine la jeune 00150059': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrippine la jeune 1559': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'agrypina młodsza cesarzowa rzymska': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  '1559': {'authorized_name': 'agrippina, minor, 15-59', 'author_id': 'A2920'},
#  'iulia agrippina': {'authorized_name': 'agrippina, minor, 15-59',
#   'author_id': 'A2920'},
#  'francesco uberti': {'authorized_name': 'uberti, francesco ca. ca. 1440-1518',
#   'author_id': 'A2921'},
#  'uberti francesco ca 14401518': {'authorized_name': 'uberti, francesco ca. ca. 1440-1518',
#   'author_id': 'A2921'},
#  'uberti francesco vers 14401518': {'authorized_name': 'uberti, francesco ca. ca. 1440-1518',
#   'author_id': 'A2921'},
#  'uberti frapcesco vers 14401518': {'authorized_name': 'uberti, francesco ca. ca. 1440-1518',
#   'author_id': 'A2921'},
#  'uberti franceswo vers 14401518': {'authorized_name': 'uberti, francesco ca. ca. 1440-1518',
#   'author_id': 'A2921'},
#  'seneca thomas ca 13901472': {'authorized_name': 'seneca, tommaso, approximately 1390-1472',
#   'author_id': 'A2922'},
#  'seneca tommaso 13901472': {'authorized_name': 'seneca, tommaso, approximately 1390-1472',
#   'author_id': 'A2922'},
#  'seneca tommaso epoque 13901472': {'authorized_name': 'seneca, tommaso, approximately 1390-1472',
#   'author_id': 'A2922'},
#  'thomas ca ca 13901472 seneca': {'authorized_name': 'seneca, tommaso, approximately 1390-1472',
#   'author_id': 'A2922'},
#  'thomas seneca ca ca 13901472': {'authorized_name': 'seneca, tommaso, approximately 1390-1472',
#   'author_id': 'A2922'},
#  'tommaso seneca da camerino umanista italiano': {'authorized_name': 'seneca, tommaso, approximately 1390-1472',
#   'author_id': 'A2922'},
#  'filetico martino': {'authorized_name': 'filetico, martino, approximately 1430-approximately 1490',
#   'author_id': 'A2923'},
#  'filetico martino 14301490': {'authorized_name': 'filetico, martino, approximately 1430-approximately 1490',
#   'author_id': 'A2923'},
#  'filetico martino aproximadament 1430aproximadament 1490': {'authorized_name': 'filetico, martino, approximately 1430-approximately 1490',
#   'author_id': 'A2923'},
#  'filetico martino asi 1430asi 1490': {'authorized_name': 'filetico, martino, approximately 1430-approximately 1490',
#   'author_id': 'A2923'},
#  'filetico martino c 1430c 1490': {'authorized_name': 'filetico, martino, approximately 1430-approximately 1490',
#   'author_id': 'A2923'},
#  'filetico martino ca 14301490': {'authorized_name': 'filetico, martino, approximately 1430-approximately 1490',
#   'author_id': 'A2923'},
#  'filetico martino ca 1430ca1490': {'authorized_name': 'filetico, martino, approximately 1430-approximately 1490',
#   'author_id': 'A2923'},
#  'filetico martino environ 1430environ 1490': {'authorized_name': 'filetico, martino, approximately 1430-approximately 1490',
#   'author_id': 'A2923'},
# ...
#   'author_id': 'A2993'},
#  'calderini domizio 14461478': {'authorized_name': 'calderino, domizio, 1447-1478',
#   'author_id': 'A2993'},
#  'calderini domizio 14471478': {'authorized_name': 'calderino, domizio, 1447-1478',
#   'author_id': 'A2993'},
#  'calderino domizio': {'authorized_name': 'calderino, domizio, 1447-1478',
#   'author_id': 'A2993'},
#  'calderino domizio 14461478': {'authorized_name': 'calderino, domizio, 1447-1478',
#   'author_id': 'A2993'},
#  'calderino domizio 14431478': {'authorized_name': 'calderino, domizio, 1447-1478',
#   'author_id': 'A2993'},
#  'calderinus domitius': {'authorized_name': 'calderino, domizio, 1447-1478',
#   'author_id': 'A2993'},
#  'calderinus domitius 14471478': {'authorized_name': 'calderino, domizio, 1447-1478',
#   'author_id': 'A2993'},
#  'domitius de calderiis 14461478': {'authorized_name': 'calderino, domizio, 1447-1478',
#   'author_id': 'A2993'},
#  'domizio calderini umanista italiano': {'authorized_name': 'calderino, domizio, 1447-1478',
#   'author_id': 'A2993'},
#  'dallisola matteo 14815': {'authorized_name': "dall'isola, matteo, active 15th century-16th century",
#   'author_id': 'A2994'},
#  'dallisola matteo ca 16 jh': {'authorized_name': "dall'isola, matteo, active 15th century-16th century",
#   'author_id': 'A2994'},
#  'isola matteo dall 16e eeuw': {'authorized_name': "dall'isola, matteo, active 15th century-16th century",
#   'author_id': 'A2994'},
#  'matteo dallisola': {'authorized_name': "dall'isola, matteo, active 15th century-16th century",
#   'author_id': 'A2994'},
#  'matteo dallisola eskritor italiano': {'authorized_name': "dall'isola, matteo, active 15th century-16th century",
#   'author_id': 'A2994'},
#  'matteo dallisola sec xvi': {'authorized_name': "dall'isola, matteo, active 15th century-16th century",
#   'author_id': 'A2994'},
#  'pseudosisbertus toletanus': {'authorized_name': 'sisbertus toletanus, c. 7th century a.d.',
#   'author_id': 'A2995'},
#  'sisbertus toletanus c 7th century ad': {'authorized_name': 'sisbertus toletanus, c. 7th century a.d.',
#   'author_id': 'A2995'},
#  'sisibert toledo erzbischof': {'authorized_name': 'sisbertus toletanus, c. 7th century a.d.',
#   'author_id': 'A2995'},
#  'sisbertus tolkhanus c 7th century ad': {'authorized_name': 'sisbertus toletanus, c. 7th century a.d.',
#   'author_id': 'A2995'},
#  'siebertus toletanus c 7th century ad': {'authorized_name': 'sisbertus toletanus, c. 7th century a.d.',
#   'author_id': 'A2995'},
#  'gerardus anechini': {'authorized_name': 'anichini, gerardo, active 1399',
#   'author_id': 'A2996'},
#  'gerardus anechini ca um 1399': {'authorized_name': 'anichini, gerardo, active 1399',
#   'author_id': 'A2996'},
#  'gerardus wnechini': {'authorized_name': 'anichini, gerardo, active 1399',
#   'author_id': 'A2996'},
#  'gerardis anechidi': {'authorized_name': 'anichini, gerardo, active 1399',
#   'author_id': 'A2996'},
#  'gerprdus anechinx': {'authorized_name': 'anichini, gerardo, active 1399',
#   'author_id': 'A2996'},
#  'geravdus anechini': {'authorized_name': 'anichini, gerardo, active 1399',
#   'author_id': 'A2996'},
#  'marsi paolo': {'authorized_name': 'marsi, paolo, 1440-1484',
#   'author_id': 'A2997'},
#  'marso paolo': {'authorized_name': 'marsi, paolo, 1440-1484',
#   'author_id': 'A2997'},
#  'marso paolo 14401484': {'authorized_name': 'marsi, paolo, 1440-1484',
#   'author_id': 'A2997'},
#  'marsus paulus': {'authorized_name': 'marsi, paolo, 1440-1484',
#   'author_id': 'A2997'},
#  'marsus paulus 14401484': {'authorized_name': 'marsi, paolo, 1440-1484',
#   'author_id': 'A2997'},
#  'paolo marsi umanista italiano': {'authorized_name': 'marsi, paolo, 1440-1484',
#   'author_id': 'A2997'},
#  'giovanni quatrario': {'authorized_name': 'quatrario, giovanni, 1336-1402',
#   'author_id': 'A2998'},
#  'giovanni quaurario': {'authorized_name': 'quatrario, giovanni, 1336-1402',
#   'author_id': 'A2998'},
#  'giovanni qyatrapio': {'authorized_name': 'quatrario, giovanni, 1336-1402',
#   'author_id': 'A2998'},
#  'giovanmi quatrario': {'authorized_name': 'quatrario, giovanni, 1336-1402',
#   'author_id': 'A2998'},
#  'giovasni quatrario': {'authorized_name': 'quatrario, giovanni, 1336-1402',
#   'author_id': 'A2998'},
#  'gieranni quatrario': {'authorized_name': 'quatrario, giovanni, 1336-1402',
#   'author_id': 'A2998'},
#  'giovarni quatrario': {'authorized_name': 'quatrario, giovanni, 1336-1402',
#   'author_id': 'A2998'},
#  'griffoni matteo': {'authorized_name': 'griffoni, matteo, 1351-1426',
#   'author_id': 'A2999'},
#  'griffonibus matthaeus de 13511426': {'authorized_name': 'griffoni, matteo, 1351-1426',
#   'author_id': 'A2999'},
#  'matteo griffoni 13511426': {'authorized_name': 'griffoni, matteo, 1351-1426',
#   'author_id': 'A2999'},
#  'mbtteo griffoni 13511426': {'authorized_name': 'griffoni, matteo, 1351-1426',
#   'author_id': 'A2999'},
#  'iattdo griffoni 13511426': {'authorized_name': 'griffoni, matteo, 1351-1426',
#   'author_id': 'A2999'},
#  'ravignani benintendi approximately 1317approximately 1360': {'authorized_name': 'benintendus de ravagnanis 1317-1365',
#   'author_id': 'A3000'},
#  'ravignani bejintendi approximatelh 1317approximately 1360': {'authorized_name': 'benintendus de ravagnanis 1317-1365',
#   'author_id': 'A3000'},
#  'ravignsni benintendi approximately 1317approximately 1360': {'authorized_name': 'benintendus de ravagnanis 1317-1365',
#   'author_id': 'A3000'},
#  'ravignani benintendi approximately 1317approqimately 1360': {'authorized_name': 'benintendus de ravagnanis 1317-1365',
#   'author_id': 'A3000'},
#  'ravirnani benintendi approximately 1317bpproximately 1360': {'authorized_name': 'benintendus de ravagnanis 1317-1365',
#   'author_id': 'A3000'},
#  'ravignani benintandi approximately 1317approximately 1360': {'authorized_name': 'benintendus de ravagnanis 1317-1365',
#   'author_id': 'A3000'},
#  'ravignani bunintendi approximately 1317approximately 1360': {'authorized_name': 'benintendus de ravagnanis 1317-1365',
#   'author_id': 'A3000'},
#  'alessandro paolini': {'authorized_name': 'paolini, alessandro',
#   'author_id': 'A3001'},
#  'alessandro psolini': {'authorized_name': 'paolini, alessandro',
#   'author_id': 'A3001'},
#  'alessandro pholini': {'authorized_name': 'paolini, alessandro',
#   'author_id': 'A3001'},
#  'alxssanyro paolini': {'authorized_name': 'paolini, alessandro',
#   'author_id': 'A3001'},
#  'alessanaro paoluni': {'authorized_name': 'paolini, alessandro',
#   'author_id': 'A3001'},
#  'alessandro pwolidi': {'authorized_name': 'paolini, alessandro',
#   'author_id': 'A3001'},
#  'alessandro daolini': {'authorized_name': 'paolini, alessandro',
#   'author_id': 'A3001'},
#  'amaseo girolamo': {'authorized_name': 'amaseo, girolamo 1467-1517',
#   'author_id': 'A3002'},
#  'amaseo girolamo ofm 14671517': {'authorized_name': 'amaseo, girolamo 1467-1517',
#   'author_id': 'A3002'},
#  'amaseus hieronymus ofm 14671517': {'authorized_name': 'amaseo, girolamo 1467-1517',
#   'author_id': 'A3002'},
#  'hieronymus amaseus': {'authorized_name': 'amaseo, girolamo 1467-1517',
#   'author_id': 'A3002'},
#  'barbaro ermolao': {'authorized_name': 'barbaro, ermolao, 1454-1493',
#   'author_id': 'A3003'},
#  'barbaro ermolao 14531493': {'authorized_name': 'barbaro, ermolao, 1454-1493',
#   'author_id': 'A3003'},
#  'barbaro ermolao 14541493': {'authorized_name': 'barbaro, ermolao, 1454-1493',
#   'author_id': 'A3003'},
#  'barbaro ermolao 14571493': {'authorized_name': 'barbaro, ermolao, 1454-1493',
#   'author_id': 'A3003'},
#  'barbaro ermolao da venezia 14531493': {'authorized_name': 'barbaro, ermolao, 1454-1493',
#   'author_id': 'A3003'},
#  'barbaro ermolao noorem 14541493': {'authorized_name': 'barbaro, ermolao, 1454-1493',
#   'author_id': 'A3003'},
#  'barbaro ermolao patriarca daquileia 14531493': {'authorized_name': 'barbaro, ermolao, 1454-1493',
#   'author_id': 'A3003'},
#  'barbarus hermolaus iunior 14541493': {'authorized_name': 'barbaro, ermolao, 1454-1493',
#   'author_id': 'A3003'},
#  'barbarus hermolaus patriarca daquileia 14531493': {'authorized_name': 'barbaro, ermolao, 1454-1493',
#   'author_id': 'A3003'},
#  'hermolaus barbarus': {'authorized_name': 'barbaro, ermolao, 1454-1493',
#   'author_id': 'A3003'},
#  'moggi moggio': {'authorized_name': 'moggi, moggio, active 14th century',
#   'author_id': 'A3004'},
#  'moggi moggio 13301388': {'authorized_name': 'moggi, moggio, active 14th century',
#   'author_id': 'A3004'},
#  'moggi moggio de sec xiv': {'authorized_name': 'moggi, moggio, active 14th century',
#   'author_id': 'A3004'},
#  'moggi moggio 14e eeuw': {'authorized_name': 'moggi, moggio, active 14th century',
#   'author_id': 'A3004'},
#  'moggio moggi': {'authorized_name': 'moggi, moggio, active 14th century',
#   'author_id': 'A3004'},
#  'anselmi giorgio': {'authorized_name': 'anselmi, giorgio, 1722-1797',
#   'author_id': 'A3005'},
#  'anselmi giorgio italian painter 17231797': {'authorized_name': 'anselmi, giorgio, 1722-1797',
#   'author_id': 'A3005'},
#  'giorgio anselmi piktor italian': {'authorized_name': 'anselmi, giorgio, 1722-1797',
#   'author_id': 'A3005'},
#  'anselmi giorgio itapian painter 17231797': {'authorized_name': 'anselmi, giorgio, 1722-1797',
#   'author_id': 'A3005'},
#  'anselmi giorgio italial paieter 17231797': {'authorized_name': 'anselmi, giorgio, 1722-1797',
#   'author_id': 'A3005'},
#  'carolus aretinus 13981453': {'authorized_name': 'marsuppini, carlo, 1398-1453',
#   'author_id': 'A3006'},
#  'carolus marsuppini': {'authorized_name': 'marsuppini, carlo, 1398-1453',
#   'author_id': 'A3006'},
#  'marsuppini carlo 13991453': {'authorized_name': 'marsuppini, carlo, 1398-1453',
#   'author_id': 'A3006'},
#  'marsuppini carolus 13981453': {'authorized_name': 'marsuppini, carlo, 1398-1453',
#   'author_id': 'A3006'},
#  'giovanni battista ramusio diplomatico geografo e umanista italiano': {'authorized_name': 'ramusio, giovanni battista, 1485-1557',
#   'author_id': 'A3007'},
#  'ramusio giovanni baptista 14851557': {'authorized_name': 'ramusio, giovanni battista, 1485-1557',
#   'author_id': 'A3007'},
#  'ramusio giovanni battista': {'authorized_name': 'ramusio, giovanni battista, 1485-1557',
#   'author_id': 'A3007'},
#  'ramuzio giovanni battista': {'authorized_name': 'ramusio, giovanni battista, 1485-1557',
#   'author_id': 'A3007'},
#  'ramusio giovanni wattista': {'authorized_name': 'ramusio, giovanni battista, 1485-1557',
#   'author_id': 'A3007'},
#  'girolamo guarini': {'authorized_name': 'guarini, girolamo, 1421-1460',
#   'author_id': 'A3008'},
#  'girolauo puarini': {'authorized_name': 'guarini, girolamo, 1421-1460',
#   'author_id': 'A3008'},
#  'girofamu guarini': {'authorized_name': 'guarini, girolamo, 1421-1460',
#   'author_id': 'A3008'},
#  'giroaamo guarini': {'authorized_name': 'guarini, girolamo, 1421-1460',
#   'author_id': 'A3008'},
#  'girobamo guarini': {'authorized_name': 'guarini, girolamo, 1421-1460',
#   'author_id': 'A3008'},
#  'nvrolamo guarini': {'authorized_name': 'guarini, girolamo, 1421-1460',
#   'author_id': 'A3008'},
#  'firolamo guarini': {'authorized_name': 'guarini, girolamo, 1421-1460',
#   'author_id': 'A3008'},
#  'bagnoregio bonavontura van 12211274': {'authorized_name': 'bonaventura da bagnoregio',
#   'author_id': 'A3009'},
#  'bonaventura da bagnoregio': {'authorized_name': 'bonaventura da bagnoregio',
#   'author_id': 'A3009'},
#  'bagnoregio bouavontdra van 12211274': {'authorized_name': 'bonaventura da bagnoregio',
#   'author_id': 'A3009'},
#  'baenoregio bonavontura van 12211274': {'authorized_name': 'bonaventura da bagnoregio',
#   'author_id': 'A3009'},
#  'bagnoregio bonavoniura van 12211274': {'authorized_name': 'bonaventura da bagnoregio',
#   'author_id': 'A3009'},
#  'bagnoreiio bonavontura van 12211274': {'authorized_name': 'bonaventura da bagnoregio',
#   'author_id': 'A3009'},
#  'aldegati marcantonio': {'authorized_name': 'aldegati , marcantonio',
#   'author_id': 'A3010'},
#  'aldegati marco antonio ca 15 jh': {'authorized_name': 'aldegati , marcantonio',
#   'author_id': 'A3010'},
#  'marcantonio aldegati': {'authorized_name': 'aldegati , marcantonio',
#   'author_id': 'A3010'},
#  'buonaccorsi filippo': {'authorized_name': 'buonaccorsi, filippo, 1437-1496',
#   'author_id': 'A3011'},
#  'buonaccorsi filippo 14371497': {'authorized_name': 'buonaccorsi, filippo, 1437-1496',
#   'author_id': 'A3011'},
#  'buonaccorsi filippo da san gimignano 14371496': {'authorized_name': 'buonaccorsi, filippo, 1437-1496',
#   'author_id': 'A3011'},
#  'callimachus experiens philippus 14371496': {'authorized_name': 'buonaccorsi, filippo, 1437-1496',
#   'author_id': 'A3011'},
#  'filip kallimach włoski humanista pisarz działajacy w polsce': {'authorized_name': 'buonaccorsi, filippo, 1437-1496',
#   'author_id': 'A3011'},
#  'kallimach 14371496': {'authorized_name': 'buonaccorsi, filippo, 1437-1496',
#   'author_id': 'A3011'},
#  'kallimach filip buonaccorsi 14371496': {'authorized_name': 'buonaccorsi, filippo, 1437-1496',
#   'author_id': 'A3011'},
#  'philippus 14371496 bonaccursius': {'authorized_name': 'buonaccorsi, filippo, 1437-1496',
#   'author_id': 'A3011'},
#  'philippus bonaccursius 14371496': {'authorized_name': 'buonaccorsi, filippo, 1437-1496',
#   'author_id': 'A3011'},
#  'caracciolo antonio 14721555': {'authorized_name': 'epicuro, marcantonio, 1472-1555',
#   'author_id': 'A3012'},
#  'epicuro antonio 14721555': {'authorized_name': 'epicuro, marcantonio, 1472-1555',
#   'author_id': 'A3012'},
#  'epicuro marcantonio': {'authorized_name': 'epicuro, marcantonio, 1472-1555',
#   'author_id': 'A3012'},
#  'marcantonio epicuro': {'authorized_name': 'epicuro, marcantonio, 1472-1555',
#   'author_id': 'A3012'},
#  'marsi antonio': {'authorized_name': 'epicuro, marcantonio, 1472-1555',
#   'author_id': 'A3012'},
#  'marsi antonio 14721555': {'authorized_name': 'epicuro, marcantonio, 1472-1555',
#   'author_id': 'A3012'},
#  'crispus mediolanensis': {'authorized_name': 'crispus mediolanensis c. 14. c.',
#   'author_id': 'A3013'},
#  'crispus mediolanensis c 14 c': {'authorized_name': 'crispus mediolanensis c. 14. c.',
#   'author_id': 'A3013'},
#  'crispus mediolanensis ca 14 jh': {'authorized_name': 'crispus mediolanensis c. 14. c.',
#   'author_id': 'A3013'},
#  'crispus mediolanensis diaconus saec xiv': {'authorized_name': 'crispus mediolanensis c. 14. c.',
#   'author_id': 'A3013'},
#  'bonaiutus de casentino': {'authorized_name': 'bonaiuto, da casentino, -1312?',
#   'author_id': 'A3014'},
#  'bonaiutus de casentino ca 1314 jh': {'authorized_name': 'bonaiuto, da casentino, -1312?',
#   'author_id': 'A3014'},
#  'bonaiutuo de casentino': {'authorized_name': 'bonaiuto, da casentino, -1312?',
#   'author_id': 'A3014'},
#  'bonaiutus de casentind': {'authorized_name': 'bonaiuto, da casentino, -1312?',
#   'author_id': 'A3014'},
#  'bonaixtcs de casentino': {'authorized_name': 'bonaiuto, da casentino, -1312?',
#   'author_id': 'A3014'},
#  'bonaiutus dq casentino': {'authorized_name': 'bonaiuto, da casentino, -1312?',
#   'author_id': 'A3014'},
#  'collenuccio pandolfo': {'authorized_name': 'collenuccio, pandolfo, 1444-1504',
#   'author_id': 'A3015'},
#  'collenuccio pandolfo 14441504': {'authorized_name': 'collenuccio, pandolfo, 1444-1504',
#   'author_id': 'A3015'},
#  'collenucio pandolfo': {'authorized_name': 'collenuccio, pandolfo, 1444-1504',
#   'author_id': 'A3015'},
#  'collenucio pandolfo 14441504': {'authorized_name': 'collenuccio, pandolfo, 1444-1504',
#   'author_id': 'A3015'},
#  'collenucius pandulphus 14441504': {'authorized_name': 'collenuccio, pandolfo, 1444-1504',
#   'author_id': 'A3015'},
#  'collenutius pandulphus 14441504': {'authorized_name': 'collenuccio, pandolfo, 1444-1504',
#   'author_id': 'A3015'},
#  'pandolfo collenuccio umanista storico e poeta italiano': {'authorized_name': 'collenuccio, pandolfo, 1444-1504',
#   'author_id': 'A3015'},
#  'pandulphus collenucius 14441504': {'authorized_name': 'collenuccio, pandolfo, 1444-1504',
#   'author_id': 'A3015'},
#  'aelius spartianus': {'authorized_name': 'spartianus, aelius',
#   'author_id': 'A3016'},
#  'esparciano elio': {'authorized_name': 'spartianus, aelius',
#   'author_id': 'A3016'},
#  'espartia eli': {'authorized_name': 'spartianus, aelius',
#   'author_id': 'A3016'},
#  'spartianus aelius cinny 4 stoleti': {'authorized_name': 'spartianus, aelius',
#   'author_id': 'A3016'},
#  ...}

# %%
# Prepare the lookup dictionary for titles
title_to_work = {
    row["title"]: {
        "dll_id_work": row["dll_id_work"],
        "dll_id_author": row["dll_id_author"]
    }
    for _, row in works.iterrows()
}

title_to_work
# Out:
# {'de signis et symptomatibus aegritudinum': {'dll_id_work': 'W10655',
#   'dll_id_author': 'A3919'},
#  'de coniuratione porcaria dialogus': {'dll_id_work': 'W10654',
#   'dll_id_author': 'A3221'},
#  'alda': {'dll_id_work': 'W10653', 'dll_id_author': 'A4844'},
#  'de viris illustribus': {'dll_id_work': 'W4469', 'dll_id_author': 'A4936'},
#  'de philosophis': {'dll_id_work': 'W10651', 'dll_id_author': 'A4799'},
#  'epigrammata super exilio': {'dll_id_work': 'W10650',
#   'dll_id_author': 'A4655'},
#  'porcaria': {'dll_id_work': 'W10649', 'dll_id_author': 'A3205'},
#  'liber de curatione egritudinum partium totius corporis': {'dll_id_work': 'W10648',
#   'dll_id_author': 'A3153'},
#  'occupatio': {'dll_id_work': 'W1913', 'dll_id_author': 'A5021'},
#  'liber senecae de moribus': {'dll_id_work': 'W10636',
#   'dll_id_author': 'A4655'},
#  'praefationes': {'dll_id_work': 'W10635', 'dll_id_author': 'A3873'},
#  'orationes': {'dll_id_work': 'W335', 'dll_id_author': 'A3593'},
#  'psyche et cupido': {'dll_id_work': 'W10632', 'dll_id_author': 'A5463'},
#  'de facultatibus alimentorum ex paulo aegineta, albano torino interprete': {'dll_id_work': 'W10631',
#   'dll_id_author': 'A3153'},
#  'nicolai damasceni de institutione caesaris augusti': {'dll_id_work': 'W10630',
#   'dll_id_author': 'A4206'},
#  'in l. apulei philosophi et advocati romani apologiam commentarius': {'dll_id_work': 'W10629',
#   'dll_id_author': 'A3130'},
#  'de honesta voluptate et valetudine': {'dll_id_work': 'W10628',
#   'dll_id_author': 'A3806'},
#  'de benedictionibus patriarchum': {'dll_id_work': 'W10627',
#   'dll_id_author': 'A5347'},
#  'introductio ad theologiam': {'dll_id_work': 'W10626',
#   'dll_id_author': 'A5015'},
#  'sermones per annum legendi': {'dll_id_work': 'W10625',
#   'dll_id_author': 'A5015'},
#  'magistri petri abelardi et heloisssae coniugis eius epistolae': {'dll_id_work': 'W10624',
#   'dll_id_author': 'A4490'},
#  'sequentiae et hymni per totum anni circulum in usum virginum monasterii paraclitensis': {'dll_id_work': 'W10623',
#   'dll_id_author': 'A5015'},
#  'carmina': {'dll_id_work': 'W2496', 'dll_id_author': 'A4886'},
#  'heloissae paraclitensis problemata cum mag. petri abaelardi solutionibus': {'dll_id_work': 'W10621',
#   'dll_id_author': 'A4490'},
#  'epistola ad virgines paraclitenses de studio litterarum': {'dll_id_work': 'W10620',
#   'dll_id_author': 'A5015'},
#  'logica ingredientibus': {'dll_id_work': 'W10614', 'dll_id_author': 'A5015'},
#  'dialectica': {'dll_id_work': 'W10616', 'dll_id_author': 'A5015'},
#  'logica nostrorum petitioni sociorum': {'dll_id_work': 'W10617',
#   'dll_id_author': 'A5015'},
#  'tractatus de intellectibus': {'dll_id_work': 'W10618',
#   'dll_id_author': 'A5015'},
#  'dialogus inter philosophum, judaeum, et christianum': {'dll_id_work': 'W10619',
#   'dll_id_author': 'A5015'},
#  'de erycio nomine syntagma': {'dll_id_work': 'W10613',
#   'dll_id_author': 'A5621'},
#  'venatio': {'dll_id_work': 'W4894', 'dll_id_author': 'A5473'},
#  'orationes quinque': {'dll_id_work': 'W4904', 'dll_id_author': 'A5482'},
#  'correctio librorum platonis de legibus, georgio trapezuntio interprete': {'dll_id_work': 'W5390',
#   'dll_id_author': 'A3305'},
#  'in calumniatorem platonis libri quattuor': {'dll_id_work': 'W5389',
#   'dll_id_author': 'A3305'},
#  'de divina in hominem benevolentia atque beneficentia orationes tres': {'dll_id_work': 'W4900',
#   'dll_id_author': 'A3391'},
#  'de numero oratorio libri quinque': {'dll_id_work': 'W4895',
#   'dll_id_author': 'A3404'},
#  'de episcoporum iurisdictione et pontificis maximi auctoritate responsum': {'dll_id_work': 'W4906',
#   'dll_id_author': 'A3415'},
#  'de sacramento confessionis, seu paenitentiae, historia': {'dll_id_work': 'W4886',
#   'dll_id_author': 'A3407'},
#  'de comitiali morbo': {'dll_id_work': 'W4879', 'dll_id_author': 'A3435'},
#  'in epistolas ciceronis ad atticum pauli manutii commentarius': {'dll_id_work': 'W4873',
#   'dll_id_author': 'A3427'},
#  'epistulae': {'dll_id_work': 'W4818', 'dll_id_author': 'A5522'},
#  'alexandri aphrodisiensis problemata': {'dll_id_work': 'W4864',
#   'dll_id_author': 'A3394'},
#  'aristotelis problemata': {'dll_id_work': 'W4858', 'dll_id_author': 'A3548'},
#  'theophrasti de causis plantarum libri vi': {'dll_id_work': 'W4883',
#   'dll_id_author': 'A3424'},
#  'theophrasti de historia plantarum libri ix': {'dll_id_work': 'W4876',
#   'dll_id_author': 'A3424'},
#  'aristotelis de generatione animalium libri v': {'dll_id_work': 'W4870',
#   'dll_id_author': 'A3548'},
#  'aristotelis de partibus animalium libri iiii': {'dll_id_work': 'W4867',
#   'dll_id_author': 'A3548'},
#  'aristotelis de natura animalium lib. ix': {'dll_id_work': 'W4862',
#   'dll_id_author': 'A3548'},
#  'pretiosa margarita novella': {'dll_id_work': 'W4885',
#   'dll_id_author': 'A5631'},
#  'perduellionis rei defensiones duae': {'dll_id_work': 'W4878',
#   'dll_id_author': 'A3945'},
#  'in librum psalmorum breuis explanatio ad alexandrum farnesium, cardinalem amplissimum': {'dll_id_work': 'W4872',
#   'dll_id_author': 'A3968'},
#  'historiae venetae': {'dll_id_work': 'W4840', 'dll_id_author': 'A5607'},
#  'de asse et partibus ius': {'dll_id_work': 'W4833', 'dll_id_author': 'A5600'},
#  'epigrammata duodecim': {'dll_id_work': 'W4857', 'dll_id_author': 'A4758'},
#  'neniae duodecim': {'dll_id_work': 'W4853', 'dll_id_author': 'A4758'},
#  'tumulorum liber i': {'dll_id_work': 'W4848', 'dll_id_author': 'A4758'},
#  'lepidina': {'dll_id_work': 'W4836', 'dll_id_author': 'A4758'},
#  'de hortis hesperidum sive de cultu citriorum': {'dll_id_work': 'W4854',
#   'dll_id_author': 'A4758'},
#  'de luna fragmentum': {'dll_id_work': 'W4850', 'dll_id_author': 'A4758'},
#  'de fortuna': {'dll_id_work': 'W4851', 'dll_id_author': 'A4758'},
#  'liber de meteoris': {'dll_id_work': 'W4845', 'dll_id_author': 'A4758'},
#  'de immanitate': {'dll_id_work': 'W4846', 'dll_id_author': 'A4758'},
#  'epistolae': {'dll_id_work': 'W1934', 'dll_id_author': 'A5393'},
#  'de bello neapolitano': {'dll_id_work': 'W4829', 'dll_id_author': 'A4758'},
#  'de rebus coelestibus libri xiv': {'dll_id_work': 'W4837',
#   'dll_id_author': 'A4758'},
#  'dialogi': {'dll_id_work': 'W1597', 'dll_id_author': 'A4655'},
#  'aegidius': {'dll_id_work': 'W4866', 'dll_id_author': 'A4758'},
#  'actius': {'dll_id_work': 'W4861', 'dll_id_author': 'A4758'},
#  'asinus': {'dll_id_work': 'W4884', 'dll_id_author': 'A4758'},
#  'antonius': {'dll_id_work': 'W4877', 'dll_id_author': 'A4758'},
#  'charon': {'dll_id_work': 'W4871', 'dll_id_author': 'A4758'},
#  'de sermone libri vi': {'dll_id_work': 'W4835', 'dll_id_author': 'A4758'},
#  'commentationes in centum claudii ptolemaei sententias': {'dll_id_work': 'W4831',
#   'dll_id_author': 'A4758'},
#  'tractatus': {'dll_id_work': 'W365', 'dll_id_author': 'A4821'},
#  'de aspiratione': {'dll_id_work': 'W3575', 'dll_id_author': 'A4905'},
#  'de magnanimitate': {'dll_id_work': 'W4839', 'dll_id_author': 'A4758'},
#  'de prudentia': {'dll_id_work': 'W4832', 'dll_id_author': 'A4758'},
#  'de conviventia': {'dll_id_work': 'W4856', 'dll_id_author': 'A4758'},
#  'de splendore': {'dll_id_work': 'W4852', 'dll_id_author': 'A4758'},
#  'de magnificentia': {'dll_id_work': 'W4847', 'dll_id_author': 'A4758'},
#  'de beneficentia': {'dll_id_work': 'W4841', 'dll_id_author': 'A4758'},
#  'de liberalitate': {'dll_id_work': 'W4834', 'dll_id_author': 'A4758'},
#  'de fortitudine': {'dll_id_work': 'W4859', 'dll_id_author': 'A4758'},
#  'de oboedientia': {'dll_id_work': 'W4882', 'dll_id_author': 'A4758'},
#  'de principe': {'dll_id_work': 'W4951', 'dll_id_author': 'A3806'},
#  'urania sive de stellis libri v': {'dll_id_work': 'W4863',
#   'dll_id_author': 'A4758'},
#  'hendecasyllaborum seu baiarum libri ii': {'dll_id_work': 'W4887',
#   'dll_id_author': 'A4758'},
#  'eridanus': {'dll_id_work': 'W4880', 'dll_id_author': 'A4758'},
#  'meliseus': {'dll_id_work': 'W4874', 'dll_id_author': 'A4758'},
#  'de amore coniugali libri iii': {'dll_id_work': 'W4869',
#   'dll_id_author': 'A4758'},
#  'acon': {'dll_id_work': 'W4865', 'dll_id_author': 'A4758'},
#  'maeon': {'dll_id_work': 'W4828', 'dll_id_author': 'A4758'},
#  'parthenopei sive amorum libri ii': {'dll_id_work': 'W4849',
#   'dll_id_author': 'A4758'},
#  'de meteoris': {'dll_id_work': 'W4860', 'dll_id_author': 'A4758'},
#  'summa theologiae': {'dll_id_work': 'W5219', 'dll_id_author': 'A4997'},
#  'sermones': {'dll_id_work': 'W5019', 'dll_id_author': 'A5497'},
#  'lutheranismi hypotyposis': {'dll_id_work': 'W5013',
#   'dll_id_author': 'A4214'},
#  'chronica pontificum et imperatorum': {'dll_id_work': 'W3565',
#   'dll_id_author': 'A5587'},
#  'ars grammatica': {'dll_id_work': 'W2912', 'dll_id_author': 'A5127'},
#  'summa theologica': {'dll_id_work': 'W4347', 'dll_id_author': 'A4151'},
#  'periochae terentii comoediarum': {'dll_id_work': 'W4952',
#   'dll_id_author': 'A4569'},
#  'epist. a p. cornelio dolabella': {'dll_id_work': 'W2320',
#   'dll_id_author': 'A3611'},
#  'de analogia ad m. tullium ciceronem': {'dll_id_work': 'W4391',
#   'dll_id_author': 'A4644'},
#  'epist. a cn. matius': {'dll_id_work': 'W5181', 'dll_id_author': 'A4634'},
#  'iurisprudentia': {'dll_id_work': 'W663', 'dll_id_author': 'A3579'},
#  'epist. ab antonino pio': {'dll_id_work': 'W5057', 'dll_id_author': 'A2911'},
#  'epist. a domitiano': {'dll_id_work': 'W4068', 'dll_id_author': 'A2907'},
#  'fragmentum in quint. inst.': {'dll_id_work': 'W3897',
#   'dll_id_author': 'A2909'},
#  'epist. ab l. lucceio': {'dll_id_work': 'W3842', 'dll_id_author': 'A2878'},
#  'epist. ab l. aurelio vero': {'dll_id_work': 'W3723',
#   'dll_id_author': 'A2891'},
#  'epist. a p. cornelio lentulo spinthero': {'dll_id_work': 'W3506',
#   'dll_id_author': 'A2872'},
#  'epist. a q. caecilio metello celeri': {'dll_id_work': 'W3323',
#   'dll_id_author': 'A2875'},
#  'epist. a m’. curio': {'dll_id_work': 'W2038', 'dll_id_author': 'A2885'},
#  'epist. ab m. claudio marcello': {'dll_id_work': 'W1628',
#   'dll_id_author': 'A2871'},
#  'epist. a q. caecilio nepoti metello': {'dll_id_work': 'W1504',
#   'dll_id_author': 'A2874'},
#  'epist. a decimo iunio bruto albino': {'dll_id_work': 'W1412',
#   'dll_id_author': 'A2888'},
#  'epist. a p. vatinio': {'dll_id_work': 'W1337', 'dll_id_author': 'A2886'},
#  'epist. a nerva': {'dll_id_work': 'W648', 'dll_id_author': 'A2906'},
#  'historiae': {'dll_id_work': 'W2426', 'dll_id_author': 'A3609'},
#  'epist. ab m. lepido': {'dll_id_work': 'W483', 'dll_id_author': 'A2913'},
#  'epist. a c. trebonio': {'dll_id_work': 'W5340', 'dll_id_author': 'A2910'},
#  'fragmenta': {'dll_id_work': 'W4088', 'dll_id_author': 'A5463'},
#  'grammatica': {'dll_id_work': 'W3481', 'dll_id_author': 'A3566'},
#  'singulae uoces ex incertis libris': {'dll_id_work': 'W3117',
#   'dll_id_author': 'A5129'},
#  'de virtutibus': {'dll_id_work': 'W3133', 'dll_id_author': 'A5129'},
#  'protagoras': {'dll_id_work': 'W3084', 'dll_id_author': 'A5129'},
#  'oeconomicus': {'dll_id_work': 'W3125', 'dll_id_author': 'A5129'},
#  'de consiliis suis': {'dll_id_work': 'W3064', 'dll_id_author': 'A5129'},
#  'consolatio': {'dll_id_work': 'W3074', 'dll_id_author': 'A5129'},
#  'cato': {'dll_id_work': 'W616', 'dll_id_author': 'A5005'},
#  'de auguriis': {'dll_id_work': 'W3075', 'dll_id_author': 'A5129'},
#  'chorographia': {'dll_id_work': 'W3022', 'dll_id_author': 'A5129'},
#  'marius': {'dll_id_work': 'W3118', 'dll_id_author': 'A5129'},
#  'limon': {'dll_id_work': 'W3081', 'dll_id_author': 'A5129'},
#  'de gloria': {'dll_id_work': 'W3128', 'dll_id_author': 'A5129'},
#  'epigrammata': {'dll_id_work': 'W5061', 'dll_id_author': 'A4489'},
#  'elegia talemastis (dub.)': {'dll_id_work': 'W3054',
#   'dll_id_author': 'A5129'},
#  'alcyones': {'dll_id_work': 'W3089', 'dll_id_author': 'A5129'},
#  'fragmentum': {'dll_id_work': 'W1777', 'dll_id_author': 'A3590'},
#  'oratio': {'dll_id_work': 'W129', 'dll_id_author': 'A3620'},
#  'epistulae a traiano ad plinium': {'dll_id_work': 'W4315',
#   'dll_id_author': 'A4528'},
#  'fragmenta in macrobio': {'dll_id_work': 'W1585', 'dll_id_author': 'A5677'},
#  'oratio pridie quam in exilium iret': {'dll_id_work': 'W3082',
#   'dll_id_author': 'A5129'},
#  'pro l. vareno': {'dll_id_work': 'W3121', 'dll_id_author': 'A5129'},
#  'in toga candida': {'dll_id_work': 'W4815', 'dll_id_author': 'A4670'},
#  'pro oppio': {'dll_id_work': 'W3105', 'dll_id_author': 'A5129'},
#  'contra contionem q. metelli': {'dll_id_work': 'W3120',
#   'dll_id_author': 'A5129'},
#  'pro c. manilio': {'dll_id_work': 'W3085', 'dll_id_author': 'A5129'},
#  'pro q. gallio': {'dll_id_work': 'W3070', 'dll_id_author': 'A5129'},
#  'pro fundanio': {'dll_id_work': 'W3093', 'dll_id_author': 'A5129'},
#  'pro cornelio': {'dll_id_work': 'W4089', 'dll_id_author': 'A4670'},
#  'in p. clodium et c. curionem': {'dll_id_work': 'W3027',
#   'dll_id_author': 'A5129'},
#  'de rege alexandrino': {'dll_id_work': 'W3066', 'dll_id_author': 'A5129'},
#  'interrogatio de aere alieno milonis': {'dll_id_work': 'W3023',
#   'dll_id_author': 'A5129'},
#  'epistulae a gn. pompeio magno': {'dll_id_work': 'W3613',
#   'dll_id_author': 'A3148'},
#  'epistulae a servio sulpicio rufo': {'dll_id_work': 'W4029',
#   'dll_id_author': 'A3661'},
#  'epistulae a q. tullio cicerone': {'dll_id_work': 'W1263',
#   'dll_id_author': 'A4668'},
#  'epistulae a c. asinio pollione': {'dll_id_work': 'W3662',
#   'dll_id_author': 'A4581'},
#  'epistula ab l. munatio planco': {'dll_id_work': 'W124',
#   'dll_id_author': 'A3138'},
#  'dracontii librorum recognitio': {'dll_id_work': 'W4503',
#   'dll_id_author': 'A5395'},
#  'de situ hierusolimitanae urbis (dub.)': {'dll_id_work': 'W5166',
#   'dll_id_author': 'A5383'},
#  'epistulae sapphus (dub.)': {'dll_id_work': 'W3843',
#   'dll_id_author': 'A5522'},
#  'epistolae septem (dub.)': {'dll_id_work': 'W3726', 'dll_id_author': 'A4934'},
#  'alexandri tralliani de medicina (practica) (dub.)': {'dll_id_work': 'W3255',
#   'dll_id_author': 'A3120'},
#  'carmina (dub.)': {'dll_id_work': 'W1275', 'dll_id_author': 'A5020'},
#  'soliloquiorum animae ad deum (dub.)': {'dll_id_work': 'W2128',
#   'dll_id_author': 'A5497'},
#  'sermo de mysterio baptisimatis (dub.)': {'dll_id_work': 'W2130',
#   'dll_id_author': 'A5497'},
#  'tractatus de oratione et eleemosyna (dub.)': {'dll_id_work': 'W2124',
#   'dll_id_author': 'A5497'},
#  'speculum peccatoris (dub.)': {'dll_id_work': 'W2097',
#   'dll_id_author': 'A5497'},
#  'sermo de generalitate eleemosynarum (dub.)': {'dll_id_work': 'W2121',
#   'dll_id_author': 'A5497'},
#  'miscellanea sententiae (dub.)': {'dll_id_work': 'W2123',
#   'dll_id_author': 'A5497'},
#  'dialogus quaestionum lxv (dub.)': {'dll_id_work': 'W2096',
#   'dll_id_author': 'A5497'},
#  'de visitatione infirmorum (dub.)': {'dll_id_work': 'W2126',
#   'dll_id_author': 'A5497'},
#  'de diligendo deo (dub.)': {'dll_id_work': 'W2122', 'dll_id_author': 'A5497'},
#  'tractatus de septem vitiis et septem donis spiritus sancti (dub.)': {'dll_id_work': 'W2133',
#   'dll_id_author': 'A5497'},
#  'tractatus de creatione primi hominis (dub.)': {'dll_id_work': 'W2116',
#   'dll_id_author': 'A5497'},
#  'speculum (dub.)': {'dll_id_work': 'W2136', 'dll_id_author': 'A5497'},
#  'sermones quatuor sancto augustino attributi (dub.)': {'dll_id_work': 'W2101',
#   'dll_id_author': 'A5497'},
#  'sermones ad fratres in eremo commorantes et quosdam alios (dub.)': {'dll_id_work': 'W2099',
#   'dll_id_author': 'A5497'},
#  'sermo de eo quod neophytis ex oleo sancto aures et nares a sacerdotibus illiniantur (dub.)': {'dll_id_work': 'W2112',
#   'dll_id_author': 'A5497'},
#  'sermo de bono disciplinae (dub.)': {'dll_id_work': 'W2107',
#   'dll_id_author': 'A5497'},
#  'scala paradisi (dub.)': {'dll_id_work': 'W2132', 'dll_id_author': 'A5497'},
#  'meditationum (dub.)': {'dll_id_work': 'W2115', 'dll_id_author': 'A5497'},
#  'de vita christiana (dub.)': {'dll_id_work': 'W2134',
#   'dll_id_author': 'A5497'},
#  'de trinitate et unitate dei (dub.)': {'dll_id_work': 'W2098',
#   'dll_id_author': 'A5497'},
#  'de sobrietate et castitate (dub.)': {'dll_id_work': 'W2129',
#   'dll_id_author': 'A5497'},
#  'de rectitudine catholicae conversationis tractatus (dub.)': {'dll_id_work': 'W2111',
#   'dll_id_author': 'A5497'},
#  'de fide ad petrum sive de regula verae fidei (dub.)': {'dll_id_work': 'W2100',
#   'dll_id_author': 'A5497'},
#  'de essentia divinitatis (dub.)': {'dll_id_work': 'W2106',
#   'dll_id_author': 'A5497'},
#  'de duodecim abusionum gradibus (dub.)': {'dll_id_work': 'W2131',
#   'dll_id_author': 'A5497'},
#  'de assumptione beatae mariae virginis (dub.)': {'dll_id_work': 'W2114',
#   'dll_id_author': 'A5497'},
#  '(tractatus) de duodecim lapidibus (dub.)': {'dll_id_work': 'W2095',
#   'dll_id_author': 'A5497'},
#  'soliloquiorum adscriptorum caput postremum (dub.)': {'dll_id_work': 'W2118',
#   'dll_id_author': 'A5497'},
#  'sermo de vanitate saeculi (dub.)': {'dll_id_work': 'W2105',
#   'dll_id_author': 'A5497'},
#  'de unitate sanctae trinitatis dialogus (dub.)': {'dll_id_work': 'W2117',
#   'dll_id_author': 'A5497'},
#  'de substantia dilectionis (dub.)': {'dll_id_work': 'W2104',
#   'dll_id_author': 'A5497'},
#  'de salutaribus documentis (dub.)': {'dll_id_work': 'W2119',
#   'dll_id_author': 'A5497'},
#  'epistolae (dub.)': {'dll_id_work': 'W3546', 'dll_id_author': 'A5098'},
#  'de deo et nominibus ejus (dub.)': {'dll_id_work': 'W872',
#   'dll_id_author': 'A5096'},
#  'scripta dubiae auctoritatis (dub.)': {'dll_id_work': 'W774',
#   'dll_id_author': 'A3134'},
#  'malleus maleficarum (dub.)': {'dll_id_work': 'W626',
#   'dll_id_author': 'A5704'},
#  'tractatus de charitate (dub.)': {'dll_id_work': 'W5287',
#   'dll_id_author': 'A5497'},
#  'sermo de contemptu mundi (dub.)': {'dll_id_work': 'W5284',
#   'dll_id_author': 'A5497'},
#  'manuale (dub.)': {'dll_id_work': 'W5286', 'dll_id_author': 'A5497'},
#  'de triplici habitaculo (dub.)': {'dll_id_work': 'W5283',
#   'dll_id_author': 'A5497'},
#  'cantici magnificat expositio (dub.)': {'dll_id_work': 'W5285',
#   'dll_id_author': 'A5497'},
#  'commentarii': {'dll_id_work': 'W1496', 'dll_id_author': 'A3533'},
#  'ephemeris': {'dll_id_work': 'W5134', 'dll_id_author': 'A5314'},
#  'annales': {'dll_id_work': 'W3469', 'dll_id_author': 'A3621'},
#  'historiae per saturam': {'dll_id_work': 'W1204', 'dll_id_author': 'A2879'},
#  'de ecclesia /  cento de ecclesiis': {'dll_id_work': 'W1590',
#   'dll_id_author': 'A3068'},
#  'de aetate': {'dll_id_work': 'W4353', 'dll_id_author': 'A3055'},
#  'canones (in pauli apostoli epistula canones a peregrino episcopo)': {'dll_id_work': 'W4365',
#   'dll_id_author': 'A2917'},
#  'tractatus undecim': {'dll_id_work': 'W4343', 'dll_id_author': 'A2917'},
#  'locus vergilianus': {'dll_id_work': 'W4097', 'dll_id_author': 'A5700'},
#  'historica fragmenta': {'dll_id_work': 'W4073', 'dll_id_author': 'A3043'},
#  "epistola 'de discrictione monachorum et ruina monasteriorum'": {'dll_id_work': 'W2683',
#   'dll_id_author': 'A3067'},
#  'autobiographia': {'dll_id_work': 'W2667', 'dll_id_author': 'A5712'},
#  'epistola ad virgines monasterii sanctae mariae': {'dll_id_work': 'W2355',
#   'dll_id_author': 'A5706'},
#  'commentarii de pugna philippensi': {'dll_id_work': 'W2088',
#   'dll_id_author': 'A5711'},
#  'epistula ad quintum catulum': {'dll_id_work': 'W1657',
#   'dll_id_author': 'A3072'},
#  'epistola alexandri macedonis ad aristotelem magistruum suum de itinere suo et de situ indiae': {'dll_id_work': 'W3512',
#   'dll_id_author': 'A5709'},
#  'opera philosophica': {'dll_id_work': 'W1074', 'dll_id_author': 'A5701'},
#  'liber de catone vticensi': {'dll_id_work': 'W630', 'dll_id_author': 'A5698'},
#  'allocutio sponsalis': {'dll_id_work': 'W457', 'dll_id_author': 'A3063'},
#  'epistula ad hincmarum remensem': {'dll_id_work': 'W430',
#   'dll_id_author': 'A3053'},
#  'de vita catonis vticensis': {'dll_id_work': 'W5228',
#   'dll_id_author': 'A3075'},
#  'fragmentum historicum': {'dll_id_work': 'W401', 'dll_id_author': 'A2901'},
#  'stabat mater': {'dll_id_work': 'W643', 'dll_id_author': 'A3049'},
#  'iudicium paridis': {'dll_id_work': 'W1562', 'dll_id_author': 'A3068'},
#  'sententia de castitate sacerdotum': {'dll_id_work': 'W1589',
#   'dll_id_author': 'A5696'},
#  'epistolae duae': {'dll_id_work': 'W4276', 'dll_id_author': 'A5290'},
#  'epistolae tres': {'dll_id_work': 'W3001', 'dll_id_author': 'A5386'},
#  'historia': {'dll_id_work': 'W334', 'dll_id_author': 'A4346'},
#  'stephani abbatis epistola ad sanctum aunarium': {'dll_id_work': 'W4401',
#   'dll_id_author': 'A3062'},
#  'versus': {'dll_id_work': 'W5017', 'dll_id_author': 'A4904'},
#  'vitae adfectatorum tyrannidis': {'dll_id_work': 'W4196',
#   'dll_id_author': 'A3110'},
#  'epistola valentis et ursacii ad julium papam': {'dll_id_work': 'W4033',
#   'dll_id_author': 'A3084'},
#  'iudicium coci et pistoris iudice vulcano': {'dll_id_work': 'W3825',
#   'dll_id_author': 'A3054'},
#  'anathematismi et fidei catholicae professio': {'dll_id_work': 'W3787',
#   'dll_id_author': 'A5705'},
#  'historia sui temporis': {'dll_id_work': 'W3741', 'dll_id_author': 'A3057'},
#  'versus eucheriae poetriae': {'dll_id_work': 'W3493',
#   'dll_id_author': 'A3088'},
#  'vita et miracula s. willelmi nordovicensis': {'dll_id_work': 'W3426',
#   'dll_id_author': 'A3077'},
#  'historia caesaris': {'dll_id_work': 'W3067', 'dll_id_author': 'A5703'},
#  'epistola ad palchonium de reliquiis sancti stephani': {'dll_id_work': 'W2961',
#   'dll_id_author': 'A3131'},
#  'edictum de confirmatione concilii toletani': {'dll_id_work': 'W2682',
#   'dll_id_author': 'A3081'},
#  'carmen bucolicum de virtute signi crocis domini': {'dll_id_work': 'W2585',
#   'dll_id_author': 'A3070'},
#  'apologia evangeliorum adversus theostenem ethnicum (fragmentum)': {'dll_id_work': 'W2490',
#   'dll_id_author': 'A3103'},
#  'de iudaeis': {'dll_id_work': 'W2068', 'dll_id_author': 'A5697'},
#  'dies irae': {'dll_id_work': 'W2052', 'dll_id_author': 'A3076'},
#  'commentarii bruti': {'dll_id_work': 'W1978', 'dll_id_author': 'A5693'},
#  'acta': {'dll_id_work': 'W1962', 'dll_id_author': 'A3052'},
#  'vita alexandri severi': {'dll_id_work': 'W2839', 'dll_id_author': 'A4890'},
#  'historicum fragmentum': {'dll_id_work': 'W1266', 'dll_id_author': 'A3047'},
#  'epistula ad eucherium lugdunensem\u200f': {'dll_id_work': 'W1208',
#   'dll_id_author': 'A3095'},
#  'magistratum': {'dll_id_work': 'W155', 'dll_id_author': 'A3066'},
#  'anthologia latina xx': {'dll_id_work': 'W172', 'dll_id_author': 'A3044'},
#  'burra': {'dll_id_work': 'W5353', 'dll_id_author': 'A5688'},
#  'vita': {'dll_id_work': 'W3783', 'dll_id_author': 'A5235'},
#  'phaedrus': {'dll_id_work': 'W1473', 'dll_id_author': 'A5668'},
#  'epistola ad desiderium': {'dll_id_work': 'W2080', 'dll_id_author': 'A3060'},
#  'medea': {'dll_id_work': 'W3852', 'dll_id_author': 'A5522'},
#  'regula ad monachos': {'dll_id_work': 'W5052', 'dll_id_author': 'A5501'},
#  'de vita imperatorum': {'dll_id_work': 'W2363', 'dll_id_author': 'A5682'},
#  'de podagra': {'dll_id_work': 'W3495', 'dll_id_author': 'A3122'},
#  'epistola cypriani ad lucium papam': {'dll_id_work': 'W4462',
#   'dll_id_author': 'A5691'},
#  'epistola ad galliae atque hispaniae episcopos': {'dll_id_work': 'W4457',
#   'dll_id_author': 'A5691'},
#  'decreta ex gratiano desumpta': {'dll_id_work': 'W4444',
#   'dll_id_author': 'A5691'},
#  'psalmi et hymni': {'dll_id_work': 'W4471', 'dll_id_author': 'A3094'},
#  'anecdotes historiques, le ́gendes et apologues': {'dll_id_work': 'W4301',
#   'dll_id_author': 'A3128'},
#  'apospasmaton de rebus emeritensibus ex hispania antiqua': {'dll_id_work': 'W4111',
#   'dll_id_author': 'A3107'},
#  'de re medicina': {'dll_id_work': 'W3906', 'dll_id_author': 'A5671'},
#  'fragmenta (tripertita)': {'dll_id_work': 'W3854', 'dll_id_author': 'A3093'},
#  'versus paschales prosodici (edyll. i)': {'dll_id_work': 'W3803',
#   'dll_id_author': 'A3102'},
#  'hymni': {'dll_id_work': 'W570', 'dll_id_author': 'A5347'},
#  'chronicum [apologia ad lectorem]': {'dll_id_work': 'W3600',
#   'dll_id_author': 'A3114'},
#  'in prophetiam danielis de quattuor animalibus': {'dll_id_work': 'W3607',
#   'dll_id_author': 'A3114'},
#  'apologeticus contra recentes impugnatorem': {'dll_id_work': 'W3561',
#   'dll_id_author': 'A3114'},
#  'chronicon omnimodae historiae': {'dll_id_work': 'W3567',
#   'dll_id_author': 'A3114'},
#  'epistola ad omnem ecclesiam': {'dll_id_work': 'W3477',
#   'dll_id_author': 'A3126'},
#  'de situ terrae sanctae': {'dll_id_work': 'W3315', 'dll_id_author': 'A3115'},
#  'explanationem in artem donatem': {'dll_id_work': 'W3218',
#   'dll_id_author': 'A3135'},
#  'decretum de ecclesia toletana': {'dll_id_work': 'W2963',
#   'dll_id_author': 'A5692'},
#  'epistolae quae ad sixtum ii attinent': {'dll_id_work': 'W2804',
#   'dll_id_author': 'A3119'},
#  'iuriprudentia': {'dll_id_work': 'W2666', 'dll_id_author': 'A3111'},
#  'historia praedestinatiana quibus initiis exorta': {'dll_id_work': 'W2079',
#   'dll_id_author': 'A5674'},
#  'grammatica?': {'dll_id_work': 'W1106', 'dll_id_author': 'A3568'},
#  'malleus maleficarum': {'dll_id_work': 'W1588', 'dll_id_author': 'A5676'},
#  'de contemptu saeculi': {'dll_id_work': 'W1428', 'dll_id_author': 'A3085'},
#  'epistola consolatoria ad arcadium': {'dll_id_work': 'W1334',
#   'dll_id_author': 'A3105'},
#  'epistola ad siricum papam': {'dll_id_work': 'W1297',
#   'dll_id_author': 'A5673'},
#  'vita operaque [ex labbaeo]': {'dll_id_work': 'W780',
#   'dll_id_author': 'A3134'},
#  'epistola ad leonem papam': {'dll_id_work': 'W464', 'dll_id_author': 'A3079'},
#  'vitae': {'dll_id_work': 'W686', 'dll_id_author': 'A5005'},
#  'epistola ad senarium virum illustrem': {'dll_id_work': 'W126',
#   'dll_id_author': 'A3113'},
#  'summarii temporum': {'dll_id_work': 'W5270', 'dll_id_author': 'A3101'},
#  'epistolae dubiae (dub.)': {'dll_id_work': 'W2765', 'dll_id_author': 'A3119'},
#  'laudes thraseae paeti': {'dll_id_work': 'W2955', 'dll_id_author': 'A3090'},
#  'disputatio de rhetorica et de virtutibus': {'dll_id_work': 'W1750',
#   'dll_id_author': 'A3139'},
#  'christus xilonicus': {'dll_id_work': 'W5180', 'dll_id_author': 'A5666'},
#  'mamertini pro consulatu gratiarum actio juliano augusto': {'dll_id_work': 'W5080',
#   'dll_id_author': 'A3505'},
#  'in decem libros priores elementorum euclides commentari': {'dll_id_work': 'W5039',
#   'dll_id_author': 'A2491'},
#  'quaestiones on the posterior analytics': {'dll_id_work': 'W4941',
#   'dll_id_author': 'A4280'},
#  'diaeta theodori': {'dll_id_work': 'W4928', 'dll_id_author': 'A3493'},
#  'epistula de iure civitatis orcistenorum': {'dll_id_work': 'W2929',
#   'dll_id_author': 'A4611'},
#  'de natura generis humani': {'dll_id_work': 'W4351',
#   'dll_id_author': 'A3477'},
#  'gynaecia': {'dll_id_work': 'W4307', 'dll_id_author': 'A3477'},
#  'breviloqium': {'dll_id_work': 'W4074', 'dll_id_author': 'A5675'},
#  'de miseria condicionis humane': {'dll_id_work': 'W4050',
#   'dll_id_author': 'A3388'},
#  'fragmenta?': {'dll_id_work': 'W3837', 'dll_id_author': 'A3496'},
#  'ars dictandi': {'dll_id_work': 'W3758', 'dll_id_author': 'A4280'},
#  'de litteris et notis juris / de casis littera': {'dll_id_work': 'W3781',
#   'dll_id_author': 'A5667'},
#  'de dictamine': {'dll_id_work': 'W3620', 'dll_id_author': 'A5678'},
#  'sermo in sanctam scholaticam': {'dll_id_work': 'W3626',
#   'dll_id_author': 'A5678'},
#  'pantomimi': {'dll_id_work': 'W3629', 'dll_id_author': 'A3690'},
#  'ars palaemonis de metrica institutione': {'dll_id_work': 'W3608',
#   'dll_id_author': 'A5577'},
#  'nereus': {'dll_id_work': 'W3510', 'dll_id_author': 'A3130'},
#  'quaestiones': {'dll_id_work': 'W2456', 'dll_id_author': 'A5669'},
#  'aulularia': {'dll_id_work': 'W3797', 'dll_id_author': 'A4895'},
#  'belli carthaginiensis': {'dll_id_work': 'W2463', 'dll_id_author': 'A3667'},
#  'susanna': {'dll_id_work': 'W1983', 'dll_id_author': 'A4075'},
#  'chronologia sive libellus de mundi duratione': {'dll_id_work': 'W1881',
#   'dll_id_author': 'A5639'},
#  'expositum de die paschae et mensis': {'dll_id_work': 'W1852',
#   'dll_id_author': 'A5639'},
#  'de ponderibus et mensuris': {'dll_id_work': 'W1869',
#   'dll_id_author': 'A3137'},
#  'declamationes in catilinam': {'dll_id_work': 'W1627',
#   'dll_id_author': 'A3299'},
#  'praeceptum ad episcopos post bellum gothicum': {'dll_id_work': 'W1532',
#   'dll_id_author': 'A5681'},
#  'panegyricus genethliacus maximiano augusto dictus': {'dll_id_work': 'W1525',
#   'dll_id_author': 'A3505'},
#  'acta archelai': {'dll_id_work': 'W1256', 'dll_id_author': 'A3143'},
#  'pro insipiente': {'dll_id_work': 'W890', 'dll_id_author': 'A3121'},
#  'ludite': {'dll_id_work': 'W882', 'dll_id_author': 'A5679'},
#  'aluta': {'dll_id_work': 'W752', 'dll_id_author': 'A3927'},
#  'euripidis cyclops': {'dll_id_work': 'W731', 'dll_id_author': 'A3133'},
#  'edictum tolerationis': {'dll_id_work': 'W466', 'dll_id_author': 'A5670'},
#  'notae tironianae': {'dll_id_work': 'W269', 'dll_id_author': 'A3550'},
#  'secreti secretorum': {'dll_id_work': 'W22', 'dll_id_author': 'A3548'},
#  'oeconomica': {'dll_id_work': 'W1', 'dll_id_author': 'A3548'},
#  'panegyricus maximiano augusto dictus': {'dll_id_work': 'W5269',
#   'dll_id_author': 'A3505'},
#  'epitome altera': {'dll_id_work': 'W5363', 'dll_id_author': 'A3477'},
#  'kalendarium anno cccliv conscriptum': {'dll_id_work': 'W4921',
#   'dll_id_author': 'A4898'},
#  'de pedibus': {'dll_id_work': 'W215', 'dll_id_author': 'A3507'},
#  'sanctae brigidae virginis vita a cogitoso adornata': {'dll_id_work': 'W3664',
#   'dll_id_author': 'A5263'},
#  'oratio in gymnasio in ingelstadio publice recitata': {'dll_id_work': 'W3584',
#   'dll_id_author': 'A4753'},
#  'de gratia': {'dll_id_work': 'W3475', 'dll_id_author': 'A5243'},
#  'concilium romanum ii (ad 0495)': {'dll_id_work': 'W3403',
#   'dll_id_author': 'A5211'},
#  'concilium romanum i decreta': {'dll_id_work': 'W3399',
#   'dll_id_author': 'A5211'},
#  'concilium romanum i (ad 0494)': {'dll_id_work': 'W3395',
#   'dll_id_author': 'A5211'},
#  'somnium scipionem': {'dll_id_work': 'W3083', 'dll_id_author': 'A5129'},
#  'scripta quae exstant': {'dll_id_work': 'W3032', 'dll_id_author': 'A5189'},
#  'de consulatu suo': {'dll_id_work': 'W3104', 'dll_id_author': 'A5129'},
#  'decretalium compilatio': {'dll_id_work': 'W2978', 'dll_id_author': 'A4320'},
#  'mimus': {'dll_id_work': 'W5364', 'dll_id_author': 'A3543'},
#  'sententiarum liber quartus (appendix ix) (dub.)': {'dll_id_work': 'W2590',
#   'dll_id_author': 'A5183'},
#  'differentiarum, sive de proprietate sermonum, liber (appendix xxiii)': {'dll_id_work': 'W2588',
#   'dll_id_author': 'A5183'},
#  'hymnus eidem ab eodem missus': {'dll_id_work': 'W2545',
#   'dll_id_author': 'A5124'},
#  'epistulae ad traianum': {'dll_id_work': 'W2313', 'dll_id_author': 'A4904'},
#  'carmina erotica': {'dll_id_work': 'W1964', 'dll_id_author': 'A4758'},
#  'platonis timaeus commentaria': {'dll_id_work': 'W1703',
#   'dll_id_author': 'A4544'},
#  'instituta artium': {'dll_id_work': 'W1416', 'dll_id_author': 'A4588'},
#  'metrum parhemiacum tragicum': {'dll_id_work': 'W1354',
#   'dll_id_author': 'A5338'},
#  'registri epistolarum [appendix]': {'dll_id_work': 'W1279',
#   'dll_id_author': 'A4981'},
#  'excerpta ex patribus, collectanea': {'dll_id_work': 'W1151',
#   'dll_id_author': 'A5363'},
#  'carmina dubia': {'dll_id_work': 'W4185', 'dll_id_author': 'A4951'},
#  'nomina musarum': {'dll_id_work': 'W700', 'dll_id_author': 'A5314'},
#  'precationes duae ante missam': {'dll_id_work': 'W511',
#   'dll_id_author': 'A5347'},
#  'vita sanctae pelagiae': {'dll_id_work': 'W456', 'dll_id_author': 'A5198'},
#  'sermones s. ambrosio ascripti': {'dll_id_work': 'W484',
#   'dll_id_author': 'A5347'},
#  'sermones tres': {'dll_id_work': 'W491', 'dll_id_author': 'A5347'},
#  'decreta ex epistolis excerpta': {'dll_id_work': 'W2499',
#   'dll_id_author': 'A5197'},
#  'glossae': {'dll_id_work': 'W201', 'dll_id_author': 'A5018'},
#  'anastasii ad landuleum epistola, de scriptura (translationis stephenis martyris)': {'dll_id_work': 'W175',
#   'dll_id_author': 'A5103'},
#  'fragmenta quae ad historiam francorum pertinent': {'dll_id_work': 'W96',
#   'dll_id_author': 'A4722'},
#  'chronicum sive appendix ad gregorii turonensis historiam francorum': {'dll_id_work': 'W65',
#   'dll_id_author': 'A4722'},
#  'liber de essentia patris et filii': {'dll_id_work': 'W5301',
#   'dll_id_author': 'A5124'},
#  'de humilitate et obedientia et de calcanda superbia': {'dll_id_work': 'W5321',
#   'dll_id_author': 'A5032'},
#  'de chorographia': {'dll_id_work': 'W3840', 'dll_id_author': 'A4607'},
#  'discipline clericalis': {'dll_id_work': 'W2321', 'dll_id_author': 'A4775'},
#  'de musis versus': {'dll_id_work': 'W2425', 'dll_id_author': 'A4479'},
#  'in epistolam beati pauli ad colossenses': {'dll_id_work': 'W519',
#   'dll_id_author': 'A5347'},
#  'liber de vitiorum virtutum conflictu': {'dll_id_work': 'W5163',
#   'dll_id_author': 'A5347'},
#  'in epistolam beati pauli ad titum': {'dll_id_work': 'W5162',
#   'dll_id_author': 'A5347'},
#  'epistola ad stephanum abbatem': {'dll_id_work': 'W2477',
#   'dll_id_author': 'A5362'},
#  'sermones. de symbolo ad catechumenos sermo alius ii': {'dll_id_work': 'W2194',
#   'dll_id_author': 'A5497'},
#  'sermones. de symbolo ad catechumenos sermo alius': {'dll_id_work': 'W2191',
#   'dll_id_author': 'A5497'},
#  'sermones. de symbolo sermo ad catechumenos': {'dll_id_work': 'W2197',
#   'dll_id_author': 'A5497'},
#  'sermones x [ex cod cassinen]. sanctissimo domino nostro pio papae vii': {'dll_id_work': 'W2144',
#   'dll_id_author': 'A5497'},
#  'sermones dubii. de cataclysmo sermo ad catechumenos': {'dll_id_work': 'W2135',
#   'dll_id_author': 'A5497'},
#  'sermones ad populum. sermo sancti presbyteri eraclii discipuli sancti augustini': {'dll_id_work': 'W2127',
#   'dll_id_author': 'A5497'},
#  'sermonum fragmenta': {'dll_id_work': 'W2140', 'dll_id_author': 'A5497'},
#  'sermones ad populum. classis v. sermones dubii': {'dll_id_work': 'W2103',
#   'dll_id_author': 'A5497'},
#  'sermones quatuor': {'dll_id_work': 'W2092', 'dll_id_author': 'A5497'},
#  'sermones inediti admixtis quibusdam dubiis': {'dll_id_work': 'W2108',
#   'dll_id_author': 'A5497'},
#  'in epistolam beati pauli ad thessalonicenses secundam': {'dll_id_work': 'W566',
#   'dll_id_author': 'A5347'},
#  'philosophorum breves epistolae': {'dll_id_work': 'W577',
#   'dll_id_author': 'A5347'},
#  'in epistolam beati pauli ad timotheum primam': {'dll_id_work': 'W546',
#   'dll_id_author': 'A5347'},
#  'de vocatione gentium libri duo': {'dll_id_work': 'W550',
#   'dll_id_author': 'A5347'},
#  'in epistolam beati pauli ad timotheum secundam': {'dll_id_work': 'W548',
#   'dll_id_author': 'A5347'},
#  'in epistolam beati pauli ad romanos': {'dll_id_work': 'W552',
#   'dll_id_author': 'A5347'},
#  'in epistolam beati pauli ad philemonem': {'dll_id_work': 'W516',
#   'dll_id_author': 'A5347'},
#  'in epistolam beati pauli ad galatas': {'dll_id_work': 'W509',
#   'dll_id_author': 'A5347'},
#  'in epistolam beati pauli ad ephesios': {'dll_id_work': 'W534',
#   'dll_id_author': 'A5347'},
#  'in epistolam beati pauli (ad romanos--ad corinthios primam--ad corinthios secundam-- ad galatas--ad ephesios--ad philippenses -- ad colossenses--ad thessalonices--ad timotheum --ad titum -- ad philemonem)': {'dll_id_work': 'W512',
#   'dll_id_author': 'A5347'},
#  'expositio in septem visiones libri apocalypsis': {'dll_id_work': 'W535',
#   'dll_id_author': 'A5347'},
#  'de moribus brachmanorum': {'dll_id_work': 'W514', 'dll_id_author': 'A5347'},
#  'de excidio urbis hierosolymitanae libri quinque': {'dll_id_work': 'W532',
#   'dll_id_author': 'A5347'},
#  'de dignitate sacerdotali libellus': {'dll_id_work': 'W551',
#   'dll_id_author': 'A5347'},
#  'de concordia matthaei et lucae in genealogia christi': {'dll_id_work': 'W515',
#   'dll_id_author': 'A5347'},
#  'commentaria in epistolas b. pauli': {'dll_id_work': 'W533',
#   'dll_id_author': 'A5347'},
#  'ad virginem devotam': {'dll_id_work': 'W553', 'dll_id_author': 'A5347'},
#  'in epistolam beati pauli ad thessalonicenses primam': {'dll_id_work': 'W530',
#   'dll_id_author': 'A5347'},
#  'in epistolam beati pauli ad corinthios secundam': {'dll_id_work': 'W526',
#   'dll_id_author': 'A5347'},
#  'exorcismus': {'dll_id_work': 'W1771', 'dll_id_author': 'A5094'},
#  'de trinitate': {'dll_id_work': 'W2237', 'dll_id_author': 'A5497'},
#  'de lapsu virginis consecratae liber': {'dll_id_work': 'W506',
#   'dll_id_author': 'A5347'},
#  'commentarius in cantica canticorum': {'dll_id_work': 'W507',
#   'dll_id_author': 'A5347'},
#  'in epistolam beati pauli ad corinthios primam': {'dll_id_work': 'W493',
#   'dll_id_author': 'A5347'},
#  'acta s. sebastiani': {'dll_id_work': 'W492', 'dll_id_author': 'A5347'},
#  'in epistolam beati pauli ad philippenses': {'dll_id_work': 'W490',
#   'dll_id_author': 'A5347'},
#  'de dignitate conditionis humanae libellus': {'dll_id_work': 'W488',
#   'dll_id_author': 'A5347'},
#  'quaestionum in pentateuchum': {'dll_id_work': 'W2183',
#   'dll_id_author': 'A5497'},
#  'de vita eremitica ad sororem': {'dll_id_work': 'W2160',
#   'dll_id_author': 'A5497'},
#  'de spiritu et anima': {'dll_id_work': 'W1920', 'dll_id_author': 'A4494'},
#  'sermones ad populum. classis i. de scripturis': {'dll_id_work': 'W2192',
#   'dll_id_author': 'A5497'},
#  'sermo arianorum': {'dll_id_work': 'W2193', 'dll_id_author': 'A5497'},
#  'regulae clericis traditae fragmentum': {'dll_id_work': 'W2158',
#   'dll_id_author': 'A5497'},
#  'libellus adversus fulgentium donatistam': {'dll_id_work': 'W2156',
#   'dll_id_author': 'A5497'},
#  'sermones ad populum. classis iiii. de diversis.': {'dll_id_work': 'W2141',
#   'dll_id_author': 'A5497'},
#  'sermones ad populum. classis ii. de tempore': {'dll_id_work': 'W2195',
#   'dll_id_author': 'A5497'},
#  'sermo de unctione capitis et de pedibus lavandis': {'dll_id_work': 'W2142',
#   'dll_id_author': 'A5497'},
#  'scriptura sacrae locutionum': {'dll_id_work': 'W2165',
#   'dll_id_author': 'A5497'},
#  'regula secunda': {'dll_id_work': 'W2151', 'dll_id_author': 'A5497'},
#  'regula ad servos dei': {'dll_id_work': 'W2212', 'dll_id_author': 'A5497'},
#  'opusculum iiii sive sermo in circumcisione domini': {'dll_id_work': 'W2161',
#   'dll_id_author': 'A5497'},
#  'opusculum iii sive homilia in dominica ii adventus': {'dll_id_work': 'W2154',
#   'dll_id_author': 'A5497'},
#  'opusculum i sive liber de oratione': {'dll_id_work': 'W2186',
#   'dll_id_author': 'A5497'},
#  'liber de divinis scripturis sive speculum': {'dll_id_work': 'W2163',
#   'dll_id_author': 'A5497'},
#  'hypomnesticon vulgo libri hypognosticon': {'dll_id_work': 'W2188',
#   'dll_id_author': 'A5497'},
#  'epistola ad valerium comitem': {'dll_id_work': 'W2164',
#   'dll_id_author': 'A5497'},
#  'de vera et falsa poenitentia ad christum devotam': {'dll_id_work': 'W2153',
#   'dll_id_author': 'A5497'},
#  'de tempore barbarico': {'dll_id_work': 'W2145', 'dll_id_author': 'A5497'},
#  'sermo in pervigilio paschae de esu agni': {'dll_id_work': 'W2149',
#   'dll_id_author': 'A5497'},
#  'sermo de obedientia et humilitate': {'dll_id_work': 'W2166',
#   'dll_id_author': 'A5497'},
#  'psalterium': {'dll_id_work': 'W2169', 'dll_id_author': 'A5497'},
#  'liber sententiarum xxi/ viginti unius sententiarum': {'dll_id_work': 'W2172',
#   'dll_id_author': 'A5497'},
#  'excerpta et scripta vetera ad donatistarum historiam pertinentia': {'dll_id_work': 'W2177',
#   'dll_id_author': 'A5497'},
#  'sermones ad populum. classis iii. de sanctis': {'dll_id_work': 'W2138',
#   'dll_id_author': 'A5497'},
#  'sermo de rusticiano subdiacono': {'dll_id_work': 'W2139',
#   'dll_id_author': 'A5497'},
#  'opusculum ii sive liber de quatuor virtutibus charitatis': {'dll_id_work': 'W2146',
#   'dll_id_author': 'A5497'},
#  'in psalmum xli ad neophytos': {'dll_id_work': 'W2148',
#   'dll_id_author': 'A5497'},
#  'de summa fidei': {'dll_id_work': 'W3981', 'dll_id_author': 'A5418'},
#  'de grammatica': {'dll_id_work': 'W3556', 'dll_id_author': 'A5587'},
#  'interpretatio mystica progenitorum christi': {'dll_id_work': 'W4121',
#   'dll_id_author': 'A5449'},
#  'carmen ad rotbertum regem': {'dll_id_work': 'W3974',
#   'dll_id_author': 'A5418'},
#  'rythmus satiricus': {'dll_id_work': 'W3934', 'dll_id_author': 'A5418'},
#  'vita sancti simeonis': {'dll_id_work': 'W2577', 'dll_id_author': 'A5455'},
#  'annotationes in quaedam evangeliorum loca': {'dll_id_work': 'W2528',
#   'dll_id_author': 'A5481'},
#  'de peccato originali libri dvo': {'dll_id_work': 'W2219',
#   'dll_id_author': 'A5497'},
#  'de incarnatione verbi ad januarium; ex origenis opere peri archon': {'dll_id_work': 'W2198',
#   'dll_id_author': 'A5497'},
#  'de miraculis sancti stephani protomartyris': {'dll_id_work': 'W2210',
#   'dll_id_author': 'A5497'},
#  'de contritione cordis': {'dll_id_work': 'W2196', 'dll_id_author': 'A5497'},
#  'de consolatione mortuorum [incertus. joannes chrisostomus]': {'dll_id_work': 'W2157',
#   'dll_id_author': 'A5497'},
#  'de altercatione ecclesiae et synagogae dialogus': {'dll_id_work': 'W2159',
#   'dll_id_author': 'A5497'},
#  'contra partem donati post gesta': {'dll_id_work': 'W2184',
#   'dll_id_author': 'A5497'},
#  'cognitio vitate': {'dll_id_work': 'W2162', 'dll_id_author': 'A5497'},
#  'de mirabilibus sacrae scripturae': {'dll_id_work': 'W2202',
#   'dll_id_author': 'A5497'},
#  'de benedictionibus jacob patriarchae': {'dll_id_work': 'W1041',
#   'dll_id_author': 'A5096'},
#  'de actis cum felice manichaeo': {'dll_id_work': 'W2152',
#   'dll_id_author': 'A5497'},
#  'contra secundum juliani responsionem imperfectum': {'dll_id_work': 'W2190',
#   'dll_id_author': 'A5497'},
#  'commonitorium': {'dll_id_work': 'W494', 'dll_id_author': 'A5029'},
#  'ad valentinum epistolae duae cum subsequente libro transmissae': {'dll_id_work': 'W2187',
#   'dll_id_author': 'A5497'},
#  'de antichristo': {'dll_id_work': 'W2180', 'dll_id_author': 'A5497'},
#  'de amicitia': {'dll_id_work': 'W2167', 'dll_id_author': 'A5497'},
#  'categoriae decem ex aristotele decerpatae': {'dll_id_work': 'W2155',
#   'dll_id_author': 'A5497'},
#  'ad donatistas post collationem': {'dll_id_work': 'W2173',
#   'dll_id_author': 'A5497'},
#  'de cantico novo': {'dll_id_work': 'W2150', 'dll_id_author': 'A5497'},
#  'adversus quinque haereses': {'dll_id_work': 'W2147',
#   'dll_id_author': 'A5497'},
#  'vita sancti basili': {'dll_id_work': 'W2085', 'dll_id_author': 'A5458'},
#  'vita sanctae columbae': {'dll_id_work': 'W1656', 'dll_id_author': 'A5424'},
#  'versus de cuculo': {'dll_id_work': 'W394', 'dll_id_author': 'A5450'},
#  'epitaphium': {'dll_id_work': 'W722', 'dll_id_author': 'A5121'},
#  'conflictus veris et hiemi': {'dll_id_work': 'W363',
#   'dll_id_author': 'A5450'},
#  'cella alcuini': {'dll_id_work': 'W395', 'dll_id_author': 'A5450'},
#  'de luscinia': {'dll_id_work': 'W339', 'dll_id_author': 'A5450'},
#  'fondatio abbatiae': {'dll_id_work': 'W253', 'dll_id_author': 'A5364'},
#  "ad armenium epistola 'de ratione fidei'": {'dll_id_work': 'W265',
#   'dll_id_author': 'A5470'},
#  'sequentia de sancto michaele': {'dll_id_work': 'W386',
#   'dll_id_author': 'A5450'},
#  'commentum terentii': {'dll_id_work': 'W2071', 'dll_id_author': 'A5426'},
#  'explanatio eorundem nominum ab eodem compilata': {'dll_id_work': 'W4143',
#   'dll_id_author': 'A5449'},
#  'de quarta feria sive de cultura agri dominici': {'dll_id_work': 'W5018',
#   'dll_id_author': 'A5497'},
#  'cosmographia': {'dll_id_work': 'W4930', 'dll_id_author': 'A5417'},
#  'de linguae latinae usu': {'dll_id_work': 'W5201', 'dll_id_author': 'A3050'},
#  'carmina varia (1810)': {'dll_id_work': 'W2745', 'dll_id_author': 'A5702'},
#  'comentum super poema comedie dantis (i red.)': {'dll_id_work': 'W4128',
#   'dll_id_author': 'A2992'},
#  'vicecomitum estensisque familiae veteris affinitatis, diuturnae amicitiae ac mutui praesidii memoria': {'dll_id_work': 'W5203',
#   'dll_id_author': 'A3056'},
#  'expositio herculis furentis': {'dll_id_work': 'W5186',
#   'dll_id_author': 'A5699'},
#  'expositio l. annaei senecae agamemnonis': {'dll_id_work': 'W5179',
#   'dll_id_author': 'A5699'},
#  'contra philippum beroaldum bononiensem annotationes': {'dll_id_work': 'W5195',
#   'dll_id_author': 'A3056'},
#  'fragmenta commentarii super comoediam dantis aldigherii': {'dll_id_work': 'W4210',
#   'dll_id_author': 'A3046'},
#  'comentum super poema comedie dantis (iii red.)': {'dll_id_work': 'W4093',
#   'dll_id_author': 'A2992'},
#  'elegie': {'dll_id_work': 'W2541', 'dll_id_author': 'A4732'},
#  'epistola a sforza secondo': {'dll_id_work': 'W3836',
#   'dll_id_author': 'A3020'},
#  'alfonseis': {'dll_id_work': 'W3674', 'dll_id_author': 'A5707'},
#  'latinum sermonem olim promiscuum fuisse': {'dll_id_work': 'W3241',
#   'dll_id_author': 'A3069'},
#  'de antiquitate linguae latinae': {'dll_id_work': 'W3273',
#   'dll_id_author': 'A3069'},
#  "commento all'inferno di dante": {'dll_id_work': 'W2868',
#   'dll_id_author': 'A5714'},
#  'elenchi di letture': {'dll_id_work': 'W2744', 'dll_id_author': 'A5702'},
#  'esercitazioni latine (1809)': {'dll_id_work': 'W2729',
#   'dll_id_author': 'A5702'},
#  'tractatio de perfectae poeseos ratione': {'dll_id_work': 'W2024',
#   'dll_id_author': 'A3073'},
#  'ipercalisse': {'dll_id_work': 'W1521', 'dll_id_author': 'A3065'},
#  'de dictis et factis alphonsi regis': {'dll_id_work': 'W1285',
#   'dll_id_author': 'A3024'},
#  'alphonsi regis triumphus': {'dll_id_work': 'W1298',
#   'dll_id_author': 'A3024'},
#  'spectacula lucretiana': {'dll_id_work': 'W727', 'dll_id_author': 'A3033'},
#  'bucolica': {'dll_id_work': 'W3894', 'dll_id_author': 'A4830'},
#  'expositio seu comentum super ‘comedia’ dantis allegherii': {'dll_id_work': 'W461',
#   'dll_id_author': 'A5710'},
#  'pastoralia': {'dll_id_work': 'W5300', 'dll_id_author': 'A5718'},
#  'indiculus de haeresibus (dub.)': {'dll_id_work': 'W891',
#   'dll_id_author': 'A5096'},
#  'adversus haereses (dub.)': {'dll_id_work': 'W1261',
#   'dll_id_author': 'A3143'},
#  'biblia sacra vulgata': {'dll_id_work': 'W848', 'dll_id_author': 'A5096'},
#  'versus de pugna fontanetica': {'dll_id_work': 'W1872',
#   'dll_id_author': 'A4580'},
#  'atticus': {'dll_id_work': 'W689', 'dll_id_author': 'A5005'},
#  'hannibal': {'dll_id_work': 'W649', 'dll_id_author': 'A5005'},
#  'hamilcar': {'dll_id_work': 'W641', 'dll_id_author': 'A5005'},
#  'reges': {'dll_id_work': 'W662', 'dll_id_author': 'A5005'},
#  'timoleon': {'dll_id_work': 'W691', 'dll_id_author': 'A5005'},
#  'phocion': {'dll_id_work': 'W618', 'dll_id_author': 'A5005'},
#  'eumenes': {'dll_id_work': 'W652', 'dll_id_author': 'A5005'},
#  'agesilaus': {'dll_id_work': 'W701', 'dll_id_author': 'A5005'},
#  'pelopidas': {'dll_id_work': 'W5143', 'dll_id_author': 'A5005'},
#  'epaminondas': {'dll_id_work': 'W5135', 'dll_id_author': 'A5005'},
#  'datames': {'dll_id_work': 'W684', 'dll_id_author': 'A5005'},
#  'timotheus': {'dll_id_work': 'W674', 'dll_id_author': 'A5005'},
#  'chabrias': {'dll_id_work': 'W669', 'dll_id_author': 'A5005'},
#  'iphicrates': {'dll_id_work': 'W708', 'dll_id_author': 'A5005'},
#  'dion': {'dll_id_work': 'W5139', 'dll_id_author': 'A5005'},
#  'conon': {'dll_id_work': 'W5132', 'dll_id_author': 'A5005'},
#  'thrasybulus': {'dll_id_work': 'W677', 'dll_id_author': 'A5005'},
#  'alcibiades': {'dll_id_work': 'W672', 'dll_id_author': 'A5005'},
#  'lysander': {'dll_id_work': 'W699', 'dll_id_author': 'A5005'},
#  'cimon': {'dll_id_work': 'W5137', 'dll_id_author': 'A5005'},
#  'pausanias': {'dll_id_work': 'W5131', 'dll_id_author': 'A5005'},
#  'aristides': {'dll_id_work': 'W676', 'dll_id_author': 'A5005'},
#  'themistocles': {'dll_id_work': 'W671', 'dll_id_author': 'A5005'},
#  'miltiades': {'dll_id_work': 'W698', 'dll_id_author': 'A5005'},
#  'domitianus': {'dll_id_work': 'W1550', 'dll_id_author': 'A4799'},
#  'divus titus': {'dll_id_work': 'W1542', 'dll_id_author': 'A4799'},
#  'divus vespasianus': {'dll_id_work': 'W1581', 'dll_id_author': 'A4799'},
#  'vitellius': {'dll_id_work': 'W1572', 'dll_id_author': 'A4799'},
#  'otho': {'dll_id_work': 'W1593', 'dll_id_author': 'A4799'},
#  'galba': {'dll_id_work': 'W1556', 'dll_id_author': 'A4799'},
#  'nero': {'dll_id_work': 'W3885', 'dll_id_author': 'A4723'},
#  'divus claudius': {'dll_id_work': 'W1541', 'dll_id_author': 'A4799'},
#  'caligula': {'dll_id_work': 'W1575', 'dll_id_author': 'A4799'},
#  'tiberius': {'dll_id_work': 'W1595', 'dll_id_author': 'A4799'},
#  'divus augustus': {'dll_id_work': 'W1559', 'dll_id_author': 'A4799'},
#  'divus iulius': {'dll_id_work': 'W1548', 'dll_id_author': 'A4799'},
#  'de constantia': {'dll_id_work': 'W1602', 'dll_id_author': 'A4655'},
#  'de consolatione ad marciam': {'dll_id_work': 'W1598',
#   'dll_id_author': 'A4655'},
#  'de consolatione ad helviam': {'dll_id_work': 'W1626',
#   'dll_id_author': 'A4655'},
#  'de consolatione ad polybium': {'dll_id_work': 'W1649',
#   'dll_id_author': 'A4655'},
#  'de providentia': {'dll_id_work': 'W2907', 'dll_id_author': 'A4789'},
#  'de tranquillitate animi': {'dll_id_work': 'W1606', 'dll_id_author': 'A4655'},
#  'de vita beata': {'dll_id_work': 'W1600', 'dll_id_author': 'A4655'},
#  'de brevitate vitae': {'dll_id_work': 'W1652', 'dll_id_author': 'A4655'},
#  'de otio': {'dll_id_work': 'W5273', 'dll_id_author': 'A4655'},
#  'de ira': {'dll_id_work': 'W723', 'dll_id_author': 'A5121'},
# ...
#   'dll_id_author': 'A3857'},
#  'chronica (chronographus anni cccliv)': {'dll_id_work': 'W4340',
#   'dll_id_author': 'A4898'},
#  'laterculus': {'dll_id_work': 'W2736', 'dll_id_author': 'A4870'},
#  'commentum de controversiis agrorum (dub.)': {'dll_id_work': 'W405',
#   'dll_id_author': 'A5421'},
#  'hermeneumata monacensia (dub.)': {'dll_id_work': 'W410',
#   'dll_id_author': 'A3857'},
#  'hermeneumata bruxellensia (dub.)': {'dll_id_work': 'W406',
#   'dll_id_author': 'A3857'},
#  'liber de asse (dub.)': {'dll_id_work': 'W5274', 'dll_id_author': 'A4647'},
#  'hermeneumata celtis': {'dll_id_work': 'W402', 'dll_id_author': 'A3857'},
#  'hermeneumata einsidlensia (dub.)': {'dll_id_work': 'W435',
#   'dll_id_author': 'A3857'},
#  'hermeneumata amploniana (dub.)': {'dll_id_work': 'W399',
#   'dll_id_author': 'A3857'},
#  'hermeneumata vaticana (dub.)': {'dll_id_work': 'W433',
#   'dll_id_author': 'A3857'},
#  'colloquium harleianum': {'dll_id_work': 'W440', 'dll_id_author': 'A3857'},
#  'hermeneumata stephani (dub.)': {'dll_id_work': 'W441',
#   'dll_id_author': 'A3857'},
#  'fragmenta taurinensia': {'dll_id_work': 'W1102', 'dll_id_author': 'A4258'},
#  'fragmenta panegyrici prosa conscripti': {'dll_id_work': 'W1173',
#   'dll_id_author': 'A4965'},
#  'glossae (dub.)': {'dll_id_work': 'W1247', 'dll_id_author': 'A4599'},
#  'panegyricus dictus augustoduni a. 297-8': {'dll_id_work': 'W1265',
#   'dll_id_author': 'A5368'},
#  'commentarius in vergilii eclogas et georgica': {'dll_id_work': 'W1460',
#   'dll_id_author': 'A4588'},
#  'appendix probi (dub.)': {'dll_id_work': 'W1417', 'dll_id_author': 'A4588'},
#  'de nomine': {'dll_id_work': 'W1419', 'dll_id_author': 'A4588'},
#  'de ultimis syllabis liber': {'dll_id_work': 'W1456',
#   'dll_id_author': 'A4588'},
#  'vita vergili (probiana)': {'dll_id_work': 'W1458', 'dll_id_author': 'A4588'},
#  'res gestae alexandri macedonis': {'dll_id_work': 'W1554',
#   'dll_id_author': 'A5201'},
#  'pauli diaconi epitome': {'dll_id_work': 'W1925', 'dll_id_author': 'A4966'},
#  'scholia in horatium pseudacroniana (dub.)': {'dll_id_work': 'W2383',
#   'dll_id_author': 'A3146'},
#  'dedicatio historiarum gothorum, vandalorum, sueborum ad sisenandum regem': {'dll_id_work': 'W2575',
#   'dll_id_author': 'A5183'},
#  'herbarius': {'dll_id_work': 'W2662', 'dll_id_author': 'A4502'},
#  'de herba uettonica (dub.)': {'dll_id_work': 'W2742',
#   'dll_id_author': 'A4274'},
#  'laudatio funebris in honorem matidiae socrus; aliae orationis fragmentum': {'dll_id_work': 'W2779',
#   'dll_id_author': 'A4632'},
#  'de hortis': {'dll_id_work': 'W2841', 'dll_id_author': 'A4890'},
#  'fragmentum parisinum de uerbo': {'dll_id_work': 'W3335',
#   'dll_id_author': 'A5055'},
#  'de ordinatione partium orationis (dub.)': {'dll_id_work': 'W4334',
#   'dll_id_author': 'A4574'},
#  'de orthographia liber': {'dll_id_work': 'W3466', 'dll_id_author': 'A4565'},
#  'de compositione et de numeris oratorum': {'dll_id_work': 'W3631',
#   'dll_id_author': 'A3517'},
#  'ars grammatica (ps. asper) (dub.)': {'dll_id_work': 'W3649',
#   'dll_id_author': 'A3721'},
#  'ars (de metris horatianis)': {'dll_id_work': 'W3692',
#   'dll_id_author': 'A5570'},
#  'grammatica vergiliana': {'dll_id_work': 'W3694', 'dll_id_author': 'A3721'},
#  'commentarii in verrinas (dub.)': {'dll_id_work': 'W4072',
#   'dll_id_author': 'A4670'},
#  'commentarii in diuinationem in q. caecilium (dub.)': {'dll_id_work': 'W4084',
#   'dll_id_author': 'A4670'},
#  'explanationes in artem donati (dub.)': {'dll_id_work': 'W4290',
#   'dll_id_author': 'A4777'},
#  'de littera, de syllaba, de pedibus, de accentibus, de distinctione': {'dll_id_work': 'W4266',
#   'dll_id_author': 'A4777'},
#  'de arte grammatica (ps. sergius) (dub.)': {'dll_id_work': 'W4244',
#   'dll_id_author': 'A4777'},
#  'fragmentum de soloecismo et barbarismo (dub.)': {'dll_id_work': 'W4988',
#   'dll_id_author': 'A5127'},
#  'scholia  in verg. ecl. et georg. bernensia': {'dll_id_work': 'W5054',
#   'dll_id_author': 'A5589'},
#  'commentum de agrorum qualitate (dub.)': {'dll_id_work': 'W5176',
#   'dll_id_author': 'A5421'},
#  'hermeneumata leidensia': {'dll_id_work': 'W5175', 'dll_id_author': 'A3857'},
#  'peri hermeneias liber aristotelis latine uersus': {'dll_id_work': 'W2881',
#   'dll_id_author': 'A5469'},
#  'catholica nominum et uerborum': {'dll_id_work': 'W1434',
#   'dll_id_author': 'A4588'},
#  'asclepius (dub.)': {'dll_id_work': 'W4931', 'dll_id_author': 'A5463'},
#  'flavi vopisci syracusii divus aurelianus (dub.)': {'dll_id_work': 'W3585',
#   'dll_id_author': 'A2990'},
#  'trebelli pollionis valeriani duo (dub.)': {'dll_id_work': 'W2417',
#   'dll_id_author': 'A3091'},
#  'commodus antoninus aeli lampridi (dub.)': {'dll_id_work': 'W1361',
#   'dll_id_author': 'A3117'},
#  'trebelli pollionis gallieni duo': {'dll_id_work': 'W5298',
#   'dll_id_author': 'A3091'},
#  'diadumenus antoninus aelii lampridii (dub.)': {'dll_id_work': 'W1380',
#   'dll_id_author': 'A3117'},
#  'aeli lampridii antoninus heliogabalus (dub.)': {'dll_id_work': 'W1385',
#   'dll_id_author': 'A3117'},
#  'avidius cassius vulcacii gallicani v.c. (dub.)': {'dll_id_work': 'W1793',
#   'dll_id_author': 'A5695'},
#  'aeli spartiani severus (dub.)': {'dll_id_work': 'W1970',
#   'dll_id_author': 'A3016'},
#  'pescennius niger aeli spartiani (dub.)': {'dll_id_work': 'W1939',
#   'dll_id_author': 'A3016'},
#  'didius iulianus aeli spartiani (dub.)': {'dll_id_work': 'W1966',
#   'dll_id_author': 'A3016'},
#  'antoninus geta aeli spartiani (dub.)': {'dll_id_work': 'W1965',
#   'dll_id_author': 'A3016'},
#  'aelii spartiani de vita hadriani (dub.)': {'dll_id_work': 'W1977',
#   'dll_id_author': 'A3016'},
#  'aelii spartiani aelius (dub.)': {'dll_id_work': 'W1980',
#   'dll_id_author': 'A3016'},
#  'antoninus caracallus aeli spartiani (dub.)': {'dll_id_work': 'W1982',
#   'dll_id_author': 'A3016'},
#  'trebelli pollionis tyranni triginta (dub.)': {'dll_id_work': 'W2376',
#   'dll_id_author': 'A3091'},
#  'trebelli pollionis divus claudius (dub.)': {'dll_id_work': 'W2385',
#   'dll_id_author': 'A3091'},
#  'flavi vopisci syracusii quadrigae tyrannorum (dub.)': {'dll_id_work': 'W3570',
#   'dll_id_author': 'A2990'},
#  'flavi vopisci syracusii tacitus (dub.)': {'dll_id_work': 'W3559',
#   'dll_id_author': 'A2990'},
#  'flavi vopisci syracusii probus (dub.)': {'dll_id_work': 'W3563',
#   'dll_id_author': 'A2990'},
#  'flavi vopisci syracusii carus et carinus et numerianus (dub.)': {'dll_id_work': 'W3605',
#   'dll_id_author': 'A2990'},
#  'iuli capitolini antoninus pius (dub.)': {'dll_id_work': 'W3929',
#   'dll_id_author': 'A3038'},
#  'vita marci antonini philosophi iuli capitolini (dub.)': {'dll_id_work': 'W3903',
#   'dll_id_author': 'A3038'},
#  'iuli capitolini verus (dub.)': {'dll_id_work': 'W3909',
#   'dll_id_author': 'A3038'},
#  'helvius pertinax iuli capitolini (dub.)': {'dll_id_work': 'W3923',
#   'dll_id_author': 'A3038'},
#  'vita clodii albini iulii capitolini (dub.)': {'dll_id_work': 'W3951',
#   'dll_id_author': 'A3038'},
#  'opilius macrinus iuli capitolini (dub.)': {'dll_id_work': 'W3905',
#   'dll_id_author': 'A3038'},
#  'alexander severus aeli lampridii (dub.)': {'dll_id_work': 'W5088',
#   'dll_id_author': 'A3117'},
#  'maximini duo iuli capitolini (dub.)': {'dll_id_work': 'W3982',
#   'dll_id_author': 'A3038'},
#  'gordiani tres iuli capitolini (dub.)': {'dll_id_work': 'W3956',
#   'dll_id_author': 'A3038'},
#  'maximus et balbinus iuli capitolini (dub.)': {'dll_id_work': 'W3962',
#   'dll_id_author': 'A3038'},
#  'praefatio libri': {'dll_id_work': 'W3702', 'dll_id_author': 'A3986'},
#  'poesie latine': {'dll_id_work': 'W2732', 'dll_id_author': 'A4037'},
#  'liber johannis de ravenna de primo eius introitu ad aulam': {'dll_id_work': 'W2762',
#   'dll_id_author': 'A4037'},
#  'laus pediculi': {'dll_id_work': 'W2733', 'dll_id_author': 'A3951'},
#  'eclogue': {'dll_id_work': 'W1696', 'dll_id_author': 'A3892'},
#  'acolastus': {'dll_id_work': 'W407', 'dll_id_author': 'A3960'},
#  'gesta ferdinandi regis aragonum': {'dll_id_work': 'W5281',
#   'dll_id_author': 'A3786'},
#  'carminum': {'dll_id_work': 'W5225', 'dll_id_author': 'A3968'},
#  'dialogi duo de poetis nostrorum temporum': {'dll_id_work': 'W1326',
#   'dll_id_author': 'A3950'},
#  'iulius caesar': {'dll_id_work': 'W1464', 'dll_id_author': 'A3873'},
#  'de laboribus herculis': {'dll_id_work': 'W1599', 'dll_id_author': 'A3818'},
#  'politia literaria (pars vi)': {'dll_id_work': 'W1887',
#   'dll_id_author': 'A4017'},
#  'comentum super dantis aldigherij comoediam': {'dll_id_work': 'W1969',
#   'dll_id_author': 'A3921'},
#  'itinerarium ad sepulcrum domini': {'dll_id_work': 'W1915',
#   'dll_id_author': 'A3786'},
#  'angelinetum': {'dll_id_work': 'W2022', 'dll_id_author': 'A3860'},
#  'fabula zapelleti': {'dll_id_work': 'W2344', 'dll_id_author': 'A3915'},
#  'pammachius': {'dll_id_work': 'W2403', 'dll_id_author': 'A3870'},
#  'consolatio ad donatum': {'dll_id_work': 'W2719', 'dll_id_author': 'A4037'},
#  'liber maiolichinus': {'dll_id_work': 'W2725', 'dll_id_author': 'A4037'},
#  'rationarium vite': {'dll_id_work': 'W2743', 'dll_id_author': 'A4037'},
#  'ignoramus': {'dll_id_work': 'W2874', 'dll_id_author': 'A3845'},
#  'batrachomyomachia': {'dll_id_work': 'W3132', 'dll_id_author': 'A3809'},
#  'anima christi': {'dll_id_work': 'W3489', 'dll_id_author': 'A3716'},
#  'de arte poetica': {'dll_id_work': 'W745', 'dll_id_author': 'A4876'},
#  'de eloquentia dialogus': {'dll_id_work': 'W3796', 'dll_id_author': 'A4027'},
#  'manes catulliani': {'dll_id_work': 'W3831', 'dll_id_author': 'A3719'},
#  'note a de caelo di aristotele': {'dll_id_work': 'W4100',
#   'dll_id_author': 'A3795'},
#  'vita socratis et senecae': {'dll_id_work': 'W4141',
#   'dll_id_author': 'A3863'},
#  'apologeticus': {'dll_id_work': 'W1384', 'dll_id_author': 'A5394'},
#  'de dignitate et excellentia hominis (i-ii)': {'dll_id_work': 'W4174',
#   'dll_id_author': 'A3863'},
#  'de lingue latine differentiis': {'dll_id_work': 'W4306',
#   'dll_id_author': 'A3982'},
#  'epistulae tres ad ouidianas epistulas responsoriae': {'dll_id_work': 'W4352',
#   'dll_id_author': 'A3837'},
#  'oratio in principio studii': {'dll_id_work': 'W5037',
#   'dll_id_author': 'A3786'},
#  'de hominibus doctis': {'dll_id_work': 'W5064', 'dll_id_author': 'A4046'},
#  'invective in laurentium vallam': {'dll_id_work': 'W5083',
#   'dll_id_author': 'A3971'},
#  'canis': {'dll_id_work': 'W2831', 'dll_id_author': 'A4087'},
#  'philodoxeos fabula': {'dll_id_work': 'W2836', 'dll_id_author': 'A4087'},
#  'ad magistrum thomam stretzinger octostichon': {'dll_id_work': 'W578',
#   'dll_id_author': 'A4160'},
#  'species plantarum': {'dll_id_work': 'W1358', 'dll_id_author': 'A5601'},
#  'an vulgus et literati eodem modo per terentii tullique tempora romae locuti sint': {'dll_id_work': 'W1382',
#   'dll_id_author': 'A4123'},
#  'epistulae?': {'dll_id_work': 'W1963', 'dll_id_author': 'A4075'},
#  'gelrogallorum grassatio in lovanienses per martinum a roshem: ab eximiae spei adulescentulo flandro posteritati prodita': {'dll_id_work': 'W2462',
#   'dll_id_author': 'A4215'},
#  'lirica latina': {'dll_id_work': 'W2773', 'dll_id_author': 'A4133'},
#  'momus': {'dll_id_work': 'W2798', 'dll_id_author': 'A4087'},
#  'apologi centum': {'dll_id_work': 'W2837', 'dll_id_author': 'A4087'},
#  'musca': {'dll_id_work': 'W2813', 'dll_id_author': 'A4087'},
#  'de porcaria conjuratione': {'dll_id_work': 'W2796',
#   'dll_id_author': 'A4087'},
#  'de pictura': {'dll_id_work': 'W2816', 'dll_id_author': 'A4087'},
#  'amator': {'dll_id_work': 'W2825', 'dll_id_author': 'A4087'},
#  'vita s. potiti': {'dll_id_work': 'W2823', 'dll_id_author': 'A4087'},
#  'pontifex': {'dll_id_work': 'W2830', 'dll_id_author': 'A4087'},
#  'de equo animante': {'dll_id_work': 'W2818', 'dll_id_author': 'A4087'},
#  'theoria motus lunae': {'dll_id_work': 'W2973', 'dll_id_author': 'A4169'},
#  'ioannis hunniadae res bellicae contra turcas': {'dll_id_work': 'W3491',
#   'dll_id_author': 'A4162'},
#  'de magia mathematica': {'dll_id_work': 'W3935', 'dll_id_author': 'A4076'},
#  'de triplici minimo et mensura': {'dll_id_work': 'W3931',
#   'dll_id_author': 'A4076'},
#  'il processo di pico della mirandola': {'dll_id_work': 'W3936',
#   'dll_id_author': 'A4076'},
#  'cantus circaeus': {'dll_id_work': 'W3932', 'dll_id_author': 'A4076'},
#  'de verbis romanae locutionis': {'dll_id_work': 'W3969',
#   'dll_id_author': 'A4049'},
#  'mordentius et de mordentii circino': {'dll_id_work': 'W3953',
#   'dll_id_author': 'A4076'},
#  'libri physicorum aristotelis explanati': {'dll_id_work': 'W3967',
#   'dll_id_author': 'A4076'},
#  'animadversiones in lampadem lullianam': {'dll_id_work': 'W3964',
#   'dll_id_author': 'A4076'},
#  'figuratio aristotelici physici auditus': {'dll_id_work': 'W3954',
#   'dll_id_author': 'A4076'},
#  'de lampade venatoria': {'dll_id_work': 'W3961', 'dll_id_author': 'A4076'},
#  'de monade, numero et figura': {'dll_id_work': 'W3968',
#   'dll_id_author': 'A4076'},
#  'articuli adversus mathematicos': {'dll_id_work': 'W3952',
#   'dll_id_author': 'A4076'},
#  'de somnii interpretatione': {'dll_id_work': 'W3966',
#   'dll_id_author': 'A4076'},
#  'oratio consolatoria': {'dll_id_work': 'W3979', 'dll_id_author': 'A4076'},
#  'acrotismus camoeracensis': {'dll_id_work': 'W3970',
#   'dll_id_author': 'A4076'},
#  'oratio valedictoria': {'dll_id_work': 'W3978', 'dll_id_author': 'A4076'},
#  'de architectura lulliana': {'dll_id_work': 'W4005',
#   'dll_id_author': 'A4076'},
#  'summa terminorum metaphysicorum': {'dll_id_work': 'W4003',
#   'dll_id_author': 'A4076'},
#  'de imaginum compositione': {'dll_id_work': 'W4007',
#   'dll_id_author': 'A4076'},
#  'philosophia prima siue ontologia methodo scientifica pertractata qua omnis cognitionis humanae principia continentur': {'dll_id_work': 'W4206',
#   'dll_id_author': 'A4167'},
#  'colloquium heptaplomeres': {'dll_id_work': 'W4211',
#   'dll_id_author': 'A4074'},
#  'orbis sensualium pictus': {'dll_id_work': 'W4421', 'dll_id_author': 'A4083'},
#  'argenis': {'dll_id_work': 'W5065', 'dll_id_author': 'A5595'},
#  'carmen dedicatorium in bartholomei frankfordini editionem batrachomyomachiae a iohanne reuchlin in latinum uersae': {'dll_id_work': 'W5200',
#   'dll_id_author': 'A5594'},
#  'de umbris idearum': {'dll_id_work': 'W3972', 'dll_id_author': 'A4076'},
#  'de specierum scrutinio': {'dll_id_work': 'W3976', 'dll_id_author': 'A4076'},
#  'de lampade combinatoria': {'dll_id_work': 'W3973', 'dll_id_author': 'A4076'},
#  'ars reminescendi, triginta sigilli, sigillus sigillorum': {'dll_id_work': 'W3971',
#   'dll_id_author': 'A4076'},
#  'de ciue': {'dll_id_work': 'W5193', 'dll_id_author': 'A4195'},
#  'epistulae duo ad laeuinum torrentium': {'dll_id_work': 'W4098',
#   'dll_id_author': 'A4194'},
#  "epistula ad samuelem sorberium ad thomae hobbes opus 'de ciue' pertinens": {'dll_id_work': 'W1346',
#   'dll_id_author': 'A4226'},
#  'epistulae a sepulveda conscriptae': {'dll_id_work': 'W2945',
#   'dll_id_author': 'A4189'},
#  "praefatio ad epistularum corpus basileae a. d. 1518 sub titulo 'auctarium selectarum aliquot epistolarum erasmi roterodami ad eruditos et horum ad illum' uulgatum": {'dll_id_work': 'W308',
#   'dll_id_author': 'A4247'},
#  'instructiones': {'dll_id_work': 'W1531', 'dll_id_author': 'A5248'},
#  'ormonius': {'dll_id_work': 'W5264', 'dll_id_author': 'A4242'},
#  'leviathan': {'dll_id_work': 'W130', 'dll_id_author': 'A4195'},
#  'epistolae duae ad sepulvedam': {'dll_id_work': 'W160',
#   'dll_id_author': 'A4265'},
#  'de homine': {'dll_id_work': 'W159', 'dll_id_author': 'A4195'},
#  'augustinus': {'dll_id_work': 'W178', 'dll_id_author': 'A4203'},
#  'expositiuncula de vita erasmi': {'dll_id_work': 'W336',
#   'dll_id_author': 'A4247'},
#  'ciuitas solis': {'dll_id_work': 'W438', 'dll_id_author': 'A4235'},
#  'dedicatio et carmen dedicatorium batrachomyomachiae homeri ioanne capnione metaphraste a bartholomeo frankfordino pannonio editae': {'dll_id_work': 'W1082',
#   'dll_id_author': 'A4257'},
#  'gryllus, comoedia': {'dll_id_work': 'W1064', 'dll_id_author': 'A4257'},
#  'vigilantiae et torporis uirtute arbitra certamen': {'dll_id_work': 'W1071',
#   'dll_id_author': 'A4257'},
#  'de iure belli ac pacis libri tres': {'dll_id_work': 'W1276',
#   'dll_id_author': 'A4206'},
#  'oratio de diuo leopoldo iii austriae marchione in uniuersitate vindobonensi habita': {'dll_id_work': 'W1348',
#   'dll_id_author': 'A4179'},
#  ...}

# %%
# Prepare the dictionaries for embedding the author names and titles
canonical_authors = authors.to_dict("records")
canonical_titles = works.to_dict("records")

# %% [markdown]
# ## Prepare Embeddings

# %%
from sentence_transformers import SentenceTransformer
from tqdm.notebook import tqdm
import numpy as np

# Initialize the embedding model
embedding_model = SentenceTransformer('distiluse-base-multilingual-cased-v2')

# Extract canonical titles
canonical_titles = list(title_to_work.keys())

# Generate embeddings for canonical titles
title_embeddings = embedding_model.encode(canonical_titles)

# Store the embeddings with their respective titles
title_embeddings_dict = {
    title: embedding for title, embedding in zip(canonical_titles, title_embeddings)
}

# %% [markdown]
# ## Prepare the FAISS Vector Stores
#
# Since there are many author names to keep track of, I'm going to save them in a vector store for easier and more rapid searching instead of keeping them in memory.
#
# I'm using [FAISS (Facebook AI Similarity Search)](https://faiss.ai/) because it is reliable, open-source, and relatively easy to use. In previous versions of this experiment, I tried using [Chroma](https://www.trychroma.com/) and found that it was too buggy to use.

# %%
# import faiss

# # Generate author embeddings and set up FAISS
# author_embeddings = [embedding_model.encode(name) for name in variant_to_authorized.keys()]
# author_embeddings = np.array(author_embeddings, dtype=np.float32)

# dimension = author_embeddings.shape[1]
# author_index = faiss.IndexFlatL2(dimension)
# author_index.add(author_embeddings)

# # Map index positions to author names
# author_map = {i: name for i, name in enumerate(variant_to_authorized.keys())}

# %% [markdown]
# Note that it took 21m 36.6s to complete this step on my laptop's CPU.

# %%
# # Generate title embeddings and set up FAISS
# title_embeddings = [embedding_model.encode(title) for title in title_to_work.keys()]
# title_embeddings = np.array(title_embeddings, dtype=np.float32)

# dimension = title_embeddings.shape[1]
# title_index = faiss.IndexFlatL2(dimension)
# title_index.add(title_embeddings)

# # Map index positions to titles
# title_map = {i: title for i, title in enumerate(title_to_work.keys())}

# %% [markdown]
# It took 3m 10.7s to complete this step.

# %% [markdown]
# ### Save the vector stores to disk

# %%
# # Save author vector store
# faiss.write_index(author_index, "../author_index.faiss")

# # Save title vector store
# faiss.write_index(title_index, "../title_index.faiss")

# print("FAISS indices saved to disk.")

# import pickle

# # Save author_map and title_map
# with open("../author_map.pkl", "wb") as f:
#     pickle.dump(author_map, f)

# with open("../title_map.pkl", "wb") as f:
#     pickle.dump(title_map, f)

# print("Maps saved to disk.")
# Out:
# FAISS indices saved to disk.
# Maps saved to disk.

# %% [markdown]
# ## Utility Functions

# %%
# Import LatinCy for parsing title strings
import spacy

# Load the LatinCy spaCy model
try:
    nlp = spacy.load('la_core_web_lg')
except OSError:
    print("Downloading LatinCy model...")
    from spacy.cli import download
    download("")
    nlp = spacy.load('la_core_web_lg')

from spacy.lang.la import STOP_WORDS

# Augment the Latin stop words list
custom_stop_words = {"liber", "libri", "libro", "librum", "librorum", "libris", "libros"}
all_stop_words = STOP_WORDS.union(custom_stop_words)

def deterministic_author_match(input_author):
    """Match author using deterministic lookups."""
    input_author_normalized = normalize_author_name(input_author)
    author_info = variant_to_authorized.get(input_author_normalized)
    if author_info:
        print(f"Deterministic author match: {author_info}")
        return author_info
    return None


def tokenize_title(title):
    """Tokenize the title using LatinCy with robust custom lemmatization rules and augmented stop words."""
    doc = nlp(title.lower().strip())
    tokens = []
    for token in doc:
        # Correct lemmatization for specific cases
        lemma = token.lemma_
        if lemma in {"aeneidus", "aeneus"} or token.text in {"Aeneidos", "Aeneis"}:
            lemma = "aeneis"
        # Skip stop words (including custom stop words)
        if token.is_alpha and lemma not in all_stop_words:
            tokens.append(lemma)
    return tokens

def deterministic_title_match(input_title):
    """Match title using deterministic lookups or tokenized search."""
    input_title_cleaned = input_title.lower().strip()

    # Direct deterministic match
    title_info = title_to_work.get(input_title_cleaned)
    if title_info:
        title_info["title"] = input_title_cleaned  # Explicitly set the title key
        print(f"Deterministic title match: {title_info}")
        return title_info

    # Tokenized search
    input_tokens = tokenize_title(input_title)
    for token in input_tokens:
        if token in title_to_work:
            title_info = title_to_work[token]
            title_info["title"] = token  # Explicitly set the title key
            print(f"Tokenized title match: {title_info}")
            return title_info

    return None

def embedding_author_match(input_author):
    """Fallback to embedding-based author matching."""
    input_embedding = embedding_model.encode([input_author]).astype(np.float32)
    distances, indices = author_index.search(input_embedding, k=1)
    best_index = indices[0][0]
    best_match = author_map[best_index]
    similarity = 1 - distances[0][0]  # Convert L2 distance to similarity
    print(f"Embedding author match: {best_match} with similarity {similarity:.2f}")
    
    # Lower the threshold for fallback, if necessary
    return variant_to_authorized.get(best_match) if similarity > 0.75 else None

def embedding_title_match(input_title):
    """Fallback to embedding-based title matching."""
    input_embedding = embedding_model.encode([input_title]).astype(np.float32)
    distances, indices = title_index.search(input_embedding, k=1)
    best_index = indices[0][0]
    best_match = title_map[best_index]
    similarity = 1 - distances[0][0]  # Convert L2 distance to similarity
    if similarity > 0.8:  # Confidence threshold
        title_info = title_to_work.get(best_match, {"dll_id_work": "Unknown", "dll_id_author": "Unknown"})
        title_info["title"] = best_match  # Explicitly set the title key
        print(f"Embedding title match: {best_match} with similarity {similarity:.2f}")
        return title_info
    return None

def match_metadata(input_author, input_title):
    """Match metadata against canonical records."""
    # Author matching
    author_info = deterministic_author_match(input_author)
    if not author_info:
        author_info = embedding_author_match(input_author)
    if not author_info:
        author_info = {"authorized_name": "Unknown", "author_id": "Unknown"}
    
    # Title matching
    title_info = deterministic_title_match(input_title)
    if not title_info:
        title_info = embedding_title_match(input_title)
    if not title_info:
        title_info = {"matched_title": "Unknown", "dll_id_work": "Unknown", "dll_id_author": "Unknown"}
    
    # Combine results
    return {
        "author_info": author_info,
        "title_info": title_info
    }

# %% [markdown]
# ## Load the Vector Stores

# %%
# Code for loading vector stores, if needed
import faiss
import pickle

author_index = faiss.read_index("../author_index.faiss")
title_index = faiss.read_index("../title_index.faiss")

with open("../author_map.pkl", "rb") as f:
    author_map = pickle.load(f)

with open("../title_map.pkl", "rb") as f:
    title_map = pickle.load(f)

# %%
# Example input metadata
incoming_metadata = [
    {"author": "Vergil", "title": "Libri Duodecim Aeneidos P. Vergilii Maronis, cum annotationibus"},
    {"author": "Joannes Herryson", "title": "De Philosophis"},
    {"author": "Unknown Author", "title": "Unknown Work"},
]

# Match each metadata record
for record in incoming_metadata:
    print("\nProcessing Record:", record)
    result = match_metadata(record["author"], record["title"])
    print("Matched Result:", result)
# Out:
# Processing Record: {'author': 'Vergil', 'title': 'Libri Duodecim Aeneidos P. Vergilii Maronis, cum annotationibus'}
# Embedding author match: virgil with similarity 0.91
# Tokenized title match: {'dll_id_work': 'W3809', 'dll_id_author': 'A4830', 'title': 'aeneis'}
# Matched Result: {'author_info': {'authorized_name': 'virgil', 'author_id': 'A4830'}, 'title_info': {'dll_id_work': 'W3809', 'dll_id_author': 'A4830', 'title': 'aeneis'}}
#
# Processing Record: {'author': 'Joannes Herryson', 'title': 'De Philosophis'}
# Deterministic author match: {'authorized_name': 'herryson, joannes', 'author_id': 'A1868'}
# Deterministic title match: {'dll_id_work': 'W10651', 'dll_id_author': 'A4799', 'title': 'de philosophis'}
# Matched Result: {'author_info': {'authorized_name': 'herryson, joannes', 'author_id': 'A1868'}, 'title_info': {'dll_id_work': 'W10651', 'dll_id_author': 'A4799', 'title': 'de philosophis'}}
#
# Processing Record: {'author': 'Unknown Author', 'title': 'Unknown Work'}
# Embedding author match: hrotsvit autorin des frühmittelalters with similarity 0.36
# Matched Result: {'author_info': {'authorized_name': 'Unknown', 'author_id': 'Unknown'}, 'title_info': {'matched_title': 'Unknown', 'dll_id_work': 'Unknown', 'dll_id_author': 'Unknown'}}

# %%
def process_metadata(input_df):
    """Process input dataframe and match metadata."""
    matched_authors = []
    authorized_names = []
    dll_id_authors = []
    author_match_similarities = []
    author_match_methods = []

    matched_titles = []
    dll_id_works = []
    title_match_similarities = []
    title_match_methods = []

    for _, row in input_df.iterrows():
        # Author processing
        input_author = row["author"]
        author_info = deterministic_author_match(input_author) or embedding_author_match(input_author)
        if not author_info:
            # If no match found, set a default fallback
            author_info = {
                "authorized_name": "Unknown",
                "author_id": "Unknown",
                "similarity": 0.0,
            }
            match_method = "unknown"
        else:
            match_method = author_info.get("match_method", "deterministic")

        matched_authors.append(input_author)
        authorized_names.append(author_info["authorized_name"])
        dll_id_authors.append(author_info["author_id"])
        author_match_similarities.append(author_info.get("similarity", 0.0))
        author_match_methods.append(match_method)

        # Title processing
        input_title = row["title"]
        title_info = deterministic_title_match(input_title) or embedding_title_match(input_title)
        if not title_info:
            title_info = {"title": "Unknown", "dll_id_work": "Unknown", "dll_id_author": "Unknown"}
            title_similarity = 0.0
            title_match_method = "unknown"
        else:
            title_similarity = title_info.get("similarity", 1.0)
            title_match_method = title_info.get("match_method", "deterministic")

        matched_titles.append(title_info["title"])
        dll_id_works.append(title_info["dll_id_work"])
        title_match_similarities.append(title_similarity)
        title_match_methods.append(title_match_method)

    # Create the output DataFrame
    output_df = input_df.copy()
    output_df["authorized_name"] = authorized_names
    output_df["dll_id_author"] = dll_id_authors
    output_df["author_match_similarity"] = author_match_similarities
    output_df["author_match_method"] = author_match_methods

    output_df["matched_title"] = matched_titles
    output_df["dll_id_work"] = dll_id_works
    output_df["title_match_similarity"] = title_match_similarities
    output_df["title_match_method"] = title_match_methods

    return output_df

input_df = pd.DataFrame(input_data)
output_df = process_metadata(input_df)


# Example usage
input_data = {
    "author": ["Vergil", "P. Vergilius Maro"],
    "title": ["Libri Duodecim Aeneidos P. Vergilii Maronis, cum annotationibus", "Aeneis"],
    "publisher": ["Publisher A", "Publisher B"],
    "place": ["Place A", "Place B"],
    "year": ["1501", "1502"],
    "url": ["http://example.com/aeneis1", "http://example.com/aeneis2"]
}

input_df = pd.DataFrame(input_data)
output_df = process_metadata(input_df)
# Out:
# Embedding author match: virgil with similarity 0.91
# Tokenized title match: {'dll_id_work': 'W3809', 'dll_id_author': 'A4830', 'title': 'aeneis'}
# Embedding author match: mariano vittori with similarity 0.65
# Deterministic title match: {'dll_id_work': 'W3809', 'dll_id_author': 'A4830', 'title': 'aeneis'}
# Embedding author match: virgil with similarity 0.91
# Tokenized title match: {'dll_id_work': 'W3809', 'dll_id_author': 'A4830', 'title': 'aeneis'}
# Embedding author match: mariano vittori with similarity 0.65
# Deterministic title match: {'dll_id_work': 'W3809', 'dll_id_author': 'A4830', 'title': 'aeneis'}

# %%
output_df
# Out:
#               author                                              title  \
# 0             Vergil  Libri Duodecim Aeneidos P. Vergilii Maronis, c...
# 1  P. Vergilius Maro                                             Aeneis
#
#      publisher    place  year                         url authorized_name  \
# 0  Publisher A  Place A  1501  http://example.com/aeneis1          virgil
# 1  Publisher B  Place B  1502  http://example.com/aeneis2          virgil
#
#   dll_id_author  author_match_similarity author_match_method matched_title  \
# 0         A4830                      0.0            embedded        aeneis
# 1         A4830                      1.0      title_fallback        aeneis
#
#   dll_id_work  title_match_similarity title_match_method
# 0       W3809                     1.0      deterministic
# 1       W3809                     1.0      deterministic

# %%
hathi = pd.read_csv('../data/hathi.csv',encoding='utf-8',quotechar='"')

# %%
hathi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24799 entries, 0 to 24798
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   author     23835 non-null  object
#  1   title      24799 non-null  object
#  2   publisher  24788 non-null  object
#  3   place      24799 non-null  object
#  4   year       24799 non-null  int64
#  5   url        24799 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 1.1+ MB

# %%
# Out:
# pandas.core.series.Series

# %%
output_df = process_metadata(hathi)
# Out:
# Embedding author match: nansius, franciscus, 1525?-1595 with similarity 0.72
# Embedding author match: meizter, ferdinand, 1828-1915 with similarity 0.48
# Embedding author match: rutgers, johannes, 1589-1625. with similarity 0.76
# Embedding author match: juliano, emperador de roma with similarity 0.64
# Embedding author match: nemezjanus with similarity 0.43
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Deterministic author match: {'authorized_name': 'kircher, athanasius, 1602-1680', 'author_id': 'A4106'}
# Tokenized title match: {'dll_id_work': 'W2525', 'dll_id_author': 'A4610', 'title': 'distributio'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: hincmar, archbishop of reims, ca. 806-882 with similarity 0.58
# Deterministic author match: {'authorized_name': 'acosta, josé de, 1540-1600', 'author_id': 'A5598'}
# Embedding author match: hincmar, archbishop of reims, ca. 806-882 with similarity 0.58
# Embedding author match: lenzi, lorenzo, ca. 1517-1571 with similarity 0.61
# Embedding author match: hincmar, archbishop of reims, ca. 806-882 with similarity 0.58
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: rous, john, ca. 1411-1491 with similarity 0.72
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: molza, francesco maria with similarity 0.73
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Deterministic author match: {'authorized_name': 'kircher, athanasius, 1602-1680', 'author_id': 'A4106'}
# Tokenized title match: {'dll_id_work': 'W1287', 'dll_id_author': 'A4743', 'title': 'methodus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Deterministic author match: {'authorized_name': 'mersenne, marin, 1588-1648', 'author_id': 'A4211'}
# Embedding author match: hincmar, archbishop of reims, ca. 806-882 with similarity 0.58
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Deterministic author match: {'authorized_name': 'kircher, athanasius, 1602-1680', 'author_id': 'A4106'}
# Tokenized title match: {'dll_id_work': 'W1287', 'dll_id_author': 'A4743', 'title': 'methodus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: meursius, johannes, 1579-1639 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Deterministic author match: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Deterministic author match: {'authorized_name': 'kepler, johannes', 'author_id': 'A4709'}
# Embedding author match: withof, johann philipp laurenz, 1725-1789 with similarity 0.61
# Embedding author match: ovid. with similarity 0.89
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Embedding author match: urceo, antonio with similarity 0.68
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'alvares, manuel, 1526-1583', 'author_id': 'A6175'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: huttenus, hulderichus, 1488-1523 with similarity 0.59
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: spangenberg, johann, 1484-1550. with similarity 0.57
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Embedding author match: addison, joseph, 1672-1719. with similarity 0.60
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Deterministic author match: {'authorized_name': 'boethius, -524', 'author_id': 'A5469'}
# Tokenized title match: {'dll_id_work': 'W3074', 'dll_id_author': 'A5129', 'title': 'consolatio'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: prosper, of aquitaine, saint, ca. 390-ca. 463. (prosper aquitanus) with similarity 0.57
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: granius licinianus. with similarity 0.55
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: nemezjanus with similarity 0.43
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: tasso, torquato, 1544-1595. with similarity 0.73
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: valerius aedituus, činný 1. století př. kr. with similarity 0.72
# Deterministic author match: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'hyginus, gromaticus', 'author_id': 'A4606'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: withof, johann philipp laurenz, 1725-1789 with similarity 0.61
# Deterministic author match: {'authorized_name': 'kepler, johannes', 'author_id': 'A4709'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: royen, adrian van 1704-1779 with similarity 0.48
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Embedding author match: valerius antias, quintus, active 1st century b.c. with similarity 0.60
# Tokenized title match: {'dll_id_work': 'W2361', 'dll_id_author': 'A5268', 'title': 'notitia'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'duns scotus, john, approximately 1266-1308', 'author_id': 'A5593'}
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Embedding author match: madvig, johan nicolai, 1804-1886. with similarity 0.47
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: addison, joseph, 1672-1719. with similarity 0.60
# Embedding author match: honorius, julius. with similarity 0.58
# Embedding author match: addison, joseph, 1672-1719. with similarity 0.60
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'commodianus', 'author_id': 'A5248'}
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'kepler, johannes', 'author_id': 'A4709'}
# Deterministic author match: {'authorized_name': 'copernicus, nicolaus, 1473-1543', 'author_id': 'A4141'}
# Embedding author match: honorius, julius. with similarity 0.58
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Embedding author match: eutropius. with similarity 0.64
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'celsus, aulus cornelius', 'author_id': 'A5349'}
# Embedding author match: marcellinus, presbyter, active 4th century with similarity 0.58
# Deterministic author match: {'authorized_name': 'bacon, roger, 1214?-1294', 'author_id': 'A4387'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: harvey, william, 1578-1657. with similarity 0.74
# Deterministic author match: {'authorized_name': 'kepler, johannes', 'author_id': 'A4709'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: nemezjanus with similarity 0.43
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Embedding author match: honorius, julius. with similarity 0.58
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'gretser, jakob, 1562-1625', 'author_id': 'A3957'}
# Tokenized title match: {'dll_id_work': 'W2830', 'dll_id_author': 'A4087', 'title': 'pontifex'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: palladius, rutilius taurus aemilianus, sec. iv-v with similarity 0.68
# Deterministic author match: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Deterministic author match: {'authorized_name': 'huygens, christiaan, 1629-1695', 'author_id': 'A4138'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: honorius, julius. with similarity 0.58
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Embedding author match: gaius galerius valerius maximianus with similarity 0.48
# Tokenized title match: {'dll_id_work': 'W4498', 'dll_id_author': 'A5182', 'title': 'epitome'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'silius italicus, tiberius catius', 'author_id': 'A4804'}
# Tokenized title match: {'dll_id_work': 'W2361', 'dll_id_author': 'A5268', 'title': 'notitia'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'victor, sextus aurelius', 'author_id': 'A4936'}
# Tokenized title match: {'dll_id_work': 'W4498', 'dll_id_author': 'A5182', 'title': 'epitome'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Embedding author match: madvig, johan nicolai, 1804-1886. with similarity 0.47
# Embedding author match: bodecher benning, johan, 1606-1642 with similarity 0.73
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'juvenal', 'author_id': 'A5304'}
# Deterministic author match: {'authorized_name': 'kircher, athanasius, 1602-1680', 'author_id': 'A4106'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'claudianus, claudius', 'author_id': 'A4503'}
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: vahlen, johannes, 1830-1911 with similarity 0.63
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'kepler, johannes', 'author_id': 'A4709'}
# Embedding author match: marcellinus, presbyter, active 4th century with similarity 0.58
# Deterministic author match: {'authorized_name': 'florus, lucius annaeus', 'author_id': 'A5047'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Embedding author match: honorius, julius. with similarity 0.58
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Embedding author match: pomponius, sextus with similarity 0.70
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'kepler, johannes', 'author_id': 'A4709'}
# Embedding author match: carrara, ubertino, s.i., 1642-1716 with similarity 0.74
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: nemezjanus with similarity 0.43
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Embedding author match: bologni, g. 1454-1517 girolamo with similarity 0.44
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'maffei, giovanni pietro, 1536?-1603', 'author_id': 'A3869'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Embedding author match: suárez, francisco with similarity 0.88
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: marcellinus, presbyter, active 4th century with similarity 0.58
# Deterministic author match: {'authorized_name': 'pliny, the elder', 'author_id': 'A5537'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: nemezjanus with similarity 0.43
# Tokenized title match: {'dll_id_work': 'W3623', 'dll_id_author': 'A5083', 'title': 'praefatio'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'kepler, johannes', 'author_id': 'A4709'}
# Embedding author match: honorius, julius. with similarity 0.58
# Embedding author match: hooghe, romeyn de, c. 1645-1708 with similarity 0.65
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Deterministic author match: {'authorized_name': 'kepler, johannes', 'author_id': 'A4709'}
# Embedding author match: honorius, julius. with similarity 0.58
# Deterministic author match: {'authorized_name': 'suárez, francisco, 1548-1617', 'author_id': 'A4125'}
# Embedding author match: baudouin, françois 1520-1573 with similarity 0.67
# Embedding author match: bordini, giovanni francesco, 1536-1609 with similarity 0.87
# Embedding author match: camden, william with similarity 0.25
# Embedding author match: porthius, johannes, 1537-1597 with similarity 0.61
# Tokenized title match: {'dll_id_work': 'W1242', 'dll_id_author': 'A5350', 'title': 'regula'}
# Deterministic author match: {'authorized_name': 'muret, marc-antoine, 1526-1585', 'author_id': 'A3873'}
# Tokenized title match: {'dll_id_work': 'W4877', 'dll_id_author': 'A4758', 'title': 'antonius'}
# Deterministic author match: {'authorized_name': 'muret, marc-antoine, 1526-1585', 'author_id': 'A3873'}
# Tokenized title match: {'dll_id_work': 'W4877', 'dll_id_author': 'A4758', 'title': 'antonius'}
# Embedding author match: krohn, fritz 1873-1941 with similarity 0.59
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: opitz, martin, 1597-1639. with similarity 0.65
# Embedding author match: candidus, petrus 1399-1477 with similarity 0.62
# Embedding author match: ritschl, friedrich wilhelm, 1806-1876. with similarity 0.61
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'curtius rufus, quintus', 'author_id': 'A4602'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'florus, lucius annaeus', 'author_id': 'A5047'}
# Tokenized title match: {'dll_id_work': 'W4498', 'dll_id_author': 'A5182', 'title': 'epitome'}
# Embedding author match: nemezjanus with similarity 0.43
# Tokenized title match: {'dll_id_work': 'W3623', 'dll_id_author': 'A5083', 'title': 'praefatio'}
# Embedding author match: schweickhofer, johannes with similarity 0.49
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Embedding author match: aynardus with similarity 0.74
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: bake, john, 1787-1864 with similarity 0.65
# Embedding author match: saint john chrysostom with similarity 0.52
# Tokenized title match: {'dll_id_work': 'W3049', 'dll_id_author': 'A5099', 'title': 'prolegomena'}
# Embedding author match: clement, of alexandria, saint, ca. 150-ca. 215 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W863', 'dll_id_author': 'A5377', 'title': 'hymnus'}
# Embedding author match: henzen, johann heinrich wilhelm, 1816-1887 with similarity 0.56
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: heraclius with similarity 0.65
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Embedding author match: heraclius with similarity 0.65
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Embedding author match: heiberg, johan ludvig, 1854-1928. with similarity 0.59
# Embedding author match: naevius, iunior with similarity 0.69
# Embedding author match: nemezjanus with similarity 0.43
# Embedding author match: pontiayus with similarity 0.84
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: gilbert, william with similarity 0.62
# Embedding author match: eutropius. with similarity 0.80
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: ildephonsus helgen with similarity 0.72
# Tokenized title match: {'dll_id_work': 'W4035', 'dll_id_author': 'A5463', 'title': 'apologia'}
# Embedding author match: kloie, samuel beniamin, 1730-1798 with similarity 0.60
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: phreas, john, 14.. ?-1465, érudit with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W390', 'dll_id_author': 'A4354', 'title': 'dialogus'}
# Deterministic author match: {'authorized_name': 'augustine, of hippo, saint, 354-430', 'author_id': 'A5497'}
# Tokenized title match: {'dll_id_work': 'W178', 'dll_id_author': 'A4203', 'title': 'augustinus'}
# Embedding author match: juliano, emperador de roma with similarity 0.64
# Embedding author match: juliano, emperador de roma with similarity 0.64
# Embedding author match: catullus, valerius with similarity 0.83
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: catullus, valerius with similarity 0.83
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: catullus, valerius with similarity 0.83
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W3101', 'dll_id_author': 'A5129', 'title': 'orator'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W3101', 'dll_id_author': 'A5129', 'title': 'orator'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W3101', 'dll_id_author': 'A5129', 'title': 'orator'}
# Embedding author match: paulus, julius with similarity 0.59
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Embedding author match: bekker, immanuel, 1785-1871. with similarity 0.57
# Deterministic author match: {'authorized_name': 'curtius rufus, quintus', 'author_id': 'A4602'}
# Deterministic author match: {'authorized_name': 'curtius rufus, quintus', 'author_id': 'A4602'}
# Deterministic author match: {'authorized_name': 'curtius rufus, quintus', 'author_id': 'A4602'}
# Embedding author match: frontinus, sextus iulius with similarity 0.69
# Embedding author match: galvani, aloysius with similarity 0.84
# Tokenized title match: {'dll_id_work': 'W689', 'dll_id_author': 'A5005', 'title': 'atticus'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Deterministic author match: {'authorized_name': 'lachmann, karl, 1793-1851', 'author_id': 'A6090'}
# Deterministic author match: {'authorized_name': 'mela, pomponius', 'author_id': 'A4607'}
# Deterministic author match: {'authorized_name': 'mela, pomponius', 'author_id': 'A4607'}
# Deterministic author match: {'authorized_name': 'nepos, cornelius', 'author_id': 'A5005'}
# Tokenized title match: {'dll_id_work': 'W616', 'dll_id_author': 'A5005', 'title': 'cato'}
# Deterministic author match: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Deterministic author match: {'authorized_name': 'ovid, 43 b.c.-17 a.d. or 18 a.d.', 'author_id': 'A5522'}
# Tokenized title match: {'dll_id_work': 'W4916', 'dll_id_author': 'A4958', 'title': 'epistola'}
# Deterministic author match: {'authorized_name': 'persius', 'author_id': 'A4892'}
# Embedding author match: paphnutius with similarity 0.82
# Tokenized title match: {'dll_id_work': 'W1473', 'dll_id_author': 'A5668', 'title': 'phaedrus'}
# Embedding author match: paphnutius with similarity 0.82
# Tokenized title match: {'dll_id_work': 'W4877', 'dll_id_author': 'A4758', 'title': 'antonius'}
# Embedding author match: paphnutius with similarity 0.82
# Embedding author match: paphnutius with similarity 0.82
# Embedding author match: paphnutius with similarity 0.82
# Embedding author match: paphnutius with similarity 0.82
# Embedding author match: paphnutius with similarity 0.82
# Embedding author match: paphnutius with similarity 0.82
# Embedding author match: paphnutius with similarity 0.82
# Embedding author match: paphnutius with similarity 0.82
# Embedding author match: paphnutius with similarity 0.82
# Embedding author match: paphnutius with similarity 0.82
# Embedding author match: nemezjanus with similarity 0.43
# Embedding author match: namatianus, claudius rutilius, active 5th century with similarity 0.78
# Deterministic author match: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Tokenized title match: {'dll_id_work': 'W937', 'dll_id_author': 'A5096', 'title': 'daniel'}
# Deterministic author match: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Tokenized title match: {'dll_id_work': 'W937', 'dll_id_author': 'A5096', 'title': 'daniel'}
# Deterministic author match: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Tokenized title match: {'dll_id_work': 'W937', 'dll_id_author': 'A5096', 'title': 'daniel'}
# Deterministic author match: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Tokenized title match: {'dll_id_work': 'W129', 'dll_id_author': 'A3620', 'title': 'oratio'}
# Deterministic author match: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Embedding author match: seneca, lucius annaeus philosophus 4 pr. kr.–65 with similarity 0.59
# Deterministic author match: {'authorized_name': 'silius italicus, tiberius catius', 'author_id': 'A4804'}
# Embedding author match: papeus, petrus with similarity 0.78
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tibullus', 'author_id': 'A4791'}
# Deterministic author match: {'authorized_name': 'tibullus', 'author_id': 'A4791'}
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'tibullus', 'author_id': 'A4791'}
# Deterministic author match: {'authorized_name': 'tibullus', 'author_id': 'A4791'}
# Embedding author match: gaius galerius valerius maximianus with similarity 0.55
# Embedding author match: optatianus porfyrius, publilius with similarity 0.76
# Deterministic author match: {'authorized_name': 'velleius paterculus', 'author_id': 'A4542'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'velleius paterculus', 'author_id': 'A4542'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'velleius paterculus', 'author_id': 'A4542'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Embedding author match: velleius paterculus, gaius, 19 a.c.-30 d.c. with similarity 0.78
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Deterministic author match: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Deterministic author match: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Embedding author match: brotier, gabriel 1723-1789 s.i. with similarity 0.47
# Embedding author match: dübner, jean-frédéric, 1802-1867 with similarity 0.69
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: gerson, jean, 1363-1429 with similarity 0.55
# Embedding author match: alanus, de insulis, m. 1202. with similarity 0.35
# Embedding author match: frey, josef, 1834-1910 with similarity 0.52
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: abbo metensis ca. 627 – 643 with similarity 0.55
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: abbo metensis ca. 627 – 643 with similarity 0.55
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: ibn rushd, muhammad with similarity 0.61
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Embedding author match: halm, carl, 1809-1882 with similarity 0.50
# Embedding author match: nemezjanus with similarity 0.43
# Embedding author match: döring, friedrich wilhelm, 1756-1837. with similarity 0.62
# Tokenized title match: {'dll_id_work': 'W2361', 'dll_id_author': 'A5268', 'title': 'notitia'}
# Deterministic author match: {'authorized_name': 'linné, carl von, 1707-1778', 'author_id': 'A5601'}
# Embedding author match: bissel, johann 1601-1682 s.i. with similarity 0.44
# Embedding author match: clement, of alexandria, saint with similarity 0.42
# Deterministic author match: {'authorized_name': 'dante alighieri, 1265-1321', 'author_id': 'A4646'}
# Embedding author match: heidenhain, friedrich jakob, 1845-1912 with similarity 0.64
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: aphthonius. with similarity 0.63
# Tokenized title match: {'dll_id_work': 'W1954', 'dll_id_author': 'A3584', 'title': 'comoedia'}
# Embedding author match: macer floridus, pseud. with similarity 0.66
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'zwingli, ulrich, 1484-1531', 'author_id': 'A5582'}
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: nemezjanus with similarity 0.43
# Tokenized title match: {'dll_id_work': 'W29', 'dll_id_author': 'A5405', 'title': 'testamentum'}
# Deterministic author match: {'authorized_name': 'anselm, saint, archbishop of canterbury', 'author_id': 'A5460'}
# Embedding author match: calvino, giovanni, 1509-1564 with similarity 0.74
# Tokenized title match: {'dll_id_work': 'W1242', 'dll_id_author': 'A5350', 'title': 'regula'}
# Embedding author match: egenolff, petrus, 1851-1901 with similarity 0.50
# Embedding author match: publilius syrus. with similarity 0.23
# Deterministic author match: {'authorized_name': 'paulus, julius', 'author_id': 'A3822'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'augustine, of hippo, saint, 354-430', 'author_id': 'A5497'}
# Tokenized title match: {'dll_id_work': 'W178', 'dll_id_author': 'A4203', 'title': 'augustinus'}
# Deterministic author match: {'authorized_name': 'augustine, of hippo, saint, 354-430', 'author_id': 'A5497'}
# Tokenized title match: {'dll_id_work': 'W178', 'dll_id_author': 'A4203', 'title': 'augustinus'}
# Deterministic author match: {'authorized_name': 'augustine, of hippo, saint, 354-430', 'author_id': 'A5497'}
# Tokenized title match: {'dll_id_work': 'W178', 'dll_id_author': 'A4203', 'title': 'augustinus'}
# Deterministic author match: {'authorized_name': 'augustine, of hippo, saint, 354-430', 'author_id': 'A5497'}
# Tokenized title match: {'dll_id_work': 'W178', 'dll_id_author': 'A4203', 'title': 'augustinus'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Embedding author match: heraclius with similarity 0.65
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Embedding author match: heraclius with similarity 0.65
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Embedding author match: heraclius with similarity 0.65
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Embedding author match: heraclius with similarity 0.65
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Embedding author match: heraclius with similarity 0.65
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Embedding author match: heraclius with similarity 0.65
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Embedding author match: heraclius with similarity 0.65
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'homer', 'author_id': 'A3276'}
# Deterministic author match: {'authorized_name': 'homer', 'author_id': 'A3276'}
# Deterministic author match: {'authorized_name': 'homer', 'author_id': 'A3276'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# ...
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'homer', 'author_id': 'A3276'}
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'homer', 'author_id': 'A3276'}
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: auspicjusz (święty). with similarity 0.18
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Deterministic author match: {'authorized_name': 'curtius rufus, quintus', 'author_id': 'A4602'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'cicero, marcus tullius', 'author_id': 'A5129'}
# Embedding author match: desiderius cadurcensis episcopus cadurcensis with similarity 0.56
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Embedding author match: persius. with similarity 0.89
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: persius. with similarity 0.89
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: ignatius diaconus. with similarity 0.59
# Embedding author match: calcidius. with similarity 0.67
# Embedding author match: clarke, john d. with similarity 0.45
# Embedding author match: wycliffe, john, -1384 with similarity 0.83
# Tokenized title match: {'dll_id_work': 'W365', 'dll_id_author': 'A4821', 'title': 'tractatus'}
# Embedding author match: fabricius, johann albert, 1668-1736. with similarity 0.49
# Embedding author match: fabricius, johann albert, 1668-1736. with similarity 0.49
# Embedding author match: meiser, karl, 1843-1912. with similarity 0.48
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: hume, david 1558?-163.? with similarity 0.71
# Embedding author match: nordmeyer, gustavus with similarity 0.39
# Deterministic author match: {'authorized_name': 'priscianus, theodorus', 'author_id': 'A3493'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Embedding author match: claudiano. with similarity 0.77
# Embedding author match: heraeus, wilhelm, 1862-1938 with similarity 0.64
# Deterministic author match: {'authorized_name': 'sallust', 'author_id': 'A5543'}
# Embedding author match: seneca, lucius annaeus philosophus 4 pr. kr.–65 with similarity 0.59
# Tokenized title match: {'dll_id_work': 'W3074', 'dll_id_author': 'A5129', 'title': 'consolatio'}
# Embedding author match: seneca, lucius annaeus philosophus 4 a. c.-65 with similarity 0.63
# Embedding author match: seneca, lucius annaeus philosophus 4 a. c.-65 with similarity 0.63
# Embedding author match: papeus, petrus with similarity 0.78
# Embedding author match: papeus, petrus with similarity 0.78
# Embedding author match: papeus, petrus with similarity 0.78
# Embedding author match: papeus, petrus with similarity 0.78
# Embedding author match: papeus, petrus with similarity 0.78
# Embedding author match: papeus, petrus with similarity 0.78
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Embedding author match: nogara, bartolomeo, barone, 1868-1954 with similarity 0.66
# Embedding author match: velleius paterculus, gaius, 19 a.c.-30 d.c. with similarity 0.78
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Deterministic author match: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Deterministic author match: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'virgil', 'author_id': 'A4830'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Deterministic author match: {'authorized_name': 'campion, thomas', 'author_id': 'A5559'}
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Deterministic author match: {'authorized_name': 'ambrose, saint, bishop of milan', 'author_id': 'A5347'}
# Tokenized title match: {'dll_id_work': 'W3074', 'dll_id_author': 'A5129', 'title': 'consolatio'}
# Embedding author match: musonius rufus, c. with similarity 0.65
# Tokenized title match: {'dll_id_work': 'W2761', 'dll_id_author': 'A3451', 'title': 'ilias'}
# Embedding author match: palingenio stellato, marcelo, ca.1500-ca.1543. with similarity 0.80
# Embedding author match: lactantius, ap 240-ap 320 with similarity 0.87
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: meiser, karl, 1843-1912. with similarity 0.57
# Tokenized title match: {'dll_id_work': 'W863', 'dll_id_author': 'A5377', 'title': 'hymnus'}
# Deterministic author match: {'authorized_name': 'luther, martin', 'author_id': 'A4756'}
# Deterministic author match: {'authorized_name': 'luther, martin', 'author_id': 'A4756'}
# Deterministic author match: {'authorized_name': 'luther, martin', 'author_id': 'A4756'}
# Deterministic author match: {'authorized_name': 'luther, martin', 'author_id': 'A4756'}
# Deterministic author match: {'authorized_name': 'luther, martin', 'author_id': 'A4756'}
# Deterministic author match: {'authorized_name': 'luther, martin', 'author_id': 'A4756'}
# Deterministic author match: {'authorized_name': 'luther, martin', 'author_id': 'A4756'}
# Deterministic author match: {'authorized_name': 'luther, martin', 'author_id': 'A4756'}
# Deterministic author match: {'authorized_name': 'juvenal', 'author_id': 'A5304'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Deterministic author match: {'authorized_name': 'horace', 'author_id': 'A4876'}
# Deterministic author match: {'authorized_name': 'juvenal', 'author_id': 'A5304'}
# Embedding author match: müller, lucian, 1836-1898, latiniste with similarity 0.37
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Deterministic author match: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Deterministic author match: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Deterministic author match: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Deterministic author match: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Deterministic author match: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Deterministic author match: {'authorized_name': 'lucretius carus, titus', 'author_id': 'A5001'}
# Deterministic author match: {'authorized_name': 'manilius, marcus', 'author_id': 'A5565'}
# Deterministic author match: {'authorized_name': 'rutilius lupus, publius', 'author_id': 'A4568'}
# Embedding author match: ovid, 43 b.c.-17 a.d. or 18 a.d. with similarity 0.84
# Tokenized title match: {'dll_id_work': 'W1777', 'dll_id_author': 'A3590', 'title': 'fragmentum'}
# Embedding author match: ovid, 43 b.c.-17 a.d. or 18 a.d. with similarity 0.84
# Deterministic author match: {'authorized_name': 'persius', 'author_id': 'A4892'}
# Tokenized title match: {'dll_id_work': 'W5075', 'dll_id_author': 'A3645', 'title': 'satura'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Deterministic author match: {'authorized_name': 'livy', 'author_id': 'A4979'}
# Deterministic author match: {'authorized_name': 'lucan', 'author_id': 'A5075'}
# Embedding author match: bekker, august immanuel, 1785-1871 with similarity 0.52
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'tacitus, cornelius', 'author_id': 'A4796'}
# Tokenized title match: {'dll_id_work': 'W334', 'dll_id_author': 'A4346', 'title': 'historia'}
# Embedding author match: ephraem, syrus, saint with similarity 0.41
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Embedding author match: porthius, johannes, 1537-1597 with similarity 0.60
# Tokenized title match: {'dll_id_work': 'W1242', 'dll_id_author': 'A5350', 'title': 'regula'}
# Deterministic author match: {'authorized_name': 'linné, carl von, 1707-1778', 'author_id': 'A5601'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Embedding author match: athanase, saint, patriarche d'alexandrie, -373 with similarity 0.77
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Embedding author match: cyprianus antiochia, bischof, heiliger -304 with similarity 0.59
# Tokenized title match: {'dll_id_work': 'W5139', 'dll_id_author': 'A5005', 'title': 'dion'}
# Embedding author match: caussin, nicolas, 1583-1651. with similarity 0.71
# Embedding author match: caussin, nicolas, 1583-1651. with similarity 0.71
# Embedding author match: caussin, nicolas, 1583-1651. with similarity 0.71
# Embedding author match: valerius aedituus, činný 1. století př. kr. with similarity 0.72
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Embedding author match: caussin, nicolas, 1583-1651. with similarity 0.71
# Embedding author match: caussin, nicolas, 1583-1651. with similarity 0.71
# Embedding author match: caussin, nicolas, 1583-1651. with similarity 0.71
# Embedding author match: nemezjanus with similarity 0.43
# Tokenized title match: {'dll_id_work': 'W923', 'dll_id_author': 'A5096', 'title': 'iob'}
# Embedding author match: koechly, hermann 1815-1876 with similarity 0.54
# Embedding author match: vahlen, johannes, 1830-1911 with similarity 0.63
# Embedding author match: vahlen, johannes, 1830-1911 with similarity 0.63
# Deterministic author match: {'authorized_name': 'thomas, à kempis, 1380-1471', 'author_id': 'A4319'}
# Deterministic author match: {'authorized_name': 'thomas, à kempis, 1380-1471', 'author_id': 'A4319'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Deterministic author match: {'authorized_name': 'thomas, aquinas, saint', 'author_id': 'A4997'}
# Embedding author match: nissen, theodor karl johannes 1873-1946 with similarity 0.51
# Embedding author match: nemezjanus with similarity 0.43
# Tokenized title match: {'dll_id_work': 'W356', 'dll_id_author': 'A3567', 'title': 'carmen'}
# Deterministic author match: {'authorized_name': 'persius', 'author_id': 'A4892'}
# Embedding author match: iuvenalis, decimus iunius ca. 67-nach 127 with similarity 0.48
# Embedding author match: nemezjanus with similarity 0.43

# %%
output_df.head()
# Out:
#                             author  \
# 0  Du Creux, François, 1596?-1666.
# 1    Meyer, Ernst H. F. 1791-1858.
# 2     Laet, Joannes de, 1593-1649.
# 3                   Caesar, Julius
# 4                          Unknown
#
#                                                title  \
# 0  Historiæ canadensis, seu Novæ-Franciæ libri de...
# 1  Ernesti Meyer de plantis labradoricis libri tres.
# 2  Novus orbis, seu Descriptionis Indiae Occident...
# 3  C. Julii Cæsaris commentariorum De Bello Galli...
# 4  Collectanea latina seu ecclesiasticæ antiquita...
#
#                                            publisher place  year  \
# 0  Apud Sebastianum Cramoisy et Sebast. Mabre-Cra...   fr   1664
# 1                    Sumtibus Leopoldi Vossii, 1830.   gw   1830
# 2                             Apud Elzevirios, 1633.   ne   1633
# 3                           Armour and Ramsay, 1849.   quc  1849
# 4                                      [s.n.], 1853.   onc  1853
#
#                                                  url authorized_name  \
# 0  https://hdl.handle.net/2027/aeu.ark:/13960/t25...         Unknown
# 1  https://hdl.handle.net/2027/aeu.ark:/13960/t5q...         Unknown
# 2  https://hdl.handle.net/2027/aeu.ark:/13960/t61...         Unknown
# 3  https://hdl.handle.net/2027/aeu.ark:/13960/t6t...         Unknown
# 4  https://hdl.handle.net/2027/aeu.ark:/13960/t77...         Unknown
#
#   dll_id_author  author_match_similarity author_match_method matched_title  \
# 0       Unknown                      0.0             unknown       Unknown
# 1       Unknown                      0.0             unknown       Unknown
# 2       Unknown                      0.0             unknown       Unknown
# 3       Unknown                      0.0             unknown       Unknown
# 4       Unknown                      0.0             unknown       Unknown
#
#   dll_id_work  title_match_similarity title_match_method
# 0     Unknown                     0.0            unknown
# 1     Unknown                     0.0            unknown
# 2     Unknown                     0.0            unknown
# 3     Unknown                     0.0            unknown
# 4     Unknown                     0.0            unknown

# %%
output_df['title_match_similarity'].value_counts()
# Out:
# title_match_similarity
# 0.0    16838
# 1.0     7961
# Name: count, dtype: int64
