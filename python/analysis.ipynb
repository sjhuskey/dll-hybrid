# %% [markdown]
# # Analysis of Output from Hybrid Approach

# %%
# Import the Pandas library
import pandas as pd

# Read in the output data
df = pd.read_csv('../data/output_df.csv',encoding='utf-8',quotechar='"')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24799 entries, 0 to 24798
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   author                   24799 non-null  object
#  1   deterministic_author     9303 non-null   object
#  2   fuzzy_author             22465 non-null  object
#  3   fuzzy_author_score       24799 non-null  float64
#  4   distilbert_author        24799 non-null  object
#  5   distilbert_author_score  24799 non-null  float64
#  6   title                    24799 non-null  object
#  7   deterministic_title      7932 non-null   object
#  8   fuzzy_title              23933 non-null  object
#  9   fuzzy_title_score        24799 non-null  float64
# dtypes: float64(3), object(7)
# memory usage: 1.9+ MB

# %% [markdown]
# ## First impressions
#
# Just looking at the output of the `info()` method, I see that there are 24,799 total rows in the dataframe. Some of the columns do not have data in all of the rows. Specifically, `deterministic_author`, `fuzzy_author`, `deterministic_title`, and `fuzzy_title` have empty cells. That suggests that the deterministic method is by far the most "conservative" approach, and it looks like the fuzzy matching approach is a distant second in that regard.

# %%
df.describe()
# Out:
#        fuzzy_author_score  distilbert_author_score  fuzzy_title_score
# count        24799.000000             24799.000000       24799.000000
# mean            84.393939                 0.820866           0.826490
# std             27.896863                 0.283701           0.157406
# min              0.000000                 0.082294           0.000000
# 25%             85.500000                 0.679279           0.855000
# 50%             90.000000                 0.999989           0.855000
# 75%            100.000000                 0.999999           0.855000
# max            100.000000                 1.000000           0.917241

# %% [markdown]
# The `describe()` method only covers three columns, but it tells its own story. The fuzzy matching method appears to be slightly more liberal, with a 84.39% matching average, while the DistilBERT model had an 82.19% average. More revealing is the quartile output, with 25% of the records getting an 85.5% match from the fuzzy method, while only the DistilBERT model returned 67.9% at that level. On the other hand, at the 50% mark and above, the DistilBERT model appears to be slightly more confident.

# %%
df.head()
# Out:
#                             author deterministic_author  \
# 0  Du Creux, François, 1596?-1666.                  NaN
# 1    Meyer, Ernst H. F. 1791-1858.                  NaN
# 2     Laet, Joannes de, 1593-1649.                  NaN
# 3                   Caesar, Julius                  NaN
# 4                          Unknown                  NaN
#
#                                         fuzzy_author  fuzzy_author_score  \
# 0  {'authorized_name': 'mirk, john, active 1403?'...                85.5
# 1  {'authorized_name': 'vopiscus, flavius', 'auth...                85.5
# 2  {'authorized_name': 'herryson, joannes', 'auth...                85.5
# 3  {'authorized_name': 'caesar, julius', 'author_...                96.0
# 4                                                NaN                 0.0
#
#                                    distilbert_author  distilbert_author_score  \
# 0  {'authorized_name': 'cruz, luís da, 1543-1604...                 0.467436
# 1  {'authorized_name': 'meyer, wilhelm, 1845-1917...                 0.999939
# 2  {'authorized_name': 'larroumet, gustave', 'aut...                 0.494394
# 3  {'authorized_name': 'caesar, julius', 'author_...                 0.999999
# 4  {'authorized_name': 'stephanus abbas 4. or 6th...                 0.177454
#
#                                                title deterministic_title  \
# 0  Historiæ canadensis, seu Novæ-Franciæ libri de...                 NaN
# 1  Ernesti Meyer de plantis labradoricis libri tres.                 NaN
# 2  Novus orbis, seu Descriptionis Indiae Occident...                 NaN
# 3  C. Julii Cæsaris commentariorum De Bello Galli...                 NaN
# 4  Collectanea latina seu ecclesiasticæ antiquita...                 NaN
#
#                                          fuzzy_title  fuzzy_title_score
# 0  {'dll_id_work': 'W10626', 'dll_id_author': 'A5...              0.855
# 1  {'dll_id_work': 'W4469', 'dll_id_author': 'A49...              0.855
# 2  {'dll_id_work': 'W10655', 'dll_id_author': 'A3...              0.855
# 3  {'dll_id_work': 'W5389', 'dll_id_author': 'A33...              0.855
# 4  {'dll_id_work': 'W10631', 'dll_id_author': 'A3...              0.855

# %%
# Get the number of unique values in the `author` column
df['author'].nunique()
# Out:
# 6018

# %% [markdown]
# ## Dealing with Greek Names
#
# It turns out that a lot of the values in the `author` column are Greek names. That's because the titles of critical editions of Greek texts are often published with Latinized forms of the authors' names and titles. That actually makes the results a little better.
#
# **Conclusion** I should remove the Greek authors before doing any analysis.
#
# Fortunately, I have a list of Greek author names that I pulled from the TLG and the Perseus Project. I'll use those to reduce the number of records in the dataframe.

# %%
# Read in Greek names
greek = pd.read_csv('../data/greek.csv',encoding='utf-8')

# %% [markdown]
# This is from a previous project. The `Latin` column has `1` for "Latin" and `0` for "Greek". I'll filter it down to just those with the "Greek" classification.
#
# I'll get a sorted list of the unique values from `Authorized Name` and use that to filter the `output_df` dataframe.

# %%
greek_list = sorted(greek['Authorized Name'].unique())
print(f"Number of unique authors in the Greek list: {len(greek_list)}")
# Use the `unique_greek_names` list to filter the original `output_df` dataframe
latin_only = df[~df['author'].isin(greek_list)]
# Get the number of unique values in the original output_df datframe
print(f"Number of unique values in the original dataframe: {df['author'].nunique()}")
# Get the number of unique values in the latin_only dataframe
print(f"Number of unique values in the latin_only dataframe: {latin_only['author'].nunique()}")
# Out:
# Number of unique authors in the Greek list: 2210
# Number of unique values in the original dataframe: 6018
# Number of unique values in the latin_only dataframe: 5939

# %%
removed_authors = df[df['author'].isin(greek_list)]
removed_authors_list = sorted(removed_authors['author'].unique())
# Check the list of authors removed
for author in removed_authors_list:
    print(author)
# Out:
# Aelian, 3rd cent.
# Aeschylus
# Alexander, of Aphrodisias
# Apollonius, Rhodius
# Apollonius, of Perga
# Archimedes
# Aretaeus, of Cappadocia
# Aristides Quintilianus
# Aristophanes
# Aristotle
# Arrian
# Artemidorus, Daldianus
# Athenaeus, of Naucratis
# Atilius Fortunatianus, 4th cent.
# Ausonius, Decimus Magnus
# Bacchylides
# Bion, of Phlossa near Smyrna
# Cassius Dio Cocceianus
# Celsus, Aulus Cornelius
# Charisius, Flavius Sosipater.
# Colluthus, of Lycopolis
# Cyril, Saint, Bishop of Jerusalem, approximately 315-386
# Demetrius, of Phaleron, b. ca. 350 B.C.
# Demosthenes
# Dictys, Cretensis
# Diodorus, Siculus
# Diogenes Laertius
# Dionysius, of Halicarnassus
# Diophantus, of Alexandria
# Dioscorides Pedanius, of Anazarbos
# Dositheus, Magister
# Ephraem, Syrus, Saint, 303-373
# Epictetus
# Epiphanius, Saint, Bishop of Constantia in Cyprus, approximately 310-403
# Euripides
# Firmicus Maternus, Julius.
# Galen
# Gregory, of Nazianzus, Saint
# Harpocration, Valerius
# Heliodorus, of Emesa
# Heraclitus, of Ephesus
# Herodotus
# Hesiod
# Hippocrates
# Homer
# Irenaeus, Saint, Bishop of Lyon
# John Chrysostom, Saint, -407
# Josephus, Flavius
# Longus
# Marcus Aurelius, Emperor of Rome, 121-180
# Michael, of Ephesus
# Musaeus, Grammaticus
# Nemesius, Bishop of Emesa
# Nicander, of Colophon
# Origen
# Pappus, of Alexandria
# Philo, of Alexandria
# Philodemus, ca. 110-ca. 40 B.C.
# Philoponus, John, 6th cent.
# Phocylides, fl. 544-541 B.C.
# Pindar
# Plato
# Plotinus
# Priscian, fl. ca. 500-530
# Pseudo-Dionysius, the Areopagite
# Ptolemy, 2nd cent.
# Quintus, Smyrnaeus, 4th cent.
# Seneca, Lucius Annaeus, ca. 4 B.C.-65 A.D.
# Sextus, Empiricus
# Sophonias
# Stobaeus
# Themistius
# Theocritus
# Theodosius, active 1st century B.C.
# Theon, of Smyrna
# Theophrastus
# Thucydides
# Tryphiodorus
# Xenophon

# %%
# Check the remaining authors for any Greek names that were missed.
for author in sorted(latin_only['author'].unique()):
    print(author)
# Out:
# Abad, Diego José, 1727-1779
# Abadía de Santillana del Mar.
# Abati, Baldo Angelo
# Abaunza, Pedro de 1599-1649.
# Abbatius, Baldus Angelus, 16th cent.
# Abbeloos, J. B. 1836-1896.
# Abbeloos, Jean Baptiste, 1836-1906.
# Abbo, Monk of St. Germain, approximately 850-approximately 923.
# Abdias, Obispo de Babilonia.
# Abelard, Peter, 1079-1142.
# Abicht, Rudolf, 1850-1921.
# Abrahams, Nicolai Christian Levin, 1798-1870.
# Abril, Pedro Simón, ca. 1530- ca. 1595.
# Abu al-Faraj al-Isbahani, 897 or 8-967.
# Abū Miḥjan al-Thaqafī, active 629-637
# Abū Miḥjan al-Thaqafī, fl. 629-637.
# Abū Tammām Ḥabīb ibn Aws al-Ṭāʼī, active 808-842
# Abū Tammām Ḥabīb ibn Aws al-Ṭāʾī, fl. 808-842,
# Abū al-Rabīʻ Sulaymān ibn ʻAbd Allāh al-Muwaḥḥid.
# Abū ʻUbayd al-Qāsim ibn Sallām, approximately 773-approximately 837
# Abū al-Faraj al-Iṣbahānī, 897 or 898-967.
# Academia Molshemensis (Francia)
# Accademia degli Occulti (Brescia)
# Acevedo, Alfonso de, 1518-1598
# Achilles Tatius
# Achilles Tatius.
# Achillini, Alessandro
# Achillini, Alessandro, 1463-1512.
# Acidalius, Valens, 1567-1595
# Ackermann, Johann Christian Gottlieb, 1756-1801
# Ackermann, Petrus Fouerius, 1771-1831
# Aconcio, Iacopo, -1566.
# Acosta, Jose de, 1540-1600.
# Acosta, José de, 1540-1600,
# Acosta, José de, 1540-1600.
# Actuarius, Johannes.
# Adam, F. 1835-1909.
# Adam, Ludwig.
# Adamnan, Santo, ca. 628-704.
# Ader, Guillaume, b. 1578.
# Ader, Guillaume.
# Adriano VI, Papa, 1459-1523.
# Aecio de Amida
# Aecio de Amida.
# Aelian, active 3rd century
# Aelian, active 3rd century.
# Aelianus, Tacticus, 2nd cent.
# Aeschines.
# Aesop
# Aesop.
# Agahd, Reinhold Hermann August.
# Agassiz, Louis, 1807-1873.
# Agathias Scholasticus, 536-582.
# Agathias, -582
# Agathias, -582.
# Agathias, d. 582.
# Agnelo de Rávena
# Agobard, Saint, 769-840.
# Agobardo, Santo, 760-840.
# Agricola, Georg, 1494-1555
# Agricola, Georg, 1494-1555.
# Agricola, Rodolphus, 1443?-1485.
# Agricola, Rudolf, 1443?-1485.
# Agrippa von Nettesheim, Heinrich Cornelius, 1486?-1535.
# Aguilon, François de (S.I.), 1567-1617
# Aguilón, François de, 1567-1617.
# Agustin, Santo, Obispo de Hipona, 354-430.
# Agustín, Antonio, 1517-1586
# Agustín, Antonio, 1517-1586.
# Agustín, Antonio, 1517-1586
# Agustín, Antonio, 1517-1586.
# Agustín, Santo, Obispo de Hipona, 354-430
# Agustín, Santo, Obispo de Hipona, 354-430.
# Ahlgrimm, Paul.
# Ahrens, Heinrich Ludolf, 1809-1881.
# Ailly, Pierre d', 1350-1420?
# Alanus de Insulis
# Alanus, de Insulis, d. 1202.
# Albani, Giovanni Girolamo, Cardenal.
# Albani, Giovanni Girolamo, Cardinal, 1504-1591
# Albategnius., d. 920.
# Albertano, da Brescia, active 13th century.
# Alberti, Leon Battista, 1404-1472
# Alberti, Leon Battista, 1404-1472.
# Albertini, Hannibal.
# Alberto Magno, Santo, 1206-1280
# Alberto Magno, Santo, 1206-1280.
# Albertus, Magnus, Saint, 1193?-1280
# Albertus, Magnus, Saint, 1193?-1280.
# Albertus, de Saxonia, d. 1390.
# Albino, Giovanni.
# Albinus, Bernhard Siegfried, 1697-1770.
# Albrecht, Andreas, d. 1628.
# Albumasar.
# Alcalá, Pedro de.
# Alciati, Andrea, 1492-1550
# Alciati, Andrea, 1492-1550.
# Alciati, Andrea.
# Alciphron.
# Alcuin, 735-804
# Alcuin, 735-804.
# Alcázar, Luis de (S.I.), 1554-1613.
# Aldhelm, Saint, 640?-709.
# Aldrovandi, Ulisse, 1522-1605.
# Aldrovandi, Ulisse, 1522-1605?
# Alegambe, Philippo, 1592-1652
# Alegre, Francisco Javier.
# Alejandro de Afrodisia
# Aleksander Jagiellończyk, King of Poland, 1461-1506.
# Alessandri, Alessandro, 1461-1523.
# Alessandrini, Giulio.
# Alexander Trallianus.
# Alexander of Hales, ca. 1185-1245.
# Alexander, ab Alexandro, d. 1523.
# Alexander, de Villa Dei.
# Alexander, of Aphrodisias.
# Alexandre, Noel (O.P.)
# Alexandre, Noel, (O.P.)
# Alexandre, Noël, 1639-1724.
# Alfani, Francesco
# Alfonso de Madrigal, 1400-1455
# Alfonso de Madrigal, 1400-1455.
# Alfonso, Francisco (S.I.)
# Alfonso, Francisco, (S.I.)
# Alfred, of Sareshel
# Ali B. Rudwan
# Ali ibn Abi Talib.
# Allacci, Leone
# Allacci, Leone, 1586-1669.
# Allen, Henry.
# Allen, William, Cardenal, 1532-1594
# Allen, William, Cardinal.
# Allestree, Richard, 1619-1681
# Alonso de Orozco, Santo, 1500-1591.
# Alpini, P.
# Alpini, Prosper, 1553-1617
# Alpini, Prosper, 1553-1617,
# Alpini, Prosper, 1553-1617.
# Alpino, Prospero, 1553-1617.
# Alprunio, Francesco Antonio.
# Alsario della Croce, Vincenzo, 1576-1631.
# Alsario della Croce, Vincenzo.
# Altamirano e Velasques, Joaõ.
# Altkamp, Karl.
# Alvares, Manuel (S.I.), 1526-1583
# Alvares, Manuel (S.I.), 1526-1583.
# Alvares, Manuel, 1526-1583.
# Alvarez de Paz, Diego (S.I.), 1560-1620
# Alvarez de Paz, Diego (S.I.), 1560-1620.
# Alvarez de Paz, Jacobo (S.I.)
# Alvarez de Paz, Jacobo, (S.I.)
# Alvarez, Diego, Arzobispo de Trani.
# Alvisi, Edoardo, 1850-1915.
# Amama, Sixtinus, 1593-1629.
# Amaral, Antonio Cardoso do.
# Amarcius, active 11th century
# Amarcius, active 11th century.
# Amat de Graveson, Ignace Hyacinthe (O.P.), 1670-1733
# Amat de Graveson, Ignace Hyacinthe (O.P.), 1670-1733.
# Amati, Pasquale,
# Amato Lusitano.
# Amato, Antonino de.
# Amaya, Francisco de.
# Ambrosch, Julius Athanasius, 1804-1856.
# Ambrose, Saint, Bishop of Milan, -397
# Ambrose, Saint, Bishop of Milan, -397.
# Ambrose, Saint, Bishop of Milan, d. 397.
# Ambrosio, Santo, Obispo de Milán, 340-397.
# Amelli, Ambrogio, 1848-1933.
# Amiano Marcelino.
# Amico, Bartolomeo, 1562-1649.
# Ammer, Engelbert
# Ammianus Marcellinus
# Ammianus Marcellinus.
# Ampelius, Lucius
# Ampelius, Lucius.
# Ampzing, Johannes Assuerus, 1558-1642.
# Anacker, Ferdinand, 1866-
# Anacreon
# Anacreon.
# Anacreonte.
# Anastasius, the Librarian, approximately 810-approximately 878.
# Ancarano, Pietro Giovanni d', fl. 1580
# Anderton, James, 1557-1618.
# Andrea da Castroreale.
# Andreae, Antonius, -approximately 1320.
# Andreae, Antonius, [ca. 1320]
# Andreantonelli, Sebastiano.
# Andreas, Capellanus.
# Andreä, Johann Valentin, 1586-1654.
# Andreucci, Andrea Girolamo, (S.I.)
# Angeli, Alessandro degli, -1620.
# Angeli, Alessandro degli.
# Angeli, Francesco Maria, 1632?-1697.
# Angeli, Pietro, 1517-1596
# Angellier, Auguste, 1847-1911
# Angellier, Auguste, 1847-1911.
# Angelucci, Teodoro, d. ca. 1600.
# Angelucci, Teodoro.
# Angleberme, Jean Pyrrhus.
# Angriani, Michele, (O.C.)
# Angriani, Michele.
# Anguiano Sedano, Cristóbal de.
# Anhalt, Ottocar.
# Anianus, Magister.
# Anjos, Luis dos, (O.S.A.)
# Annat, François, 1590-1670.
# Ansaldi, Casto Innocenzo (O.P.)
# Ansegisus, Saint, Abbot of Fontenelle, approximately 770-833.
# Anselm, Saint, Archbishop of Canterbury, 1033-1109
# Anselm, Saint, Archbishop of Canterbury, 1033-1109.
# Anselminus de Orto.
# Anselmo, Aurelio.
# Anselmo, Santo, Arzobispo de Canterbury, 1033-1109
# Anselmo, Santo, Arzobispo de Canterbury, 1033-1109.
# Antonelli, Giovanni Carlo
# Antonelli, Giovanni Carlo.
# Antonellus, Joannes Carolus, bp. of Ferentino, d. 1694.
# Antonini, Mario.
# Antonino, Arzobispo de Florencia, Santo.
# Antonio da Budrio
# Antonio da Budrio.
# Antonio de Córdoba (O.F.M.)
# Antonio, Nicolás, 1617-1684.
# Antonio, Nicolás, 1617-1684
# Antonio, Nicolás, 1617-1684.
# Antonius, Augustus.
# Antonius, Marcus, 83 B.C.?-30 B.C.
# Apiano
# Apiano.
# Apianus, Petrus, 1482-1535.
# Apicio, Marco Gavio.
# Apicius.
# Apollodorus.
# Apollonio à Iesu
# Apollonius, Dyscolus, 2nd cent
# Apollonius, Dyscolus, active 2nd century
# Apollonius, Levinus.
# Apollonius, Paradoxographus.
# Apollonius, Rhodius.
# Apollonius, of Athens.
# Apollonius, of Perga.
# Apollonius, paradoxographus.
# Apolodoro de Atenas.
# Apolonio de Pérgamo.
# Apolonio de Rodas.
# Aponius.
# Appendini, Francesco Maria, 1769-1837.
# Appendini, Francesco Maria.
# Appendix Vergiliana.
# Apponius
# Apponius.
# Apuleius
# Apuleius.
# Apuleyo, Lucio, 125-180 d. C.
# Apuleyo, Lucio.
# Aquenza e Mossa, Pietro
# Aranda Quintanilla y Mendoza, Pedro de (O.F.M.)
# Aranda, Felipe (S.I.), 1642-1695.
# Aranzi, Giulio Cesare, 1530-1589.
# Arato de Soles.
# Arator, Subdiaconus, fl. 513-544.
# Arbroath Abbey.
# Arceo, Francisco, 1494-1575.
# Archimedes.
# Archivio di Stato (Siena, Italy)
# Aretaeus, of Cappadocia.
# Areteo de Capadocia.
# Arethas, Arzobispo de Cesarea.
# Argenterio, Giovanni.
# Argoli, Andrea.
# Arias Montano, Benito, 1527-1598.
# Arias de Mesa, Fernando.
# Aringhi, Paolo, 1600-1676
# Aringhi, Paolo, 1600-1676.
# Aristides Quintilianus.
# Aristophanes.
# Aristoteles, 384-322 a.C.
# Aristotle.
# Aristófanes.
# Aristóteles, 384-322 a.C.
# Arminius, Jacobus, 1560-1609.
# Armstedt, R.
# Arnau, José
# Arnaud, George d', 1711-1740.
# Arnauld, Antoine, 1612-1694.
# Arngrímur Jónsson, 1568-1648.
# Arnim, Hans Friedrich August von, 1859-1931.
# Arnim, Max, 1889-
# Arnisaeus, Henning, d. 1636?
# Arnobio.
# Arnobius, of Sicca
# Arnobius, of Sicca.
# Arnold, Fr. Aug. 1812-1869.
# Arntzenius, Hendrik Jan, 1734-1797.
# Arntzenius, Hendrik Jan, 1735-1797.
# Arpe, Peter Friedrich, 1682-1740
# Arquímedes, (287-212 a.C.)
# Arquímedes, 287-212 a.C.
# Arrian.
# Arriano, Flavio
# Arrianus, Flavius.
# Arrowsmith, John, 1602-1659.
# Artemidoro.
# Artephius,
# Artephius.
# Arthus, Gotthard.
# Artis, Jean d'
# Arévalo, Faustino, 1747-1824.
# Ascham, Roger, 1515-1568.
# Asclepiadeus, Androphilus.
# Asher, Georg Michael.
# Asinio, Giovanni Battista.
# Assemani, Giuseppe Luigi, 1710?-1782.
# Assemani, Giuseppe Simone, 1687-1768.
# Asso y del Río, Ignacio Jordán de, 1742-1814
# Ast, Friedrich, 1778-1841
# Astesano, Antonio, 1412-
# Astete, Gaspar (S.I.), 1537-1601.
# Astruc, Jean, 1684-1766.
# Atanasio, Santo, ca. 297-373.
# Ateneo de Naúcratis.
# Ateneo de Náucratis
# Athanasius, Saint, Patriarch of Alexandria, -373
# Athanasius, Saint, Patriarch of Alexandria, d. 373.
# Athenaeus, of Naucratis.
# Atilius Fortunatianus, active 4th century.
# Atto, Obispo de Vercelli.
# Auerbach, Bertrand, 1856-1942
# Augenio, Orazio
# Augenio, Orazio.
# Augurelli, Giovanni Aurelio, approximately 1456-1524?,
# Augustine, Saint, Bishop of Hippo
# Augustine, Saint, Bishop of Hippo.
# Augustine, of Hippo, Saint, 354-430
# Augustine, of Hippo, Saint, 354-430,
# Augustine, of Hippo, Saint, 354-430.
# Augustinus, Aurelius, Saint, bp. of Hippo.
# Aulin, Lars Axel Alfred.
# Aulisio, Domenico d', 1639-1717.
# Aureliano, Celio.
# Aurelianus, Caelius
# Aurelianus, Caelius.
# Aurelius Victor, Sextus.
# Aurelius, Julianus.
# Ausfeld, Ricardus, b. 1864.
# Ausonio, Decio Magno.
# Ausonius, Decimus Magnus.
# Autolycus.
# Autpert, Ambrosio.
# Avancini, Nicolaus von, 1611-1686.
# Avendaño, Sebastian de (O.F.M.)
# Aventinus, Johannes, 1477-1534.
# Averani, Benedetto, 1645-1707.
# Averani, Giuseppe, 1662-1738.
# Averroës, 1126-1198.
# Avicena
# Avicena.
# Avieno, Rufo Festo
# Avienus, Rufius Festus
# Avienus, Rufius Festus.
# Avila y Zúñiga, Luis de.
# Avitus, Alcimus Ecdicius, Saint, d. 518.
# Avitus, Saint, Bishop of Vienne.
# Ayala, Baltasar de
# Aymerich, Mateo (S.I.), 1715-1799.
# Aynscom, Franciscus Xaverius, Père , (S.I.)
# Ayrault, Pierre
# Ayrault, Pierre, 1536-1601.
# Azevedo, Manuel de, (S.I.), 1713-1796.
# Azpilcueta, Martín de, 1492?-1586.
# Azpilcueta, Martín de, 1492-1586.
# Bacanelli, Giovanni Battista
# Bacchylides.
# Bacci, Andrea, -1600.
# Bacci, Andrea, 1524-1600.
# Bach, Johann August.
# Bachoff von Echt, Reiner, 1575-1640.
# Bacon, Francis, 1561-1626
# Bacon, Francis, 1561-1626.
# Bacon, John, (O.C.)
# Bacon, Roger, 1214?-1294
# Bacon, Roger, 1214?-1294.
# Bacon, Roger.
# Baconthorpe, John, -1346.
# Baconthorpe, John, ca. 1290-1346.
# Baconthorpe, John, m.1346
# Bader, Francis.
# Baer, Julius B. b. 1881.
# Baerland, Adriaan van.
# Baerle, Caspar van, 1584-1648.
# Baeumker, Clemens, 1853-1924.
# Baeza, Gaspar
# Baglivi, Giorgio, 1668-1707
# Baglivi, Giorgio, 1668-1707.
# Baglivi, Giorgio.
# Baiardi, Giovanni Battista, 1530-1600.
# Bailleu, Paul, 1853-1922.
# Bailleu, Paul.
# Baillon, Guillaume
# Baillou, Guillaume de, 1538-1616
# Baillou, Guillaume de, 1538-1616.
# Baiter, J. G. 1801-1877.
# Baius, Michael, 1513-1589.
# Baïf, Lazare de, 1496?-1547.
# Balainio, Joannes, fl. 1580.
# Balboa de Mogrovejo, Juan de.
# Balde, Jakob, 1604-1668
# Balde, Jakob, 1604-1668.
# Baldelli, Niccolò (S.I.), 1573-1655.
# Baldinotti, Cesare.
# Balinghem, Antoine de (S.I.), 1571-1630.
# Ballerini, Antonio, 1805-1881.
# Ballerini, Pietro, 1698-1769.
# Balli, Antonio.
# Baluze, Etienne, 1630-1718.
# Balzac, Jean-Louis Guez, Señor de, 1594-1654.
# Balzac, Jean-Louis Guez, seigneur de, 1597-1654.
# Balzarano, Giovanni Paolo.
# Bancel, Louis (O.P.)
# Bancel, Louis (O.P.), 1628-1685
# Bancel, Louis (O.P.), 1628-1685.
# Bandiera, Giovanni Niccolò.
# Bandini, Angelo Maria, 1726-1803.
# Banduri, Anselmo, (O.S.B.)
# Baptista, Mantuanus, 1447-1516.
# Baptista, Mantuanus, 1448-1516.
# Bar Hebraeus, 1226-1286.
# Baratieri, Bartolomeo dei, 15th cent.
# Barbato, Orazio.
# Barbette, Paul, d. 1666?
# Barbo, Paolo (O.P.)
# Barbosa, Agostinho, 1590-1649.
# Barbosa, Agostino, 1590-1649
# Barbosa, Agostino, 1590-1649.
# Barbosa, Enmanuele.
# Barbosa, Pedro.
# Barclay, John, 1582-1621.
# Barclay, William, 1546 or 1547-1608.
# Barclay, William.
# Bardají, Francisco Juan.
# Bardají, Juan.
# Barelli, Enrico, 1724-1817.
# Baricelli, Giulio Cesare.
# Barlezio, Marino.
# Baron, Eguinaire
# Baron, Eguinaire.
# Baron, Hyacinthe Théodore, 1686-1758.
# Baron, Vincent (O.P.)
# Barone, Antonio, 1632-1713.
# Baronio Manfredi, Francesco.
# Baronio, Cesare, 1538-1607.
# Barozzi, Francesco
# Barozzi, Francesco, 1537-1604.
# Barri, Gabriele, 1510-ca.1577
# Barrientos, Bartolomé.
# Bartal, György, 1785-1865.
# Bartelon, Pantaléon
# Barth, Caspar von, 1587-1658.
# Barth, Kaspar von, 1587-1658.
# Bartholin, Thomas, 1616-1680
# Bartholin, Thomas, 1616-1680.
# Bartholomaeus, of Carthagena.
# Bartholomæus, de Cotton, -1298?
# Bartoletti, Fabrizio, 1576-1630.
# Bartoletti, Fabrizio.
# Bartolo da Sassoferrato
# Bartolo, of Sassoferrato, 1313-1357.
# Bartolomei, Enrico.
# Bartolomé de los Mártires, Beato
# Bascape, Carlo.
# Basil, Saint, Bishop of Caesarea, approximately 329-379
# Basil, Saint, Bishop of Caesarea, approximately 329-379.
# Basil, Saint, Bishop of Caesarea, ca. 329-379.
# Basilio I, Emperador de Bizancio, ca. 867-886.
# Basilio, Santo, Obispo de Cesarea, 329?-379.
# Basilius, Valentinus.
# Basinio, da Parma, 1425-1457.
# Bassewitz, Ferdinand von.
# Bassolis, Joannes de.
# Bastgen, Philip.
# Baudouin, Benoît, -1632.
# Baudouin, François, 1520-1573.
# Baudri de Therouanne.
# Bauer, C. L.
# Bauhin, Caspar
# Bauhuis, Bernard, 1575-1619.
# Baumann, Eduard.
# Baur, Johannes Baptist
# Baviera, Baverio, -1480.
# Bay, Jacobus de
# Bayer, T. S. 1694-1738.
# Bayerische Staatsbibliothek.
# Baynes, Ralph
# Beauxamis, Thomas (O.C.)
# Becan, Jan, 1518-1572.
# Becanus, Martinus (S.I.), 1563-1624.
# Becanus, Martinus, (S.I.), 1563-1624
# Becanus, Martinus, (S.I.), 1563-1624.
# Becanus, Martinus, 1563-1624.
# Becanus, Martinus.
# Beccadelli, Antonio, 1394-1471
# Beccadelli, Antonio, 1394-1471.
# Becerra Valcarce, Diego, 1627-1684.
# Becher, Johann Joachim, 1635-1682.
# Becichemi, Marino
# Becius, Franciscus
# Becius, Franciscus.
# Beck, Christian Daniel, 1757-1832.
# Becker, Gustav Heinrich, 1833-1886.
# Becker, Gustav.
# Becker, Gustavus.
# Becker, W. A. (Wilhelm Adolf), 1796-1846.
# Beda, El Venerable, Santo, 673-735
# Beda, El Venerable, Santo, 673-735.
# Beda, Noel.
# Bede, the Venerable, Saint, 673-735
# Bede, the Venerable, Saint, 673-735.
# Bedjan, Paul, 1838-1920,
# Bedjanić, Martin.
# Beelić, Franjo.
# Beier, Karl, 1790-1828.
# Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621
# Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621.
# Bellegni, Caroli.
# Bellemera, Egidio de
# Bellenden, William, d. 1633?
# Bellermann, Friedrich, 1795-1874.
# Bellini, Lorenzo, 1643-1704.
# Bellmann, Carl Friedrich Alexander.
# Bellon, E., abbé.
# Bellone, Niccolò.
# Belloni, Paolo, 1573-1625.
# Belon, Pierre, 1517?-1564.
# Belon, Pierre.
# Belostenec, Ivan, 1595-1675.
# Belsheim, Johannus Engebretsen, 1829-1909.
# Bembo, Pietro, 1470-1547
# Bembo, Pietro, 1470-1547.
# Benavides y Sarzosa, Juan Antonio.
# Benci, Francesco (S.I.), 1542-1594.
# Benci, Francesco, 1542-1594
# Benecke, Karl, 1800-1847.
# Benedetti, Giovanni Battista, 1530-1590.
# Benedetti, Giovanni Battista.
# Benedict XIV, Pope, 1675-1758
# Benedict XIV, Pope, 1675-1758.
# Benedicto XIV, Papa, 1675-1758
# Benedicto XIV, Papa, 1675-1758.
# Benedicto, XIV, Papa, 1675-1758.
# Benet, Cipriano, (O.P.), (1460-1530)
# Beni, Iacopo
# Benicken, Hans Carl, 1844-
# Benito, Santo, ca. 480-547
# Benoist, Renè.
# Benseler, Gustav Eduard, 1806-1868
# Benzi, Ugo
# Benzoni, Girolamo, 1519-
# Benzoni, Girolamo, 1519-1572?
# Benzoni, Rutilio.
# Berardi, Carlo Sebastiano, 1719-1768.
# Berchorius, Petrus.
# Berengar, of Tours, approximately 1000-1088
# Berettari, Sebastiano (S.I.)
# Berge, Karl Richard, 1871-
# Berger, Joachim Ernst.
# Berger, Johann Gottfried von, 1659-1736
# Berger, Johann Gottfried.
# Berger, Samuel, 1843-1900.
# Bergius, Matthias, 1536-1592.
# Bergk, Theodor, 1812-1881.
# Bergk, Theodor.
# Berigard, Claude Guillermet, seigneur de, 1591-1663.
# Berlan, Francesco, 1821-1886,
# Berlich, Matthias.
# Berlioux, Etienne Félix, 1828-1910.
# Bernard de Gordon
# Bernard, Edward, 1638-1696.
# Bernard, of Chartres.
# Bernard, of Clairvaux, Saint, 1090 or 1091-1153
# Bernard, of Clairvaux, Saint, 1090 or 1091-1153.
# Bernard, of Clairvaux, Saint, 1090 or 91-1153
# Bernard, of Clairvaux, Saint, 1090 or 91-1153.
# Bernardi, Biagio.
# Bernardi, Blasius, -1612.
# Bernardino de San Antonio, (O.SS.T.)
# Bernardino de Siena, Santo, 1380-1444.
# Bernardo, Santo, 1090-1153
# Bernardo, Santo, 1090-1153.
# Bernhardy, Gottfried, 1800-1875.
# Bernoulli, Jakob, 1654-1705
# Bernoulli, Jakob, 1654-1705.
# Bernoulli, Johann, 1667-1748.
# Beroaldo, Filippo, 1453-1505
# Beroaldo, Filippo, 1453-1505.
# Berosio.
# Berosus, the Chaldean.
# Bersuire, Pierre, ca.1290-1362
# Berti, Giovanni Lorenzo, 1696-1766
# Berti, Giovanni Lorenzo, 1696-1766.
# Bertius, Petrus, 1565-1629.
# Bertrand, Nicolas.
# Besold, Christoph, 1577-1638.
# Bessarion, Cardenal, 1395-1472.
# Besson, Jacques (Mathematician)
# Bettini, Mario
# Bettini, Mario.
# Beveridge, William, 1637-1708
# Beveridge, William, 1637-1708.
# Beverwyck, Jan van, 1594-1647
# Beyer, Christoph, 1695-1758.
# Bèze, Théodore de, 1519-1605
# Bénard, Léon, b. 1847.
# Bhartr̥hari.
# Bianchi, Simon Giovanni, 1693-1775.
# Biblioteca apostolica vaticana.
# Biblioteca medicea laurenziana.
# Biblioteca nazionale marciana.
# Bibliotheca Palatina (Biblioteca apostolica vaticana)
# Bickell, Gustav, 1838-1906.
# Bidermann, Jakob, 1577 or 1578-1639.
# Bidermann, Jakob, 1577-1639.
# Bidloo, Govard, 1649-1713.
# Biel, Gabriel, d. 1495
# Biel, Gabriel, d.1495.
# Biel, Gabriel.
# Biese, Alfred, 1856-1930
# Biese, Nicolas
# Biesenthal, Johann Heinrich, 1800-1886.
# Biesius, Nicolaus.
# Bijnkershoek, Cornelis van, 1673-1743.
# Bilfinger, Christian Ludwig.
# Billet, Pierre Paul.
# Binsfeld, Peter.
# Biondo Flavio, 1392-1463.
# Biondo, Flavio, 1388-1463
# Biondo, Flavio, 1388-1463.
# Biragus, Aloysius.
# Birkenstock, Johann Melchior von, 1738-1809.
# Birkholz, Adam Michael, 1746-1818.
# Bisciola, Lelio (S.I.)
# Bisciola, Lelio, (S.I.)
# Bissel, Johann, 1601-1682
# Bissel, Johann, 1601-1682.
# Biumi, Giovanni Pietro, m. 1631?
# Biuso, Carmelo.
# Biéchy, Amand, b. 1813.
# Blackwood, Adam, 1539-1613
# Blarru, Pierre de, 1437-1510.
# Blasendorf, Carl.
# Blaufuss, Joannes, 1863-
# Bleek, Gerrit Willem van.
# Bleynianus, Antonius Fabricius.
# Blois, Louis de (O.S.B.), 1506-1566.
# Blois, Louis de, 1506-1566
# Blois, Louis de, 1506-1566.
# Blomfield, Charles James, 1786-1857
# Bludau, August, 1862-1930.
# Bluhme, Fridericus, 1881-
# Bluhme, Friedrich, 1881-
# Blumenbach, Johann Friedrich
# Blumenbach, Johann Friedrich.
# Boccaccio, Giovanni, 1313-1375.
# Bocchi, Achille, 1488-1562
# Bocchi, Achille, 1488-1562.
# Bochart, Samuel, 1599-1667.
# Bocksch, Otto, 1867-
# Bodin, Jean , 1530-1596.
# Bodin, Jean, 1530-1596.
# Bodleian Library.
# Boecio, Anicio Manlio Torcuato Severino
# Boecio, Anicio Manlio Torcuato Severino.
# Boeckelmann, Johan Frederik, 1632-1681
# Boeckh, August, 1785-1867.
# Boecler, Johann Heinrich, 1611-1672.
# Boehlau, Car.
# Boehlau, Carl.
# Boehlau, Karl.
# Boerhaave, Hermann, 1668-1738
# Boerhaave, Hermann, 1668-1738.
# Boethius, -524
# Boethius, -524.
# Boethius, d. 524
# Boethius, d. 524.
# Boettcher, Carl.
# Boettinger, Karl August, 1760-1835.
# Bohadsch, Johann Baptiste.
# Bohlen, Peter von, 1796-1840.
# Boileau, Jacques, 1635-1716.
# Boissard, Jean Jacques, 1528-1602.
# Bolducio, Jacques, (O.F.M. Cap.)
# Bolle, L.
# Bolzanio, Urbano, ca. 1443-1524.
# Bona, Giovanni (O. Cist.), Cardenal, 1609-1674
# Bona, Giovanni, 1609-1674.
# Bona, Joannis.
# Bonacina, Martino, 1585-1631
# Bonacina, Martino, 1585-1631.
# Bonaert, Olivier.
# Bonafous, Norbert Alexandre, b. 1809.
# Bonamici, Filippo.
# Bonaventure, Saint, Cardinal, approximately 1217-1274.
# Bonaventure, Saint, Cardinal, ca. 1217-1274.
# Bonbra, Franciscus David.
# Boncore di Santa Vittoria, fl. 1340.
# Bonello, Andrea, active 13th century
# Bonello, Andrea.
# Bonet-Maury, Gaston, 1842-1919.
# Bonfini, Antonio, 1427-1502.
# Boniface, Saint, Archbishop of Mainz, approximately 675-754
# Bonifacio, Baldassarre, 1585-1659.
# Bonifacio, Juan, 1538-1606.
# Bonifacius Stephanus, bp. of Stagno, -1582.
# Bonitz, Hermann, 1814-1888
# Bonitz, Hermann, 1814-1888.
# Bonizo, Bp. of Sutri, ca.1045-ca.1096.
# Bonizo, of Sutri, approximately 1045-approximately 1095.
# Bonnefons, Jean, 1554-1614.
# Bonomi, Giovanni Domenico.
# Boodt, Anselmus de, 1550-1632.
# Boppert, Conradus.
# Borcholten, Johann, 1535-1593
# Borcholten, Johann, 1535-1593.
# Borcholten, Johannes, 1535-1593.
# Bordini, Giovanni Francesco, ca. 1536-1609.
# Bordoni, Francesco (O.F.M.), 1595-1671.
# Borelli, Giovanni Alfonso, 1608-1679.
# Borgia, Girolamo.
# Borgo, Petro Battista.
# Borluut, Willem, approximately 1535-
# Borový, Klement, 1838-1897
# Borrello, Camillo.
# Borrhaus, Martin, 1499-1564.
# Borromini, Francesco, 1599-1667.
# Borsati, Francesco.
# Borsdorf, Th.
# Boskierus Hannonius, Philippus
# Bossche, Guilaume van den, fl. 1638.
# Bossche, Guillaume van den.
# Bossi, Giovanni Angelo, 1590-1665
# Bossuet, Jacques Benigne, 1627-1704.
# Bossulus, Matthaeus.
# Botallo, Leonardo, 1530-approximately 1587.
# Botallo, Leonardo, d. 1587.
# Botallo, Leonardo.
# Botero, Giovanni, 1540-1617
# Botero, Giovanni, 1540-1617.
# Botero, Giovanni, ca. 1543-1617
# Bothe, Friedrich Heinrich, 1771-1855.
# Bottari, Giovanni Gaetano, 1689-1775.
# Bou, Baltasar Manuel
# Bouelles, Charles de
# Bouelles, Charles de.
# Bouguer, M. 1698-1758.
# Bouguer, Pierre, 1698-1758
# Boulduc, Jacques (O.F.M. Cap.)
# Boulenger, Jules Cesar, 1558-1628.
# Boulenger, Jules César, 1558-1628
# Boulenger, Jules César, 1558-1628.
# Boulenger, Pierre.
# Bourgeois, Jean (S.I.)
# Boussuet, Francois, 1520-1572.
# Boussuet, François.
# Bouvy, Edmond
# Bovelles, Charles de.
# Bovillus, Carolus, 1479-1567.
# Bovio, Carlo, 1614-1705.
# Bowen, Charles Synge Christopher Bowen, Baron, 1835-1894.
# Boxhorn, Marcus Zuerius, 1612-1653.
# Boyle, Robert, 1627-1691.
# Bozio, Tommaso (O.C.), 1548-1610
# Bozio, Tommaso (O.C.), 1548-1610.
# Bozio, Tommaso, O.C. 1548-1610
# Böttiger, Karl August, 1760-1835.
# Bra, Hendrik van, 1554-1622.
# Braam, Pieter van.
# Bracciolini, Poggio, 1380-1459.
# Bracton, Henry de, -1268.
# Bradwardine, Thomas, 1290?-1349.
# Braeutigam, Walter, 1883-
# Brahe, Tycho, 1546-1601.
# Brandes, Karl, 1861-
# Brandis, Christian August, 1790-1867.
# Brandl, Vincenc, 1834-1901.
# Brandt, Karl, 1858-
# Brant, Sebastian, 1458-1521,
# Brasavola, Antonio Musa (1500-1555)
# Brasavola, Antonio Musa, 1500-1555.
# Braschi, Giovanni Battista, Obispo de Sarsina.
# Braun, Georg.
# Braun, Johann
# Braun, Johannes, 1628-1708.
# Braunhard, Wilhelm, 1807-1866.
# Bravardinus, Thomas.
# Bravo, Bartolomé (S.I.) 1554-1607.
# Bravo, Bartolomé (S.I.), 1554-1607.
# Bravo, Bartolomé, (S.I.), 1554-1607.
# Bravo, Juan, fl. 1546-1596.
# Braxator, Rudolf Franz, 1845-
# Braxator, Rudolf Franz, b. 1845.
# Bredenbach, Tilmann, ca. 1544-1587.
# Brederodius, Petrus Cornelius.
# Bredow, Ferdinand Julius Caesar
# Bredow, Ferdinand.
# Breitenbach, Ludwig, 1813-1885.
# Brenna, Luigi, (S.I.)
# Brerewood, Edward, 1565?-1613.
# Bresser, Martin de (S.I.), 1584-
# Bretschneider, Karl Gottlieb, 1776-1848
# Bretschneider, Karl Gottlieb, 1776-1848.
# Briet, Philippe (S.I.)
# Brigida de Suecia, Santa, ca. 1303-1373.
# Brink, Barend ten, 1803-1875.
# Bripius, Josephus.
# Brisson, Barnabe
# Brisson, Barnabe.
# Brisson, Barnabé, 1531-1591.
# Britonio, Girolamo.
# Brix, Ernst Julius, 1815-
# Brix, Ernst Julius, 1815-1887.
# Brocardo, Jacopo.
# Broickwy a Koninckstein, Antonius (O.F.M.), 1470?-1541.
# Broickwy a Konincksteyn, Antonius, (O.F.M.)
# Bronchorst, Jan van, 1494-1570.
# Brosses, Pierre de, active 16th century,
# Brouwer, Christoph, 1559-1617.
# Brower, Christopher (S.I.)
# Bruck, Jacobus à.
# Brulefer, Stephanus (O.F.M.)
# Brulefer, Stephanus, (O.F.M.)
# Bruni, Leonardo, 1369-1444.
# Brunius, C. G. 1792-1869.
# Brunnemann, Johann, 1608-1672.
# Bruno Magdeburgensis, active 1084-
# Bruno de Asti, Santo, 1049-1123
# Bruno, Giordano, 1548-1600.
# Bruno, Santo, ca. 1030-1101.
# Bruno, of Magdeburg, active 1084
# Brunus, Conradus, 1491?-1563.
# Brusoni, Lucio Domitio
# Brusoni, Lucio Domitio.
# Brusoni, Lucio Domizio.
# Bruyn, Johannes de, 1620-1675.
# Bryennius, Nicephorus, Caesar, c.1137.
# Bucer, Martin, 1491-1551.
# Buchanan, David, 1595?-1652?
# Buchanan, George, 1506-1582
# Buchanan, George, 1506-1582.
# Buchenau, Georg.
# Buchholtz, Hermann.
# Buchner, August, 1591-1661.
# Bucoldianus, Gerardus.
# Budan, Emilio de.
# Budapest (Hungary). Magyar Nemzeti Museum. Szechenyi Bibliothek.
# Bude, Guillaume, 1468-1540.
# Budeius, Stephanus Parmenius.
# Budel, René, -1597
# Budel, René, -1597.
# Budé, Guillaume, 1468-1540.
# Budé, Guillaume, 1468-1540.
# Buecheler, Franz, 1837-1908
# Buecheler, Franz, 1837-1908.
# Buenaventura de San Agustín (Jer.)
# Buenaventura de San Agustín, (Jer.)
# Buenaventura, Santo, 1221-1274
# Buenaventura, Santo, 1221-1274.
# Buiza y Llamazares, Juan de.
# Bukentop, Henri van, ca. 1653-1716.
# Bulenger, Julio Cesar
# Bulengerus, Julio Cesar, 1558-1628.
# Bullinger, Heinrich, 1504-1575.
# Buno, Johannes, 1617-1697,
# Buonamici, Castruccio, 1710-1761.
# Buonamici, Francesco, -1604.
# Buonamici, Francesco.
# Buondelmonti, Cristoforo, approximately 1385-approximately 1430.
# Burchard, Johann Friedrich Wilhelm,
# Burchardus, Episcopus Wormaciensis
# Burchardus, Episcopus Wormaciensis.
# Burckhard, Jakob, 1681-1752.
# Burdegati, Sante.
# Burger, Konrad, 1856-1912.
# Burgerbibliothek Bern.
# Burggrav, Johann Ernst
# Buridan, Jean, 1300-1358.
# Buridan, Jean.
# Buridanus, Johannes.
# Burlaeus, Gualterus, 1275-1345?
# Burman, Pieter, 1668-1741.
# Burmeister, C. E. I.
# Burnet, Thomas, 1635-1715.
# Burnet, Thomas, 1635?-1715
# Burnet, Thomas, 1635?-1715.
# Burroughs, Edward Arthur.
# Bursian, Konrad.
# Busaeus, Johannes (S.I.), 1547-1611.
# Busenbaum, Hermann, 1600-1668.
# Busius, Paulus.
# Bussmann, K. H. A.
# Bustamante de la Camara, Juan.
# Bustamante de la Cámara, Juan, 16th cent.
# Butler, Samuel, 1774-1839
# Buttmann, August, 1806-
# Buxtorf, Johann, 1564-1629
# Buxtorf, Johann, 1564-1629.
# Buxtorf, Johann, 1599-1664.
# Buys, Jan, 1547-1611.
# Bynaeus, Anthony, 1654-1698.
# Bynkershoek, Cornelis van, 1673-1743.
# Byzantine Empire.
# Bèze, Théodore de, 1519-1605.
# Bérnard, Léon, 1847-
# Böckh, August, 1785-1867.
# Böttcher, Julius Friedrich, 1801-1863.
# Böttiger, Karl August, 1760-1835.
# Bülow, Paul, 1848-
# Bābai, the elder, 569 (ca.)-628.
# Bēssariōn, Cardinal, 1403-1472
# Būṣīrī, Sharaf al-Dīn Muḥammad ibn Saʻīd, 1213?-1296?
# CCPB000038379-1
# CORDUS, Valerius.
# Cabedo, Jorge de, 1525-1604
# Cabedo, Jorge de, 1525-1604.
# Caesalpinus, Andreas.
# Caesar, Julius
# Caesar, Julius.
# Caesarius, of Heisterbach, approximately 1180-approximately 1240.
# Caesius Bassus, active 1st century.
# Cagnati, Marsilio, 1543-1612
# Cahen, Raymond.
# Caietanus, Costantinus
# Caimo, Pompeo.
# Calcagnini, Celio
# Calchi, Tristano, b. ca. 1462.
# Caldeira, Duarte.
# Caldera de Heredia, Gaspar, 1591-
# Caldera de Heredia, Gaspar.
# Calderón, Antonio, Arzobispo de Granada.
# Calebow, Eric.
# Callaghan, John, 1605-1654,
# Callimachus.
# Calmet, Augustin (O.S.B.), 1672-1757.
# Calmet, Augustin, 1672-1757.
# Calvete de Estrella, Juan Cristóbal, d. 1593.
# Calvete de Estrella, Juan Cristóbal 1525-1593.
# Calvete de Estrella, Juan Cristóbal, -1593.
# Calvin, Jean, 1509-1564.
# Camañes, Pedro
# Camerani, Francesco.
# Camerario, Bartolomeo, 1497-1564.
# Camerarius, Joachim, 1534-1598.
# Camers, Joannes, 1447-1546
# Camers, Johannes.
# Campanella, Tommaso, 1568-1639
# Campanella, Tommaso, 1568-1639.
# Campano, Giannantonio, Bishop, 1429-1477.
# Campano, Giovanni Antonio, 1429-1477.
# Campion, Thomas, 1567-1620.
# Campolongo, Emilio.
# Cancellieri, Francesco, 1751-1826
# Cancellieri, Francesco, 1751-1826.
# Cancellieri, Orfeo, d. 1503.
# Candel, Jules.
# Canepari, Pietro Maria
# Canepari, Pietro Maria.
# Canet, Victor.
# Cangiamila, Francesco.
# Canivez, E.
# Cannegieter, Herman, 1723-1804.
# Cano, Juan, -1705
# Cano, Juan, -1705.
# Cano, Melchor (O.P.) 1509-1560
# Cano, Melchor (O.P.) 1509-1560.
# Cano, Melchor (O.P.), 1509-1560.
# Cano, Melchor, 1509?-1560.
# Canonieri, Pietro Andrea, -1639.
# Canonieri, Pietro Andrea.
# Canoniero, Pietro Andrea.
# Cantalicio, Giovanni Battista, Cardenal, ca.1450-1514
# Canter, Willem, 1542-1575.
# Cantiuncula, Claudius, -1560?
# Capaccio, Giulio Cesare, 1552-1634
# Capasso, Giovanni Battista.
# Capecelatro, Ettore.
# Capelle, C. 1841-
# Capitis, Firminus
# Capobianco, Giovanni Francesco, 1560?-1633.
# Capone, Giulio
# Capone, Giulio.
# Cappel, Jacques, 1570-1624.
# Cappella, Prospero, m. 1703.
# Capra, Galeazzo Flavio, 1487-1537.
# Capreolus, Johannes.
# Caprili, Pio Enea.
# Caracciolo, Giovanni Battista, 1695-1765.
# Caracciolus, Antonius.
# Carafa, Giuseppe Maria, 1717-1786.
# Caramuel de Lobkowitz, Juan, 1606-1682.
# Caranza, Alonso.
# Carbone de Costacciaro, Lodovico.
# Carbone, Lodovico
# Carbone, Lodovico.
# Carboni, Lodovico.
# Carcano, Archileo
# Carcano, Leone Giambattista
# Cardano, Gerolamo, 1501-1576.
# Cardano, Girolamo, 1501-1576
# Cardano, Girolamo, 1501-1576.
# Cardano, Girolamo.
# Cardellini, Vittorio.
# Cardillo de Villalpando, Gaspar
# Cardillo de Villalpando, Gaspar.
# Cardona, Juan Bautista.
# Cardoso, Isaac.
# Carena, Cesare
# Carlo di Sant'Antonio da Padova, 1621-1695
# Carmeni, Daniele.
# Carmina burana.
# Carocci, Vincenzo.
# Carolus, Johannes, 1534-1598.
# Carpenteius, Johannes.
# Carpio, Francisco del, fl. 1635.
# Carpzov, Johann Gottlob, 1679-1767.
# Carpzov, Johann Gottlob.
# Carranza, Alonso.
# Carrasco del Saz, Francisco.
# Carrion, Louis, 1547-1595.
# Cartagena, Antonio de.
# Cartagena, Juan de (O.F.M.), 1563-1617.
# Cartagena, Juan de (O.F.M.), 1563-1618.
# Cartagena, Juan de, (O.F.M.), 1563-1617
# Cartari, Flaminio
# Carvajal, Luis de (O.F.M.)
# Casal, Gaspar do (O.S.A), 1510-1584.
# Casal, Gaspar do, (O.S.A.), 1510-1584.
# Casati, Paolo, (S.I.)
# Casati, Paolo, 1617-1707.
# Casaubon, I.
# Casaubon, Isaac, 1559-1614.
# Casilio, Giovanni Battista (S.I.), 1596-1675
# Casiodoro, Magno Aurelio
# Casiodoro, Magno Aurelio.
# Casoli, Alfonso M.
# Cassian, John, approximately 360-approximately 435
# Cassian, John, approximately 360-approximately 435,
# Cassian, John, approximately 360-approximately 435.
# Cassian, John, ca. 360-ca. 435.
# Cassianus, Johannes, ca.360-435
# Cassianus, Johannes, ca.360-435.
# Cassiodorus, Flavius Magnus Aurelius
# Cassiodorus, Senator, ca. 487-ca. 580
# Cassiodorus, Senator, ca. 487-ca. 580.
# Cassius Dio Cocceianus.
# Cassius Felix
# Cassius Felix, active 447
# Castañiza, Juan de, (O.S.B.), m. 1598.
# Castel, Antonio (O.F.M.), 1655-1713
# Castel, Antonio (O.F.M.), 1655-1713.
# Castellani, Giulio, 1528-1586
# Castellani, Vincenzo.
# Castellesi, Adriano.
# Castellion, Sébastien, 1515-1563.
# Castellion, Sébastien, 1515-1563.
# Castiglione, Baldassarre, conte, 1478-1529.
# Castilla, Diego de (O.C.)
# Castilla, Diego de, (O.C.)
# Castillo Sotomayor, Juan del, 1563-1640.
# Castillo y Artiga, Diego del, 1605-1670
# Castillo y Artiga, Diego del, 1605-1670.
# Castro, Alfonso de (O.F.M.), 1495-1558.
# Castro, Alfonso de, 1494 or 1495-1558.
# Castro, Alfonso de, 1495-1558
# Castro, Alfonso de, 1495-1558.
# Castro, Andrés Antonio de.
# Castro, Cristóbal, (S.I.), 1551-1615.
# Castro, Cristóbal.
# Castro, Estêvão Rodrigues de, 1559-1638.
# Castro, Rodrigo de, 1546-1627
# Castroni, Benedetto Maria.
# Castrovol, Pedro de.
# Catalani, Giusseppe.
# Catallus, Gaius Valerius.
# Catedral Primada de Toledo. Biblioteca.
# Catherine, of Alexandria, Saint.
# Catholic Church
# Catholic Church.
# Catholic Church. Archdiocese of Prague (Czech Republic)
# Catholic Church. Diocese of Lincoln (England). Bishop (1209-1235 : Hugh, of Wells).
# Catholic Church. Pope
# Catholic Church. Pope (1592-1605 : Clement VIII)
# Catholic Church. Pope (1740-1758 : Benedict XIV)
# Catholic Church. Pope (590-604 : Gregory I)
# Catholic Church. Rota Romana
# Cathédral Saint-Julien (Le Mans, France). Chapître.
# Cato, Marcus Porcius, 234 B.C.-149 B.C.
# Cato, Marcus Porcius, 234-149 B.C.
# Cato, Valerius.
# Catullus, Gaius Valerius
# Catullus, Gaius Valerius.
# Catullus, Gaius Valerius. Carmen 63.
# Catullus, Valerius.
# Catulo, Cayo Valerio
# Catulo, Cayo Valerio.
# Catón, Marco Porcio (Mayor)
# Caussin, Nicolas (S.I.), 1583-1651
# Caussin, Nicolas (S.I.), 1583-1651.
# Caussin, Nicolas, (S.I.), 1583-1651
# Caussin, Nicolas, (S.I.), 1583-1651.
# Caussin, Nicolas, 1583-1651.
# Cavallin, Samuel Gustaf, b. 1828.
# Cavoto, Giovanni Battista
# Cavretto, Pietro, b. ca. 1424
# Cefali, Giovanni
# Cefali, Giovanni.
# Cellarius, Balthasar
# Cellarius, Christoph, 1638-1707.
# Celso, Aulo Cornelio
# Celso, Aulo Cornelio.
# Celsus, Aulus Cornelius.
# Celsus, Aurelius Cornelius, 25 B.C.-A.D. 50.
# Cenci, Luigi, -1637.
# Ceneau, Robert, 1483-1560.
# Censorinus.
# Cerda, Juan Luis de la, 1560-1643.
# Ceruti, Federico, 1532-1611
# Cesalpino, Andrea, 1524 or 1525-1603.
# Cesalpino, Andrea, ca.1524-1603.
# Cesarini, Virginio, 1595-1624
# Cesarini, Virginio, 1595-1624.
# Ceva, Tomás.
# Chabert, Samuel, 1868-1924.
# Chalkokondyles, Laonikos, ca. 1430-ca. 1490.
# Chalkokondylēs, Laonikos, ca. 1430-ca. 1490.
# Chambers, David, 1530?-1592.
# Champier, Symphorien, 1472?-ca. 1535
# Champier, Symphorien, 1472?-ca. 1535.
# Chansonnette, Claude.
# Charles II, King of France, 823-877.
# Charleton, Walter, 1619-1707.
# Charpentier, Jacques
# Charpentier, Jacques.
# Chasseneuz, Barthélemy de, approximately 1480-1541.
# Chaulmer, Charles.
# Chavasse, Balthasar (S.I.), 1561-1634.
# Chaves, Pedro, (O.S.B.)
# Chesio, Bartolomeo.
# Chesneau, Nicolas.
# Chetham's Library.
# Cheyne, James, 1545-1602.
# Chiaramonti, Scipione, 1565-1652.
# Chiericato, Giovanni María, 1633-1717.
# Chifflet, Pierre-François, 1592-1682
# Chokier, Jean, 1571-1656.
# Choniates, Nicetas, ca. 1140-1213.
# Choppin, Rene, 1537-1606.
# Choppin, René, 1537-1606.
# Choppin, René, 1537-1606.
# Christ Church (University of Oxford)
# Christ, Johann Friedrich, 1700-1756.
# Christ, Wilhelm von, 1831-1906.
# Christmann, Jakob, 1554-1613
# Chrysoloras, Manuel, ca. 1350-1415.
# Church of England
# Church of England.
# Ciabatta, Filippo,
# Ciampini, Giovanni Giustino, 1633-1698
# Ciampini, Giovanni Giustino, 1633-1698.
# Ciampini, Giovanni Giusto, 1633-1698.
# Cicero, M. Tullius, 106-43 v. Chr.
# Cicero, M. Tullius.
# Cicero, Marcus Tullius
# Cicero, Marcus Tullius, 106-43 B.C. E.
# Cicero, Marcus Tullius.
# Cicero. De finibus. Latin.
# Cicerón, Marco Tulio, 106-43 a.C.
# Cigala, Honufrio
# Cinnamus, Ioannes.
# Cinnamus, Johannes.
# Cinquarbres, Jean.
# Ciofani, Ercole
# Cioffi, Pietro
# Cipolla, Bartolomeo, ca. 1420-1475.
# Cippico, Coriolano, 1425?-1493?
# Cipriano, Santo, Obispo de Cartago, ca. 210-258.
# Cirilo, Santo, Patriarca de Alejandría, 376?-444
# Cirilo, Santo, Patriarca de Alejandría, 376?-444.
# Ciruelo, Pedro
# Cisner, Nicolaus, 1529-1583.
# Cisorio, Aloisio
# City of London (England)
# Clapmarius, Arnoldus, 1574-1604.
# Clark, Albert Curtis, 1859-1937.
# Clarke, Robert (O. Cart.)
# Clarke, Robert, -1675.
# Claro, Giulio 1525-1575.
# Claro, Giulio, 1525-1575.
# Claudiano, Claudio.
# Claudianus Mamertus, -approximately 474.
# Claudianus, Claudio.
# Claudianus, Claudius
# Claudianus, Claudius.
# Claudini, Giulio Cesare, ca. 1550-1618
# Clausen, F.
# Claveus, Gasto, n. ca. 1520.
# Clavius, Christophorus, 1538-1612
# Clavius, Christophorus, 1538-1612.
# Clement I, Pope
# Clement VIII, Pope, 1536-1605.
# Clement, Claude, 1594-1642.
# Clement, Claude, ca. 1594-1642.
# Clement, Joannes Franciscus, 1823-1892.
# Clement, of Alexandria, Saint, approximately 150-approximately 215
# Clement, of Alexandria, Saint, approximately 150-approximately 215.
# Clemente I, Papa.
# Clemente de Alejandría.
# Clemente, Juan.
# Clenardus, Nicolaus, 1495-1543.
# Cleomedes.
# Clerval, A. 1859-1918
# Clénard, Nicolas, 1493 or 1494-1542.
# Clicthove, Josse
# Clicthove, Jossé
# Clicthove, Jossé.
# Close, A. M.
# Closs, Johann Friedrich.
# Cloyne. Diocese.
# Cluwer, Philip
# Clüver, Philipp, 1580-1622
# Clément, Félix, 1822-1885
# Coccejus, Johannes, 1603-1669.
# Cochlaeus, Johannes, 1479-1552
# Cochlaeus, Johannes, 1479-1552.
# Codinus, George
# Codinus, Georgius
# Codronchi, Giovanni Baptista.
# Coelho, Jorge
# Cohn, Arthur
# Cohn, Arthur.
# Colegio Menor de Carmelitas Descalzos (Alcalá de Henares)
# Colegio Menor de Santo Tomás de Aquino (Alcalá de Henares)
# Colegio de Santo Tomás de Aquino (Alcalá de Henares)
# Colegio de la Compañía de Jesús (Coimbra)
# Coler, Martin.
# Colet, John, 1467?-1519.
# Collin, Matthaeus von
# Collio, Francisco, d. 1640
# Colombet, Claude, fl. 1636.
# Colonia, Dominique de (S.I.), 1660-1741.
# Colonia, Dominique de, (S.I.), 1660-1741.
# Colonia, Dominique de, 1660-1741
# Colonia, Dominique de, 1660-1741.
# Columela, Lucio Junio Moderato.
# Columella, Lucius Junius Moderatus
# Columella, Lucius Junius Moderatus.
# Colutio, Francisco.
# Combach, Ludwig, 1590-1657.
# Combes, Jean de (O.F.M.)
# Comitolo, Paolo (S.I.), 1544-1626.
# Commire, Jean, 1625-1702.
# Commodianus
# Commodianus.
# Comnena, Anna, 1083-
# Comnena, Anna, 1083-1148.
# Comnena, Anna, b. 1083.
# Comnena, Anna.
# Compayré, Gabriel, 1843-1913.
# Concina, Daniele, (O.P.), 1687-1756.
# Confraternitas Beatae Mariae de anima Teutonicorum de urbe.
# Coninck, Aegidio de (S.I.)
# Conn, George.
# Connan, François.
# Conrad, Julius.
# Conring, Hermann, 1606-1681.
# Constantine VII Porphyrogenitus, Emperor of the East, 905-959.
# Constantino Africano.
# Constantino, Manuel, m.1614
# Constantino, VII, Porfirogéneta, Emperador de Bizancio.
# Contador de Argote, Jeronimo.
# Contador de Argote, Jeronymo, 1676-1749.
# Contarini, Gasparo
# Contarini, Gasparo, 1483-1542.
# Contarini, Gasparo.
# Contarini, Vincenzo, 1577-1617.
# Contarini, Vincenzo.
# Contelori, Felice, 1588-1652
# Conti, Natale, 1520-1582
# Conti, Natale, 1520-1582.
# Conti, Natale, ca. 1520-ca. 1580
# Conti, Natale, ca. 1520-ca. 1580.
# Contzen, Adam (S.I.), (1571-1635)
# Copernicus, Nicolaus, 1473-1543
# Copernicus, Nicolaus, 1473-1543.
# Coppenstein, Johann Andreas (O.P.)
# Copus, Joannes.
# Corazza, Caietanus, (CC.RR.MM.)
# Cordewener, Egidius Josephus Leonardus Ludovica Eugenius.
# Cordewener, Laubert Hubert Joseph Egidius Louis Eugène, 1867-
# Cordier, Mathurin, 1479-1564
# Cordier, Mathurin, 1479-1564.
# Cordus, Euricius, 1484-1535.
# Corippus, Flavius Cresconius.
# Cormier, Thomas, ca. 1523-1600.
# Cornarius, Ianus
# Cornelius, Carl.
# Cornely, Rudolph, 1830-1908.
# Corpus iuris civilis. Institutiones.
# Corradi, Lancelotto, 16th cent.
# Corradi, Sebastiano, -1556.
# Corradi, Sebastiano, 1510-1556
# Corradi, Sebastiano, 1510-1556.
# Corradi, Sebastiano, d. 1556.
# Corradini, Pietro Marcellino, 1658-1743.
# Corradini, Pietro Marcellino, Cardinal, 1658-1743.
# Corrado, Pirro
# Corssen, Peter, 1856-
# Cortese, Giacomo, 1859-
# Cortesi, Paolo, 1465-1510.
# Corti, Franceschino, ca. 1470-1533.
# Corti, Matteo, 475-1542
# Cortnumm, Justus, 1624-1675.
# Corvinus, Johannes Arnoldi, approximately 1582-1650.
# Costa, Francesco.
# Costa, Giovanni Battista.
# Costa, Juan, ca. 1550- 1597.
# Costa, Manuel da, m. 1562.
# Costeo, Giovanni.
# Coster, François (S.I.), 1532-1619
# Coster, François (S.I.), 1532-1619.
# Cottereau, Claude, 1499-1550.
# Couret, Alphonse.
# Court, Benoît de.
# Covarrubias Leyva, Diego de, 1512-1577
# Covarrubias Leyva, Diego de, 1512-1577.
# Covarrubias y Leyva, Diego de, 1512-1577.
# Coville, Alfred, 1860-1942
# Cowley, Abraham, 1618-1667
# Cowley, Abraham, 1618-1667.
# Coytard de Thaire, Jean.
# Cozzando, Leonardo, fl. 1620-1694.
# Cragius, Niels, 1549-1602.
# Craig, Thomas, Sir, 1538-1608.
# Cramer, Ludwig Dankegott, 1791-1824.
# Crato von Crafftheim, Johann, 1519-1585
# Crato von Crafftheim, Johann, 1519-1585.
# Cremani, Aloisii.
# Cremani, Luigi, 1748-1838.
# Cremer, Gabriel Henry.
# Cressolles, Louis, (S.I.), 1568-1634.
# Cressolles, Louis, 1568-1634.
# Creux, François du.
# Croiset, Maurice, 1846-1935.
# Crokart, Petrus.
# Croll, Oswald, approximately 1560-1609.
# Croll, Oswald.
# Cropp, Paul, 1875-
# Crotto, Giovanni.
# Crucius, Jacobus, 1579-1635?
# Crusius, Martin, 1526-1607
# Crusius, Thomas Theodorus, 1648-1728.
# Cucchi, Marco Antonio, 1506-1567.
# Cueppers, Franz Joseph.
# Cujas, Jacques, 1522-1590
# Cujas, Jacques, 1522-1590.
# Cunaeus, Petrus, 1586-1638.
# Cunich, Raimondo, 1719-1794.
# Cuper, Gisbert, 1644-1716.
# Cuper, Luca.
# Cuperus, Gisbertus.
# Curcio Rufo, Quinto.
# Curiel, Juan Alfonso.
# Curione, Celio Augustino, 1538-1567
# Curtius Rufus, Quintus
# Curtius Rufus, Quintus,
# Curtius Rufus, Quintus.
# Curtius, Cornelius
# Curtze, Maximilian, 1837-1903.
# Cuspinianus, Johannes, 1473-1529
# Cutelli, Mario, 1584-1654.
# Cyprian, Saint, Bishop of Carthage
# Cyprian, Saint, Bishop of Carthage.
# Cyprianus Gallus, active 5th century,
# Cyriacus, Franciscus Niger, active 1629.
# Czerner, Bartholomaeus.
# César, Cayo Julio, 100-44 a.C.
# D'Abano, Pietro.
# Dadin de Hauteserre, Antoine, 1602-1682
# Dadin de Hauteserre, Antoine, 1602-1682.
# Daillé, Jean, 1594-1670.
# Daillé, Jean, 1594-1670.
# Dal Monte, Guidobaldo, 1545-1607.
# Dallier, Lubin.
# Dana, Joseph, 1769-1849.
# Dandini, Girolamo, ca. 1554-1634.
# Daneau, Lambert, approximately 1530-1595?
# Daniels, A. von 1800-1868.
# Dankovszky, Gregor, 1784-1857
# Dankovszky, Gregor, 1784-1857.
# Dante Alighieri, 1265-1321
# Dante Alighieri, 1265-1321.
# Danz, Johann Traugott Leberecht, 1769-1851.
# Dares Frigio.
# Darmesteter, Arsène, 1846-1888.
# Dati, Leonardo, -1425.
# Daubriz, Charles.
# Dautremer, L.
# David, von Augsburg, -1271
# Daza, Diego (S.I.)
# De Marinis, Donato Antonio.
# De Pietri, Francesco
# De Pozza, Nicolai Aloysii Comitis.
# De Rada, Girolamo, 1814-1903.
# De Rogatis, Bartolomeo, 1596-1656
# De Rosa, Tommaso
# De Rossi, Giovanni Bernardo, 1742-1831
# De Rossi, Giovanni Bernardo, 1742-1831.
# De Vio, Tommaso, 1469-1534
# De Vio, Tommaso, 1469-1534.
# De Vío, Tommaso, 1469-1534
# Decembrio, Angelo, approximately 1415-1462.
# Decembrio, Angelo, ca. 1415-1462.
# Dechamps, Etienne-Agard, (S.I.), 1613-1701.
# Decius, Jodocus Ludovicus, approximately 1485-1545.
# Decsi, János, -1601.
# Dedouvres, L.
# Defensor de Ligugé
# Del Garbo, Tommaso, ca. 1305-1370.
# Del Pozzo, Giacomo, 1508-1563.
# Del Rio, Martin Antoine, 1551-1608
# Delfio, Porto Euterio.
# Della Porta, Giovan Battista, 1535?-1615
# Della Porta, Giovan Battista, 1535?-1615.
# Delrío, Martín Antonio, 1551-1608.
# Demetrius Pepagomenus, active 1260.
# Demetrius Pepagomenus, s.13.
# Demetrius, Phalereus.
# Demosthenes.
# Dempster, Thomas, 1579?-1625
# Denari, Odofredo, -1265
# Deneke, Ewald, 1893-
# Denis le Chartreux (O. Cart.), 1402-1471.
# Denis le Chartreux, (O. Cart.), 1402-1471.
# Denis the Carthusian, 1402-1471.
# Denis, Michael, 1729-1800.
# Denis, the Carthusian, 1402-1471.
# Deodato, Claudio.
# Des Francs, Louis Benjamin, 1814-1886.
# Desbillons, François-Joseph Terrasse, 1711-1789,
# Descartes, René, 1596-1650.
# Desericzky, József Ince, 1702-1763.
# Deseriz, Jósef Ince.
# Desing, Anselm (O.S.B.)
# Desmarts, Samuel.
# Dessen, Bernard von, 1510-1574.
# Devarius, Matthaeus, b. 1505?
# Devaux, Andreas.
# Devoti, Giovanni, 1744-1820.
# Devoti, Giovanni, Arzobispo de Cartago, 1744-1820.
# Devoti, Joannis.
# Deza, Diego, Arzobispo de Sevilla.
# Diana, Antonino (CC.RR.MM.)
# Dicastillo, Juan de (S.I.), 1585-1643.
# Dickson, David, 1583?-1663.
# Dictys, Cretensis.
# Dicuil, active 825.
# Dicuil, fl. 825.
# Dieckhoff, Otto.
# Dieckmann, W.
# Diefenbach, Lorenz, 1806-1883.
# Diemerbroeck, Isbrand
# Diertins, Joseph
# Dietrich, Johann Friedrich, -1833.
# Dietrich, von Nieheim, ca. 1340-1418.
# Dietz, Friedrich Reinhold, 1804-1836.
# Dieven, Pieter van , 1536-1581.
# Dilthey, Karl, 1839-1907.
# Dinter, Bernhard, 1825-
# Dio Chrysostomus.
# Diodoro Sículo.
# Diodorus, Siculus.
# Diogenes Laercio
# Diogenes Laercio.
# Diogenes Laertius.
# Diomedes.
# Dion Casio
# Dionisio de Halicarnaso, ca. 60-5 a.C.
# Dionysius Cartusianus
# Dionysius Cartusianus.
# Dionysius Cisterciensis.
# Dionysius, of Halicarnassus.
# Dionysius, of Tel-Maḥrē, Patriarch of Antioch, -845.
# Dioscorides Pedanius, of Anazarbos.
# Dioscórides.
# Diotallevi, Francesco, 1580-1620.
# Diplovatatius, Thomas, 1468-1541
# Diskowsky, Oscar
# Dittmar, H.
# Dittmar, Hermann.
# Diógenes Laercio.
# Dión Casio.
# Dobrovský, Josef, 1753-1829
# Dobrovský, Josef, 1753-1829.
# Dobrovský, Josef, 1753-1829.
# Doc, Jean, Obispo de Laon
# Doc, Jean, Obispo de Laon.
# Dodoens, Rembert
# Dodoens, Rembert, 1517-1585.
# Doehner, Theodor. [from old catalog]
# Doissin, Louis, 1727-1753.
# Doissin, Louis.
# Dolaus, Johann, 1651-1707.
# Dolz, Juan.
# Dominicus a Sancta Trinitate, O.C.D., 1616-1687.
# Dominicus de Flandria
# Dominique de la Saint-Trinite, (O.C.D.)
# Donati, Alessandro, 1584-1640.
# Donati, Giovanni Battista
# Donati, Marcello
# Doneau, Hugues  , 1527-1591.
# Doneau, Hugues, 1527-1591.
# Doni, Gio. Battista 1593 or 1594-1647
# Donne, William Bodham, 1807-1882.
# Dorléans, Louis (1542-1629)
# Dornsperger, Johann Andreas, active 16th century-17th century.
# Douaren, Francois, 1509-1559.
# Douaren, François, 1509-1559.
# Doujat, Jean
# Doujat, Jean.
# Döhner, Theodor.
# Drach, Paul, 1791-1865.
# Drachmann, A. B. 1860-1935.
# Draco, Johannes Jacobus, 1595-1648.
# Draco, of Stratonica.
# Draconcio, Blosio Emilio.
# Dracontius, Blossius Aemilius, active 5th century
# Dracontius, Blossius Aemilius, active 5th century.
# Drathschmidt, Paulus, 1879-
# Draud, Georg, 1573-1630.
# Draud, Georg, 1573-1635
# Draud, Georg, 1573-1635.
# Dresser, Matthaeus, 1536-1607
# Drewniok, Paulus, 1888-
# Drexel, Jeremias, 1581-1638,
# Drexel, Jeremias, 1581-1638.
# Drexel, Jeremías (S.I.), 1581-1638
# Driedo, Johannes, 1480-1535
# Driedo, Johannes, 1480-1535.
# Drouin, René Hyacinthe (O.P.), 1680-1740
# Drouin, René Hyacinthe (O.P.), 1680-1740.
# Drouin, René Hyacinthe, (O.P.)
# Drouin, René-Hyacinthe (O.P.), 1680-1740
# Drouin, René-Hyacinthe (O.P.), 1680-1740.
# Drusius, Joannes, 1550-1616
# Drusius, Johannes, 1550-1616
# Drusius, Johannes, 1550-1616.
# Dryvère, Jerémie de.
# Du Bellay, Martin.
# Du Buisson, Petro Daniele.
# Du Cange, Charles Du Fresne, sieur, 1610-1688.
# Du Cerceau, Jean-Antoine, 1670-1730.
# Du Chesne, Joseph, 1546-1609.
# Du Creux, François, 1596?-1666.
# Du Creux, François, 1596?-1666.
# Du Faur de Saint-Jorry, Pierre, 1532?-1600.
# Du Hamel, Jean Baptiste, 1624-1706.
# Du Hamel, Jean-Baptiste, 1624-1706.
# Du Jardin, Jacques, 1585-1633.
# Du Jarric, Pierre, 1566-1617.
# Du Jou, François (1589-1677)
# Du Laurens, André
# Du Moulin, Antoine, ca. 1510-1551.
# Du Préau, Gabriel.
# Du Rivail, Aymar, 1490-1557.
# Du Tillet, Jean
# Duardo, Leonardo (C.R.), 1566-1643
# Dubedout, Ernest.
# Dublioul, Jean
# Dubois De Le Boë, François, 1614-1665.
# Dubois, Jacques, 1478-1555.
# Dubravius, Jan, approximately 1486-1553.
# Dubravius, Joannes, 1486ca. - 1553.
# Dubrovnik (Republic)
# Duchesne de Saint-Leger, Theotine
# Duck, Arthur, 1580-1648.
# Duck, Arthur, Sir, 1580-1648.
# Dueñas, Pedro de.
# Dufayard, Ch. 1860-
# Dufourcq, Albert, 1872-1952.
# Dulaurens, François.
# Dulaurens,François.
# Dullaert, Johannes.
# Dunbar, George, 1774-1851.
# Duns Scotus, John, approximately 1266-1308
# Duns Scotus, John, approximately 1266-1308.
# Duns Scotus, John, ca. 1266-1308.
# Dupont, Paul, 1850-
# Dupuy, Jacques, 1591-1656.
# Dupuyherbault, Gabriel.
# Durand de Saint-Pourçain, Guillaume, Évêque de Meaux, ca. 1275-1334.
# Durand, Barthelemy d'Antibes (O.F.M.)
# Durandus, of Saint-Pourçain, Bishop of Meaux, ca. 1275-1334.
# Durant, Jean-Etienne, 1534-1589
# Durant, Jean-Etienne, 1534-1589.
# Durastanti, Giano Matteo
# Duret, Louis, 1527-1586.
# Durham Cathedral.
# Duvergier de Hauranne, Jean, 1581-1643.
# Dübner, Fr. 1802-1867,
# Dürer, Albrecht, 1471-1528
# Dürer, Albrecht, 1471-1528.
# Dyckhoff, Sigimund.
# Dymmok, Roger, fl. 1395.
# Díaz Mayorga, Pedro.
# Díaz de Arce, Juan, 1594-1653.
# Díaz de Luco, Juan Bernal, 1495-1556
# Döring, F. W. 1757-1837
# Dürer, Albrecht, 1471-1528.
# Długosz, Jan, 1415-1480
# Długosz, Jan, 1415-1480.
# Echtermeyer, Ernst Theodor, 1805-1844.
# Eck, Johann von
# Eck, Johann von.
# Eckert, Walther, 1887-
# Eckhart, Johann Georg von, 1674-1730.
# Eckolt, Amadeus, 1623-1668.
# Eckstein, Friedrich August, b. 1810.
# Eden, Robert, 1701-1759.
# Eder, Georg, 1523-1586.
# Edwardes, David.
# Edwards, Thomas, 1729-1785.
# Edwards, Walter Manoel.
# Efren de Nisibis, Santo, 303-373.
# Eggers, H.
# Eggs, George Joseph.
# Egidio da Presentaçao (O.S.A.)
# Ehinger, Elias, active 1633.
# Eichler, Edmund.
# Eichstaedt, Heinrich Carl Abraham, 1772-1848
# Eichstaedt, Heinrich Carl Abraham, 1772-1848.
# Einsiedler, Josephus Maria, 1870-
# Einsiedler, Josephus Maria, b. 1870.
# Ekkehard IV, approximately 980-approximately 1060.
# Elcarte, Francisco de.
# Eliano, Claudio.
# Elias, of Nisibis, 975-
# Elias, of Nisibis, 975-1046
# Elizalde, Miguel de (S.I.), 1616-1678.
# Elsner, Jakob, 1692-1750
# Elster, Johann Christian.
# Elvenich, Peter Joseph, 1796-1886
# Emili, Paolo, 1460-1529
# Emili, Paolo.
# Emlein, Friedericus, 1876-
# Emlein, Friedrich, 1886-
# Emmius, Ubbo, 1547-1625
# Emotte, Pierre.
# Enderlein, Friedrich Leonhard, 1801-1876.
# Enderlein, Friedrich Leonhard, b. 1801.
# Endlicher, István László, 1804-1849.
# Enenckel, Georgius Acacius, Baron von Hoheneck.
# Engbers, Bernard H. [from old catalog]
# Engbers, Bernhard Heinrich.
# Engelke, Karl, 1889-
# Enger, Maximilian,
# Engstro  m, Einar.
# Engström, Einar, 1899-1973.
# Enk, P. J. 1885-1963.
# Enk, Petrus Joannes, 1885-
# Ennius, Quintus.
# Ennodius, Magnus Felix, Obispo de Ticino
# Ennodius, Magnus Felix, Saint, 474-521
# Ennodius, Magnus Felix, Saint, 474-521.
# Enrique Susón, Beato, 1295-1366.
# Enrique de Berg, Beato, 1295-1366.
# Enríquez de Villacorta, Francisco.
# Ens, Gaspar, approximately 1570-
# ...
# Thomas à Kempis, 1380-1471.
# Thomas, Antoine, 1857-1935
# Thomas, Aquinas, Saint, 1225?-1274
# Thomas, Aquinas, Saint, 1225?-1274.
# Thomas, à Becket, Saint, 1118?-1170.
# Thomas, à Kempis, 1380-1471
# Thomas, à Kempis, 1380-1471.
# Thomas, de Argentina, -1357.
# Thomas, de Cantimpré, ca. 1200-ca. 1270.
# Thomas, of Elmham, d. 1440?
# Thomas, of Ely, fl. 1174.
# Thomas, à Kempis, 1380-1471
# Thomas, à Kempis, 1380-1471.
# Thomasius, Christian, 1655-1728
# Thomasius, Christian, 1655-1728.
# Thomassin, Louis, 1619-1695.
# Thorius, Raphael, -1625
# Thou, Jacques Auguste de, 1553-1617.
# Thou, Jacques-Auguste de, 1553-1617.
# Thucydides.
# Thyraeus, Petrus (S.I.)
# Tibullus
# Tibullus.
# Tigerström, Friedrich Wilhelm von, 1803-1868.
# Tiraqueau, André, 1488-1558
# Tirelli, Maurizio, active 1630.
# Tirinus, Jacobus (S.I.), 1580-1636.
# Tirinus, Jacobus, (S.I.), 1580-1636.
# Titelmans, François (O.F.M.)
# Titelmans, François, (O.F.M.)
# Tittmann, Johann August Heinrich.
# Titus, of Bostra, Bishop of Bostra, active approximately 362-378.
# Titz, Heinrich Gottlieb
# Titze, Franz Nicolaus.
# Titze, Franz Niklas, 1769-1858,
# Tkalčić, Ivan Krstitelj, 1840-1904,
# Tkač, Ignác,
# Todd, F. A. 1880-1944.
# Toledano, García.
# Toledo, Francisco de, 1532-1596
# Toledo, Francisco de, 1532-1596.
# Toleto, Pietro Giacomo
# Tomasini, Giacomo Filippo, 1595-1655
# Tomasini, Giacomo Filippo, 1595-1655.
# Tomaszewski, Anton.
# Tomkowicz, Stanisław.
# Tommasi, Giuseppe Maria, 1649-1713
# Tommasi, Giuseppe Maria, 1649-1713.
# Tomás de Aquino, Santo, 1225-1274
# Tomás de Aquino, Santo, 1225-1274.
# Tomás de Aquino, Santo, 1225?-1274
# Tomás de Aquino, Santo, 1225?-1274.
# Tomás de Jesús (O.C.D.)
# Tomás de Villanueva, Santo, 1486-1555.
# Tonduti, Pierre François de, 1583-1669.
# Tonduti, Pierre-François de
# Tonduti, Pierre-François de.
# Tordera, Vicente
# Torelli, Giuseppe, 1721-1781.
# Torquemada, Juan de, 1388-1468
# Torquemada, Juan de, 1388-1468.
# Torre, Marco
# Torreblanca Villalpando, Francisco.
# Torrecilla, Martin de (O.F.M. Cap.)
# Torres, Francisco de (S.I.)
# Torricelli, Evangelista.
# Torsellini, Orazio, 1545-1599
# Torsellini, Orazio, 1545-1599.
# Torsellino, Orazio (S.I.), 1545-1599.
# Torsellino, Orazio, 1545-1599.
# Tortora, Agostino
# Toscano, Isidoro.
# Tozzi, Luca.
# Törneros, Adolph, 1794-1839.
# Traber, Zacharias, 1611-1679
# Trapani (Italy : Province).
# Trentacinque, Alessandro.
# Trevisano, Tommaso
# Trigault, Nicolas, 1577-1628
# Trigault, Nicolas, 1577-1628.
# Triller, Daniel Wilhelm, 1695-1782.
# Trincavelli, Vittore
# Trissino, Galeazzo.
# Trithemius, Johannes.
# Trogo Pompeyo.
# Trombetta, Antonio, 1436-1517
# Tross, Ludwig, 1795-1864.
# Trott, Nicolas, 1663-1740.
# Trottus, Albertus
# Trujillo, Tomás de (O.P.)
# Trull, Juan.
# Tryphiodorus.
# Tschischwitz, Benno, 1828-1890.
# Tuch, Friedrich, 1806-1867.
# Tucídides ca. 460-ca. 400 a. C.
# Tucídides, ca. 460-ca. 400 a. C.
# Tulp, Nicolaas 1593-1674.
# Turnèbe, Adrien, 1512-1565
# Turnèbe, Adrien
# Turnébe, Adrien, 1512-1565.
# Turrettini, François, 1623-1687
# Turrettini, François, 1623-1687.
# Turrettini, François, 1623-1687.
# Turselin, Orazio (S.I.), 1545-1599.
# Turtureto, Vincenzo.
# Turzani, Francesco
# Tuscany (Italy). Rota florentina.
# Twesten, August, 1789-1876.
# Tydeman, H. W. 1778-1863
# Tzschirner, Fr.
# Tácito, Cayo Cornelio.
# Täuber, Isidorus.
# Ubaldi, Baldo degli, 1327?-1400
# Ubaldi, Baldo degli.
# Ubaldini, Giovanni Paolo.
# Ulate, Miguel de.
# Ullrich, R.
# Ullrich, Richard, 1866-
# Ulpian.
# Ulpianus, Domitius, approximately 160-228.
# Ulstadius, Philippus.
# Unger, Hermann.
# Unger, Robert August, 1813-
# Unger, Robert.
# Universität Bonn. Philologische Gesellschaft.
# Universitätsbibliothek München.
# Universitèat Jena.
# Université de Paris
# University of Cambridge
# Universität Göttingen.
# Universität Ingolstadt. Bibliothek.
# Universitätsbibliothek Leipzig.
# Uniwersytet Wrocławski im. Bolesława Bieruta.
# Unknown
# Untzer, Matthias, 1581-1624.
# Unverfärth, Joachim Martin.
# Uppenkamp, August.
# Upton, Nicholas, 1400?-1457.
# Uriendt, Maximilien.
# Ursaya, Domingo.
# Ursinus Velius, Caspar, 1493-1539.
# Ursinus Velius, Caspar.
# Ussher, James, 1581-1656
# Vadianus, Joachim, 1484-1551.
# Vagedes, Heinrich, -1698.
# Vahlen, Johannes, 1830-1911
# Vahlen, Johannes, 1830-1911.
# Vairo, Leonardo (O.S.B.)
# Vaissière, Pierre de, 1867-1942
# Valckenaer, Lodewijk Caspar, 1715-1785
# Valencia, Gregorio de (S.I.)
# Valencia, Melchor de.
# Valenti, Ferdinando.
# Valentibus, Ferdinandus de.
# Valentin, Veit.
# Valenzuela Velázquez, Juan Bautista, 1574-1645
# Valenzuela Velázquez, Juan Bautista, 1574-1645.
# Valeriano Bolzani, Giovan Piero, 1477-1558.
# Valeriano, Pierio, 1477-1560.
# Valerio Flaco, Cayo.
# Valerio Máximo, Publio
# Valerio Máximo, Publio.
# Valerio, Luca, 1522-1618
# Valerius Flaccus, Gaius, 1st cent
# Valerius Flaccus, Gaius, 1st cent.
# Valerius Flaccus, Gaius, active 1st century
# Valerius Flaccus, Gaius, active 1st century.
# Valerius Maximus
# Valerius Maximus,
# Valerius Maximus.
# Valerius Maximus. [from old catalog]
# Valerius, Cornelius.
# Valerius, Maximus.
# Valiero, Agostino 1531-1606.
# Valiero, Agostino, 1531-1606
# Valiero, Agostino, 1531-1606.
# Valiero, Agostino, cardinal, 1531-1606.
# Valla, Lorenzo, 1406-1457.
# Valla, Lorenzo, 1407-1457.
# Valleriole, François, 1504-1580.
# Valles, Francisco, 1524-1592.
# Vallés, Francisco, 1524-1592
# Vallés, Francisco, 1524-1592.
# Valois, Henri de, 1603-1676.
# Valsecchi, Antonino (O.P.)
# Valturio, Roberto, 1405-1475
# Valturio, Roberto, 1405-1475.
# Vanallus, Andrea.
# Varnhagen, Hermann, 1850-1924,
# Varnhagen, Hermann, 1850-1924.
# Varro, Marcus Terentius
# Varro, Marcus Terentius,
# Varro, Marcus Terentius.
# Varrón, Marco Terencio
# Varrón, Marco Terencio.
# Vassis, Sp., 1852-
# Vast, Henri, 1847-1921
# Vater, Johann Severin, 1771-1826
# Vattasso, Marco, 1869-1925.
# Vaucher, Louis, 1820-
# Vaucher, Louis.
# Vaudus, Joannes, active 16th century.
# Vavasseur, François, 1605-1681
# Vavasseur, François, 1605-1681.
# Vavasseur, François (S.I.)
# Vaz, Alvaro, 1526-1593.
# Vazquez Morales, Joaquín José
# Vazquez de Menchaca, Fernando de.
# Vázquez Menchaca, Fernando, 1512-1569.
# Vecchi, Paolo.
# Vedelius, Nicolaas, 1596-1642
# Veen, Otto van, 1556-1629
# Vega, Andreas de, 1498-1549
# Vega, Andreas de, 1498-1549.
# Vega, Andrés de (O.F.M.)
# Vega, Cristobal de.
# Vega, Pedro de la
# Vegecio, fl. s.4
# Vegecio, fl. s.4.
# Vegetius Renatus, Flavius.
# Vegetius Renatus, Publius
# Vegetius Renatus, Publius.
# Vegio, Maffeo, 1407-1458
# Vel, Caspar Ursinus, 1493-1538.
# Velazquez, Juan Antonio (S.I.) , 1585-1669.
# Velazquez, Juan Antonio (S.I.), 1585-1669.
# Veleyo Patérculo, Cayo
# Veleyo Patérculo, Cayo.
# Velleius Paterculus, approximately 19 B.C.-approximately 30 A.D.
# Velleius Paterculus, ca. 19 B.C.-ca. 30 A.D.
# Velletri (Italy)
# Velloso, José Mariano da Conceição, 1742-1811.
# Velser, Marcus, 1558-1614.
# Velázquez, Andrés
# Velázquez, Juan Antonio (S.I.), 1585-1669.
# Venatorius, Daniel.
# Venema, Hermann, 1697-1787.
# Verallo, Paolo Emilio.
# Verbiest, Ferdinand, 1623-1688.
# Verde, Francesco, 1631-1706.
# Verepaeus, Simon, 1522?-1598.
# Verepaeus, Simon.
# Vergara, Francisco, 1484-1545.
# Vergil, Polydore, 1470?-1555
# Vergil, Polydore, 1470?-1555.
# Vergilio, Polidoro.
# Vergilius Maro, Publius.
# Verheyen, Philip, 1648-1710
# Verheyen, Philippe, 1648-1710.
# Verino, Ugolino, 1438-1516
# Verino, Ugolino, 1438-1516.
# Verlenius, Hieronymus
# Vermigli, Pietro Martire, 1499-1562.
# Vernerey, Jean.
# Verney, Luis Antonio, 1713-1792.
# Vernezza di Freney, Giuseppe, 1745-1822
# Verona (Italy)
# Verrio Flaco, Marco.
# Verrius Flaccus, Marcus
# Vervorst, Firmin.
# Verzosa, Juan de.
# Vesalius, Andreas, 1514-1564,
# Vesalius, Andreas, 1514-1564.
# Vessem, Joseph van.
# Vettius Valens.
# Vettori, Pietro, 1499-1585
# Vettori, Pietro, 1499-1585.
# Vicario, Bartolomeo.
# Vicente Ferrer, Santo, 1350-1419
# Vicente Ferrer, Santo, 1350-1419.
# Vicente de Lerins, Santo, s.5.
# Vico, Enea, 1523-1567
# Vico, Enea, 1523-1567.
# Vico, Giambattista, 1668-1744
# Victor, Sextus Aurelius
# Victor, Sextus Aurelius.
# Victorinus, Saint, Bishop of Poetovio, -304?
# Vida, Marco Girolamo, 1470-1566
# Vida, Marco Girolamo, 1470-1566.
# Vida, Marco Girolamo, approximately 1485-1566.
# Vida, Marco Girolamo, ca. 1485-1566.
# Vida, Marco Girolamo.
# Vielmi, Girolamo, m.1581
# Vielmi, Girolamo, m.1581.
# Vieri, Francesco de'
# Vigel, Nikolaus, 1529-1600.
# Vigelius, Nicolaus
# Vigelius, Nicolaus.
# Viger, François, 1590-1647
# Viger, François, 1590-1647.
# Viger, François, d. 1647.
# Viger, François, 1590-1647.
# Vigiliis von Creutzenfeld, Stephan Hieronymus de.
# Vignier, Nicolas, 1530-1596.
# Vignoli, Giovanni.
# Vignolius, Joannes.
# Villagut, Alonso.
# Villani, Filippo, -1405.
# Villani, Filippo, d. 1405?
# Villar, Ignacio del.
# Villaret, Oskar.
# Villarreal, Juan de
# Villaverde, Miguel de, (O.F.M.)
# Villavicencio, Lorenzo de.
# Vimercati, Francesco
# Vinkesteyn, C. J.
# Vinkesteyn, Cornelius Joannes.
# Vinnius, Arnoldus, 1588-1657
# Vinnius, Arnoldus, 1588-1657.
# Viperano, Giovanni Antonio
# Viperano, Giovanni Antonio, 1535-1610.
# Viperano, Giovanni Antonio.
# Virgil
# Virgil,
# Virgil.
# Virgile (0070-0019 av. J.-C.).
# Virgilio Marón, Publio, 70-19 a. C.
# Virgilio, Polydoro, 1470?-1555
# Virgilio, Polydoro, 1470?-1555.
# Virgilius Maro, Grammaticus, active 7th century.
# Virgilius Maro, P., 70 v.Chr.-19 v.Chr.
# Vismara, Ercole
# Visser, Didericus.
# Vitellio.
# Vitoria, Francisco de, 1483-1546.
# Vitriaco, Giacomo de.
# Vitringa, Campegius, 1659-1722
# Vitringa, Campegius, 1659-1722.
# Vitrubio Polion, Marco.
# Vitrubio Polión, Marco.
# Vitruvius Pollio
# Vitruvius Pollio, Marcus.
# Vitruvius Pollio.
# Vittori, Leonello
# Vivaldi, Giovanni Lodovico.
# Vivaldi, Giovanni Ludovico
# Vives, Jerónimo (O.P.)
# Vives, Juan Luis, 1492-1540
# Vives, Juan Luis, 1492-1540.
# Vivianus, Joannes Baptista.
# Vivien, Joris, b. 1536.
# Vivio, Francesco, approximately 1532-1616.
# Vivio, Francesco, n.ca.1532
# Viète, François.
# Vliet, Joannes van der.
# Vlis, Christian Jacob van der.
# Voerda, Nicasius de.
# Voet, Joahnnes, 1647-1713.
# Voet, Johannes, 1647-1713.
# Voet, Paul, 1619-1667
# Voet, Paul, 1619-1667.
# Vogel, August.
# Voigt, Gottfried, 1644-1682.
# Voigt, Paul Friedrich Wilhelm, 1857-
# Voigt, Richard
# Voigt, Richard.
# Voisin, Joseph de, 1610-1685.
# Volckamer, Johann Georg, 1662-1744.
# Volckmar, Johann.
# Volckmar, K. 1814-1872.
# Volkmann, Alfred Wilhelm, 1800-1877.
# Volkmann, Richard Emil.
# Volkmann, Richard von, 1830-1889,
# Volkmann, Richard von, 1830-1889.
# Volland, Johann.
# Volpi, Gio. Antonio, 1686-1766
# Voltaire, 1694-1778
# Vom Hagen, Carolus, active 17th century.
# Vorlaender, Wilhelm, 1841-
# Vossius, Gerard Joannes, 1577-1649.
# Vossius, Gerardus Joannes, 1577-1649
# Vossius, Gerardus Joannes, 1577-1649.
# Vossius, Gerardus Johannes 1577-1649
# Vossius, Gerardus Johannes 1577-1649.
# Vossius, Gerardus Johannes, 1577-1649
# Vossius, Gerardus Johannes, 1577-1649.
# Vossius, Gerhard Johann, 1577-1649.
# Vossius, Isaac, 1618-1689.
# Voëll, Jean.
# Voïgtius, Richard. [from old catalog]
# Vriemoet, Emo Lucius, 1699-1760.
# Vries, Hugo de, 1848-1935.
# Vultejus, Hermann, 1565-1634.
# Vázquez de Menchaca, Fernando de
# Vázquez de Menchaca, Fernando de.
# Vázquez de Menchaca, Fernando.
# Vázquez, Gabriel (S.I.), 1551-1604.
# Vālmīki.
# Wade, Thomas, 1805-1875.
# Waechter, William.
# Waehner, Andreas Georgio.
# Wageningen, Jacob van.
# Wagenseil, Johann Christoph
# Wagenseil, Johann Christoph, 1633-1705.
# Wagner, Friedrich Wilhelm, 1814-1857
# Wagner, Friedrich Wilhelm, 1814-1857.
# Wagner, Johann Augustin.
# Waitz, Theodor.
# Walahfrid Strabo, 807?-849
# Walahfrid Strabo, 807?-849.
# Waldung, Wolfgang, 1554-1621.
# Walle, Jacques van de, 1599-1690.
# Wallis, John.
# Walram, Bishop of Naumberg, d. 1111.
# Walram, Bishop of Naumburg, -1111.
# Walter, of Aquitaine.
# Walther, Georg Heinrich.
# Waser, Caspar.
# Weber, Eduard Otto.
# Weber, Friedrich August.
# Weber, Karl Friedrich, 1794-1861.
# Weber, Theodor Hubert, 1836-
# Wecker, Johann Jacob, 1528-1586
# Wecker, Johann Jacob, 1528-1586.
# Wedel, Georg Wolfgang, 1645-1721
# Wehner, Paul Matthias, 1583-1612.
# Weichert, Jonathan August, 1788-1844.
# Weidenfeld, Johann Seger.
# Weidgen, J.
# Weidgen, J. [from old catalog]
# Weidler, Johann Friedrich, 1691-1755.
# Weinhold, Karl, 1823-1901.
# Weiser, Joseph.
# Weiss, Adolf, 1849-1924.
# Weisse, Christian Hermann.
# Weissenbach, Joseph Anton.
# Weissenbach, Joseph.
# Weitenauer, Ignaz, (S.I.)
# Weller, G.
# Welsch, Georg Hieronymus, 1624-1677.
# Welser, Marcus, 1558-1614.
# Wendelin, Marcus Friedrich
# Wermuth, Carl.
# Wermuth, Karl.
# Werner, Johannes, 1468-1528.
# Wesenbeck, Matthaeus, 1531-1586
# Wesenbeck, Matthaeus, 1531-1586.
# Wesseling, Petrus, 1692-1764
# Wesseling, Petrus, 1692-1764.
# Westermann, Anton, 1806-1869.
# Westheimer, Bartholomeus, 1504-approximately 1570.
# Westhoff, Bernhard.
# Weston, Eduard.
# Westphal, Johann Friedrich.
# Weyer, Johann, 1515-1588,
# Weyer, Johann, 1515-1588.
# Weyers, Heinrich Engelin.
# Weygel, Joseph Anton.
# Wicelius, Georgius
# Wickham, E. C. 1834-1910
# Widl, Adam, 1639-1710.
# Widukind von Korvei, fl. 970.
# Widukind, of Corvey, approximately 925-approximately 973
# Widukind, of Corvey, approximately 925-approximately 973.
# Wier, Jean.
# Wiggert, J.
# Wilamowitz-Moellendorff, Ulrich von, 1848-1931.
# Wild, Johann (O.F.M.)
# Wilde, Jacob de, 1645-1725?
# Wilken, Friedrich, 1777-1840.
# Willenborg, Heinrich Clemens.
# William of Newburgh, (O.S.A.), 1136?-1201?
# William, of Auvergne, Bishop of Paris, -1249.
# William, of Auvergne, Bishop of Paris, 1180-1249.
# William, of Malmesbury, approximately 1090-1143.
# William, of Newburgh, 1136-1201?
# Willis, John, d. 1625.
# Willis, Thomas
# Willis, Thomas, 1621-1675.
# Willis, Thomas.
# Willughbeii, Francisci
# Willughby, Francis, 1635-1672.
# Wilmanns, August.
# Wilmius, Johannes.
# Wilson, H. A. 1854-1927.
# Winckelmann, Johann Just, 1620-1699.
# Winckler, Daniel, fl. 1623-1629.
# Winer, Georg Benedikt, 1789-1858.
# Winiewski, Franz.
# Wion, Arnold.
# Wirtz, Paul, 1875-
# Wisén, Magne Ingemund, 1874-
# Witelo, 13th cent.
# Witsius, Herman, 1636-1708.
# Wodrig, Albert. [from old catalog]
# Woelffel, Heinrich.
# Wolbero.
# Wolf, F. A. 1759-1824.
# Wolff, H. H.
# Wolffel, Henricus.
# Woltjer, J.
# Woog, Carl Christian, 1713-1771.
# Wopkens, Thomas, 1700-1755.
# Wopkens, Thomas.
# Worcester Cathedral
# Worcester Cathedral.
# Worm, Ole, 1588-1654.
# Worp, prior of Thabor, 1538.
# Wotton, Edward, 1492-1555.
# Wouters, Martín (O.E.S.A.)
# Wölffel, H.
# Wölfflin, Eduard von, 1831-1908.
# Wuestemann, Ernst Friedrich, 1799-1856,
# Wurmser, Bernhard.
# Wycliffe, John, -1384.
# Wycliffe, John, d. 1384.
# Wyttenbach, Daniel Albert, 1746-1820
# Wyttenbach, Daniel Albert, 1746-1820.
# Wyttenbach, Daniel, 1746-1820.
# Wöhlermann, Otto.
# Wölffel, Henricus.
# Würdtwein, Stefan Alexander, 1719-1796.
# Wāqidī, Muḥammad ibn ʻUmar, 747 or 8-823.
# Wāqidī, Muḥammad ibn ʻUmar, 747 or 748-823.
# Xammar, Joan Pau.
# Xenophon, of Ephesus
# Xenophon.
# Yamblico.
# Yanguas, Juan de (O.P.)
# Yañez Parladorio, Juan.
# Yuhanna Ibn Serapion, s. 9
# Yver, J. G.
# Yáñez Parladorio, Juan
# Zabarella, Francesco
# Zabarella, Jacopo, 1533-1589.
# Zacarias, Obispo de Crisópolis.
# Zaccagni, Lelio, 1595-1678.
# Zaccaria, Francescantonio, 1714-1795.
# Zaccaria, Francesco Antonio, (S.I.)
# Zacchia, Paolo.
# Zacuto, Abraham ben Samuel, b. ca. 1450.
# Zacutus Lusitanus, 1575-1642.
# Zacutus, Lusitanus, 1575-1642.
# Zahlfeldt, Franz, b. 1853.
# Zallinger Zum Thurm, Jakob Anton von (1735-1813)
# Zallinger Zum Thurm, Jakob Anton von,  (1735-1813)
# Zallinger zum Thurm, Jakob Anton von, 1735-1813.
# Zamora y Clavería, José
# Zanchi, Basilio, 1501-1558
# Zander, C. M.
# Zander, Carl M. 1845-
# Zannoni, Gio. Batista, 1774-1832.
# Zecchi, Lelio, m. 1610.
# Zecchi, Lelio, m.1610
# Zeger, Tacitus Nicolaus.
# Zeiller, Martin, 1589-1661.
# Zepeda Castro y Gudiel, Francisco José de
# Ziegler, Kaspar, 1621-1690
# Ziegler, Kaspar, 1621-1690.
# Zimmermann, Eugen.
# Zimmermann, Richard, 1861-
# Zoega, Georg, 1755-1809
# Zoesius, Hendrik, -1627.
# Zoesius, Henricus, 1571-1627
# Zoesius, Henricus, 1571-1627.
# Zola, Giuseppe, 1739-1806
# Zola, Giuseppe, 1739-1806.
# Zola, Josephus.
# Zorell, Franz, 1863-1947.
# Zuffi, Giovanni.
# Zumel, Francisco, 1540-1607.
# Zumpt, A. W. 1815-1877.
# Zurita, Jerónimo
# Zwingli, Ulrich 1484-1531.
# Zwingli, Ulrich, 1484-1531.
# Zype, Frans van den, 1580-1650.
# Zúñiga, Diego de (O.S.A.)
# [Johanneau, Eloi] [from old catalog]
# [Lawrance, Walter John] [from old catalog]
# Æschines.
# Łaski, Jan, 1499-1560
# Łaski, Jan, 1499-1560.
# Ǩimmich, Joseph.
# ʻAlī ibn Abī Ṭālib, Caliph, approximately 600-661
# ʻAlī ibn Uthmān, al-Ūshī.
# ʻAmr ibn Kulthūm, active 6th century.
# Ḥillī, Ṣafī al-Dīn ʻAbd al-ʻAzīz ibn Sarāyā, 1278-
# Ḥārith ibn Ḥillizah, active 6th century.

# %% [markdown]
# This is bad. There are still lots of Greek authors in the mix.
#
# **Conclusion**: I need to train another model to identify Greek author names.

# %%
from transformers import DistilBertForSequenceClassification, DistilBertTokenizerFast
# Ensure labels are loaded
greek_model_path = '../greek'
greek_model = DistilBertForSequenceClassification.from_pretrained(greek_model_path)
tokenizer = DistilBertTokenizerFast.from_pretrained(greek_model_path)

if not hasattr(greek_model.config, "id2label") or not greek_model.config.id2label:
    # Define your labels if they weren't saved correctly
    labels = ["Latin", "Greek"]
    greek_model.config.id2label = {idx: label for idx, label in enumerate(labels)}
    greek_model.config.label2id = {label: idx for idx, label in enumerate(labels)}

greek_model.config.id2label = {0: "Greek", 1: "Latin"}
greek_model.config.label2id = {"Greek": 0, "Latin": 1}

# Save the updated model configuration
greek_model.save_pretrained('./greek')

# %%
import torch.nn.functional as F

def classify_author_language(input_author):
    """Classify the author's language as Greek or Latin using the fine-tuned model."""
    if not isinstance(input_author, str):
        return "Unknown", 0.0

    # Tokenize and encode the input author name
    inputs = tokenizer(input_author, return_tensors="pt", truncation=True, padding=True)
    outputs = greek_model(**inputs)
    logits = outputs.logits.detach().cpu()

    # Apply softmax to logits to get probabilities
    probabilities = F.softmax(logits, dim=-1).numpy()
    predicted_class = probabilities.argmax(axis=-1)[0]
    confidence = probabilities.max()  # Highest probability

    # Use the id2label mapping for label names
    predicted_label = greek_model.config.id2label[predicted_class]
    print(f"Language Classification: {input_author} -> {predicted_label} (Confidence: {confidence:.4f})")

    return predicted_label, confidence

def classify_and_split_by_language(processed_df):
    """Classify authors as Greek or Latin and split the dataframe."""
    language_results = []

    for _, row in processed_df.iterrows():
        input_author = row["author"]

        # Perform language classification
        author_language, language_confidence = classify_author_language(input_author)

        # Add the results to a new row
        language_results.append({
            **row,  # Include existing row data
            "language": author_language,
            "language_confidence": language_confidence,
        })

    # Create an updated dataframe with language classification
    classified_df = pd.DataFrame(language_results)

    # Split the dataframe into Greek and Latin subsets
    greek_df = classified_df[classified_df["language"] == "Greek"].reset_index(drop=True)
    latin_df = classified_df[classified_df["language"] == "Latin"].reset_index(drop=True)

    return classified_df, greek_df, latin_df

# %%
import csv
# Classify authors by language and split into Greek/Latin dataframes
classified_df, greek_df, latin_df = classify_and_split_by_language(df)

# Save the results if needed
classified_df.to_csv("../data/classified_metadata.csv", index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)
greek_df.to_csv("../data/greek_authors.csv", index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)
latin_df.to_csv("../data/latin_authors.csv", index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)

# Display the results
print("Classified DataFrame:")
print(classified_df.head())
print("\nGreek Authors DataFrame:")
print(greek_df.head())
print("\nLatin Authors DataFrame:")
print(latin_df.head())
# Out:
# Language Classification: Du Creux, François, 1596?-1666. -> Latin (Confidence: 1.0000)
# Language Classification: Meyer, Ernst H. F. 1791-1858. -> Latin (Confidence: 1.0000)
# Language Classification: Laet, Joannes de, 1593-1649. -> Latin (Confidence: 1.0000)
# Language Classification: Caesar, Julius -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Kircher, Athanasius, 1602-1680 -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Hincmar, Archbishop of Reims, approximately 806-882 -> Latin (Confidence: 1.0000)
# Language Classification: Acosta, José de, 1540-1600, -> Latin (Confidence: 1.0000)
# Language Classification: Hincmar, Archbishop of Reims, approximately 806-882 -> Latin (Confidence: 1.0000)
# Language Classification: Lessius, Leonardus, 1554-1623 -> Latin (Confidence: 1.0000)
# Language Classification: Hincmar, Archbishop of Reims, approximately 806-882 -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Riccioli, Giovanni Battista, 1598-1671, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Guazzo, Francesco Maria, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Kircher, Athanasius, 1602-1680. -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Mersenne, Marin, 1588-1648, -> Latin (Confidence: 1.0000)
# Language Classification: Hincmar, Archbishop of Reims, approximately 806-882 -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Kircher, Athanasius, 1602-1680. -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Drexel, Jeremias, 1581-1638, -> Latin (Confidence: 1.0000)
# Language Classification: Virgil. -> Latin (Confidence: 1.0000)
# Language Classification: Kepler, Johannes, 1571-1630. -> Latin (Confidence: 1.0000)
# Language Classification: Roothaan, Joannes Philippus, 1785-1853 -> Latin (Confidence: 1.0000)
# Language Classification: Arrian. -> Greek (Confidence: 0.9995)
# Language Classification: Euclid, -> Greek (Confidence: 0.9998)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Alvares, Manuel, 1526-1583. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Huygens, Constantijn, 1596-1687 -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Nieremberg, Juan Eusebio, 1595-1658. -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Reiske, Johann Jacob, 1716-1774. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suárez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Virgil. -> Latin (Confidence: 1.0000)
# Language Classification: Boethius, -524. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Prosper, of Aquitaine, Saint, approximately 390-approximately 463. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Vitruvius Pollio. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Torsellino, Orazio, 1545-1599. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Juvencus, Caius Vettius Aquilinus. -> Latin (Confidence: 1.0000)
# Language Classification: Lucretius Carus, Titus. -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius. -> Latin (Confidence: 1.0000)
# Language Classification: Hyginus, Gromaticus. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Roothaan, Joannes Philippus, 1785-1853 -> Latin (Confidence: 1.0000)
# Language Classification: Kepler, Johannes, 1571-1630. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suárez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Rostowski, Stanislaw, 1711-1784. -> Latin (Confidence: 1.0000)
# Language Classification: Valerius Flaccus, Gaius, active 1st century. -> Latin (Confidence: 1.0000)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Duns Scotus, John, ca. 1266-1308. -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Navarrete, Jean André, 1730-1811. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Reiske, Johann Jacob, 1716-1774. -> Latin (Confidence: 1.0000)
# Language Classification: Caesar, Julius. -> Latin (Confidence: 1.0000)
# Language Classification: Reiske, Johann Jacob, 1716-1774. -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Commodianus. -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius. -> Latin (Confidence: 1.0000)
# Language Classification: Kepler, Johannes, 1571-1630. -> Latin (Confidence: 1.0000)
# Language Classification: Copernicus, Nicolaus, 1473-1543 -> Latin (Confidence: 1.0000)
# Language Classification: Caesar, Julius. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius. -> Latin (Confidence: 1.0000)
# Language Classification: Herodotus. -> Greek (Confidence: 0.9999)
# Language Classification: Celsus, Aulus Cornelius. -> Greek (Confidence: 0.9999)
# Language Classification: Nonius Marcellus, active 4th century. -> Greek (Confidence: 0.9988)
# Language Classification: Bacon, Roger, 1214?-1294. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Nakatenus, Wilhelm, 1617-1682. -> Latin (Confidence: 1.0000)
# Language Classification: Kepler, Johannes, 1571-1630. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Caesar, Julius. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Gretser, Jakob, 1562-1625. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Palladius, Rutilius Taurus Aemilianus. -> Latin (Confidence: 1.0000)
# Language Classification: Lucretius Carus, Titus. -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Huygens, Christiaan, 1629-1695. -> Latin (Confidence: 1.0000)
# Language Classification: Suárez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Caesar, Julius. -> Latin (Confidence: 1.0000)
# Language Classification: Valerius Maximus. -> Latin (Confidence: 1.0000)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Silius Italicus, Tiberius Catius. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Victor, Sextus Aurelius. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Navarrete, Jean André, 1730-1811. -> Latin (Confidence: 1.0000)
# Language Classification: Callaghan, John, 1605-1654, -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Juvenal. -> Greek (Confidence: 0.9999)
# Language Classification: Kircher, Athanasius, 1602-1680 -> Latin (Confidence: 1.0000)
# Language Classification: Suárez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Claudianus, Claudius -> Greek (Confidence: 0.9999)
# Language Classification: Knabenbauer, Joseph, 1839-1911. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suárez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Kepler, Johannes, 1571-1630. -> Latin (Confidence: 1.0000)
# Language Classification: Nonius Marcellus, active 4th century. -> Greek (Confidence: 0.9988)
# Language Classification: Florus, Lucius Annaeus. -> Latin (Confidence: 1.0000)
# Language Classification: Caesar, Julius. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius. -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617, -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Propertius, Sextus. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suárez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Kepler, Johannes, 1571-1630. -> Latin (Confidence: 1.0000)
# Language Classification: Noceti, Carlo, 1694-1759. -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Bellarmino, Roberto Francesco Romolo, Saint, 1542-1621. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Maffei, Giovanni Pietro, 1536?-1603. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Franchis, Francesco de. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Nonius Marcellus, active 4th century. -> Greek (Confidence: 0.9988)
# Language Classification: Pliny, the Elder -> Latin (Confidence: 1.0000)
# Language Classification: Suárez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Kepler, Johannes, 1571-1630. -> Latin (Confidence: 1.0000)
# Language Classification: Caesar, Julius. -> Latin (Confidence: 1.0000)
# Language Classification: Horatius, Romanus, fl. 1450. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Kepler, Johannes, 1571-1630. -> Latin (Confidence: 1.0000)
# Language Classification: Caesar, Julius. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Doni, Gio. Battista 1593 or 1594-1647 -> Latin (Confidence: 1.0000)
# Language Classification: Viger, François, 1590-1647 -> Latin (Confidence: 1.0000)
# Language Classification: Lucas, Karl Wilhelm. -> Latin (Confidence: 1.0000)
# Language Classification: Portus, Aemilius, 1550-1614 or 1615 -> Latin (Confidence: 1.0000)
# Language Classification: Muret, Marc-Antoine, 1526-1585 -> Latin (Confidence: 1.0000)
# Language Classification: Muret, Marc-Antoine, 1526-1585 -> Latin (Confidence: 1.0000)
# Language Classification: Klausen, Rudolf Heinrich, 1807-1840. -> Latin (Confidence: 1.0000)
# Language Classification: Martin, Bernard, 1574-1639. -> Latin (Confidence: 1.0000)
# Language Classification: Wesseling, Petrus, 1692-1764 -> Latin (Confidence: 1.0000)
# Language Classification: Hanow, Rudolf, 1806-1871. -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Curtius Rufus, Quintus -> Latin (Confidence: 1.0000)
# Language Classification: Florus, Lucius Annaeus -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Burchard, Johann Friedrich Wilhelm, -> Latin (Confidence: 1.0000)
# Language Classification: Anacreon -> Greek (Confidence: 0.9999)
# Language Classification: Vater, Johann Severin, 1771-1826 -> Latin (Confidence: 1.0000)
# Language Classification: John Chrysostom, Saint, -407 -> Greek (Confidence: 0.9999)
# Language Classification: Clement, of Alexandria, Saint, approximately 150-approximately 215 -> Greek (Confidence: 0.9999)
# Language Classification: Henrichsen, Rudolf Johann Frederik, 1800-1871. -> Latin (Confidence: 1.0000)
# Language Classification: Herodotus -> Greek (Confidence: 0.9999)
# Language Classification: Herodotus -> Greek (Confidence: 0.9999)
# Language Classification: Lauer, Julius Franz, 1819-1850. -> Latin (Confidence: 1.0000)
# Language Classification: Nemesius, Bp. of Emesa -> Greek (Confidence: 0.9999)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Pindar -> Greek (Confidence: 0.9999)
# Language Classification: Groke, Th. Wilhelm. -> Latin (Confidence: 1.0000)
# Language Classification: Theocritus. -> Greek (Confidence: 0.9999)
# Language Classification: Xenophon -> Greek (Confidence: 0.9999)
# Language Classification: Butler, Samuel, 1774-1839 -> Latin (Confidence: 1.0000)
# Language Classification: Katrares, Johannes, 14th cent. -> Latin (Confidence: 1.0000)
# Language Classification: Augustine, of Hippo, Saint, 354-430. -> Latin (Confidence: 1.0000)
# Language Classification: Caesar, Julius -> Latin (Confidence: 1.0000)
# Language Classification: Caesar, Julius -> Latin (Confidence: 1.0000)
# Language Classification: Catullus, Gaius Valerius -> Latin (Confidence: 1.0000)
# Language Classification: Catullus, Gaius Valerius -> Latin (Confidence: 1.0000)
# Language Classification: Catullus, Gaius Valerius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Persyn, Janus Van. -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Wopkens, Thomas, 1700-1755. -> Latin (Confidence: 1.0000)
# Language Classification: Curtius Rufus, Quintus -> Latin (Confidence: 1.0000)
# Language Classification: Curtius Rufus, Quintus -> Latin (Confidence: 1.0000)
# Language Classification: Curtius Rufus, Quintus -> Latin (Confidence: 1.0000)
# Language Classification: Frontinus, Sextus Julius -> Latin (Confidence: 1.0000)
# Language Classification: Gellius, Aulus -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Lachmann, Karl, 1793-1851 -> Latin (Confidence: 1.0000)
# Language Classification: Mela, Pomponius -> Latin (Confidence: 1.0000)
# Language Classification: Mela, Pomponius -> Latin (Confidence: 1.0000)
# Language Classification: Nepos, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Ovid, 43 B.C.-17 A.D. or 18 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Ovid, 43 B.C.-17 A.D. or 18 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Ovid, 43 B.C.-17 A.D. or 18 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Persius -> Latin (Confidence: 1.0000)
# Language Classification: Phaedrus -> Latin (Confidence: 0.9997)
# Language Classification: Phaedrus -> Latin (Confidence: 0.9997)
# Language Classification: Phaedrus -> Latin (Confidence: 0.9997)
# Language Classification: Phaedrus -> Latin (Confidence: 0.9997)
# Language Classification: Phaedrus -> Latin (Confidence: 0.9997)
# Language Classification: Phaedrus -> Latin (Confidence: 0.9997)
# Language Classification: Phaedrus -> Latin (Confidence: 0.9997)
# Language Classification: Phaedrus -> Latin (Confidence: 0.9997)
# Language Classification: Phaedrus -> Latin (Confidence: 0.9997)
# Language Classification: Phaedrus -> Latin (Confidence: 0.9997)
# Language Classification: Phaedrus -> Latin (Confidence: 0.9997)
# Language Classification: Phaedrus -> Latin (Confidence: 0.9997)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Rutilius Namatianus, Claudius, active 5th century -> Latin (Confidence: 1.0000)
# Language Classification: Sallust, 86 B.C.-34 B.C. -> Latin (Confidence: 1.0000)
# Language Classification: Sallust, 86 B.C.-34 B.C. -> Latin (Confidence: 1.0000)
# Language Classification: Sallust, 86 B.C.-34 B.C. -> Latin (Confidence: 1.0000)
# Language Classification: Sallust, 86 B.C.-34 B.C. -> Latin (Confidence: 1.0000)
# Language Classification: Sallust, 86 B.C.-34 B.C. -> Latin (Confidence: 1.0000)
# Language Classification: Sallust, 86 B.C.-34 B.C. -> Latin (Confidence: 1.0000)
# Language Classification: Seneca, Lucius Annaeus, approximately 4 B.C.-65 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Silius Italicus, Tiberius Catius -> Latin (Confidence: 1.0000)
# Language Classification: Statius, P. Papinius -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Tibullus -> Latin (Confidence: 1.0000)
# Language Classification: Tibullus -> Latin (Confidence: 1.0000)
# Language Classification: Tibullus -> Latin (Confidence: 1.0000)
# Language Classification: Tibullus -> Latin (Confidence: 1.0000)
# Language Classification: Valerius Maximus -> Latin (Confidence: 1.0000)
# Language Classification: Vegetius Renatus, Publius -> Latin (Confidence: 1.0000)
# Language Classification: Velleius Paterculus, approximately 19 B.C.-approximately 30 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Velleius Paterculus, approximately 19 B.C.-approximately 30 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Velleius Paterculus, approximately 19 B.C.-approximately 30 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Velleius Paterculus, ca. 19 B.C.-ca. 30 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Virgil -> Latin (Confidence: 1.0000)
# Language Classification: Virgil -> Latin (Confidence: 1.0000)
# Language Classification: Virgil -> Latin (Confidence: 1.0000)
# Language Classification: Braunhard, Wilhelm, 1807-1866. -> Latin (Confidence: 1.0000)
# Language Classification: Fuss, J. D, 1782-1860. -> Latin (Confidence: 1.0000)
# Language Classification: Jordan, of Saxony, -1237 -> Latin (Confidence: 1.0000)
# Language Classification: Monachus, Haymarus, Patriarch of Jerusalem, d. 1202. -> Greek (Confidence: 0.9649)
# Language Classification: Dietrich, Johann Friedrich, -1833. -> Latin (Confidence: 1.0000)
# Language Classification: Abū Miḥjan al-Thaqafī, active 629-637 -> Latin (Confidence: 1.0000)
# Language Classification: Abū Miḥjan al-Thaqafī, active 629-637 -> Latin (Confidence: 1.0000)
# Language Classification: Muḥammad ibn 'Umar, al-Wākidī. -> Latin (Confidence: 1.0000)
# Language Classification: Schmidt, Carl, 1868-1938 -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Hauber, Karl Friedrich, 1775-1851. -> Latin (Confidence: 1.0000)
# Language Classification: Linné, Carl von, 1707-1778 -> Latin (Confidence: 1.0000)
# Language Classification: Bianchi, Simon Giovanni, 1693-1775. -> Latin (Confidence: 1.0000)
# Language Classification: Catherine, of Alexandria, Saint. -> Greek (Confidence: 0.9998)
# Language Classification: Dante Alighieri, 1265-1321 -> Latin (Confidence: 1.0000)
# Language Classification: Heine, Heinrich, 1797-1856 -> Latin (Confidence: 1.0000)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Macer, Floridus. -> Latin (Confidence: 1.0000)
# Language Classification: Zwingli, Ulrich 1484-1531. -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Anselm, Saint, Archbishop of Canterbury, 1033-1109 -> Latin (Confidence: 1.0000)
# Language Classification: Kazenberger, Kilian, -1750 -> Latin (Confidence: 1.0000)
# Language Classification: Elvenich, Peter Joseph, 1796-1886 -> Latin (Confidence: 1.0000)
# Language Classification: Index librorum prohibitorum. -> Greek (Confidence: 0.9994)
# Language Classification: Paulus, Julius. -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Augustine, Saint, Bishop of Hippo -> Latin (Confidence: 1.0000)
# Language Classification: Augustine, Saint, Bishop of Hippo -> Latin (Confidence: 1.0000)
# Language Classification: Augustine, Saint, Bishop of Hippo -> Latin (Confidence: 1.0000)
# Language Classification: Augustine, Saint, Bishop of Hippo -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Herodotus -> Greek (Confidence: 0.9999)
# Language Classification: Herodotus -> Greek (Confidence: 0.9999)
# Language Classification: Herodotus -> Greek (Confidence: 0.9999)
# Language Classification: Herodotus -> Greek (Confidence: 0.9999)
# Language Classification: Herodotus -> Greek (Confidence: 0.9999)
# Language Classification: Herodotus -> Greek (Confidence: 0.9999)
# Language Classification: Herodotus -> Greek (Confidence: 0.9999)
# Language Classification: Homer -> Greek (Confidence: 0.9999)
# Language Classification: Homer -> Greek (Confidence: 0.9999)
# Language Classification: Homer -> Greek (Confidence: 0.9999)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius. -> Latin (Confidence: 1.0000)
# Language Classification: Claudianus, Claudius -> Greek (Confidence: 0.9999)
# Language Classification: Claudianus, Claudius -> Greek (Confidence: 0.9999)
# Language Classification: Claudianus, Claudius -> Greek (Confidence: 0.9999)
# Language Classification: Claudianus, Claudius -> Greek (Confidence: 0.9999)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Gellius, Aulus -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Horace. -> Latin (Confidence: 1.0000)
# Language Classification: Horace -> Latin (Confidence: 1.0000)
# Language Classification: Horace. -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Mela, Pomponius -> Latin (Confidence: 1.0000)
# Language Classification: Martial -> Latin (Confidence: 1.0000)
# Language Classification: Martial -> Latin (Confidence: 1.0000)
# Language Classification: Lucretius Carus, Titus -> Latin (Confidence: 1.0000)
# Language Classification: Mela, Pomponius -> Latin (Confidence: 1.0000)
# Language Classification: Lucretius Carus, Titus -> Latin (Confidence: 1.0000)
# Language Classification: Ovid, 43 B.C.-17 A.D. or 18 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Ovid, 43 B.C.-17 A.D. or 18 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Seneca, Lucius Annaeus, approximately 4 B.C.-65 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Silius Italicus, Tiberius Catius -> Latin (Confidence: 1.0000)
# Language Classification: Silius Italicus, Tiberius Catius -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Prudentius, 348- -> Latin (Confidence: 1.0000)
# Language Classification: Propertius, Sextus -> Latin (Confidence: 1.0000)
# Language Classification: Quintilian. -> Latin (Confidence: 1.0000)
# Language Classification: Tibullus -> Latin (Confidence: 1.0000)
# Language Classification: Virgil. -> Latin (Confidence: 1.0000)
# Language Classification: Virgil -> Latin (Confidence: 1.0000)
# Language Classification: Virgil. -> Latin (Confidence: 1.0000)
# Language Classification: Virgil -> Latin (Confidence: 1.0000)
# Language Classification: Guarino, Veronese, 1374-1460 -> Latin (Confidence: 1.0000)
# Language Classification: Epiphanius, Saint, Bishop of Constantia in Cyprus, approximately 310-403. -> Greek (Confidence: 0.9999)
# Language Classification: Epiphanius, Saint, Bishop of Constantia in Cyprus, approximately 310-403. -> Greek (Confidence: 0.9999)
# Language Classification: Euripides -> Greek (Confidence: 0.9999)
# Language Classification: Apuleius. -> Latin (Confidence: 1.0000)
# Language Classification: Commodianus -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Philo, of Alexandria -> Greek (Confidence: 0.9999)
# Language Classification: Philo, of Alexandria -> Greek (Confidence: 0.9999)
# Language Classification: Pindar -> Greek (Confidence: 0.9999)
# Language Classification: Plato. -> Greek (Confidence: 0.9999)
# Language Classification: Plato. -> Greek (Confidence: 0.9999)
# Language Classification: Plato. -> Greek (Confidence: 0.9999)
# Language Classification: Plato. -> Greek (Confidence: 0.9999)
# Language Classification: Plato. -> Greek (Confidence: 0.9999)
# Language Classification: Plato -> Greek (Confidence: 0.9999)
# Language Classification: Plotinus -> Greek (Confidence: 0.9999)
# Language Classification: Plotinus -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Aristophanes. -> Greek (Confidence: 0.9999)
# Language Classification: Demosthenes -> Greek (Confidence: 0.9999)
# Language Classification: Demosthenes -> Greek (Confidence: 0.9999)
# Language Classification: Demosthenes -> Greek (Confidence: 0.9999)
# Language Classification: Demosthenes -> Greek (Confidence: 0.9999)
# Language Classification: Plutarch. -> Greek (Confidence: 0.9999)
# Language Classification: Plutarch. -> Greek (Confidence: 0.9999)
# Language Classification: Plutarch. -> Greek (Confidence: 0.9999)
# Language Classification: Plutarch. -> Greek (Confidence: 0.9999)
# Language Classification: Plutarch. -> Greek (Confidence: 0.9999)
# Language Classification: Plutarch. -> Greek (Confidence: 0.9999)
# Language Classification: Plutarch. -> Greek (Confidence: 0.9999)
# Language Classification: Homer -> Greek (Confidence: 0.9999)
# Language Classification: Homer -> Greek (Confidence: 0.9999)
# Language Classification: Homer. -> Greek (Confidence: 0.9999)
# Language Classification: Theophrastus. -> Greek (Confidence: 0.9997)
# Language Classification: Thucydides -> Greek (Confidence: 0.9999)
# Language Classification: Xenophon -> Greek (Confidence: 0.9999)
# Language Classification: Lucas, Christian Theodor Ludwig. -> Latin (Confidence: 1.0000)
# Language Classification: Herbert, of Bosham, fl. 1162-1186. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Somoogyi, Ambrosius, fl. 1604. -> Latin (Confidence: 1.0000)
# Language Classification: Somoogyi, Ambrosius, fl. 1604. -> Latin (Confidence: 1.0000)
# Language Classification: Benedict XIV, Pope, 1675-1758 -> Latin (Confidence: 1.0000)
# Language Classification: Benedict XIV, Pope, 1675-1758 -> Latin (Confidence: 1.0000)
# Language Classification: Benedict XIV, Pope, 1675-1758 -> Latin (Confidence: 1.0000)
# Language Classification: Benedict XIV, Pope, 1675-1758 -> Latin (Confidence: 1.0000)
# Language Classification: Benedict XIV, Pope, 1675-1758 -> Latin (Confidence: 1.0000)
# Language Classification: Benedict XIV, Pope, 1675-1758 -> Latin (Confidence: 1.0000)
# Language Classification: Benedict XIV, Pope, 1675-1758 -> Latin (Confidence: 1.0000)
# Language Classification: Benedict XIV, Pope, 1675-1758 -> Latin (Confidence: 1.0000)
# Language Classification: Benedict XIV, Pope, 1675-1758 -> Latin (Confidence: 1.0000)
# Language Classification: Benedict XIV, Pope, 1675-1758 -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Suarez, Francisco, 1548-1617. -> Latin (Confidence: 1.0000)
# Language Classification: Stosch, Ferdinand, 1717-1780. -> Latin (Confidence: 1.0000)
# Language Classification: Borový, Klement, 1838-1897 -> Latin (Confidence: 1.0000)
# Language Classification: Borový, Klement, 1838-1897 -> Latin (Confidence: 1.0000)
# Language Classification: Borový, Klement, 1838-1897 -> Latin (Confidence: 1.0000)
# Language Classification: Borový, Klement, 1838-1897 -> Latin (Confidence: 1.0000)
# Language Classification: Borový, Klement, 1838-1897 -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Epictetus -> Greek (Confidence: 0.9999)
# Language Classification: Epictetus -> Greek (Confidence: 0.9999)
# Language Classification: Epictetus -> Greek (Confidence: 0.9999)
# Language Classification: Epictetus -> Greek (Confidence: 0.9999)
# Language Classification: Duns Scotus, John, approximately 1266-1308 -> Latin (Confidence: 1.0000)
# Language Classification: Osorio, Jeronymo, Bishop of Silves, 1506-1580. -> Latin (Confidence: 1.0000)
# Language Classification: Osorio, Jeronymo, Bishop of Silves, 1506-1580. -> Latin (Confidence: 1.0000)
# Language Classification: Osorio, Jeronymo, Bishop of Silves, 1506-1580. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Origen -> Greek (Confidence: 0.9999)
# Language Classification: Długosz, Jan, 1415-1480 -> Latin (Confidence: 1.0000)
# Language Classification: Assemani, Giuseppe Luigi, 1710?-1782. -> Latin (Confidence: 1.0000)
# Language Classification: Forcellini, Egidio, 1688-1768 -> Latin (Confidence: 1.0000)
# Language Classification: Vigiliis von Creutzenfeld, Stephan Hieronymus de. -> Latin (Confidence: 1.0000)
# Language Classification: Vigiliis von Creutzenfeld, Stephan Hieronymus de. -> Latin (Confidence: 1.0000)
# Language Classification: Kühnöl, Christian Gottlieb, 1768-1841, -> Latin (Confidence: 1.0000)
# Language Classification: Cicero, Marcus Tullius -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Livy -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius -> Latin (Confidence: 1.0000)
# Language Classification: Albategnius., d. 920. -> Latin (Confidence: 1.0000)
# Language Classification: Origen -> Greek (Confidence: 0.9999)
# Language Classification: Ḥamzah al-Iṣfahānī, 893 or 894-970 or 971. -> Latin (Confidence: 1.0000)
# Language Classification: Plato -> Greek (Confidence: 0.9999)
# Language Classification: Celsus, Aulus Cornelius -> Greek (Confidence: 0.9999)
# ...
# Language Classification: Tacitus, Cornelius. -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius. -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius. -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius. -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius. -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius. -> Latin (Confidence: 1.0000)
# Language Classification: Campion, Thomas, 1567-1620. -> Latin (Confidence: 1.0000)
# Language Classification: Ambrose, Saint, Bishop of Milan, d. 397. -> Latin (Confidence: 1.0000)
# Language Classification: Moritz, C. -> Latin (Confidence: 1.0000)
# Language Classification: Palingenio Stellato, Marcello, ca. 1500-ca. 1543. -> Latin (Confidence: 1.0000)
# Language Classification: Lactantius, ca. 240-ca. 320. -> Latin (Confidence: 1.0000)
# Language Classification: Milchsack, Gustav, 1850-1919. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Luther, Martin, 1483-1546. -> Latin (Confidence: 1.0000)
# Language Classification: Juvenal. -> Greek (Confidence: 0.9999)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Horace. -> Latin (Confidence: 1.0000)
# Language Classification: Horace. -> Latin (Confidence: 1.0000)
# Language Classification: Horace. -> Latin (Confidence: 1.0000)
# Language Classification: Horace. -> Latin (Confidence: 1.0000)
# Language Classification: Horace. -> Latin (Confidence: 1.0000)
# Language Classification: Juvenal. -> Greek (Confidence: 0.9999)
# Language Classification: Lopes dos Santos Valente, António, 1839-1896. -> Latin (Confidence: 1.0000)
# Language Classification: Lucretius Carus, Titus. -> Latin (Confidence: 1.0000)
# Language Classification: Lucretius Carus, Titus. -> Latin (Confidence: 1.0000)
# Language Classification: Lucretius Carus, Titus. -> Latin (Confidence: 1.0000)
# Language Classification: Lucretius Carus, Titus. -> Latin (Confidence: 1.0000)
# Language Classification: Lucretius Carus, Titus. -> Latin (Confidence: 1.0000)
# Language Classification: Lucretius Carus, Titus. -> Latin (Confidence: 1.0000)
# Language Classification: Lucretius Carus, Titus. -> Latin (Confidence: 1.0000)
# Language Classification: Manilius, Marcus. -> Latin (Confidence: 1.0000)
# Language Classification: Rutilius Lupus, Publius. -> Greek (Confidence: 0.9998)
# Language Classification: Ovid, 43 B.C.-17 or 18 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Ovid, 43 B.C.-17 or 18 A.D. -> Latin (Confidence: 1.0000)
# Language Classification: Persius. -> Latin (Confidence: 1.0000)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Livy. -> Latin (Confidence: 1.0000)
# Language Classification: Lucan, 39-65. -> Latin (Confidence: 1.0000)
# Language Classification: Petermann, August, 1818- -> Latin (Confidence: 1.0000)
# Language Classification: Tacitus, Cornelius. -> Latin (Confidence: 1.0000)
# Language Classification: Sandras, Etienne Gustave -> Latin (Confidence: 1.0000)
# Language Classification: Portus, Aemilius, 1550-1614 or 15. -> Latin (Confidence: 1.0000)
# Language Classification: Linné, Carl von, 1707-1778 -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Athanasius, Saint, Patriarch of Alexandria, d. 373. -> Greek (Confidence: 0.9999)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Epiphanius, Saint, Bishop of Constantia in Cyprus, ca. 310-403. -> Greek (Confidence: 0.9999)
# Language Classification: Petau, Denis, 1583-1652. -> Latin (Confidence: 1.0000)
# Language Classification: Petau, Denis, 1583-1652. -> Latin (Confidence: 1.0000)
# Language Classification: Petau, Denis, 1583-1652. -> Latin (Confidence: 1.0000)
# Language Classification: Juvencus, Caius Vettius Aquilinus. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Petau, Denis, 1583-1652. -> Latin (Confidence: 1.0000)
# Language Classification: Petau, Denis, 1583-1652. -> Latin (Confidence: 1.0000)
# Language Classification: Petau, Denis, 1583-1652. -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Klostermann, Erich, 1870-1963. -> Latin (Confidence: 1.0000)
# Language Classification: Knabenbauer, Joseph, 1839-1911. -> Latin (Confidence: 1.0000)
# Language Classification: Knabenbauer, Joseph, 1839-1911. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, à Kempis, 1380-1471. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, à Kempis, 1380-1471. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Thomas, Aquinas, Saint, 1225?-1274. -> Latin (Confidence: 1.0000)
# Language Classification: Neumann, Karl Johannes, 1857- -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Language Classification: Persius. -> Latin (Confidence: 1.0000)
# Language Classification: Jaʻfarī, Ṣāliḥ ibn al-Ḥusayn, d. 1269 or 70., جعفري، صالح بن الحسين. -> Latin (Confidence: 1.0000)
# Language Classification: Unknown -> Greek (Confidence: 0.9993)
# Classified DataFrame:
#                             author deterministic_author  \
# 0  Du Creux, François, 1596?-1666.                  NaN
# 1    Meyer, Ernst H. F. 1791-1858.                  NaN
# 2     Laet, Joannes de, 1593-1649.                  NaN
# 3                   Caesar, Julius                  NaN
# 4                          Unknown                  NaN
#
#                                         fuzzy_author  fuzzy_author_score  \
# 0  {'authorized_name': 'mirk, john, active 1403?'...                85.5
# 1  {'authorized_name': 'vopiscus, flavius', 'auth...                85.5
# 2  {'authorized_name': 'herryson, joannes', 'auth...                85.5
# 3  {'authorized_name': 'caesar, julius', 'author_...                96.0
# 4                                                NaN                 0.0
#
#                                    distilbert_author  distilbert_author_score  \
# 0  {'authorized_name': 'cruz, luís da, 1543-1604...                 0.467436
# 1  {'authorized_name': 'meyer, wilhelm, 1845-1917...                 0.999939
# 2  {'authorized_name': 'larroumet, gustave', 'aut...                 0.494394
# 3  {'authorized_name': 'caesar, julius', 'author_...                 0.999999
# 4  {'authorized_name': 'stephanus abbas 4. or 6th...                 0.177454
#
#                                                title deterministic_title  \
# 0  Historiæ canadensis, seu Novæ-Franciæ libri de...                 NaN
# 1  Ernesti Meyer de plantis labradoricis libri tres.                 NaN
# 2  Novus orbis, seu Descriptionis Indiae Occident...                 NaN
# 3  C. Julii Cæsaris commentariorum De Bello Galli...                 NaN
# 4  Collectanea latina seu ecclesiasticæ antiquita...                 NaN
#
#                                          fuzzy_title  fuzzy_title_score  \
# 0  {'dll_id_work': 'W10626', 'dll_id_author': 'A5...              0.855
# 1  {'dll_id_work': 'W4469', 'dll_id_author': 'A49...              0.855
# 2  {'dll_id_work': 'W10655', 'dll_id_author': 'A3...              0.855
# 3  {'dll_id_work': 'W5389', 'dll_id_author': 'A33...              0.855
# 4  {'dll_id_work': 'W10631', 'dll_id_author': 'A3...              0.855
#
#   language  language_confidence
# 0    Latin             0.999986
# 1    Latin             0.999987
# 2    Latin             0.999987
# 3    Latin             0.999982
# 4    Greek             0.999343
#
# Greek Authors DataFrame:
#        author deterministic_author  \
# 0     Unknown                  NaN
# 1     Arrian.                  NaN
# 2     Euclid,                  NaN
# 3     Unknown                  NaN
# 4  Herodotus.                  NaN
#
#                                         fuzzy_author  fuzzy_author_score  \
# 0                                                NaN                 0.0
# 1  {'authorized_name': 'avianus', 'author_id': 'A...                90.0
# 2  {'authorized_name': 'gelasius i, pope', 'autho...                90.0
# 3                                                NaN                 0.0
# 4  {'authorized_name': 'serlo', 'author_id': 'A49...                90.0
#
#                                    distilbert_author  distilbert_author_score  \
# 0  {'authorized_name': 'stephanus abbas 4. or 6th...                 0.177454
# 1  {'authorized_name': 'avianus', 'author_id': 'A...                 0.932865
# 2  {'authorized_name': 'heraclides, ponticus', 'a...                 0.325279
# 3  {'authorized_name': 'stephanus abbas 4. or 6th...                 0.177454
# 4  {'authorized_name': 'pliny, the elder', 'autho...                 0.453805
#
#                                                title  \
# 0  Collectanea latina seu ecclesiasticæ antiquita...
# 1  Arriani Anabasis et Indica : ex optimo codice ...
# 2  Euclidis elementorum libri XV : accessit XVI d...
# 3  Liber precum : in quo variae et multae egregia...
# 4  Herodoti historiarum libri IX / recognovit et ...
#
#                                  deterministic_title  \
# 0                                                NaN
# 1  {'dll_id_work': 'W1777', 'dll_id_author': 'A35...
# 2                                                NaN
# 3                                                NaN
# 4  {'dll_id_work': 'W334', 'dll_id_author': 'A434...
#
#                                          fuzzy_title  fuzzy_title_score  \
# 0  {'dll_id_work': 'W10631', 'dll_id_author': 'A3...              0.855
# 1  {'dll_id_work': 'W10648', 'dll_id_author': 'A3...              0.855
# 2  {'dll_id_work': 'W10655', 'dll_id_author': 'A3...              0.855
# 3  {'dll_id_work': 'W10655', 'dll_id_author': 'A3...              0.855
# 4  {'dll_id_work': 'W10655', 'dll_id_author': 'A3...              0.855
#
#   language  language_confidence
# 0    Greek             0.999343
# 1    Greek             0.999509
# 2    Greek             0.999832
# 3    Greek             0.999343
# 4    Greek             0.999876
#
# Latin Authors DataFrame:
#                             author deterministic_author  \
# 0  Du Creux, François, 1596?-1666.                  NaN
# 1    Meyer, Ernst H. F. 1791-1858.                  NaN
# 2     Laet, Joannes de, 1593-1649.                  NaN
# 3                   Caesar, Julius                  NaN
# 4     Drexel, Jeremias, 1581-1638,                  NaN
#
#                                         fuzzy_author  fuzzy_author_score  \
# 0  {'authorized_name': 'mirk, john, active 1403?'...                85.5
# 1  {'authorized_name': 'vopiscus, flavius', 'auth...                85.5
# 2  {'authorized_name': 'herryson, joannes', 'auth...                85.5
# 3  {'authorized_name': 'caesar, julius', 'author_...                96.0
# 4                                                NaN                 0.0
#
#                                    distilbert_author  distilbert_author_score  \
# 0  {'authorized_name': 'cruz, luís da, 1543-1604...                 0.467436
# 1  {'authorized_name': 'meyer, wilhelm, 1845-1917...                 0.999939
# 2  {'authorized_name': 'larroumet, gustave', 'aut...                 0.494394
# 3  {'authorized_name': 'caesar, julius', 'author_...                 0.999999
# 4  {'authorized_name': 'drepanius florus 5th cent...                 0.969138
#
#                                                title  \
# 0  Historiæ canadensis, seu Novæ-Franciæ libri de...
# 1  Ernesti Meyer de plantis labradoricis libri tres.
# 2  Novus orbis, seu Descriptionis Indiae Occident...
# 3  C. Julii Cæsaris commentariorum De Bello Galli...
# 4  R.P. Hieremiae Drexelii e Societate Jesu Opera...
#
#                                  deterministic_title  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'dll_id_work': 'W365', 'dll_id_author': 'A482...
#
#                                          fuzzy_title  fuzzy_title_score  \
# 0  {'dll_id_work': 'W10626', 'dll_id_author': 'A5...              0.855
# 1  {'dll_id_work': 'W4469', 'dll_id_author': 'A49...              0.855
# 2  {'dll_id_work': 'W10655', 'dll_id_author': 'A3...              0.855
# 3  {'dll_id_work': 'W5389', 'dll_id_author': 'A33...              0.855
# 4  {'dll_id_work': 'W10629', 'dll_id_author': 'A3...              0.855
#
#   language  language_confidence
# 0    Latin             0.999986
# 1    Latin             0.999987
# 2    Latin             0.999987
# 3    Latin             0.999982
# 4    Latin             0.999987

# %% [markdown]
# It took 18m 37.0s to classify the authors as "Latin" or "Greek".
#
# Let's inspect the Greek and Latin sets.

# %%
print(f"Number of rows in the Greek dataframe: {len(greek_df)}")
print(f"Number of rows in the Latin dataframe: {len(latin_df)}")

print(f"The classification step removed {len(classified_df)-len(latin_df)} records")
# Out:
# Number of rows in the Greek dataframe: 4088
# Number of rows in the Latin dataframe: 20711
# The classification step removed 4088 records

# %% [markdown]
# Let's inspect the content of the Greek dataframe.

# %%
for author in greek_df['author'].unique():
    print(author)
# Out:
# Unknown
# Arrian.
# Euclid,
# Herodotus.
# Celsus, Aulus Cornelius.
# Nonius Marcellus, active 4th century.
# Juvenal.
# Claudianus, Claudius
# Anacreon
# John Chrysostom, Saint, -407
# Clement, of Alexandria, Saint, approximately 150-approximately 215
# Herodotus
# Nemesius, Bp. of Emesa
# Pindar
# Theocritus.
# Xenophon
# Monachus, Haymarus, Patriarch of Jerusalem, d. 1202.
# Catherine, of Alexandria, Saint.
# Aristophanes.
# Index librorum prohibitorum.
# Homer
# Epiphanius, Saint, Bishop of Constantia in Cyprus, approximately 310-403.
# Euripides
# Philo, of Alexandria
# Plato.
# Plato
# Plotinus
# Demosthenes
# Plutarch.
# Homer.
# Theophrastus.
# Thucydides
# Epictetus
# Origen
# Celsus, Aulus Cornelius
# Epiphanius, Saint, Bishop of Constantia in Cyprus, approximately 310-403
# Aristotle
# Archimedes.
# Dioscorides Pedanius, of Anazarbos
# Nicomachus, of Gerasa.
# Proclus, approximately 410-485
# Xenophon, of Ephesus
# Nonius Marcellus, active 4th century
# Gregory, of Nyssa, Saint, approximately 335-approximately 394.
# Theocritus
# Sextus, Empiricus
# Philostratus, the Athenian, active 2nd century-3rd century
# Longus
# Stobaeus
# Apollonius, of Athens.
# Arrian
# Philo, of Byzantium
# Justin, Martyr, Saint
# Hippocrates
# Īshō y̐abh III, Patriarch of the Nestorians, -657 or 658.
# Elias, of Nisibis, 975-1046
# Firmicus Maternus, Julius.
# Iamblichus, approximately 250-approximately 330.
# Anacreon.
# Varro, Marcus Terentius.
# Lucian, of Samosata
# Tacticus, Cornelius.
# Ramain, Georges.
# Isocrates.
# Proclus, approximately 410-485.
# Eusebius, of Caesarea, Bishop of Caesarea, approximately 260-approximately 340.
# Cleomedes.
# Orpheus.
# Pindar.
# Euclid.
# Aristotle.
# Agathias, d. 582.
# Marcus Aurelius, Emperor of Rome, 121-180.
# Apollodorus.
# Ptolemy, active 2nd century.
# Artephius,
# Josephus, Flavius.
# Autolycus.
# Gregory, of Nazianzus, Saint
# Nemesius, Bp. of Emesa.
# Macarius, the Egyptian, Saint, active 4th century
# Hero, of Alexandria.
# Misset, E.,
# Galen
# Cassius Felix, active 447
# Isaac, of Antioch.
# Heriodianus, active 3 century.
# Priscian, active approximately 500-530.
# Aelian, active 3rd century.
# Josephus, Flavius
# Cyril, Saint, Bishop of Jerusalem, approximately 315-386
# Rutilius Lupus, Publius.
# Lydus, Ioannes Laurentius, 490-
# Diogenes Laertius
# Ephraem, Syrus, Saint, 303-373
# Juvenal
# Hesiod
# Dictys, Cretensis.
# Agathias, -582
# Theophilus, Presbyter, active 12th century.
# Harpocration, Valerius
# Gregorius, Abp. of Corinth, fl. ca. 1200.
# Bacchylides
# Aristides Quintilianus
# Pseudo-Dionysius, the Areopagite.
# Eusebius, of Caesarea, Bishop of Caesarea, approximately 260-approximately 340
# Theophrastus
# Diophantus, of Alexandria
# Athanasius, Saint, Patriarch of Alexandria, -373
# Hippolytus, Antipope, approximately 170-235 or 236
# Irenaeus, Saint, Bishop of Lyon.
# Macé, Alcide.
# Xenophon.
# Alciphron.
# Bion, of Phlossa near Smyrna
# Colluthus, of Lycopolis
# Diodorus, Siculus.
# Dionysius, of Halicarnassus
# Dositheus, Magister
# Harpocration, Valerius.
# Herodian.
# Döhner, Theodor.
# Polyaenus.
# Strabo.
# Tryphiodorus
# Ǩimmich, Joseph.
# Klodiě, Antonius.
# Varro, Marcus Terentius
# Frémy, A.
# Bibliotheca Palatina (Biblioteca apostolica vaticana)
# Basil, Saint, Bishop of Caesarea, approximately 329-379
# Philo, of Alexandria.
# Nicander, of Colophon.
# Aelian, active 3rd century
# Apollonius, Rhodius
# Aeschylus
# Aesop
# Ausonius, Decimus Magnus
# Theophilus Antiochenus.
# Musaeus, Grammaticus.
# Nilles, Nicolaus, 1828-1907.
# Thoemes, Nicolaus.
# Theodosius, active 1st century B.C.
# Archimedes
# Thucydides.
# Oppian, active 2nd century.
# Æschines.
# Dionysius, of Halicarnassus.
# Apollonius, Dyscolus, active 2nd century
# Nonnus, of Panopolis.
# Moschion, the physician.
# Pythagoras.
# Aretaeus, of Cappadocia.
# Cassius Dio Cocceianus
# Hesiod.
# Aristophanes
# Aeschines.
# Achilles Tatius
# Athenaeus, of Naucratis.
# Titus, of Bostra, Bishop of Bostra, active approximately 362-378.
# John Chrysostom, Saint, -407.
# Hippocrates.
# Claudianus, Claudius.
# Stovaios, Iōannēs.
# Joannes, Monachus, active 10th century?
# Celsus, Aurelius Cornelius, 25 B.C.-A.D. 50.
# Moschion (Physician)
# Clement, of Alexandria, Saint, approximately 150-approximately 215.
# Hesychius, of Miletus.
# Cassius Dio Cocceianus.
# Galen.
# Stobaeus.
# Ausonius, Decimus Magnus.
# Psellus, Michael.
# Demetrius Pepagomenus, active 1260.
# Nonnos, Theophanēs, active 10th century.
# Martianus Capella.
# Apollonius, Dyscolus, 2nd cent
# Plotinus.
# Dioscorides Pedanius, of Anazarbos.
# Justin, Martyr, Saint.
# Lucian, of Samosata.
# Häussner, J. b. 1850.
# Diogenes Laertius.
# Eustathius, Macrembolites, 12th cent.
# Basil, Saint, Bishop of Caesarea, ca. 329-379.
# Bryennius, Nicephorus, Caesar, c.1137.
# Demosthenes.
# Demetrius, Phalereus.
# Justinianus, Flavius Anicius I, the great, emperor of Rome.
# Sappho.
# Procopius.
# Athanasius, Saint, Patriarch of Alexandria, d. 373.
# Heraclitus, of Ephesus
# Achilles Tatius.
# Priscian, active approximately 500-530
# Origen.
# Vettius Valens.
# Dionysius, of Tel-Maḥrē, Patriarch of Antioch, -845.
# Diodorus, Siculus
# Varro, Marcus Terentius,
# Lydus, Johannes Laurentius, 490-approximately 565.
# Methodius, of Olympus, Saint, -311.
# Philostratus, the Athenian, active 2nd century-3rd century.
# Charisius, Flavius Sosipater.
# Quintus, Smyrnaeus, active 4th century.
# Quintus, Smyrnaeus, 4th cent.
# Philodemus, approximately 110 B.C.-approximately 40 B.C.
# Nicephorus, Blemmydes, 1197-1272.
# Tryphiodorus.
# Nemesius, Bishop of Emesa
# Bacchylides.
# Dictys, Cretensis
# Philes, Manuel, ca. 1275-1340.
# Kālidāsa.
# Irenaeus, Saint, Bishop of Lyon
# Herodianus, Aelius, active 2nd century.
# Biblioteca medicea laurenziana.
# Gregorius, abp. of Corinth, fl ca 1200.
# Moses, of Khoren, active 5th century.
# Corpus iuris civilis. Institutiones.
# Heliodorus, of Emesa
# Athenaeus, of Naucratis
# Eustathius, Macrembolites, active 12th century.
# Menelaus, of Alexandria
# Theon, of Smyrna
# Musaeus, Grammaticus
# Artemidorus, Daldianus
# Juvenalis, D.J.
# Biblioteca apostolica vaticana.
# Apollonius, of Perga
# Secchi, Ancleto.
# Sextus, Empiricus.
# Libanius.
# Simocatta, Theophylactus.
# Philoponus, John, active 6th century.
# Ptolemy, 2nd cent.
# Polybius.
# Galemis, Clauduis.
# Lysias.
# Aurelianus, Caelius.
# Theophilus, Saint, active 2nd century.
# Schütz, G. H.
# Misset, E.
# Hul̈sen, F.
# Krüger, M. J.
# Kimmich, Josephus, 1862-
# Clement I, Pope
# Nicander, of Colophon
# Wölffel, H.
# Constantine VII Porphyrogenitus, Emperor of the East, 905-959.
# Byzantine Empire.
# Apollonius, Paradoxographus.
# Procopius, of Gaza, approximately 475-approximately 528.
# Strabo,
# Sophocles.
# Pappus, of Alexandria
# Pachymeres, George, 1242-approximately 1310.
# Longus.
# Fronto, Marcus Cornelius.
# Aretaeus, of Cappadocia
# Agathias, -582.
# Königsdorfer, Isidor.
# Pausanias, active approximately 150-175.
# Göring, A.
# Maximus, Confessor, Saint, approximately 580-662.
# Hermogenes, active 2nd century.
# Manasseh ben Israel, 1604-1657.
# John Chrysostom, Saint, d. 407.
# Lutheran Church.
# Pelliccia, Alessio Aurelio.
# Philoponus, John, 6th cent.
# Eusebius, of Caesarea, Bishop of Caesarea, ca. 260-ca. 340.
# Evagrius, Scholasticus, b. 536?
# Aelian, 3rd cent.
# Apollonius, paradoxographus.
# Polster, A.
# Sion College. Library.
# Ephraem, Syrus, Saint, 303-373.
# Justinian I, Emperor of the East, 483?-565.
# Proclus, ca. 410-485.
# Universitätsbibliothek München.
# Apollonius, of Perga.
# Apollonius, Rhodius.
# Phocylides, fl. 544-541 B.C.
# Semonides, of Amorgos.
# Īshō-Yahbh, of Kuphlānā, 7th cent.
# Draco, of Stratonica.
# Demetrius, of Phaleron, b. ca. 350 B.C.
# Lydus, Johannes Laurentius, 490-approximately 565
# Theodores, Bishop of Cyrrhus.
# Basil, Saint, Bishop of Caesarea, approximately 329-379.
# Aesop.
# Elias, of Nisibis, 975-
# Themistius.
# Berosus, the Chaldean.
# Epiphanius, Saint, Bishop of Constantia in Cyprus, ca. 310-403
# Lenfant, David.
# Philo, of Byblos.
# Östling, Nicolaus.
# Gregory, of Nyssa, Saint, ca. 335-ca. 394.
# Kynaston, Herbert, 1835-1910.
# Hierocles, of Alexandria, active 430.
# Mesuë, 924 or 5-1015.
# Alexander, of Aphrodisias.
# Marcus Aurelius, Emperor of Rome, 121-180
# Hermogenes, 2nd cent
# Hierocles, of Alexandria, fl. 430
# Alexander, of Aphrodisias
# Themistius
# Michael, of Ephesus
# Sophonias
# Simplicius, of Cilicia.
# Pseudo-Dionysius, the Areopagite
# Philoponus, John, 6th cent
# Priscian, fl. ca. 500-530
# Aurelianus, Caelius
# Apollonio à Iesu
# Comnena, Anna, 1083-
# Orpheus (Greek mythological character)
# Prodromus, Theodore.
# Aristides Quintilianus.
# Philodemus, ca. 110-ca. 40 B.C.
# Terentianus Maurus.
# Iamblichus, ca. 250-ca. 330.
# Anastasius, the Librarian, approximately 810-approximately 878.
# Panyasis, fl. 500-450 B.C.
# Hipócrates.
# Rhasis, Mohammed.
# Galeno.
# Celso, Aulo Cornelio.
# Paracelso.
# Diogenes Laercio.
# Hipócrates
# Lyège, Jean, n.1520?
# Paracelso
# Polibio
# Yuhanna Ibn Serapion, s. 9
# Josefo, Flavio, ca. 37-ca. 100.
# Apolonio de Pérgamo.
# Pseudo Dionisio Areopagita.
# Euclides.
# Artephius.
# Opiano de Apamea.
# Aristóteles, 384-322 a.C.
# Teofrasto.
# Plukenet, Leonard
# Dionysius Cartusianus
# Devoti, Joannis.
# Apollonius, Levinus.
# Arato de Soles.
# Galeno
# Ptolomeo, Claudio.
# Ptolomeo, Claudio
# Estrabón
# Clemente de Alejandría.
# Aecio de Amida.
# Orígenes.
# Isidoro de Pelusio, Santo.
# Filóstrato, Flavio, ca. 170-ca. 249
# Nicephorus Callistus, ca. 1256-1335.
# Paulus Aegineta
# Paulus Aegineta.
# Gregorio de Nisa, Santo, ca. 335-ca. 394.
# Filopón, Juan.
# Eusebio de Cesarea, Obispo de Cesarea, ca. 265-ca. 340
# Ireneo, Santo, Obispo de Lyon
# Plotino.
# Epifanio, Santo, Obispo de Constancia, ca. 315-403.
# Cirilo, Santo, Patriarca de Alejandría, 376?-444.
# Marciano Capella.
# Juan Damasceno, Santo, 676-ca. 750.
# Teodosio de Tripoli.
# Juan Crisóstomo, Santo, ca. 344-407
# Dionysius Cartusianus.
# Justino, Santo, 100?-165?
# Abdias, Obispo de Babilonia.
# Atanasio, Santo, ca. 297-373.
# Georgius Trapezuntius
# Dionysius Cisterciensis.
# Dioscórides.
# Berosio.
# Opiano.
# Basilio, Santo, Obispo de Cesarea, 329?-379.
# Juliano, Emperador de Roma, 331-363.
# Georgius Trapezuntius.
# Iglesia Católica
# Aponius.
# Filón de Alejandria, ca. 25 a.C.-ca. 50
# Diodoro Sículo.
# Platón, ca. 427-348 a.C.
# Solís, Feliciano de.
# Herodoto, 484-425 a. C.
# Constantino, VII, Porfirogéneta, Emperador de Bizancio.
# Juan Crisóstomo, Santo, ca. 344-407.
# Estrabón.
# Artis, Jean d'
# Magalhaes, Cosmé.
# Filón de Alejandria, ca. 25 a.C.-ca. 50.
# Johannes Philoponus.
# Lupus, Chretien
# Flórez Díez de Mena, Blas.
# Monachus, Antonius.
# Sosa, Mateo de.
# Gregorio Nacianceno, Santo, 330-390.
# Coninck, Aegidio de (S.I.)
# Gregorio Taumaturgo, Santo, ca. 213-270.
# Ireneo, Santo, Obispo de Lyon.
# Machicado y Rosillo, Manuel.
# Arquímedes, (287-212 a.C.)
# Procopio de Gaza, ca. 465-ca. 528
# Eusebio de Cesarea, Obispo de Cesarea, ca. 265-ca. 340.
# Hipocrates.
# Tucídides, ca. 460-ca. 400 a. C.
# Diogenes Laercio
# Casiodoro, Magno Aurelio.
# Arriano, Flavio
# Constantino Africano.
# Aecio de Amida
# Theodoretus, Obispo de Cyrrhus,  393-460.
# Proclo, 412-485
# Euclides
# Cirilo, Santo, Patriarca de Alejandría, 376?-444
# Alejandro de Afrodisia
# Herón, de Alejandría
# Arquímedes, 287-212 a.C.
# Jesuitas.
# Artemidoro.
# Herón, de Alejandría.
# Albumasar.
# Efren de Nisibis, Santo, 303-373.
# Eliano, Claudio.
# Pseudo Dionisio Areopagita
# Apolodoro de Atenas.
# Iavelli, Crisóstomo (O.P.)
# Sicilia (Reino)
# Basilio I, Emperador de Bizancio, ca. 867-886.
# Comnena, Anna.
# Apolonio de Rodas.
# Quinto de Esmirna.
# Basilius, Valentinus.
# Hierocles Platónico, s.5 d.C.
# Proclo, 412-485.
# Magnen, Jean Chrysostome.
# Temistio.
# Casiodoro, Magno Aurelio
# Homero.
# Luciano de Samosata.
# Dion Casio
# Yamblico.
# Tucídides ca. 460-ca. 400 a. C.
# Epo, Boetius.
# Máximo, el Confesor, Santo, 580-662
# Jesuitas
# Hostus, Mathaeus.
# Heródoto, 484-425 a. C.
# Esopo, 620?-560? a.C.
# Polibio.
# Diógenes Laercio.
# Hémeré, Claude.
# Ferdinandi, Epifanio.
# Hesiodo.
# Diomedes.
# Ateneo de Náucratis
# Contador de Argote, Jeronimo.
# Ausonio, Decio Magno.
# Pontio Legionensi, Basilio.
# Jenofonte, ca. 430 a.C-ca. 354 a.C
# Juan Casiano, Santo, ca. 360-ca. 432.
# Sereno Samonico, Quinto.
# Alexander Trallianus.
# Aureliano, Celio.
# Oribasio.
# Teodoreto, Obispo de Ciro.
# Nicetas Acominatus Choniates.
# Herodiano, 170-240.
# Clemente I, Papa.
# Doc, Jean, Obispo de Laon.
# Aristoteles, 384-322 a.C.
# Mishna.
# Epicteto.
# Juvenal, Decio Junio.
# Areteo de Capadocia.
# Celso, Aulo Cornelio
# Apiano.
# Píndaro, ca. 518-ca. 438 a. C.
# Sicco, Anacleto (CC.RR.MM.)
# Origenes.
# Zacarias, Obispo de Crisópolis.
# Pamphylus, Jacobus
# Claudianus, Claudio.
# Philostorgius.
# Claudiano, Claudio.
# Plutarco, ca. 46-ca. 119.
# Simplicio.
# Procopio de Cesárea.
# Anacreonte.
# Epo, Boetius
# Procopio de Cesarea.
# Agathias Scholasticus, 536-582.
# Comnena, Anna, 1083-1148.
# Pachymeres, George, 1242-ca. 1310.
# Genesios, Ioseph, fl. 912-959.
# Nicolas de Damasco.
# HIPOCRATES.
# Dión Casio.
# Apiano
# Deodato, Claudio.
# Aristófanes.
# Dionisio de Halicarnaso, ca. 60-5 a.C.
# Musaeus, S. V d. de J. C.
# Polieno.
# Heliodoro.
# Heliodoro
# Asclepiadeus, Androphilus.
# Marco Aurelio, Emperador de Roma, 121-180
# Arethas, Arzobispo de Cesarea.
# Demetrius Pepagomenus, s.13.
# Ateneo de Naúcratis.
# Pausanias.
# Theophilus, G.
# Aelianus, Tacticus, 2nd cent.
# Atilius Fortunatianus, 4th cent.
# Joannes Kyriotes, called Geometres, 10th cent.
# Horapollo.
# Lydus, Johannes.
# Pindarus.
# Dio Chrysostomus.
# Arrianus, Flavius.
# Paulus, Aegineta.
# Homerus.
# Īshō y̐abh III, Patriarch of the Nestorians, d. 657 or 8.
# Theodorus, Flavius Mallius, ca. 350-410.
# Comnena, Anna, b. 1083.
# Panyassis Halicarnassensis.
# Callimachus.
# Epiphanius, Saint, Bishop of Constantia in Cyprus, ca. 310-403.

# %% [markdown]
# Weird. Juvenal was classified as a Greek author! I should move him back to the Latin author dataframe.

# %%
juvenal_list = ['Juvenal.','Juvenal','Juvenalis, D.J.']
juvenal = greek_df[greek_df['author'].astype('str').isin(juvenal_list)]
juvenal
# Out:
#         author                               deterministic_author  \
# 8     Juvenal.  {'authorized_name': 'juvenal', 'author_id': 'A...
# 108   Juvenal.  {'authorized_name': 'juvenal', 'author_id': 'A...
# 233   Juvenal.  {'authorized_name': 'juvenal', 'author_id': 'A...
# 239   Juvenal.  {'authorized_name': 'juvenal', 'author_id': 'A...
# 312   Juvenal.  {'authorized_name': 'juvenal', 'author_id': 'A...
# ...        ...                                                ...
# 3966  Juvenal.  {'authorized_name': 'juvenal', 'author_id': 'A...
# 4022  Juvenal.  {'authorized_name': 'juvenal', 'author_id': 'A...
# 4036  Juvenal.  {'authorized_name': 'juvenal', 'author_id': 'A...
# 4080  Juvenal.  {'authorized_name': 'juvenal', 'author_id': 'A...
# 4081  Juvenal.  {'authorized_name': 'juvenal', 'author_id': 'A...
#
#                                            fuzzy_author  fuzzy_author_score  \
# 8     {'authorized_name': 'juvenal', 'author_id': 'A...               100.0
# 108   {'authorized_name': 'juvenal', 'author_id': 'A...               100.0
# 233   {'authorized_name': 'juvenal', 'author_id': 'A...               100.0
# 239   {'authorized_name': 'juvenal', 'author_id': 'A...               100.0
# 312   {'authorized_name': 'juvenal', 'author_id': 'A...               100.0
# ...                                                 ...                 ...
# 3966  {'authorized_name': 'juvenal', 'author_id': 'A...               100.0
# 4022  {'authorized_name': 'juvenal', 'author_id': 'A...               100.0
# 4036  {'authorized_name': 'juvenal', 'author_id': 'A...               100.0
# 4080  {'authorized_name': 'juvenal', 'author_id': 'A...               100.0
# 4081  {'authorized_name': 'juvenal', 'author_id': 'A...               100.0
#
#                                       distilbert_author  \
# 8     {'authorized_name': 'juvenal', 'author_id': 'A...
# 108   {'authorized_name': 'juvenal', 'author_id': 'A...
# 233   {'authorized_name': 'juvenal', 'author_id': 'A...
# 239   {'authorized_name': 'juvenal', 'author_id': 'A...
# 312   {'authorized_name': 'juvenal', 'author_id': 'A...
# ...                                                 ...
# 3966  {'authorized_name': 'juvenal', 'author_id': 'A...
# 4022  {'authorized_name': 'juvenal', 'author_id': 'A...
# 4036  {'authorized_name': 'juvenal', 'author_id': 'A...
# 4080  {'authorized_name': 'juvenal', 'author_id': 'A...
# 4081  {'authorized_name': 'juvenal', 'author_id': 'A...
#
#       distilbert_author_score  \
# 8                    0.999999
# 108                  0.999999
# 233                  0.999999
# 239                  0.999999
# 312                  0.999999
# ...                       ...
# 3966                 0.999999
# 4022                 0.999999
# 4036                 0.999999
# 4080                 0.999999
# 4081                 0.999999
#
#                                                   title  \
# 8     D. Ivni Ivvenalis Satvrarvm libri V; edited wi...
# 108   D. Junii Juvenalis Saturarum libri v. mit erkl...
# 233   D. Iunii Iuvenalis Satirarum libri quinque. Ac...
# 239   D. Iuni Iuvenalis Saturarum libri V / edited w...
# 312   Ivnii Ivvenalis Aqvinatis Satyrographi opvs : ...
# ...                                                 ...
# 3966  D. Iunii Iuvenalis Satirarum libri quinque : a...
# 4022  Saturarum libri V cum scholiis veteribus / rec...
# 4036  D. Iunii Iuvenalis Satirarum libri quinque. Ac...
# 4080  La Satira prima di D. Giunio Giovenale / comme...
# 4081  D. Iunii Iuvenalis Satirarum libri quinque : a...
#
#                                     deterministic_title  \
# 8                                                   NaN
# 108   {'dll_id_work': 'W5075', 'dll_id_author': 'A36...
# 233                                                 NaN
# 239   {'dll_id_work': 'W5075', 'dll_id_author': 'A36...
# 312                                                 NaN
# ...                                                 ...
# 3966                                                NaN
# 4022  {'dll_id_work': 'W5075', 'dll_id_author': 'A36...
# 4036                                                NaN
# 4080                                                NaN
# 4081                                                NaN
#
#                                             fuzzy_title  fuzzy_title_score  \
# 8     {'dll_id_work': 'W5389', 'dll_id_author': 'A33...              0.855
# 108   {'dll_id_work': 'W5389', 'dll_id_author': 'A33...              0.855
# 233   {'dll_id_work': 'W5389', 'dll_id_author': 'A33...              0.855
# 239   {'dll_id_work': 'W5389', 'dll_id_author': 'A33...              0.855
# 312   {'dll_id_work': 'W10631', 'dll_id_author': 'A3...              0.855
# ...                                                 ...                ...
# 3966  {'dll_id_work': 'W10631', 'dll_id_author': 'A3...              0.855
# 4022  {'dll_id_work': 'W10655', 'dll_id_author': 'A3...              0.855
# 4036  {'dll_id_work': 'W5389', 'dll_id_author': 'A33...              0.855
# 4080  {'dll_id_work': 'W1590', 'dll_id_author': 'A30...              0.855
# 4081  {'dll_id_work': 'W10631', 'dll_id_author': 'A3...              0.855
#
#      language  language_confidence
# 8       Greek             0.999857
# 108     Greek             0.999857
# 233     Greek             0.999857
# 239     Greek             0.999857
# 312     Greek             0.999857
# ...       ...                  ...
# 3966    Greek             0.999857
# 4022    Greek             0.999857
# 4036    Greek             0.999857
# 4080    Greek             0.999857
# 4081    Greek             0.999857
#
# [68 rows x 12 columns]

# %% [markdown]
# ## Deterministic Author Matching
#
# I want to see where this method reported a match.

# %%
# Make a dataframe of just the author and deterministic author columns
deterministic = df[['author','deterministic_author']]
# Filter out the NA values
deterministic = deterministic[deterministic['deterministic_author'].notna()]
deterministic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9303 entries, 6 to 24796
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                9303 non-null   object
#  1   deterministic_author  9303 non-null   object
# dtypes: object(2)
# memory usage: 218.0+ KB

# %%
# Count the number of unique values in the deterministic_author column
deterministic['deterministic_author'].nunique()
# Out:
# 461

# %% [markdown]
# There are 461 unique values in the `deterministic_author` column.
#
# I'm going to make a CSV file so that I can investigate the matches more easily. I'll sort the `deterministic` dataframe by the `author` column first, then save the sorted dataframe as a CSV file.

# %%
sorted_deterministic = deterministic.sort_values(axis='index',by='author')

# %%
import csv
sorted_deterministic.to_csv('../data/deterministic_author.csv',index=False,quoting=csv.QUOTE_ALL)

# %% [markdown]
# As expected, every match achieved by the deterministic method was 100% accurate. On the other hand, it matched only 491 of the 6,018 unique values in the `author` column.

# %% [markdown]
# ## Fuzzy Author Matching

# %%
# Make a dataframe of the fuzzy matching columns and the author column
fuzzy = df[['author','fuzzy_author','fuzzy_author_score']]
# Eliminate any NaN cells
fuzzy = fuzzy[fuzzy['fuzzy_author'].notna()]

fuzzy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22465 entries, 0 to 24797
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   author              22465 non-null  object
#  1   fuzzy_author        22465 non-null  object
#  2   fuzzy_author_score  22465 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 702.0+ KB

# %%
# Count the number of unique values in the fuzzy_author column
fuzzy['fuzzy_author'].nunique()
# Out:
# 1140

# %% [markdown]
# The fuzzy matching method returned 1,140 unique values compared to the 6,018 unique values in the `author` column.
#
# Let's see the rows where there isn't a match.

# %%
unmatched_fuzzy = df[df['fuzzy_author'].isna()]
# Show the number of unique author values in the unmatched_fuzzy dataframe
display(unmatched_fuzzy['author'].nunique())
# Display the list of unmatched author names
authors_list = unmatched_fuzzy['author'].to_list()
set(authors_list)
# Out:
# 467
# {'Academia Molshemensis (Francia)',
#  'Achilles Tatius',
#  'Achilles Tatius.',
#  'Acidalius, Valens, 1567-1595',
#  'Aeschines.',
#  'Aeschylus',
#  'Aesop',
#  'Aesop.',
#  'Agathias, -582',
#  'Agathias, -582.',
#  'Albertini, Hannibal.',
#  'Albumasar.',
#  'Alciphron.',
#  'Alegambe, Philippo, 1592-1652',
#  'Alvisi, Edoardo, 1850-1915.',
#  'Amama, Sixtinus, 1593-1629.',
#  'Amati, Pasquale,',
#  'Anacreon',
#  'Anacreon.',
#  'Anacreonte.',
#  'Andreantonelli, Sebastiano.',
#  'Anhalt, Ottocar.',
#  'Apollodorus.',
#  'Apollonius, Paradoxographus.',
#  'Apollonius, Rhodius',
#  'Apollonius, Rhodius.',
#  'Apollonius, paradoxographus.',
#  'Appendix Vergiliana.',
#  'Archimedes',
#  'Archimedes.',
#  'Aristophanes',
#  'Aristophanes.',
#  'Aristófanes.',
#  'Arngrímur Jónsson, 1568-1648.',
#  'Artemidoro.',
#  'Artephius,',
#  'Artephius.',
#  'Asclepiadeus, Androphilus.',
#  'Auerbach, Bertrand, 1856-1942',
#  'Augenio, Orazio',
#  'Augenio, Orazio.',
#  'Autolycus.',
#  'Bacchylides',
#  'Bacchylides.',
#  'Bar Hebraeus, 1226-1286.',
#  'Barbato, Orazio.',
#  'Barbosa, Agostinho, 1590-1649.',
#  'Barbosa, Enmanuele.',
#  'Barrientos, Bartolomé.',
#  'Bartelon, Pantaléon',
#  'Bartoletti, Fabrizio, 1576-1630.',
#  'Bartoletti, Fabrizio.',
#  'Bayerische Staatsbibliothek.',
#  'Bellegni, Caroli.',
#  'Bellone, Niccolò.',
#  'Belsheim, Johannus Engebretsen, 1829-1909.',
#  'Bhartr̥hari.',
#  'Biblioteca apostolica vaticana.',
#  'Biblioteca medicea laurenziana.',
#  'Biblioteca nazionale marciana.',
#  'Bibliotheca Palatina (Biblioteca apostolica vaticana)',
#  'Bidloo, Govard, 1649-1713.',
#  'Biragus, Aloysius.',
#  'Biuso, Carmelo.',
#  'Bocchi, Achille, 1488-1562',
#  'Bocchi, Achille, 1488-1562.',
#  'Bodleian Library.',
#  'Bonet-Maury, Gaston, 1842-1919.',
#  'Borový, Klement, 1838-1897',
#  'Boussuet, François.',
#  'Brandl, Vincenc, 1834-1901.',
#  'Brink, Barend ten, 1803-1875.',
#  'Brisson, Barnabe',
#  'Brisson, Barnabe.',
#  'Brisson, Barnabé, 1531-1591.',
#  'Buonamici, Castruccio, 1710-1761.',
#  'Burdegati, Sante.',
#  'Burgerbibliothek Bern.',
#  'Bérnard, Léon, 1847-',
#  'CCPB000038379-1',
#  'Caimo, Pompeo.',
#  'Caldeira, Duarte.',
#  'Capecelatro, Ettore.',
#  'Carmeni, Daniele.',
#  'Carmina burana.',
#  'Castellion, Sébastien, 1515-1563.',
#  'Catalani, Giusseppe.',
#  'Cellarius, Balthasar',
#  'Cesarini, Virginio, 1595-1624',
#  'Cesarini, Virginio, 1595-1624.',
#  "Chetham's Library.",
#  'Choppin, René, 1537-1606.',
#  'Cigala, Honufrio',
#  'Ciofani, Ercole',
#  'Cippico, Coriolano, 1425?-1493?',
#  'Clicthove, Josse',
#  'Clicthove, Jossé',
#  'Clicthove, Jossé.',
#  'Cloyne. Diocese.',
#  'Clément, Félix, 1822-1885',
#  'Coelho, Jorge',
#  'Comnena, Anna, 1083-1148.',
#  'Connan, François.',
#  'Contarini, Gasparo',
#  'Contarini, Gasparo.',
#  'Cordier, Mathurin, 1479-1564',
#  'Cordier, Mathurin, 1479-1564.',
#  'Corpus iuris civilis. Institutiones.',
#  'Corradi, Sebastiano, -1556.',
#  'Corradi, Sebastiano, 1510-1556',
#  'Corradi, Sebastiano, 1510-1556.',
#  'Corrado, Pirro',
#  'Cragius, Niels, 1549-1602.',
#  'Cremani, Aloisii.',
#  'Croiset, Maurice, 1846-1935.',
#  'Cuperus, Gisbertus.',
#  'Cutelli, Mario, 1584-1654.',
#  'Darmesteter, Arsène, 1846-1888.',
#  'Decsi, János, -1601.',
#  'Delfio, Porto Euterio.',
#  'Demosthenes',
#  'Demosthenes.',
#  'Denari, Odofredo, -1265',
#  'Deneke, Ewald, 1893-',
#  'Desbillons, François-Joseph Terrasse, 1711-1789,',
#  'Desericzky, József Ince, 1702-1763.',
#  'Deseriz, Jósef Ince.',
#  'Diemerbroeck, Isbrand',
#  'Diodoro Sículo.',
#  'Diogenes Laercio',
#  'Diogenes Laercio.',
#  'Diogenes Laertius',
#  'Diogenes Laertius.',
#  'Dion Casio',
#  'Diógenes Laercio.',
#  'Dión Casio.',
#  'Dodoens, Rembert',
#  'Dodoens, Rembert, 1517-1585.',
#  'Drexel, Jeremias, 1581-1638,',
#  'Drexel, Jeremias, 1581-1638.',
#  'Dubrovnik (Republic)',
#  'Dulaurens, François.',
#  'Dulaurens,François.',
#  'Dyckhoff, Sigimund.',
#  'Eckolt, Amadeus, 1623-1668.',
#  'Emlein, Friedericus, 1876-',
#  'Emmius, Ubbo, 1547-1625',
#  'Endlicher, István László, 1804-1849.',
#  'Engström, Einar, 1899-1973.',
#  'Enrique Susón, Beato, 1295-1366.',
#  'Epicteto.',
#  'Epictetus',
#  'Epo, Boetius',
#  'Epo, Boetius.',
#  'Esteve, José, 1550-1603',
#  'Estrabón',
#  'Estrabón.',
#  'Euclides',
#  'Euclides.',
#  'Euripides',
#  'Fagundes, Estevao, 1577-1645.',
#  'Falcucci, Nicolò',
#  'Farinacci, Prospero, 1554-1618.',
#  'Favazza, Salvator.',
#  'Fedro.',
#  'Feith, Everard.',
#  'Ferry, C[amille]',
#  'Filalteo, Lucillo.',
#  'Fine, Oronce, 1494-1555.',
#  'Fine, Oronce.',
#  'Firdawsī',
#  'Flemyng, Malcolm.',
#  'Fomann, Ortolphus, 1560-1634.',
#  'Fontanini, Giusto, 1666-1736.',
#  'Foës, Anuce, 1562-1595.',
#  'Freher, Marquard, 1565-1614.',
#  'Fritsch, Ahasver, 1629-1701.',
#  'Frizzo, G[iacinto]',
#  'Froidmont, Libert, 1587-1653.',
#  'Galemis, Clauduis.',
#  'Gasquy, Armand.',
#  'Gasté, Armand, 1838-1902.',
#  'Gathendjian, Yovsep Vardaplt.',
#  'Gaufredi,Johannes',
#  'Gemma Frisius, Rainer.',
#  'Genoa (Republic)',
#  'Germonius, Angstasius.',
#  'Ghetaldi, Marino, 1566-1626.',
#  'Goebel, Severin.',
#  'Goltzius, Hubert, 1526-1583',
#  'Goltzius, Hubert, 1526-1583.',
#  'Grassi, Paride, ca.1470-1528',
#  'Grassi, Paride, ca.1470-1528.',
#  'Gratama, Menno Schaaff.',
#  'Gripenhielm, Emund, 1622-1675.',
#  'Grisel, Hercule, 1595-1677.',
#  'Grosso, Stefano, 1824-1903.',
#  'Guazzini, Sebastiano.',
#  'Guazzo, Stefano, 1530-1593',
#  'Guidacerius, Agathius, 1477?-1540.',
#  'Gustafsson, Fridolf Vladimir.',
#  'Hallier, François.',
#  'Hamilton, Sidney Craves, 1855-',
#  'Hebbelynck, Adolphe, 1859-1939.',
#  'Heeringa, Didericus',
#  'Heeringa, Didericus.',
#  'Heliodoro',
#  'Heliodoro.',
#  'Heuter, Pontus, 1535-1602.',
#  'Heuter, Pontus.',
#  'Hildesheimer, Hirsch',
#  'Hodža, Michal Miloslav, 1811-1870.',
#  'Holyday, Barten, 1593-1661.',
#  'Horapollo.',
#  'Hostus, Mathaeus.',
#  'Hovhannēs, Ōdznetsʻi, -729.',
#  'Huber, Ulrik, 1636-1694.',
#  'Hult, Joh. Ferd.',
#  'Hurtado, Tomás (CC.RR.MM.), 1570-1649',
#  'Hurtado, Tomás (CC.RR.MM.), 1570-1649.',
#  'Hüntemann, Ulrico, 1869-1936.',
#  'Iglesia Católica',
#  'Iglesia Católica.',
#  'Imruʼ al-Qays, 497-545.',
#  'Imruʾ al-Qays, 497-545.',
#  'Index librorum prohibitorum.',
#  'Intriglioli, Nicolo.',
#  'Jannelli, Cataldo,',
#  'Jannelli, Cataldo, 1781-1841.',
#  'Jesuitas',
#  'Jesuitas.',
#  'Jiménez Patón, Bartolomé, 1569-1640.',
#  'Kada, Carolomann.',
#  'Kant, Immanuel, 1724-1804.',
#  'Kazenberger, Kilian, -1750',
#  'Keck.',
#  'Kempensis, Thomae.',
#  'Kleemann, Selmar, 1851-1931.',
#  'Kolinovics, Gábor, 1698-1770.',
#  'Krawutschke, Alois',
#  'Krisper, Crescentius, 1679-1749.',
#  'Kromer, Marcin, 1512-1589',
#  'Kālidāsa.',
#  'Landívar, Rafael, 1731-1793.',
#  'Langford, Mr. 1711-1774,',
#  'Lapini, Eufrosino, m.1571.',
#  'Leidecker, Melchier.',
#  'Lessius, Leonardus, 1554-1623',
#  'Lessius, Leonardus, 1554-1623.',
#  'Libanius.',
#  'Liceti, Fortunio, 1577-1657.',
#  'Lilie, Ern. Godofr.',
#  'Linden, Johan-Antonides vander, 1609-1664.',
#  'Llandaff (Diocese)',
#  'Locati, Umberto, 1503-1587',
#  'Lopes dos Santos Valente, António, 1839-1896.',
#  'Lüdecke, Friederick.',
#  'López Bravo, Mateo',
#  'Macé, Alcide.',
#  'Macé, Alcide.',
#  'Magalhaes, Cosmé.',
#  'Maggi, Ottaviano.',
#  'Maignan, Emmanuel, 1601-1676',
#  'Maillet, Eugène.',
#  'Maimónides, 1135-1204',
#  'Maimónides, 1135-1204.',
#  'Maiolo, Simone, 1520-1597?',
#  'Maler, Guilelmo.',
#  'Manasseh ben Israel, 1604-1657.',
#  'Mariscotti, Ercole.',
#  'Marracci, Ippolito, 1604-1675',
#  'Marracci, Ippolito, 1604-1675.',
#  'Martiano, Próspero.',
#  'Marulic, Marko, 1450-1524',
#  'Marulic, Marko, 1450-1524.',
#  'Mastrillo, Garzia, 1620',
#  'Mastrillo, Garzía, 1620.',
#  'Matteucci, Aloysius',
#  'Mausonius, Horidus.',
#  'Mazzolini, Silvestro, 1456?-1523',
#  'Mechovius, Guilhelmus.',
#  'Monaci, Ernesto, 1844-1918.',
#  'Mone, Fridegar, 1796-1871.',
#  'Monti, Panfilo',
#  'Montivs, Hieronymvs.',
#  'Munkelif, Norway. (Benedictine Monastery)',
#  'Mynsinger, Joachimus (1517-1588)',
#  'Nardi, Baltasare.',
#  'Nasafī, Awḥad al-Dīn.',
#  'Nawawī, 1233-1277.',
#  'Ninguarda, Feliciano m.1595',
#  'Nizolio, Mario, 1498-1566.',
#  'Nobili, Flaminio, 1532-1590',
#  'Nogueras, Jaime.',
#  'Novotný, František.',
#  'Novotný, Frantisek.',
#  "O'Flaherty, Roderic, 1629-1718.",
#  'Offerhaus, Leonardus, 1669-1779.',
#  'Olsson, Inguar.',
#  'Opalinski, Lukasz',
#  'Orpheus.',
#  'Orígenes.',
#  'Osório, Jerónimo, 1506-1580.',
#  'Pagnini, Sante.',
#  'Paleario, Aonio, 1503-1570',
#  'Panvinio, Onofrio, 1529-1568',
#  'Panvinio, Onofrio, 1529-1568.',
#  'Panvinio, Onofrio, 1530-1568',
#  'Panvinio, Onofrio, 1530-1568.',
#  'Panyassis Halicarnassensis.',
#  'Paparella, Sebastiano',
#  'Paparella, Sebastiano.',
#  'Pardo, Jerónimo.',
#  'Pereira, Bartholomeu, 1588-1650.',
#  'Péan Gatineau.',
#  'Philostorgius.',
#  'Piazza, Salomone.',
#  'Pietrasanta, Silvestro, 1590-1647.',
#  'Pindarus.',
#  'Pinelo, Benito.',
#  'Pissinio, Sebastiano.',
#  'Pistoris, Hartmann',
#  'Pistoris, Hartmann.',
#  'Pitcairn, Archibald, 1652-1713',
#  'Pitcairn, Archibald, 1652-1713.',
#  'Plutarch.',
#  'Podlusányi, Zsigmond, 1714-1758.',
#  'Polyaenus.',
#  'Praed, Winthrop Mackworth, 1802-1839.',
#  'Praetorius, Abdias, 1524-1573',
#  'Praetorius, Abdias, 1524-1573.',
#  'Pratensis, Jason, 1486-1558',
#  'Pratensis, Jason, 1486-1558.',
#  'Procaccini, Calisto.',
#  'Pruzsinszky, Janes',
#  'Pythagoras.',
#  'Quesnel, Pasquier, 1634-1719',
#  'Rader, Matthäus, 1561-1634',
#  'Rader, Matthäus, 1561-1634.',
#  'Ragusa, Dalmatia.',
#  'Ramiro, Jerónimo.',
#  'Ravideva.',
#  'Reis, António dos, (C.O.), 1690-1738.',
#  'Remondini (Firm).',
#  'Renaudot, Eusèbe, 1646-1720',
#  'Rescius, Stanislaus',
#  'Rhasis, Mohammed.',
#  'Rhode, Feodor.',
#  'Rijksuniversiteit Groningen',
#  'Rijksuniversiteit te Leiden. Bibliotheek.',
#  'Riminaldi, Ippolito, 1520-1589.',
#  'Rinaldi, Odorico.',
#  'Rivera, Lázaro.',
#  'Riviere, Lazare, 1589-1655.',
#  'Robertson, Abram, 1751-1826.',
#  'Robles Salcedo, Blas.',
#  'Robles Salzedo, Blas',
#  'Rocafull, José.',
#  'Rolfinck, Werner 1599-1673.',
#  'Rolli, Celestino.',
#  'Roorda, Taco, 1801-1874',
#  'Rostowski, Stanislaw, 1711-1784.',
#  'Ruiz Villegas, Fernando.',
#  'Sabunde, Ramón.',
#  'Sala, Paschasio.',
#  'Sanchuniathon.',
#  'Sand, Christof, 1644-1680.',
#  'Sandeo, Felino María.',
#  'Sappel, Ladislaus',
#  'Sappel, Ladislaus.',
#  'Sappho.',
#  'Sarmentero, Bartolomé',
#  'Sarmentero, Bartolomé.',
#  'Sassonia, Ercole, 1551-1607',
#  'Sassonia, Ercole, 1551-1607.',
#  'Scaccia, Segismundo.',
#  'Scaccia,Segismundo.',
#  'Schedel, Hartmann, 1440-1514.',
#  'Scheiner, Cristoph, 1575-1650',
#  'Schevichavius, Gisbertus, 1558-1622.',
#  'Schlögl, Nivard.',
#  'Schott, Gaspar, 1608-1666.',
#  'Schramm, Erduin, 1872-',
#  'Schramm, Erduinus, 1872-',
#  'Schultz, Alwin, 1838-1909.',
#  'Secchi, Ancleto.',
#  'Serlio, Sebastiano, 1475-1554.',
#  'Serrano, Tomás.',
#  'Shih ching.',
#  'Silos, Ioanne Michaele, 1601-1674.',
#  'Simocatta, Theophylactus.',
#  'Sion College. Library.',
#  'Sixtinus, Regnerus, 1543-1617',
#  'Sixtinus, Regnerus, 1543-1617.',
#  'Smelingus, Tilmannus.',
#  'Snell, Willebrord, 1591-1626',
#  'Snellius, Willebrord, 1580-1626.',
#  'Sophocles.',
#  'Sophonias',
#  'Speckhan, Eberhard.',
#  'Sprockhoff, Erich, 1883-',
#  'Sprüngli, Hartmann.',
#  'Stift Klosterneuburg.',
#  'Stobaeus',
#  'Stobaeus.',
#  'Storr, Rayner.',
#  'Stovaios, Iōannēs.',
#  'Streitwolf, Frid. Guil.',
#  'Struś, Józef, 1510-1568.',
#  'Sturla Þórðarson, 1214-1284.',
#  'Sussanneau, Hubert, 1512-1550.',
#  'Swedenborg, Emanuel, 1688-1772',
#  'Swedenborg, Emanuel, 1688-1772.',
#  'Széchényi, Ferenc, gróf, 1754-1820.',
#  'Sánchez, Tomás 1550-1610',
#  'Sánchez, Tomás, 1550-1610',
#  'Sánchez, Tomás, 1550-1610.',
#  'Tacquet, André, 1612-1660.',
#  'Tapper, Ruard.',
#  'Temistio.',
#  'Teofrasto.',
#  'Themistius',
#  'Themistius.',
#  'Theocritus',
#  'Theocritus.',
#  'Thorius, Raphael, -1625',
#  'Thucydides',
#  'Thucydides.',
#  'Tiraqueau, André, 1488-1558',
#  'Tkač, Ignác,',
#  'Toledano, García.',
#  'Tomkowicz, Stanisław.',
#  'Törneros, Adolph, 1794-1839.',
#  'Traber, Zacharias, 1611-1679',
#  'Tryphiodorus',
#  'Tryphiodorus.',
#  'Tschischwitz, Benno, 1828-1890.',
#  'Turrettini, François, 1623-1687.',
#  'Universitätsbibliothek München.',
#  'Universitèat Jena.',
#  'Universität Göttingen.',
#  'Universität Ingolstadt. Bibliothek.',
#  'Unknown',
#  'Uriendt, Maximilien.',
#  'Valenti, Ferdinando.',
#  'Valleriole, François, 1504-1580.',
#  'Vazquez Morales, Joaquín José',
#  'Vázquez Menchaca, Fernando, 1512-1569.',
#  'Velázquez, Andrés',
#  'Vervorst, Firmin.',
#  'Vismara, Ercole',
#  'Visser, Didericus.',
#  'Vitringa, Campegius, 1659-1722',
#  'Vitringa, Campegius, 1659-1722.',
#  'Viète, François.',
#  'Voet, Joahnnes, 1647-1713.',
#  'Willughbeii, Francisci',
#  'Wolbero.',
#  'Worm, Ole, 1588-1654.',
#  'Xenophon',
#  'Xenophon.',
#  'Yamblico.',
#  'Zaccagni, Lelio, 1595-1678.',
#  'Zaccaria, Francescantonio, 1714-1795.',
#  'Zecchi, Lelio, m.1610',
#  'Zurita, Jerónimo',
#  'Æschines.'}

# %%
# Out:
# Aelian, 3rd cent.
# Aeschylus
# Alexander, of Aphrodisias
# Apollonius, Rhodius
# Apollonius, of Perga
# Archimedes
# Aretaeus, of Cappadocia
# Aristides Quintilianus
# Aristophanes
# Aristotle
# Arrian
# Artemidorus, Daldianus
# Athenaeus, of Naucratis
# Atilius Fortunatianus, 4th cent.
# Ausonius, Decimus Magnus
# Bacchylides
# Bion, of Phlossa near Smyrna
# Cassius Dio Cocceianus
# Celsus, Aulus Cornelius
# Charisius, Flavius Sosipater.
# Colluthus, of Lycopolis
# Cyril, Saint, Bishop of Jerusalem, approximately 315-386
# Demetrius, of Phaleron, b. ca. 350 B.C.
# Demosthenes
# Dictys, Cretensis
# Diodorus, Siculus
# Diogenes Laertius
# Dionysius, of Halicarnassus
# Diophantus, of Alexandria
# Dioscorides Pedanius, of Anazarbos
# Dositheus, Magister
# Ephraem, Syrus, Saint, 303-373
# Epictetus
# Epiphanius, Saint, Bishop of Constantia in Cyprus, approximately 310-403
# Euripides
# Firmicus Maternus, Julius.
# Galen
# Gregory, of Nazianzus, Saint
# Harpocration, Valerius
# Heliodorus, of Emesa
# Heraclitus, of Ephesus
# Herodotus
# Hesiod
# Hippocrates
# Homer
# Irenaeus, Saint, Bishop of Lyon
# John Chrysostom, Saint, -407
# Josephus, Flavius
# Longus
# Marcus Aurelius, Emperor of Rome, 121-180
# Michael, of Ephesus
# Musaeus, Grammaticus
# Nemesius, Bishop of Emesa
# Nicander, of Colophon
# Origen
# Pappus, of Alexandria
# Philo, of Alexandria
# Philodemus, ca. 110-ca. 40 B.C.
# Philoponus, John, 6th cent.
# Phocylides, fl. 544-541 B.C.
# Pindar
# Plato
# Plotinus
# Priscian, fl. ca. 500-530
# Pseudo-Dionysius, the Areopagite
# Ptolemy, 2nd cent.
# Quintus, Smyrnaeus, 4th cent.
# Seneca, Lucius Annaeus, ca. 4 B.C.-65 A.D.
# Sextus, Empiricus
# Sophonias
# Stobaeus
# Themistius
# Theocritus
# Theodosius, active 1st century B.C.
# Theon, of Smyrna
# Theophrastus
# Thucydides
# Tryphiodorus
# Xenophon

# %% [markdown]
# ## Deterministic Matching, Again

# %%
# Make a dataframe of just the author and deterministic author columns
deterministic = latin_only[['author','deterministic_author']]
# Filter out the NA values
deterministic = deterministic[deterministic['deterministic_author'].notna()]
deterministic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9150 entries, 6 to 24796
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                9150 non-null   object
#  1   deterministic_author  9150 non-null   object
# dtypes: object(2)
# memory usage: 214.5+ KB

# %% [markdown]
# The original `deterministic` frame had 9,303 rows. This one has 9,150.

# %%
# Make a sorted dataframe of the deterministic values
sorted_deterministic = deterministic.sort_values(axis='index',by='author')
# Save it as a CSV, appending "2" to the title to preserve the original
sorted_deterministic.to_csv('../data/deterministic_author_2.csv',index=False,quoting=csv.QUOTE_ALL)

# %% [markdown]
# ## Fuzzy Authors, Again

# %%
# Make a dataframe of the fuzzy matching columns and the author column
fuzzy = latin_only[['author','fuzzy_author','fuzzy_author_score']]
# Eliminate any NaN cells
fuzzy = fuzzy[fuzzy['fuzzy_author'].notna()]

print(fuzzy.info())

# Count the number of unique values in the fuzzy_author column
print(f"Total number of unique values in the fuzzy_author column: {fuzzy['fuzzy_author'].nunique()}")

unmatched_fuzzy = latin_only[latin_only['fuzzy_author'].isna()]
# Show the number of unique author values in the unmatched_fuzzy dataframe
print(f"Number of unique values in the unmatched_fuzzy dataframe: {unmatched_fuzzy['author'].nunique()}")
# Display the list of unmatched author names
sorted(unmatched_fuzzy['author'].unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21938 entries, 0 to 24797
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   author              21938 non-null  object
#  1   fuzzy_author        21938 non-null  object
#  2   fuzzy_author_score  21938 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 685.6+ KB
# None
# Total number of unique values in the fuzzy_author column: 1135
# Number of unique values in the unmatched_fuzzy dataframe: 451
# ['Academia Molshemensis (Francia)',
#  'Achilles Tatius',
#  'Achilles Tatius.',
#  'Acidalius, Valens, 1567-1595',
#  'Aeschines.',
#  'Aesop',
#  'Aesop.',
#  'Agathias, -582',
#  'Agathias, -582.',
#  'Albertini, Hannibal.',
#  'Albumasar.',
#  'Alciphron.',
#  'Alegambe, Philippo, 1592-1652',
#  'Alvisi, Edoardo, 1850-1915.',
#  'Amama, Sixtinus, 1593-1629.',
#  'Amati, Pasquale,',
#  'Anacreon',
#  'Anacreon.',
#  'Anacreonte.',
#  'Andreantonelli, Sebastiano.',
#  'Anhalt, Ottocar.',
#  'Apollodorus.',
#  'Apollonius, Paradoxographus.',
#  'Apollonius, Rhodius.',
#  'Apollonius, paradoxographus.',
#  'Appendix Vergiliana.',
#  'Archimedes.',
#  'Aristophanes.',
#  'Aristófanes.',
#  'Arngrímur Jónsson, 1568-1648.',
#  'Artemidoro.',
#  'Artephius,',
#  'Artephius.',
#  'Asclepiadeus, Androphilus.',
#  'Auerbach, Bertrand, 1856-1942',
#  'Augenio, Orazio',
#  'Augenio, Orazio.',
#  'Autolycus.',
#  'Bacchylides.',
#  'Bar Hebraeus, 1226-1286.',
#  'Barbato, Orazio.',
#  'Barbosa, Agostinho, 1590-1649.',
#  'Barbosa, Enmanuele.',
#  'Barrientos, Bartolomé.',
#  'Bartelon, Pantaléon',
#  'Bartoletti, Fabrizio, 1576-1630.',
#  'Bartoletti, Fabrizio.',
#  'Bayerische Staatsbibliothek.',
#  'Bellegni, Caroli.',
#  'Bellone, Niccolò.',
#  'Belsheim, Johannus Engebretsen, 1829-1909.',
#  'Bhartr̥hari.',
#  'Biblioteca apostolica vaticana.',
#  'Biblioteca medicea laurenziana.',
#  'Biblioteca nazionale marciana.',
#  'Bibliotheca Palatina (Biblioteca apostolica vaticana)',
#  'Bidloo, Govard, 1649-1713.',
#  'Biragus, Aloysius.',
#  'Biuso, Carmelo.',
#  'Bocchi, Achille, 1488-1562',
#  'Bocchi, Achille, 1488-1562.',
#  'Bodleian Library.',
#  'Bonet-Maury, Gaston, 1842-1919.',
#  'Borový, Klement, 1838-1897',
#  'Boussuet, François.',
#  'Brandl, Vincenc, 1834-1901.',
#  'Brink, Barend ten, 1803-1875.',
#  'Brisson, Barnabe',
#  'Brisson, Barnabe.',
#  'Brisson, Barnabé, 1531-1591.',
#  'Buonamici, Castruccio, 1710-1761.',
#  'Burdegati, Sante.',
#  'Burgerbibliothek Bern.',
#  'Bérnard, Léon, 1847-',
#  'CCPB000038379-1',
#  'Caimo, Pompeo.',
#  'Caldeira, Duarte.',
#  'Capecelatro, Ettore.',
#  'Carmeni, Daniele.',
#  'Carmina burana.',
#  'Castellion, Sébastien, 1515-1563.',
#  'Catalani, Giusseppe.',
#  'Cellarius, Balthasar',
#  'Cesarini, Virginio, 1595-1624',
#  'Cesarini, Virginio, 1595-1624.',
#  "Chetham's Library.",
#  'Choppin, René, 1537-1606.',
#  'Cigala, Honufrio',
#  'Ciofani, Ercole',
#  'Cippico, Coriolano, 1425?-1493?',
#  'Clicthove, Josse',
#  'Clicthove, Jossé',
#  'Clicthove, Jossé.',
#  'Cloyne. Diocese.',
#  'Clément, Félix, 1822-1885',
#  'Coelho, Jorge',
#  'Comnena, Anna, 1083-1148.',
#  'Connan, François.',
#  'Contarini, Gasparo',
#  'Contarini, Gasparo.',
#  'Cordier, Mathurin, 1479-1564',
#  'Cordier, Mathurin, 1479-1564.',
#  'Corpus iuris civilis. Institutiones.',
#  'Corradi, Sebastiano, -1556.',
#  'Corradi, Sebastiano, 1510-1556',
#  'Corradi, Sebastiano, 1510-1556.',
#  'Corrado, Pirro',
#  'Cragius, Niels, 1549-1602.',
#  'Cremani, Aloisii.',
#  'Croiset, Maurice, 1846-1935.',
#  'Cuperus, Gisbertus.',
#  'Cutelli, Mario, 1584-1654.',
#  'Darmesteter, Arsène, 1846-1888.',
#  'Decsi, János, -1601.',
#  'Delfio, Porto Euterio.',
#  'Demosthenes.',
#  'Denari, Odofredo, -1265',
#  'Deneke, Ewald, 1893-',
#  'Desbillons, François-Joseph Terrasse, 1711-1789,',
#  'Desericzky, József Ince, 1702-1763.',
#  'Deseriz, Jósef Ince.',
#  'Diemerbroeck, Isbrand',
#  'Diodoro Sículo.',
#  'Diogenes Laercio',
#  'Diogenes Laercio.',
#  'Diogenes Laertius.',
#  'Dion Casio',
#  'Diógenes Laercio.',
#  'Dión Casio.',
#  'Dodoens, Rembert',
#  'Dodoens, Rembert, 1517-1585.',
#  'Drexel, Jeremias, 1581-1638,',
#  'Drexel, Jeremias, 1581-1638.',
#  'Dubrovnik (Republic)',
#  'Dulaurens, François.',
#  'Dulaurens,François.',
#  'Dyckhoff, Sigimund.',
#  'Eckolt, Amadeus, 1623-1668.',
#  'Emlein, Friedericus, 1876-',
#  'Emmius, Ubbo, 1547-1625',
#  'Endlicher, István László, 1804-1849.',
#  'Engström, Einar, 1899-1973.',
#  'Enrique Susón, Beato, 1295-1366.',
#  'Epicteto.',
#  'Epo, Boetius',
#  'Epo, Boetius.',
#  'Esteve, José, 1550-1603',
#  'Estrabón',
#  'Estrabón.',
#  'Euclides',
#  'Euclides.',
#  'Fagundes, Estevao, 1577-1645.',
#  'Falcucci, Nicolò',
#  'Farinacci, Prospero, 1554-1618.',
#  'Favazza, Salvator.',
#  'Fedro.',
#  'Feith, Everard.',
#  'Ferry, C[amille]',
#  'Filalteo, Lucillo.',
#  'Fine, Oronce, 1494-1555.',
#  'Fine, Oronce.',
#  'Firdawsī',
#  'Flemyng, Malcolm.',
#  'Fomann, Ortolphus, 1560-1634.',
#  'Fontanini, Giusto, 1666-1736.',
#  'Foës, Anuce, 1562-1595.',
#  'Freher, Marquard, 1565-1614.',
#  'Fritsch, Ahasver, 1629-1701.',
#  'Frizzo, G[iacinto]',
#  'Froidmont, Libert, 1587-1653.',
#  'Galemis, Clauduis.',
#  'Gasquy, Armand.',
#  'Gasté, Armand, 1838-1902.',
#  'Gathendjian, Yovsep Vardaplt.',
#  'Gaufredi,Johannes',
#  'Gemma Frisius, Rainer.',
#  'Genoa (Republic)',
#  'Germonius, Angstasius.',
#  'Ghetaldi, Marino, 1566-1626.',
#  'Goebel, Severin.',
#  'Goltzius, Hubert, 1526-1583',
#  'Goltzius, Hubert, 1526-1583.',
#  'Grassi, Paride, ca.1470-1528',
#  'Grassi, Paride, ca.1470-1528.',
#  'Gratama, Menno Schaaff.',
#  'Gripenhielm, Emund, 1622-1675.',
#  'Grisel, Hercule, 1595-1677.',
#  'Grosso, Stefano, 1824-1903.',
#  'Guazzini, Sebastiano.',
#  'Guazzo, Stefano, 1530-1593',
#  'Guidacerius, Agathius, 1477?-1540.',
#  'Gustafsson, Fridolf Vladimir.',
#  'Hallier, François.',
#  'Hamilton, Sidney Craves, 1855-',
#  'Hebbelynck, Adolphe, 1859-1939.',
#  'Heeringa, Didericus',
#  'Heeringa, Didericus.',
#  'Heliodoro',
#  'Heliodoro.',
#  'Heuter, Pontus, 1535-1602.',
#  'Heuter, Pontus.',
#  'Hildesheimer, Hirsch',
#  'Hodža, Michal Miloslav, 1811-1870.',
#  'Holyday, Barten, 1593-1661.',
#  'Horapollo.',
#  'Hostus, Mathaeus.',
#  'Hovhannēs, Ōdznetsʻi, -729.',
#  'Huber, Ulrik, 1636-1694.',
#  'Hult, Joh. Ferd.',
#  'Hurtado, Tomás (CC.RR.MM.), 1570-1649',
#  'Hurtado, Tomás (CC.RR.MM.), 1570-1649.',
#  'Hüntemann, Ulrico, 1869-1936.',
#  'Iglesia Católica',
#  'Iglesia Católica.',
#  'Imruʼ al-Qays, 497-545.',
#  'Imruʾ al-Qays, 497-545.',
#  'Index librorum prohibitorum.',
#  'Intriglioli, Nicolo.',
#  'Jannelli, Cataldo,',
#  'Jannelli, Cataldo, 1781-1841.',
#  'Jesuitas',
#  'Jesuitas.',
#  'Jiménez Patón, Bartolomé, 1569-1640.',
#  'Kada, Carolomann.',
#  'Kant, Immanuel, 1724-1804.',
#  'Kazenberger, Kilian, -1750',
#  'Keck.',
#  'Kempensis, Thomae.',
#  'Kleemann, Selmar, 1851-1931.',
#  'Kolinovics, Gábor, 1698-1770.',
#  'Krawutschke, Alois',
#  'Krisper, Crescentius, 1679-1749.',
#  'Kromer, Marcin, 1512-1589',
#  'Kālidāsa.',
#  'Landívar, Rafael, 1731-1793.',
#  'Langford, Mr. 1711-1774,',
#  'Lapini, Eufrosino, m.1571.',
#  'Leidecker, Melchier.',
#  'Lessius, Leonardus, 1554-1623',
#  'Lessius, Leonardus, 1554-1623.',
#  'Libanius.',
#  'Liceti, Fortunio, 1577-1657.',
#  'Lilie, Ern. Godofr.',
#  'Linden, Johan-Antonides vander, 1609-1664.',
#  'Llandaff (Diocese)',
#  'Locati, Umberto, 1503-1587',
#  'Lopes dos Santos Valente, António, 1839-1896.',
#  'Lüdecke, Friederick.',
#  'López Bravo, Mateo',
#  'Macé, Alcide.',
#  'Macé, Alcide.',
#  'Magalhaes, Cosmé.',
#  'Maggi, Ottaviano.',
#  'Maignan, Emmanuel, 1601-1676',
#  'Maillet, Eugène.',
#  'Maimónides, 1135-1204',
#  'Maimónides, 1135-1204.',
#  'Maiolo, Simone, 1520-1597?',
#  'Maler, Guilelmo.',
#  'Manasseh ben Israel, 1604-1657.',
#  'Mariscotti, Ercole.',
#  'Marracci, Ippolito, 1604-1675',
#  'Marracci, Ippolito, 1604-1675.',
#  'Martiano, Próspero.',
#  'Marulic, Marko, 1450-1524',
#  'Marulic, Marko, 1450-1524.',
#  'Mastrillo, Garzia, 1620',
#  'Mastrillo, Garzía, 1620.',
#  'Matteucci, Aloysius',
#  'Mausonius, Horidus.',
#  'Mazzolini, Silvestro, 1456?-1523',
#  'Mechovius, Guilhelmus.',
#  'Monaci, Ernesto, 1844-1918.',
#  'Mone, Fridegar, 1796-1871.',
#  'Monti, Panfilo',
#  'Montivs, Hieronymvs.',
#  'Munkelif, Norway. (Benedictine Monastery)',
#  'Mynsinger, Joachimus (1517-1588)',
#  'Nardi, Baltasare.',
#  'Nasafī, Awḥad al-Dīn.',
#  'Nawawī, 1233-1277.',
#  'Ninguarda, Feliciano m.1595',
#  'Nizolio, Mario, 1498-1566.',
#  'Nobili, Flaminio, 1532-1590',
#  'Nogueras, Jaime.',
#  'Novotný, František.',
#  'Novotný, Frantisek.',
#  "O'Flaherty, Roderic, 1629-1718.",
#  'Offerhaus, Leonardus, 1669-1779.',
#  'Olsson, Inguar.',
#  'Opalinski, Lukasz',
#  'Orpheus.',
#  'Orígenes.',
#  'Osório, Jerónimo, 1506-1580.',
#  'Pagnini, Sante.',
#  'Paleario, Aonio, 1503-1570',
#  'Panvinio, Onofrio, 1529-1568',
#  'Panvinio, Onofrio, 1529-1568.',
#  'Panvinio, Onofrio, 1530-1568',
#  'Panvinio, Onofrio, 1530-1568.',
#  'Panyassis Halicarnassensis.',
#  'Paparella, Sebastiano',
#  'Paparella, Sebastiano.',
#  'Pardo, Jerónimo.',
#  'Pereira, Bartholomeu, 1588-1650.',
#  'Péan Gatineau.',
#  'Philostorgius.',
#  'Piazza, Salomone.',
#  'Pietrasanta, Silvestro, 1590-1647.',
#  'Pindarus.',
#  'Pinelo, Benito.',
#  'Pissinio, Sebastiano.',
#  'Pistoris, Hartmann',
#  'Pistoris, Hartmann.',
#  'Pitcairn, Archibald, 1652-1713',
#  'Pitcairn, Archibald, 1652-1713.',
#  'Plutarch.',
#  'Podlusányi, Zsigmond, 1714-1758.',
#  'Polyaenus.',
#  'Praed, Winthrop Mackworth, 1802-1839.',
#  'Praetorius, Abdias, 1524-1573',
#  'Praetorius, Abdias, 1524-1573.',
#  'Pratensis, Jason, 1486-1558',
#  'Pratensis, Jason, 1486-1558.',
#  'Procaccini, Calisto.',
#  'Pruzsinszky, Janes',
#  'Pythagoras.',
#  'Quesnel, Pasquier, 1634-1719',
#  'Rader, Matthäus, 1561-1634',
#  'Rader, Matthäus, 1561-1634.',
#  'Ragusa, Dalmatia.',
#  'Ramiro, Jerónimo.',
#  'Ravideva.',
#  'Reis, António dos, (C.O.), 1690-1738.',
#  'Remondini (Firm).',
#  'Renaudot, Eusèbe, 1646-1720',
#  'Rescius, Stanislaus',
#  'Rhasis, Mohammed.',
#  'Rhode, Feodor.',
#  'Rijksuniversiteit Groningen',
#  'Rijksuniversiteit te Leiden. Bibliotheek.',
#  'Riminaldi, Ippolito, 1520-1589.',
#  'Rinaldi, Odorico.',
#  'Rivera, Lázaro.',
#  'Riviere, Lazare, 1589-1655.',
#  'Robertson, Abram, 1751-1826.',
#  'Robles Salcedo, Blas.',
#  'Robles Salzedo, Blas',
#  'Rocafull, José.',
#  'Rolfinck, Werner 1599-1673.',
#  'Rolli, Celestino.',
#  'Roorda, Taco, 1801-1874',
#  'Rostowski, Stanislaw, 1711-1784.',
#  'Ruiz Villegas, Fernando.',
#  'Sabunde, Ramón.',
#  'Sala, Paschasio.',
#  'Sanchuniathon.',
#  'Sand, Christof, 1644-1680.',
#  'Sandeo, Felino María.',
#  'Sappel, Ladislaus',
#  'Sappel, Ladislaus.',
#  'Sappho.',
#  'Sarmentero, Bartolomé',
#  'Sarmentero, Bartolomé.',
#  'Sassonia, Ercole, 1551-1607',
#  'Sassonia, Ercole, 1551-1607.',
#  'Scaccia, Segismundo.',
#  'Scaccia,Segismundo.',
#  'Schedel, Hartmann, 1440-1514.',
#  'Scheiner, Cristoph, 1575-1650',
#  'Schevichavius, Gisbertus, 1558-1622.',
#  'Schlögl, Nivard.',
#  'Schott, Gaspar, 1608-1666.',
#  'Schramm, Erduin, 1872-',
#  'Schramm, Erduinus, 1872-',
#  'Schultz, Alwin, 1838-1909.',
#  'Secchi, Ancleto.',
#  'Serlio, Sebastiano, 1475-1554.',
#  'Serrano, Tomás.',
#  'Shih ching.',
#  'Silos, Ioanne Michaele, 1601-1674.',
#  'Simocatta, Theophylactus.',
#  'Sion College. Library.',
#  'Sixtinus, Regnerus, 1543-1617',
#  'Sixtinus, Regnerus, 1543-1617.',
#  'Smelingus, Tilmannus.',
#  'Snell, Willebrord, 1591-1626',
#  'Snellius, Willebrord, 1580-1626.',
#  'Sophocles.',
#  'Speckhan, Eberhard.',
#  'Sprockhoff, Erich, 1883-',
#  'Sprüngli, Hartmann.',
#  'Stift Klosterneuburg.',
#  'Stobaeus.',
#  'Storr, Rayner.',
#  'Stovaios, Iōannēs.',
#  'Streitwolf, Frid. Guil.',
#  'Struś, Józef, 1510-1568.',
#  'Sturla Þórðarson, 1214-1284.',
#  'Sussanneau, Hubert, 1512-1550.',
#  'Swedenborg, Emanuel, 1688-1772',
#  'Swedenborg, Emanuel, 1688-1772.',
#  'Széchényi, Ferenc, gróf, 1754-1820.',
#  'Sánchez, Tomás 1550-1610',
#  'Sánchez, Tomás, 1550-1610',
#  'Sánchez, Tomás, 1550-1610.',
#  'Tacquet, André, 1612-1660.',
#  'Tapper, Ruard.',
#  'Temistio.',
#  'Teofrasto.',
#  'Themistius.',
#  'Theocritus.',
#  'Thorius, Raphael, -1625',
#  'Thucydides.',
#  'Tiraqueau, André, 1488-1558',
#  'Tkač, Ignác,',
#  'Toledano, García.',
#  'Tomkowicz, Stanisław.',
#  'Törneros, Adolph, 1794-1839.',
#  'Traber, Zacharias, 1611-1679',
#  'Tryphiodorus.',
#  'Tschischwitz, Benno, 1828-1890.',
#  'Turrettini, François, 1623-1687.',
#  'Universitätsbibliothek München.',
#  'Universitèat Jena.',
#  'Universität Göttingen.',
#  'Universität Ingolstadt. Bibliothek.',
#  'Unknown',
#  'Uriendt, Maximilien.',
#  'Valenti, Ferdinando.',
#  'Valleriole, François, 1504-1580.',
#  'Vazquez Morales, Joaquín José',
#  'Vázquez Menchaca, Fernando, 1512-1569.',
#  'Velázquez, Andrés',
#  'Vervorst, Firmin.',
#  'Vismara, Ercole',
#  'Visser, Didericus.',
#  'Vitringa, Campegius, 1659-1722',
#  'Vitringa, Campegius, 1659-1722.',
#  'Viète, François.',
#  'Voet, Joahnnes, 1647-1713.',
#  'Willughbeii, Francisci',
#  'Wolbero.',
#  'Worm, Ole, 1588-1654.',
#  'Xenophon.',
#  'Yamblico.',
#  'Zaccagni, Lelio, 1595-1678.',
#  'Zaccaria, Francescantonio, 1714-1795.',
#  'Zecchi, Lelio, m.1610',
#  'Zurita, Jerónimo',
#  'Æschines.']

# %% [markdown]
# Hmmm. There are still some Greek names. I guess I need to sift through the "author" column manually?
