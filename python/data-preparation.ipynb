# %% [markdown]
# # Data Preparation
#
# I'm going to try a hybrid approach to using existing data with traditional string matching techniques, with a fallback to AI/ML to suggest possibilities for unknowns or poor matches.
#
# I need to set up two sets of data:
#
# 1. Author data: This needs to include author ID, authorized name, and variant names
# 2. Title data: This needs to include work ID, work name, and associated author ID.

# %% [markdown]
# ## Authors
#
# I have an existing dataset made up of authority records from the DLL's catalog. I augmented it with variant names scraped from the Virtual International Authority File for each author. It also contains some Greek author names, but I'm not going to use those for this project.

# %%
import pandas as pd

# Read in the Authors data
df = pd.read_csv('../data/authors.csv', encoding='utf-8',quotechar='"')
# Get basic information about the dataframe
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37535 entries, 0 to 37534
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DLL Identifier (Author)  37535 non-null  object
#  1   Authorized Name          37535 non-null  object
#  2   Language                 37535 non-null  object
#  3   Variant                  37522 non-null  object
# dtypes: object(4)
# memory usage: 1.1+ MB
# None

# %%
df.head()
# Out:
#   DLL Identifier (Author)                                Authorized Name  \
# 0                  G55561                   Lycus Rheginus 3. Jh. v. Chr
# 1                  G05484  Nicephorus Saint, Patriarch of Constantinople
# 2                  G36001           Clitophon Rhodius, 1./2. Jh. v. Chr.
# 3                  G00491        Demetrius, of Phaleron, b. ca. 350 B.C.
# 4                  G43722             Echembrotus Lyricus, 6. Jh. v. Chr
#
#   Language                                     Variant
# 0    Greek                Lycus Rheginus 3. Jh. v. Chr
# 1    Greek                               Nicéphore Ier
# 2    Greek                                     Clitofó
# 3    Greek  Démétrios de Phalère 0350?-0283? av. J.-C.
# 4    Greek                                   Equembrot

# %%
# Remove the Greek authors
df = df[df['Language'] == 'Latin']
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35325 entries, 2210 to 37534
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DLL Identifier (Author)  35325 non-null  object
#  1   Authorized Name          35325 non-null  object
#  2   Language                 35325 non-null  object
#  3   Variant                  35312 non-null  object
# dtypes: object(4)
# memory usage: 1.3+ MB
#      DLL Identifier (Author)    Authorized Name Language  \
# 2210                   A1868  Herryson, Joannes    Latin
# 2211                   A1868  Herryson, Joannes    Latin
# 2212                   A1868  Herryson, Joannes    Latin
# 2213                   A1868  Herryson, Joannes    Latin
# 2214                   A1868  Herryson, Joannes    Latin
#
#                                           Variant
# 2210  Herryson, Joannes floruit=15th Century A.D.
# 2211                             Joannes Herryson
# 2212                                John Herryson
# 2213  Heryyson, Joannes floruit=15th Century A.D.
# 2214  Herryson, xoannes floruit=15th Century A.D.

# %%
# Remove the Language column
df = df.drop(columns='Language')

# %%
# Rearrange the columns
df = df[['Variant','Authorized Name','DLL Identifier (Author)']]

# %%
# Check for duplicated Variant names
df['Variant'].duplicated().value_counts()
# Out:
# Variant
# False    27291
# True      8034
# Name: count, dtype: int64

# %%
deduplicated = df.drop_duplicates(subset=['Variant'])
deduplicated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27291 entries, 2210 to 37534
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Variant                  27290 non-null  object
#  1   Authorized Name          27291 non-null  object
#  2   DLL Identifier (Author)  27291 non-null  object
# dtypes: object(3)
# memory usage: 852.8+ KB

# %%
# Check for null values
authors = deduplicated.dropna(subset=['Variant'])
authors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27290 entries, 2210 to 37534
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Variant                  27290 non-null  object
#  1   Authorized Name          27290 non-null  object
#  2   DLL Identifier (Author)  27290 non-null  object
# dtypes: object(3)
# memory usage: 852.8+ KB

# %% [markdown]
# ## Works
#
# The works CSV contains data from work records, item records, and web page records in the DLL catalog.

# %%
# Read in the data
df = pd.read_csv('../data/works.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5763 entries, 0 to 5762
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Creator                  5334 non-null   object
#  1   Title                    5763 non-null   object
#  2   Authorized Title         5763 non-null   object
#  3   DLL Identifier (Work)    5763 non-null   object
#  4   DLL Identifier (Author)  5332 non-null   object
# dtypes: object(5)
# memory usage: 225.2+ KB
#                                          Creator  \
# 0                Gilles, de Corbeil, active 1200
# 1                               Godis, Petrus de
# 2                              William, of Blois
# 3  Suetonius, approximately 69-approximately 122
# 4  Suetonius, approximately 69-approximately 122
#
#                                      Title  \
# 0  De signis et symptomatibus aegritudinum
# 1        De coniuratione Porcaria dialogus
# 2                                     Alda
# 3                     De Viris Illustribus
# 4                           De Philosophis
#
#                           Authorized Title DLL Identifier (Work)  \
# 0  De signis et symptomatibus aegritudinum                W10655
# 1        De coniuratione Porcaria dialogus                W10654
# 2                                     Alda                W10653
# 3                     De Viris Illustribus                W10652
# 4                           De Philosophis                W10651
#
#   DLL Identifier (Author)
# 0                   A3919
# 1                   A3221
# 2                   A4844
# 3                   A4799
# 4                   A4799

# %%
# Drop the column we don't need
df = df[['Title','DLL Identifier (Work)','DLL Identifier (Author)']]

# %%
# Find duplicated rows
duplicates = df[df.duplicated()]

# %%
duplicates
# Out:
#                                                   Title DLL Identifier (Work)  \
# 1032  Priapeum 'Quid Hoc Novi Est?' (Appendix Vergil...                 W4720
# 1033                                      Carmen Arvale                 W4629
# 1034                          Comment. Anquisit. Sergii                 W4638
# 1035                                  Carmen Devotionis                 W4648
# 1036                                 Carmen Evocationis                 W4623
# 1037                                Commentarii Augurum                 W4665
# 1038                    Grammatica (Anonymi Grammatici)                 W4654
# 1039                              Bucolica Einsidlensia                 W4912
# 1040                             Commentarii Consulares                 W4626
# 4096                                  De Fide Orthodoxa                 W2778
# 5323                                     Vita Iuvenalis                 W4664
# 5324                                  Tabulae Censoriae                 W4679
# 5325                                     Sacra Argeorum                 W4650
# 5334                                         Sententiae                  W257
# 5336                                    De Agri Cultura                 W5351
# 5339                        Commentarii de Bello Civili                 W3983
# 5341                                       Antibucolica                 W5095
# 5344                                       Laus Pisonis                 W4663
# 5345                                    Precatio Terrae                 W4646
# 5346                           Mimi Poetarum Incertorum                 W4642
# 5348                                            Priapea                 W4621
# 5349                           Precatio Omnium Herbarum                 W4637
# 5352                             Etruscarum Rerum Libri                 W3928
# 5376                         De medicina, versio Latina                  W622
# 5383                       Auspiciorum Liber, fragmenta                   W97
# 5389                                       Ilias Latina                 W4914
# 5405                                        Astronomica                 W3254
# 5410                                            Fabulae                 W3233
# 5414                          Gai Institutionum epitome                 W2332
# 5415                                      Institutiones                 W2278
# 5417                              Libri Rerum Romanarum                 W2086
# 5420                       De Origine Vocabulorum, frr.                 W1772
# 5433                            De Verbis ad Ius Civile                  W326
# 5439                             Commentarii Consulares                 W4626
# 5440                              Bucolica Einsidlensia                 W4912
# 5442                                Commentarii Augurum                 W4665
# 5443                                 Carmen Evocationis                 W4623
# 5444                                  Carmen Devotionis                 W4648
# 5445                          Comment. Anquisit. Sergii                 W4638
# 5479                      Priapeum 'Quid Hoc Novi Est?'                 W4720
# 5480                          Comment. Anquisit. Sergii                 W4638
# 5481                                  Carmen Devotionis                 W4648
# 5482                                 Carmen Evocationis                 W4623
# 5483                                Commentarii Augurum                 W4665
# 5484                                         grammatica                 W4654
# 5485                              Bucolica Einsidlensia                 W4912
# 5486                             Commentarii Consulares                 W4626
# 5494                                          De Metris                 W4107
# 5495                            Rerum Romanarum Liber I                 W4086
# 5535  Altercatio Hadriani Augusti et Epictiti Philos...                 W4655
# 5536                                    De Differentiis                 W4652
#
#      DLL Identifier (Author)
# 1032                     NaN
# 1033                     NaN
# 1034                     NaN
# 1035                     NaN
# 1036                     NaN
# 1037                     NaN
# 1038                     NaN
# 1039                     NaN
# 1040                     NaN
# 4096                   A4376
# 5323                     NaN
# 5324                     NaN
# 5325                     NaN
# 5334                   A4504
# 5336                   A3400
# 5339                   A3607
# 5341                   A3521
# 5344                     NaN
# 5345                     NaN
# 5346                     NaN
# 5348                     NaN
# 5349                     NaN
# 5352                   A3559
# 5376                   A3618
# 5383                   A3582
# 5389                     NaN
# 5405                   A3487
# 5410                   A3487
# 5414                   A3454
# 5415                   A3454
# 5417                   A3603
# 5420                   A3590
# 5433                   A3602
# 5439                     NaN
# 5440                     NaN
# 5442                     NaN
# 5443                     NaN
# 5444                     NaN
# 5445                     NaN
# 5479                     NaN
# 5480                     NaN
# 5481                     NaN
# 5482                     NaN
# 5483                     NaN
# 5484                     NaN
# 5485                     NaN
# 5486                     NaN
# 5494                   A3447
# 5495                   A3447
# 5535                     NaN
# 5536                     NaN

# %%
# Drop the rows from the original dataframe with na value in the Author ID column
df_no_na = df.dropna(subset=['DLL Identifier (Author)'])
df_no_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5332 entries, 0 to 5762
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Title                    5332 non-null   object
#  1   DLL Identifier (Work)    5332 non-null   object
#  2   DLL Identifier (Author)  5332 non-null   object
# dtypes: object(3)
# memory usage: 166.6+ KB

# %%
# Find duplicated rows
duplicates = df_no_na[df_no_na.duplicated()]
duplicates
# Out:
#                              Title DLL Identifier (Work)  \
# 4096             De Fide Orthodoxa                 W2778
# 5334                    Sententiae                  W257
# 5336               De Agri Cultura                 W5351
# 5339   Commentarii de Bello Civili                 W3983
# 5341                  Antibucolica                 W5095
# 5352        Etruscarum Rerum Libri                 W3928
# 5376    De medicina, versio Latina                  W622
# 5383  Auspiciorum Liber, fragmenta                   W97
# 5405                   Astronomica                 W3254
# 5410                       Fabulae                 W3233
# 5414     Gai Institutionum epitome                 W2332
# 5415                 Institutiones                 W2278
# 5417         Libri Rerum Romanarum                 W2086
# 5420  De Origine Vocabulorum, frr.                 W1772
# 5433       De Verbis ad Ius Civile                  W326
# 5494                     De Metris                 W4107
# 5495       Rerum Romanarum Liber I                 W4086
#
#      DLL Identifier (Author)
# 4096                   A4376
# 5334                   A4504
# 5336                   A3400
# 5339                   A3607
# 5341                   A3521
# 5352                   A3559
# 5376                   A3618
# 5383                   A3582
# 5405                   A3487
# 5410                   A3487
# 5414                   A3454
# 5415                   A3454
# 5417                   A3603
# 5420                   A3590
# 5433                   A3602
# 5494                   A3447
# 5495                   A3447

# %%
# Quick test to see if these are really duplicates
gai = df_no_na[df_no_na['Title'] == "Gai Institutionum epitome"]
gai
# Out:
#                           Title DLL Identifier (Work) DLL Identifier (Author)
# 966   Gai Institutionum epitome                 W2332                   A3454
# 5414  Gai Institutionum epitome                 W2332                   A3454

# %%
# Drop the duplicated rows
works = df_no_na.drop_duplicates()
df_no_na.info()
works.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5332 entries, 0 to 5762
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Title                    5332 non-null   object
#  1   DLL Identifier (Work)    5332 non-null   object
#  2   DLL Identifier (Author)  5332 non-null   object
# dtypes: object(3)
# memory usage: 166.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 5315 entries, 0 to 5762
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Title                    5315 non-null   object
#  1   DLL Identifier (Work)    5315 non-null   object
#  2   DLL Identifier (Author)  5315 non-null   object
# dtypes: object(3)
# memory usage: 166.1+ KB

# %%
works
# Out:
#                                                   Title DLL Identifier (Work)  \
# 0               De signis et symptomatibus aegritudinum                W10655
# 1                     De coniuratione Porcaria dialogus                W10654
# 2                                                  Alda                W10653
# 3                                  De Viris Illustribus                W10652
# 4                                        De Philosophis                W10651
# ...                                                 ...                   ...
# 5758  Arnobii Catholici et Serapionis Conflictus de ...                 W2526
# 5759  Rerum Gestarum (Res Gestae A fine Corneli Tact...                 W3912
# 5760                                      Asinus Aureus                 W4047
# 5761                                    Pro se de Magia                 W4035
# 5762                                            Edyllia                  W707
#
#      DLL Identifier (Author)
# 0                      A3919
# 1                      A3221
# 2                      A4844
# 3                      A4799
# 4                      A4799
# ...                      ...
# 5758                   A5481
# 5759                   A5452
# 5760                   A5463
# 5761                   A5463
# 5762                   A5314
#
# [5315 rows x 3 columns]

# %% [markdown]
# ## Normalize the data
#
# I'm going to convert all text to lower case and strip any leading or trailing white space.

# %%
import unicodedata
# Normalize text
def normalize_text(text):
    # Convert to lowercase
    text = text.lower()
    # Strip leading and trailing whitespace
    text = text.strip()
    # Normalize unicode (optional)
    text = unicodedata.normalize("NFKD", text)
    return text

authors.loc[:,'Variant'] = authors['Variant'].apply(normalize_text)
authors.loc[:,'Authorized Name'] = authors['Authorized Name'].apply(normalize_text)
works.loc[:,'Title'] = works['Title'].apply(normalize_text)

# %%
# Write the data to CSV
import csv
authors.to_csv('../data/authors_db.csv',index=False,quoting=csv.QUOTE_ALL)
works.to_csv('../data/works_db.csv',index=False,quoting=csv.QUOTE_ALL)

# %%
authors
# Out:
#                                               Variant  \
# 2210      herryson, joannes floruit=15th century a.d.
# 2211                                 joannes herryson
# 2212                                    john herryson
# 2213      heryyson, joannes floruit=15th century a.d.
# 2214      herryson, xoannes floruit=15th century a.d.
# ...                                               ...
# 37530  calpurnius siculus, titus, činný 1. století
# 37531       calpurnius siculus, titus, fl. 60 na chr.
# 37532                      calpurnius siculus, titus.
# 37533                        titus calpurnius siculus
# 37534          titus calpurnius siculus poeta romanus
#
#                  Authorized Name DLL Identifier (Author)
# 2210           herryson, joannes                   A1868
# 2211           herryson, joannes                   A1868
# 2212           herryson, joannes                   A1868
# 2213           herryson, joannes                   A1868
# 2214           herryson, joannes                   A1868
# ...                          ...                     ...
# 37530  calpurnius siculus, titus                    A910
# 37531  calpurnius siculus, titus                    A910
# 37532  calpurnius siculus, titus                    A910
# 37533  calpurnius siculus, titus                    A910
# 37534  calpurnius siculus, titus                    A910
#
# [27290 rows x 3 columns]

# %%
works
# Out:
#                                                   Title DLL Identifier (Work)  \
# 0               de signis et symptomatibus aegritudinum                W10655
# 1                     de coniuratione porcaria dialogus                W10654
# 2                                                  alda                W10653
# 3                                  de viris illustribus                W10652
# 4                                        de philosophis                W10651
# ...                                                 ...                   ...
# 5758  arnobii catholici et serapionis conflictus de ...                 W2526
# 5759  rerum gestarum (res gestae a fine corneli tact...                 W3912
# 5760                                      asinus aureus                 W4047
# 5761                                    pro se de magia                 W4035
# 5762                                            edyllia                  W707
#
#      DLL Identifier (Author)
# 0                      A3919
# 1                      A3221
# 2                      A4844
# 3                      A4799
# 4                      A4799
# ...                      ...
# 5758                   A5481
# 5759                   A5452
# 5760                   A5463
# 5761                   A5463
# 5762                   A5314
#
# [5315 rows x 3 columns]
